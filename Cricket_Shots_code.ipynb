# %%
import cv2
import numpy as np

# %%
img01=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img01,(0,0),(1200,800),(128,178,194),-1) #layout
e1 = cv2.line(img01,(500,400),(700,400),(140,160,180),1050) #dugout
e1 = cv2.line(img01,(500,400),(700,400),(106,206,234),800) #ground
e1 = cv2.line(img01,(500,400),(700,400),(35,215,0),780) #extraSpace
e1 = cv2.line(img01,(500,400),(700,400),(255,255,255),750) #boundary
e1 = cv2.line(img01,(500,400),(700,400),(0,206,0),748) #playarea
e1 = cv2.rectangle(img01,(630,300),(570,500),(128,178,194),-1) #pitch
e1 = cv2.rectangle(img01,(630,300),(570,500),(255,255,255),1) #pitchhighlighter
e1 = cv2.line(img01,(580,300),(580,315),(255,255,255),1) #leftwideline
e1 = cv2.line(img01,(620,300),(620,315),(255,255,255),1) #rightwideline
e1 = cv2.line(img01,(580,500),(580,485),(255,255,255),1) #leftwideline_non_stricker
e1 = cv2.line(img01,(620,500),(620,485),(255,255,255),1) #rightwideline_non_stricker
e1 = cv2.line(img01,(565,315),(635,315),(255,255,255),1) #crease
e1 = cv2.line(img01,(565,485),(635,485),(255,255,255),1) #crease_non_stricker
e1 = cv2.line(img01,(597,300),(603,300),(0,0,0),1) #wickets
e1 = cv2.line(img01,(597,500),(603,500),(0,0,0),1) #wickets_non_stricker
e1 = cv2.circle(img01,(600,400),270,(255,255,255),1) #insidecircle


e1 = cv2.rectangle(img01,(10,340),(1190,440),(0,0,0),-1)
e1 = cv2.putText(img01,"WORLD CUP 2023",(320,410),cv2.FONT_HERSHEY_SIMPLEX,2,(255,255,255),4)


cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
img02=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img02,(0,0),(1200,800),(128,178,194),-1) #layout
e1 = cv2.line(img02,(500,400),(700,400),(140,160,180),1050) #dugout
e1 = cv2.line(img02,(500,400),(700,400),(106,206,234),800) #ground
e1 = cv2.line(img02,(500,400),(700,400),(35,215,0),780) #extraSpace
e1 = cv2.line(img02,(500,400),(700,400),(255,255,255),750) #boundary
e1 = cv2.line(img02,(500,400),(700,400),(0,206,0),748) #playarea
e1 = cv2.rectangle(img02,(630,300),(570,500),(128,178,194),-1) #pitch
e1 = cv2.rectangle(img02,(630,300),(570,500),(255,255,255),1) #pitchhighlighter
e1 = cv2.line(img02,(580,300),(580,315),(255,255,255),1) #leftwideline
e1 = cv2.line(img02,(620,300),(620,315),(255,255,255),1) #rightwideline
e1 = cv2.line(img02,(580,500),(580,485),(255,255,255),1) #leftwideline_non_stricker
e1 = cv2.line(img02,(620,500),(620,485),(255,255,255),1) #rightwideline_non_stricker
e1 = cv2.line(img02,(565,315),(635,315),(255,255,255),1) #crease
e1 = cv2.line(img02,(565,485),(635,485),(255,255,255),1) #crease_non_stricker
e1 = cv2.line(img02,(597,300),(603,300),(0,0,0),1) #wickets
e1 = cv2.line(img02,(597,500),(603,500),(0,0,0),1) #wickets_non_stricker
e1 = cv2.circle(img02,(600,400),270,(255,255,255),1) #insidecircle


e1 = cv2.rectangle(img02,(10,340),(1190,440),(0,0,0),-1)
e1 = cv2.putText(img02,"CRICKET FEVER EVERYWHERE",(150,410),cv2.FONT_HERSHEY_SIMPLEX,2,(255,255,255),4)


cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
img03=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img03,(0,0),(1200,800),(128,178,194),-1) #layout
e1 = cv2.line(img03,(500,400),(700,400),(140,160,180),1050) #dugout
e1 = cv2.line(img03,(500,400),(700,400),(106,206,234),800) #ground
e1 = cv2.line(img03,(500,400),(700,400),(35,215,0),780) #extraSpace
e1 = cv2.line(img03,(500,400),(700,400),(255,255,255),750) #boundary
e1 = cv2.line(img03,(500,400),(700,400),(0,206,0),748) #playarea
e1 = cv2.rectangle(img03,(630,300),(570,500),(128,178,194),-1) #pitch
e1 = cv2.rectangle(img03,(630,300),(570,500),(255,255,255),1) #pitchhighlighter
e1 = cv2.line(img03,(580,300),(580,315),(255,255,255),1) #leftwideline
e1 = cv2.line(img03,(620,300),(620,315),(255,255,255),1) #rightwideline
e1 = cv2.line(img03,(580,500),(580,485),(255,255,255),1) #leftwideline_non_stricker
e1 = cv2.line(img03,(620,500),(620,485),(255,255,255),1) #rightwideline_non_stricker
e1 = cv2.line(img03,(565,315),(635,315),(255,255,255),1) #crease
e1 = cv2.line(img03,(565,485),(635,485),(255,255,255),1) #crease_non_stricker
e1 = cv2.line(img03,(597,300),(603,300),(0,0,0),1) #wickets
e1 = cv2.line(img03,(597,500),(603,500),(0,0,0),1) #wickets_non_stricker
e1 = cv2.circle(img03,(600,400),270,(255,255,255),1) #insidecircle


e1 = cv2.rectangle(img03,(10,340),(1190,440),(0,0,0),-1)
e1 = cv2.putText(img03,"HOPE OF 1.4 BILLION INDIANS",(120,410),cv2.FONT_HERSHEY_SIMPLEX,2,(255,255,255),4)


cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
img04=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img04,(0,0),(1200,800),(128,178,194),-1) #layout
e1 = cv2.line(img04,(500,400),(700,400),(140,160,180),1050) #dugout
e1 = cv2.line(img04,(500,400),(700,400),(106,206,234),800) #ground
e1 = cv2.line(img04,(500,400),(700,400),(35,215,0),780) #extraSpace
e1 = cv2.line(img04,(500,400),(700,400),(255,255,255),750) #boundary
e1 = cv2.line(img04,(500,400),(700,400),(0,206,0),748) #playarea
e1 = cv2.rectangle(img04,(630,300),(570,500),(128,178,194),-1) #pitch
e1 = cv2.rectangle(img04,(630,300),(570,500),(255,255,255),1) #pitchhighlighter
e1 = cv2.line(img04,(580,300),(580,315),(255,255,255),1) #leftwideline
e1 = cv2.line(img04,(620,300),(620,315),(255,255,255),1) #rightwideline
e1 = cv2.line(img04,(580,500),(580,485),(255,255,255),1) #leftwideline_non_stricker
e1 = cv2.line(img04,(620,500),(620,485),(255,255,255),1) #rightwideline_non_stricker
e1 = cv2.line(img04,(565,315),(635,315),(255,255,255),1) #crease
e1 = cv2.line(img04,(565,485),(635,485),(255,255,255),1) #crease_non_stricker
e1 = cv2.line(img04,(597,300),(603,300),(0,0,0),1) #wickets
e1 = cv2.line(img04,(597,500),(603,500),(0,0,0),1) #wickets_non_stricker
e1 = cv2.circle(img04,(600,400),270,(255,255,255),1) #insidecircle


e1 = cv2.rectangle(img04,(10,340),(1190,440),(0,0,0),-1)
e1 = cv2.putText(img04,"BRING IT BACK TO HOME",(200,410),cv2.FONT_HERSHEY_SIMPLEX,2,(255,255,255),4)


cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
img041=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img041,(0,0),(1200,800),(128,178,194),-1) #layout
e1 = cv2.line(img041,(500,400),(700,400),(140,160,180),1050) #dugout
e1 = cv2.line(img041,(500,400),(700,400),(106,206,234),800) #ground
e1 = cv2.line(img041,(500,400),(700,400),(35,215,0),780) #extraSpace
e1 = cv2.line(img041,(500,400),(700,400),(255,255,255),750) #boundary
e1 = cv2.line(img041,(500,400),(700,400),(0,206,0),748) #playarea
e1 = cv2.rectangle(img041,(630,300),(570,500),(128,178,194),-1) #pitch
e1 = cv2.rectangle(img041,(630,300),(570,500),(255,255,255),1) #pitchhighlighter
e1 = cv2.line(img041,(580,300),(580,315),(255,255,255),1) #leftwideline
e1 = cv2.line(img041,(620,300),(620,315),(255,255,255),1) #rightwideline
e1 = cv2.line(img041,(580,500),(580,485),(255,255,255),1) #leftwideline_non_stricker
e1 = cv2.line(img041,(620,500),(620,485),(255,255,255),1) #rightwideline_non_stricker
e1 = cv2.line(img041,(565,315),(635,315),(255,255,255),1) #crease
e1 = cv2.line(img041,(565,485),(635,485),(255,255,255),1) #crease_non_stricker
e1 = cv2.line(img041,(597,300),(603,300),(0,0,0),1) #wickets
e1 = cv2.line(img041,(597,500),(603,500),(0,0,0),1) #wickets_non_stricker
e1 = cv2.circle(img041,(600,400),270,(255,255,255),1) #insidecircle


e1 = cv2.rectangle(img041,(10,340),(1190,440),(0,0,0),-1)
e1 = cv2.putText(img041,"CHAK DE! INDIA..",(350,410),cv2.FONT_HERSHEY_SIMPLEX,2,(255,255,255),4)


cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
img05=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img05,(0,0),(1200,800),(128,178,194),-1) #layout
e1 = cv2.line(img05,(500,400),(700,400),(140,160,180),1050) #dugout
e1 = cv2.line(img05,(500,400),(700,400),(106,206,234),800) #ground
e1 = cv2.line(img05,(500,400),(700,400),(35,215,0),780) #extraSpace
e1 = cv2.line(img05,(500,400),(700,400),(255,255,255),750) #boundary
e1 = cv2.line(img05,(500,400),(700,400),(0,206,0),748) #playarea
e1 = cv2.rectangle(img05,(630,300),(570,500),(128,178,194),-1) #pitch
e1 = cv2.rectangle(img05,(630,300),(570,500),(255,255,255),1) #pitchhighlighter
e1 = cv2.line(img05,(580,300),(580,315),(255,255,255),1) #leftwideline
e1 = cv2.line(img05,(620,300),(620,315),(255,255,255),1) #rightwideline
e1 = cv2.line(img05,(580,500),(580,485),(255,255,255),1) #leftwideline_non_stricker
e1 = cv2.line(img05,(620,500),(620,485),(255,255,255),1) #rightwideline_non_stricker
e1 = cv2.line(img05,(565,315),(635,315),(255,255,255),1) #crease
e1 = cv2.line(img05,(565,485),(635,485),(255,255,255),1) #crease_non_stricker
e1 = cv2.line(img05,(597,300),(603,300),(0,0,0),1) #wickets
e1 = cv2.line(img05,(597,500),(603,500),(0,0,0),1) #wickets_non_stricker
e1 = cv2.circle(img05,(600,400),270,(255,255,255),1) #insidecircle


e1 = cv2.rectangle(img05,(10,200),(1190,600),(0,0,0),-1)
e1 = cv2.putText(img05,"FANS EXPECTING TO WITNESS MORE",(50,350),cv2.FONT_HERSHEY_SIMPLEX,2,(255,255,255),3)
e1 = cv2.putText(img05,"ICONIC SHOTS FROM THESE LEGENDS",(20,450),cv2.FONT_HERSHEY_SIMPLEX,2,(255,255,255),3)


cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # TOP VIEW

# %%
img1=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img1,(0,0),(1200,800),(128,178,194),-1) #layout
e1 = cv2.line(img1,(500,400),(700,400),(140,160,180),1050) #dugout
e1 = cv2.line(img1,(500,400),(700,400),(106,206,234),800) #ground
e1 = cv2.line(img1,(500,400),(700,400),(35,215,0),780) #extraSpace
e1 = cv2.line(img1,(500,400),(700,400),(255,255,255),750) #boundary
e1 = cv2.line(img1,(500,400),(700,400),(0,206,0),748) #playarea
e1 = cv2.rectangle(img1,(630,300),(570,500),(128,178,194),-1) #pitch
e1 = cv2.rectangle(img1,(630,300),(570,500),(255,255,255),1) #pitchhighlighter
e1 = cv2.line(img1,(580,300),(580,315),(255,255,255),1) #leftwideline
e1 = cv2.line(img1,(620,300),(620,315),(255,255,255),1) #rightwideline
e1 = cv2.line(img1,(580,500),(580,485),(255,255,255),1) #leftwideline_non_stricker
e1 = cv2.line(img1,(620,500),(620,485),(255,255,255),1) #rightwideline_non_stricker
e1 = cv2.line(img1,(565,315),(635,315),(255,255,255),1) #crease
e1 = cv2.line(img1,(565,485),(635,485),(255,255,255),1) #crease_non_stricker
e1 = cv2.line(img1,(597,300),(603,300),(0,0,0),1) #wickets
e1 = cv2.line(img1,(597,500),(603,500),(0,0,0),1) #wickets_non_stricker
e1 = cv2.circle(img1,(600,400),270,(255,255,255),1) #insidecircle

e1 = cv2.circle(img1,(600,280),5,(32,100,1),-1) #wicketkeeper
e1 = cv2.circle(img1,(925,120),5,(32,100,1),-1) #fineleg
e1 = cv2.circle(img1,(580,270),5,(32,100,1),-1) #slip
e1 = cv2.circle(img1,(490,720),5,(32,100,1),-1) #longoff
e1 = cv2.circle(img1,(720,530),5,(32,100,1),-1) #midwicket
e1 = cv2.circle(img1,(420,500),5,(32,100,1),-1) #cover
e1 = cv2.circle(img1,(150,380),5,(32,100,1),-1) #deepcoverpoint
e1 = cv2.circle(img1,(700,340),5,(32,100,1),-1) #short
e1 = cv2.circle(img1,(950,480),5,(32,100,1),-1) #deepsweep
e1 = cv2.circle(img1,(500,300),5,(32,100,1),-1) #gully
e1 = cv2.circle(img1,(610,490),5,(32,100,1),-1) #bowler

e1 = cv2.circle(img1,(590,490),5,(255,30,0),-1) #batsmen
e1 = cv2.circle(img1,(610,310),5,(255,30,0),-1) #bowler

e1 = cv2.circle(img1,(600,520),5,(0,0,255),-1) #umpire
e1 = cv2.circle(img1,(750,315),5,(0,0,255),-1) #umpire2


cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # RoHIT

# %%
img2=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img2,(0,0),(1200,800),(128,178,194),-1) #layout
e1 = cv2.line(img2,(500,400),(700,400),(140,160,180),1050) #dugout
e1 = cv2.line(img2,(500,400),(700,400),(106,206,234),800) #ground
e1 = cv2.line(img2,(500,400),(700,400),(35,215,0),780) #extraSpace
e1 = cv2.line(img2,(500,400),(700,400),(255,255,255),750) #boundary
e1 = cv2.line(img2,(500,400),(700,400),(0,206,0),748) #playarea
e1 = cv2.rectangle(img2,(630,300),(570,500),(128,178,194),-1) #pitch
e1 = cv2.rectangle(img2,(630,300),(570,500),(255,255,255),1) #pitchhighlighter
e1 = cv2.line(img2,(580,300),(580,315),(255,255,255),1) #leftwideline
e1 = cv2.line(img2,(620,300),(620,315),(255,255,255),1) #rightwideline
e1 = cv2.line(img2,(580,500),(580,485),(255,255,255),1) #leftwideline_non_stricker
e1 = cv2.line(img2,(620,500),(620,485),(255,255,255),1) #rightwideline_non_stricker
e1 = cv2.line(img2,(565,315),(635,315),(255,255,255),1) #crease
e1 = cv2.line(img2,(565,485),(635,485),(255,255,255),1) #crease_non_stricker
e1 = cv2.line(img2,(597,300),(603,300),(0,0,0),1) #wickets
e1 = cv2.line(img2,(597,500),(603,500),(0,0,0),1) #wickets_non_stricker
e1 = cv2.circle(img2,(600,400),270,(255,255,255),1) #insidecircle

e1 = cv2.circle(img2,(600,280),5,(32,100,1),-1) #wicketkeeper
e1 = cv2.circle(img2,(925,120),5,(32,100,1),-1) #fineleg
e1 = cv2.circle(img2,(580,270),5,(32,100,1),-1) #slip
e1 = cv2.circle(img2,(490,720),5,(32,100,1),-1) #longoff
e1 = cv2.circle(img2,(720,530),5,(32,100,1),-1) #midwicket
e1 = cv2.circle(img2,(420,500),5,(32,100,1),-1) #cover
e1 = cv2.circle(img2,(150,380),5,(32,100,1),-1) #deepcoverpoint
e1 = cv2.circle(img2,(700,340),5,(32,100,1),-1) #short
e1 = cv2.circle(img2,(950,480),5,(32,100,1),-1) #deepsweep
e1 = cv2.circle(img2,(500,300),5,(32,100,1),-1) #gully
e1 = cv2.circle(img2,(610,490),5,(32,100,1),-1) #bowler

e1 = cv2.circle(img2,(590,490),5,(255,30,0),-1) #batsmen
e1 = cv2.circle(img2,(610,310),5,(255,30,0),-1) #bowler

e1 = cv2.circle(img2,(600,520),5,(0,0,255),-1) #umpire
e1 = cv2.circle(img2,(750,315),5,(0,0,255),-1) #umpire2

e1 = cv2.rectangle(img2,(10,340),(1190,440),(0,0,0),-1)
e1 = cv2.putText(img2,"ROHIT - PULL SHOT",(300,412),cv2.FONT_HERSHEY_SIMPLEX,2,(255,255,255),4)


cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # First point

# %%
img3=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img3,(0,0),(1200,800),(0,178,0),-1) #layout

e1 = cv2.line(img3,(600,800),(530,400),(128,178,194),10)# left line
e1 = cv2.line(img3,(610,800),(540,400),(128,178,194),10)# left line
e1 = cv2.line(img3,(620,800),(550,400),(128,178,194),10)# left line
e1 = cv2.line(img3,(630,800),(560,400),(128,178,194),10)# left line
e1 = cv2.line(img3,(640,800),(570,400),(128,178,194),10)# left line
e1 = cv2.line(img3,(650,800),(580,400),(128,178,194),10)# left line
e1 = cv2.line(img3,(660,800),(590,400),(128,178,194),10)# left line
e1 = cv2.line(img3,(670,800),(600,400),(128,178,194),10)# left line
e1 = cv2.line(img3,(680,800),(610,400),(128,178,194),10)# left line
e1 = cv2.line(img3,(690,800),(620,400),(128,178,194),10)# left line
e1 = cv2.line(img3,(700,800),(630,400),(128,178,194),10)# left line
e1 = cv2.line(img3,(710,800),(640,400),(128,178,194),10)# left line
e1 = cv2.line(img3,(720,800),(650,400),(128,178,194),10)# left line
e1 = cv2.line(img3,(730,800),(660,400),(128,178,194),10)# left line
e1 = cv2.line(img3,(740,800),(670,400),(128,178,194),10)# left line
e1 = cv2.line(img3,(750,800),(680,400),(128,178,194),10)# left line
e1 = cv2.line(img3,(760,800),(690,400),(128,178,194),10)# left line

e1 = cv2.line(img3,(450,800),(530,400),(128,178,194),10)#right line
e1 = cv2.line(img3,(460,800),(540,400),(128,178,194),10)#right line
e1 = cv2.line(img3,(470,800),(550,400),(128,178,194),10)#right line
e1 = cv2.line(img3,(480,800),(560,400),(128,178,194),10)#right line
e1 = cv2.line(img3,(490,800),(570,400),(128,178,194),10)#right line
e1 = cv2.line(img3,(500,800),(580,400),(128,178,194),10)#right line
e1 = cv2.line(img3,(510,800),(590,400),(128,178,194),10)#right line
e1 = cv2.line(img3,(520,800),(600,400),(128,178,194),10)#right line
e1 = cv2.line(img3,(530,800),(610,400),(128,178,194),10)#right line
e1 = cv2.line(img3,(540,800),(620,400),(128,178,194),10)#right line
e1 = cv2.line(img3,(550,800),(630,400),(128,178,194),10)#right line
e1 = cv2.line(img3,(560,800),(640,400),(128,178,194),10)#right line
e1 = cv2.line(img3,(570,800),(650,400),(128,178,194),10)#right line
e1 = cv2.line(img3,(580,800),(660,400),(128,178,194),10)#right line
e1 = cv2.line(img3,(590,800),(670,400),(128,178,194),10)#right line

e1 = cv2.line(img3,(760,800),(690,400),(255,255,255),2)# left line
e1 = cv2.line(img3,(450,800),(530,400),(255,255,255),2)#right line
e1 = cv2.line(img3,(690,400),(530,400),(255,255,255),2)# middle line
e1 = cv2.line(img3,(600,1200),(600,760),(0,0,0),5)   #middle wicket   #buttom side
e1 = cv2.line(img3,(590,1200),(590,760),(0,0,0),5)   #left wicket
e1 = cv2.line(img3,(610,1200),(610,760),(0,0,0),5)   #right wicket
e1 = cv2.line(img3,(590,760),(610,760),(0,0,0),5)    #top wicket
e1 = cv2.line(img3,(430,750),(780,750),(255,255,255),2)#buttom boundary line 
e1 = cv2.line(img3,(500,750),(490,850),(255,255,255),2)#boundary left line
e1 = cv2.line(img3,(710,750),(720,850),(255,255,255),2)#boundary right line2
e1 = cv2.line(img3,(760,800),(690,400),(255,255,255),2)# left line
e1 = cv2.line(img3,(450,800),(530,400),(255,255,255),2)#right line
e1 = cv2.line(img3,(690,400),(530,400),(255,255,255),2)# middle line
e1 = cv2.line(img3,(620,400),(620,360),(0,0,0),5)   #right wicket     #top side
e1 = cv2.line(img3,(600,400),(600,360),(0,0,0),5)   #lift wicket
e1 = cv2.line(img3,(610,400),(610,360),(0,0,0),5)   #middle wicket
e1 = cv2.line(img3,(600,360),(620,360),(0,0,0),5)    #top wicket
e1 = cv2.line(img3,(490,440),(720,440),(255,255,255),2) # top boundary line
e1 = cv2.line(img3,(555,440),(560,400),(255,255,255),2)#boundary left line
e1 = cv2.line(img3,(655,440),(655,400),(255,255,255),2)#boundary right line




#indian player

e1=cv2.rectangle(img3,(642,402),(648,440),(255,0,0),-1)#right leg
e1=cv2.rectangle(img3,(629,352),(650,402),(255,0,0),-1)#body
e1=cv2.rectangle(img3,(631,402),(637,440),(255,0,0),-1)#left leg
e1=cv2.circle(img3,(640,339),13,(155,226,254),-1)# head
e1=cv2.circle(img3,(632,340),2,(0,0,0),-1)# right eye
e1=cv2.circle(img3,(637,340),2,(0,0,0),-1)# left eye
e1=cv2.circle(img3,(635,346),2,(0,0,0),-1)#mouth
e1 = cv2.line(img3,(632,364),(620,400),(155,226,254),3)#right hand 
e1 = cv2.line(img3,(641,373),(623,400),(155,226,254),3)#left hand
e1 = cv2.line(img3,(621,400),(603,435),(29,101,181),10)#bat
e1 = cv2.line(img3,(632,329),(647,329),(0,0,0),10)#top hair
e1 = cv2.line(img3,(647,336),(646,348),(0,0,0),10)#left hair


# pakistan wicket player

e1=cv2.rectangle(img3,(592,362),(586,395),(26,64,0),-1)#right leg
e1=cv2.rectangle(img3,(570,351),(593,379),(26,64,0),-1)#body
e1=cv2.rectangle(img3,(572,362),(579,395),(26,64,0),-1)#left leg
e1=cv2.circle(img3,(581,336),14,(155,226,254),-1)# head
e1=cv2.circle(img3,(576,338),2,(0,0,0),-1)# right eye
e1=cv2.circle(img3,(587,338),2,(0,0,0),-1)# left eye
e1 = cv2.line(img3,(578,345),(585,345),(0,0,0),2)#mouth
e1 = cv2.line(img3,(572,360),(582,369),(155,226,254),4)#right hand 
e1 = cv2.line(img3,(591,360),(582,369),(155,226,254),4)#left hand
e1 = cv2.line(img3,(581,368),(582,369),(255,255,255),10)#glove
e1 = cv2.line(img3,(571,326),(588,326),(0,0,0),10)#top hair



#bowler


e1=cv2.rectangle(img3,(626,759),(652,789),(26,64,0),-1)#body
e1=cv2.circle(img3,(638,745),14,(155,226,254),-1)# head
e1=cv2.circle(img3,(670,747),6,(255,255,255),-1)# right ball
e1 = cv2.line(img3,(653,764),(669,749),(155,226,254),5)#right hand 
e1 = cv2.line(img3,(625,765),(620,772),(155,226,254),5)#left hand
e1 = cv2.line(img3,(632,742),(643,742),(0,0,0),20)#top hair



# pakistan player
e1=cv2.rectangle(img3,(292,293),(300,322),(26,64,0),-1)#right leg
e1=cv2.rectangle(img3,(288,253),(320,298),(26,64,0),-1)#body
e1=cv2.rectangle(img3,(309,293),(317,322),(26,64,0),-1)#left leg
e1=cv2.circle(img3,(303,239),16,(155,226,254),-1)# head
e1=cv2.circle(img3,(295,242),2,(0,0,0),-1)# right eye
e1=cv2.circle(img3,(310,242),2,(0,0,0),-1)# left eye
e1 = cv2.line(img3,(298,249),(307,249),(0,0,0),2)#mouth
e1 = cv2.line(img3,(289,265),(294,276),(155,226,254),4)#right hand 
e1 = cv2.line(img3,(318,265),(310,276),(155,226,254),4)#left hand
e1 = cv2.line(img3,(293,229),(312,229),(0,0,0),13)#top hair


#Indian  player
e1=cv2.rectangle(img3,(548,767),(555,784),(255,0,0),-1)#left leg
e1=cv2.rectangle(img3,(569,767),(545,742),(255,0,0),-1)#body
e1=cv2.rectangle(img3,(560,767),(567,784),(255,0,0),-1)#right leg
e1=cv2.circle(img3,(557,729),14,(155,226,254),-1)# head
e1 = cv2.line(img3,(570,748),(574,761),(155,226,254),3)#right hand 
e1 = cv2.line(img3,(544,747),(537,754),(155,226,254),3)#left hand
e1 = cv2.line(img3,(575,761),(580,778),(29,101,181),10)#bat
e1 = cv2.line(img3,(550,724),(562,724),(0,0,0),21)#top hair




cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # Second point

# %%
img4=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img4,(0,0),(1200,800),(0,178,0),-1) #layout

e1 = cv2.line(img4,(600,800),(530,400),(128,178,194),10)# left line
e1 = cv2.line(img4,(610,800),(540,400),(128,178,194),10)# left line
e1 = cv2.line(img4,(620,800),(550,400),(128,178,194),10)# left line
e1 = cv2.line(img4,(630,800),(560,400),(128,178,194),10)# left line
e1 = cv2.line(img4,(640,800),(570,400),(128,178,194),10)# left line
e1 = cv2.line(img4,(650,800),(580,400),(128,178,194),10)# left line
e1 = cv2.line(img4,(660,800),(590,400),(128,178,194),10)# left line
e1 = cv2.line(img4,(670,800),(600,400),(128,178,194),10)# left line
e1 = cv2.line(img4,(680,800),(610,400),(128,178,194),10)# left line
e1 = cv2.line(img4,(690,800),(620,400),(128,178,194),10)# left line
e1 = cv2.line(img4,(700,800),(630,400),(128,178,194),10)# left line
e1 = cv2.line(img4,(710,800),(640,400),(128,178,194),10)# left line
e1 = cv2.line(img4,(720,800),(650,400),(128,178,194),10)# left line
e1 = cv2.line(img4,(730,800),(660,400),(128,178,194),10)# left line
e1 = cv2.line(img4,(740,800),(670,400),(128,178,194),10)# left line
e1 = cv2.line(img4,(750,800),(680,400),(128,178,194),10)# left line
e1 = cv2.line(img4,(760,800),(690,400),(128,178,194),10)# left line

e1 = cv2.line(img4,(450,800),(530,400),(128,178,194),10)#right line
e1 = cv2.line(img4,(460,800),(540,400),(128,178,194),10)#right line
e1 = cv2.line(img4,(470,800),(550,400),(128,178,194),10)#right line
e1 = cv2.line(img4,(480,800),(560,400),(128,178,194),10)#right line
e1 = cv2.line(img4,(490,800),(570,400),(128,178,194),10)#right line
e1 = cv2.line(img4,(500,800),(580,400),(128,178,194),10)#right line
e1 = cv2.line(img4,(510,800),(590,400),(128,178,194),10)#right line
e1 = cv2.line(img4,(520,800),(600,400),(128,178,194),10)#right line
e1 = cv2.line(img4,(530,800),(610,400),(128,178,194),10)#right line
e1 = cv2.line(img4,(540,800),(620,400),(128,178,194),10)#right line
e1 = cv2.line(img4,(550,800),(630,400),(128,178,194),10)#right line
e1 = cv2.line(img4,(560,800),(640,400),(128,178,194),10)#right line
e1 = cv2.line(img4,(570,800),(650,400),(128,178,194),10)#right line
e1 = cv2.line(img4,(580,800),(660,400),(128,178,194),10)#right line
e1 = cv2.line(img4,(590,800),(670,400),(128,178,194),10)#right line

e1 = cv2.line(img4,(760,800),(690,400),(255,255,255),2)# left line
e1 = cv2.line(img4,(450,800),(530,400),(255,255,255),2)#right line
e1 = cv2.line(img4,(690,400),(530,400),(255,255,255),2)# middle line
e1 = cv2.line(img4,(600,1200),(600,760),(0,0,0),5)   #middle wicket   #buttom side
e1 = cv2.line(img4,(590,1200),(590,760),(0,0,0),5)   #left wicket
e1 = cv2.line(img4,(610,1200),(610,760),(0,0,0),5)   #right wicket
e1 = cv2.line(img4,(590,760),(610,760),(0,0,0),5)    #top wicket
e1 = cv2.line(img4,(430,750),(780,750),(255,255,255),2)#buttom boundary line 
e1 = cv2.line(img4,(500,750),(490,850),(255,255,255),2)#boundary left line
e1 = cv2.line(img4,(710,750),(720,850),(255,255,255),2)#boundary right line

e1 = cv2.line(img4,(760,800),(690,400),(255,255,255),2)# left line
e1 = cv2.line(img4,(450,800),(530,400),(255,255,255),2)#right line
e1 = cv2.line(img4,(690,400),(530,400),(255,255,255),2)# middle line
e1 = cv2.line(img4,(620,400),(620,360),(0,0,0),5)   #right wicket     #top side
e1 = cv2.line(img4,(600,400),(600,360),(0,0,0),5)   #lift wicket
e1 = cv2.line(img4,(610,400),(610,360),(0,0,0),5)   #middle wicket
e1 = cv2.line(img4,(600,360),(620,360),(0,0,0),5)    #top wicket
e1 = cv2.line(img4,(490,440),(720,440),(255,255,255),2) # top boundary line
e1 = cv2.line(img4,(555,440),(560,400),(255,255,255),2)#boundary left line
e1 = cv2.line(img4,(655,440),(655,400),(255,255,255),2)#boundary right line



#indian player

e1=cv2.rectangle(img4,(642,402),(648,440),(255,0,0),-1)#right leg
e1=cv2.rectangle(img4,(629,352),(650,402),(255,0,0),-1)#body
e1=cv2.rectangle(img4,(631,402),(637,440),(255,0,0),-1)#left leg
e1=cv2.circle(img4,(640,339),13,(155,226,254),-1)# head
e1=cv2.circle(img4,(632,340),2,(0,0,0),-1)# right eye
e1=cv2.circle(img4,(637,340),2,(0,0,0),-1)# left eye
e1=cv2.circle(img4,(635,346),2,(0,0,0),-1)#mouth
e1 = cv2.line(img4,(632,364),(620,400),(155,226,254),3)#right hand 
e1 = cv2.line(img4,(641,373),(623,400),(155,226,254),3)#left hand
e1 = cv2.line(img4,(618,400),(596,369),(29,101,181),10)#bat
e1 = cv2.line(img4,(632,329),(647,329),(0,0,0),10)#top hair
e1 = cv2.line(img4,(647,336),(646,348),(0,0,0),10)#left hair


# pakistan wicket player

e1=cv2.rectangle(img4,(592,362),(586,395),(26,64,0),-1)#right leg
e1=cv2.rectangle(img4,(570,351),(593,379),(26,64,0),-1)#body
e1=cv2.rectangle(img4,(572,362),(579,395),(26,64,0),-1)#left leg
e1=cv2.circle(img4,(581,336),14,(155,226,254),-1)# head
e1=cv2.circle(img4,(576,338),2,(0,0,0),-1)# right eye
e1=cv2.circle(img4,(587,338),2,(0,0,0),-1)# left eye
e1 = cv2.line(img4,(578,345),(585,345),(0,0,0),2)#mouth
e1 = cv2.line(img4,(572,360),(582,369),(155,226,254),4)#right hand 
e1 = cv2.line(img4,(591,360),(582,369),(155,226,254),4)#left hand
e1 = cv2.line(img4,(581,368),(582,369),(255,255,255),10)#glove
e1 = cv2.line(img4,(571,326),(588,326),(0,0,0),10)#top hair



#bowler


e1=cv2.rectangle(img4,(626,739),(652,769),(26,64,0),-1)#body
e1=cv2.circle(img4,(638,725),14,(155,226,254),-1)# head
e1=cv2.circle(img4,(670,727),6,(255,255,255),-1)# right ball
e1 = cv2.line(img4,(653,744),(669,729),(155,226,254),5)#right hand 
e1 = cv2.line(img4,(625,745),(620,752),(155,226,254),5)#left hand
e1 = cv2.line(img4,(632,722),(643,722),(0,0,0),20)#top hair
e1=cv2.rectangle(img4,(631,769),(637,782),(26,64,0),-1)#left leg
e1=cv2.rectangle(img4,(642,769),(648,782),(26,64,0),-1)#right leg



# pakistan player
e1=cv2.rectangle(img4,(292,293),(300,322),(26,64,0),-1)#right leg
e1=cv2.rectangle(img4,(288,253),(320,298),(26,64,0),-1)#body
e1=cv2.rectangle(img4,(309,293),(317,322),(26,64,0),-1)#left leg
e1=cv2.circle(img4,(303,239),16,(155,226,254),-1)# head
e1=cv2.circle(img4,(295,242),2,(0,0,0),-1)# right eye
e1=cv2.circle(img4,(310,242),2,(0,0,0),-1)# left eye
e1 = cv2.line(img4,(298,249),(307,249),(0,0,0),2)#mouth
e1 = cv2.line(img4,(289,265),(294,276),(155,226,254),4)#right hand 
e1 = cv2.line(img4,(318,265),(310,276),(155,226,254),4)#left hand
e1 = cv2.line(img4,(293,229),(312,229),(0,0,0),13)#top hair


#Indian  player
e1=cv2.rectangle(img4,(548,767),(555,784),(255,0,0),-1)#left leg
e1=cv2.rectangle(img4,(569,767),(545,742),(255,0,0),-1)#body
e1=cv2.rectangle(img4,(560,767),(567,784),(255,0,0),-1)#right leg
e1=cv2.circle(img4,(557,729),14,(155,226,254),-1)# head
e1 = cv2.line(img4,(570,748),(574,761),(155,226,254),3)#right hand 
e1 = cv2.line(img4,(544,747),(537,754),(155,226,254),3)#left hand
e1 = cv2.line(img4,(575,761),(580,778),(29,101,181),10)#bat
e1 = cv2.line(img4,(550,724),(562,724),(0,0,0),21)#top hair




cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # 3rd point

# %%
img5=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img5,(0,0),(1200,800),(0,178,0),-1) #layout

e1 = cv2.line(img5,(600,800),(530,400),(128,178,194),10)# left line
e1 = cv2.line(img5,(610,800),(540,400),(128,178,194),10)# left line
e1 = cv2.line(img5,(620,800),(550,400),(128,178,194),10)# left line
e1 = cv2.line(img5,(630,800),(560,400),(128,178,194),10)# left line
e1 = cv2.line(img5,(640,800),(570,400),(128,178,194),10)# left line
e1 = cv2.line(img5,(650,800),(580,400),(128,178,194),10)# left line
e1 = cv2.line(img5,(660,800),(590,400),(128,178,194),10)# left line
e1 = cv2.line(img5,(670,800),(600,400),(128,178,194),10)# left line
e1 = cv2.line(img5,(680,800),(610,400),(128,178,194),10)# left line
e1 = cv2.line(img5,(690,800),(620,400),(128,178,194),10)# left line
e1 = cv2.line(img5,(700,800),(630,400),(128,178,194),10)# left line
e1 = cv2.line(img5,(710,800),(640,400),(128,178,194),10)# left line
e1 = cv2.line(img5,(720,800),(650,400),(128,178,194),10)# left line
e1 = cv2.line(img5,(730,800),(660,400),(128,178,194),10)# left line
e1 = cv2.line(img5,(740,800),(670,400),(128,178,194),10)# left line
e1 = cv2.line(img5,(750,800),(680,400),(128,178,194),10)# left line
e1 = cv2.line(img5,(760,800),(690,400),(128,178,194),10)# left line

e1 = cv2.line(img5,(450,800),(530,400),(128,178,194),10)#right line
e1 = cv2.line(img5,(460,800),(540,400),(128,178,194),10)#right line
e1 = cv2.line(img5,(470,800),(550,400),(128,178,194),10)#right line
e1 = cv2.line(img5,(480,800),(560,400),(128,178,194),10)#right line
e1 = cv2.line(img5,(490,800),(570,400),(128,178,194),10)#right line
e1 = cv2.line(img5,(500,800),(580,400),(128,178,194),10)#right line
e1 = cv2.line(img5,(510,800),(590,400),(128,178,194),10)#right line
e1 = cv2.line(img5,(520,800),(600,400),(128,178,194),10)#right line
e1 = cv2.line(img5,(530,800),(610,400),(128,178,194),10)#right line
e1 = cv2.line(img5,(540,800),(620,400),(128,178,194),10)#right line
e1 = cv2.line(img5,(550,800),(630,400),(128,178,194),10)#right line
e1 = cv2.line(img5,(560,800),(640,400),(128,178,194),10)#right line
e1 = cv2.line(img5,(570,800),(650,400),(128,178,194),10)#right line
e1 = cv2.line(img5,(580,800),(660,400),(128,178,194),10)#right line
e1 = cv2.line(img5,(590,800),(670,400),(128,178,194),10)#right line

e1 = cv2.line(img5,(760,800),(690,400),(255,255,255),2)# left line
e1 = cv2.line(img5,(450,800),(530,400),(255,255,255),2)#right line
e1 = cv2.line(img5,(690,400),(530,400),(255,255,255),2)# middle line
e1 = cv2.line(img5,(600,1200),(600,760),(0,0,0),5)   #middle wicket   #buttom side
e1 = cv2.line(img5,(590,1200),(590,760),(0,0,0),5)   #left wicket
e1 = cv2.line(img5,(610,1200),(610,760),(0,0,0),5)   #right wicket
e1 = cv2.line(img5,(590,760),(610,760),(0,0,0),5)    #top wicket
e1 = cv2.line(img5,(430,750),(780,750),(255,255,255),2)#buttom boundary line 
e1 = cv2.line(img5,(500,750),(490,850),(255,255,255),2)#boundary left line
e1 = cv2.line(img5,(710,750),(720,850),(255,255,255),2)#boundary right line

e1 = cv2.line(img5,(760,800),(690,400),(255,255,255),2)# left line
e1 = cv2.line(img5,(450,800),(530,400),(255,255,255),2)#right line
e1 = cv2.line(img5,(690,400),(530,400),(255,255,255),2)# middle line
e1 = cv2.line(img5,(620,400),(620,360),(0,0,0),5)   #right wicket     #top side
e1 = cv2.line(img5,(600,400),(600,360),(0,0,0),5)   #lift wicket
e1 = cv2.line(img5,(610,400),(610,360),(0,0,0),5)   #middle wicket
e1 = cv2.line(img5,(600,360),(620,360),(0,0,0),5)    #top wicket
e1 = cv2.line(img5,(490,440),(720,440),(255,255,255),2) # top boundary line
e1 = cv2.line(img5,(555,440),(560,400),(255,255,255),2)#boundary left line
e1 = cv2.line(img5,(655,440),(655,400),(255,255,255),2)#boundary right line




#indian player

e1=cv2.rectangle(img5,(642,402),(648,440),(255,0,0),-1)#right leg
e1=cv2.rectangle(img5,(629,352),(650,402),(255,0,0),-1)#body
e1=cv2.rectangle(img5,(631,402),(637,440),(255,0,0),-1)#left leg
e1=cv2.circle(img5,(640,339),13,(155,226,254),-1)# head
e1=cv2.circle(img5,(632,340),2,(0,0,0),-1)# right eye
e1=cv2.circle(img5,(637,340),2,(0,0,0),-1)# left eye
e1=cv2.circle(img5,(635,346),2,(0,0,0),-1)#mouth
e1 = cv2.line(img5,(632,364),(620,400),(155,226,254),3)#right hand 
e1 = cv2.line(img5,(641,373),(623,400),(155,226,254),3)#left hand
e1 = cv2.line(img5,(621,400),(584,416),(29,101,181),10)#bat
e1 = cv2.line(img5,(632,329),(647,329),(0,0,0),10)#top hair
e1 = cv2.line(img5,(647,336),(646,348),(0,0,0),10)#left hair


# pakistan wicket player

e1=cv2.rectangle(img5,(592,362),(586,395),(26,64,0),-1)#right leg
e1=cv2.rectangle(img5,(570,351),(593,379),(26,64,0),-1)#body
e1=cv2.rectangle(img5,(572,362),(579,395),(26,64,0),-1)#left leg
e1=cv2.circle(img5,(581,336),14,(155,226,254),-1)# head
e1=cv2.circle(img5,(576,338),2,(0,0,0),-1)# right eye
e1=cv2.circle(img5,(587,338),2,(0,0,0),-1)# left eye
e1 = cv2.line(img5,(578,345),(585,345),(0,0,0),2)#mouth
e1 = cv2.line(img5,(572,360),(582,369),(155,226,254),4)#right hand 
e1 = cv2.line(img5,(591,360),(582,369),(155,226,254),4)#left hand
e1 = cv2.line(img5,(581,368),(582,369),(255,255,255),10)#glove
e1 = cv2.line(img5,(571,326),(588,326),(0,0,0),10)#top hair



#bowler


e1=cv2.rectangle(img5,(626,719),(652,749),(26,64,0),-1)#body
e1=cv2.circle(img5,(638,705),14,(155,226,254),-1)# head
e1=cv2.circle(img5,(670,707),6,(255,255,255),-1)# right ball
e1 = cv2.line(img5,(653,724),(669,709),(155,226,254),5)#right hand 
e1 = cv2.line(img5,(625,725),(620,732),(155,226,254),5)#left hand
e1 = cv2.line(img5,(632,702),(643,702),(0,0,0),20)#top hair
e1=cv2.rectangle(img5,(631,749),(637,762),(26,64,0),-1)#left leg
e1=cv2.rectangle(img5,(642,749),(648,762),(26,64,0),-1)#right leg



# pakistan player
e1=cv2.rectangle(img5,(292,293),(300,322),(26,64,0),-1)#right leg
e1=cv2.rectangle(img5,(288,253),(320,298),(26,64,0),-1)#body
e1=cv2.rectangle(img5,(309,293),(317,322),(26,64,0),-1)#left leg
e1=cv2.circle(img5,(303,239),16,(155,226,254),-1)# head
e1=cv2.circle(img5,(295,242),2,(0,0,0),-1)# right eye
e1=cv2.circle(img5,(310,242),2,(0,0,0),-1)# left eye
e1 = cv2.line(img5,(298,249),(307,249),(0,0,0),2)#mouth
e1 = cv2.line(img5,(289,265),(294,276),(155,226,254),4)#right hand 
e1 = cv2.line(img5,(318,265),(310,276),(155,226,254),4)#left hand
e1 = cv2.line(img5,(293,229),(312,229),(0,0,0),13)#top hair


#Indian  player
e1=cv2.rectangle(img5,(548,767),(555,784),(255,0,0),-1)#left leg
e1=cv2.rectangle(img5,(569,767),(545,742),(255,0,0),-1)#body
e1=cv2.rectangle(img5,(560,767),(567,784),(255,0,0),-1)#right leg
e1=cv2.circle(img5,(557,729),14,(155,226,254),-1)# head
e1 = cv2.line(img5,(570,748),(574,761),(155,226,254),3)#right hand 
e1 = cv2.line(img5,(544,747),(537,754),(155,226,254),3)#left hand
e1 = cv2.line(img5,(575,761),(580,778),(29,101,181),10)#bat
e1 = cv2.line(img5,(550,724),(562,724),(0,0,0),21)#top hair




cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # 4th point

# %%
img6=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img6,(0,0),(1200,800),(0,178,0),-1) #layout

e1 = cv2.line(img6,(600,800),(530,400),(128,178,194),10)# left line
e1 = cv2.line(img6,(610,800),(540,400),(128,178,194),10)# left line
e1 = cv2.line(img6,(620,800),(550,400),(128,178,194),10)# left line
e1 = cv2.line(img6,(630,800),(560,400),(128,178,194),10)# left line
e1 = cv2.line(img6,(640,800),(570,400),(128,178,194),10)# left line
e1 = cv2.line(img6,(650,800),(580,400),(128,178,194),10)# left line
e1 = cv2.line(img6,(660,800),(590,400),(128,178,194),10)# left line
e1 = cv2.line(img6,(670,800),(600,400),(128,178,194),10)# left line
e1 = cv2.line(img6,(680,800),(610,400),(128,178,194),10)# left line
e1 = cv2.line(img6,(690,800),(620,400),(128,178,194),10)# left line
e1 = cv2.line(img6,(700,800),(630,400),(128,178,194),10)# left line
e1 = cv2.line(img6,(710,800),(640,400),(128,178,194),10)# left line
e1 = cv2.line(img6,(720,800),(650,400),(128,178,194),10)# left line
e1 = cv2.line(img6,(730,800),(660,400),(128,178,194),10)# left line
e1 = cv2.line(img6,(740,800),(670,400),(128,178,194),10)# left line
e1 = cv2.line(img6,(750,800),(680,400),(128,178,194),10)# left line
e1 = cv2.line(img6,(760,800),(690,400),(128,178,194),10)# left line

e1 = cv2.line(img6,(450,800),(530,400),(128,178,194),10)#right line
e1 = cv2.line(img6,(460,800),(540,400),(128,178,194),10)#right line
e1 = cv2.line(img6,(470,800),(550,400),(128,178,194),10)#right line
e1 = cv2.line(img6,(480,800),(560,400),(128,178,194),10)#right line
e1 = cv2.line(img6,(490,800),(570,400),(128,178,194),10)#right line
e1 = cv2.line(img6,(500,800),(580,400),(128,178,194),10)#right line
e1 = cv2.line(img6,(510,800),(590,400),(128,178,194),10)#right line
e1 = cv2.line(img6,(520,800),(600,400),(128,178,194),10)#right line
e1 = cv2.line(img6,(530,800),(610,400),(128,178,194),10)#right line
e1 = cv2.line(img6,(540,800),(620,400),(128,178,194),10)#right line
e1 = cv2.line(img6,(550,800),(630,400),(128,178,194),10)#right line
e1 = cv2.line(img6,(560,800),(640,400),(128,178,194),10)#right line
e1 = cv2.line(img6,(570,800),(650,400),(128,178,194),10)#right line
e1 = cv2.line(img6,(580,800),(660,400),(128,178,194),10)#right line
e1 = cv2.line(img6,(590,800),(670,400),(128,178,194),10)#right line

e1 = cv2.line(img6,(760,800),(690,400),(255,255,255),2)# left line
e1 = cv2.line(img6,(450,800),(530,400),(255,255,255),2)#right line
e1 = cv2.line(img6,(690,400),(530,400),(255,255,255),2)# middle line
e1 = cv2.line(img6,(600,1200),(600,760),(0,0,0),5)   #middle wicket   #buttom side
e1 = cv2.line(img6,(590,1200),(590,760),(0,0,0),5)   #left wicket
e1 = cv2.line(img6,(610,1200),(610,760),(0,0,0),5)   #right wicket
e1 = cv2.line(img6,(590,760),(610,760),(0,0,0),5)    #top wicket
e1 = cv2.line(img6,(430,750),(780,750),(255,255,255),2)#buttom boundary line 
e1 = cv2.line(img6,(500,750),(490,850),(255,255,255),2)#boundary left line
e1 = cv2.line(img6,(710,750),(720,850),(255,255,255),2)#boundary right line

e1 = cv2.line(img6,(760,800),(690,400),(255,255,255),2)# left line
e1 = cv2.line(img6,(450,800),(530,400),(255,255,255),2)#right line
e1 = cv2.line(img6,(690,400),(530,400),(255,255,255),2)# middle line
e1 = cv2.line(img6,(620,400),(620,360),(0,0,0),5)   #right wicket     #top side
e1 = cv2.line(img6,(600,400),(600,360),(0,0,0),5)   #lift wicket
e1 = cv2.line(img6,(610,400),(610,360),(0,0,0),5)   #middle wicket
e1 = cv2.line(img6,(600,360),(620,360),(0,0,0),5)    #top wicket
e1 = cv2.line(img6,(490,440),(720,440),(255,255,255),2) # top boundary line
e1 = cv2.line(img6,(555,440),(560,400),(255,255,255),2)#boundary left line
e1 = cv2.line(img6,(655,440),(655,400),(255,255,255),2)#boundary right line




#indian player

e1=cv2.rectangle(img6,(642,402),(648,440),(255,0,0),-1)#right leg
e1=cv2.rectangle(img6,(629,352),(650,402),(255,0,0),-1)#body
e1=cv2.rectangle(img6,(631,402),(637,440),(255,0,0),-1)#left leg
e1=cv2.circle(img6,(640,339),13,(155,226,254),-1)# head
e1=cv2.circle(img6,(632,340),2,(0,0,0),-1)# right eye
e1=cv2.circle(img6,(637,340),2,(0,0,0),-1)# left eye
e1=cv2.circle(img6,(635,346),2,(0,0,0),-1)#mouth
e1 = cv2.line(img6,(632,364),(620,400),(155,226,254),3)#right hand 
e1 = cv2.line(img6,(641,373),(623,400),(155,226,254),3)#left hand
e1 = cv2.line(img6,(621,400),(603,435),(29,101,181),10)#bat
e1 = cv2.line(img6,(632,329),(647,329),(0,0,0),10)#top hair
e1 = cv2.line(img6,(647,336),(646,348),(0,0,0),10)#left hair


# pakistan wicket player

e1=cv2.rectangle(img6,(592,362),(586,395),(26,64,0),-1)#right leg
e1=cv2.rectangle(img6,(570,351),(593,379),(26,64,0),-1)#body
e1=cv2.rectangle(img6,(572,362),(579,395),(26,64,0),-1)#left leg
e1=cv2.circle(img6,(581,336),14,(155,226,254),-1)# head
e1=cv2.circle(img6,(576,338),2,(0,0,0),-1)# right eye
e1=cv2.circle(img6,(587,338),2,(0,0,0),-1)# left eye
e1 = cv2.line(img6,(578,345),(585,345),(0,0,0),2)#mouth
e1 = cv2.line(img6,(572,360),(582,369),(155,226,254),4)#right hand 
e1 = cv2.line(img6,(591,360),(582,369),(155,226,254),4)#left hand
e1 = cv2.line(img6,(581,368),(582,369),(255,255,255),10)#glove
e1 = cv2.line(img6,(571,326),(588,326),(0,0,0),10)#top hair



#bowler


e1=cv2.rectangle(img6,(626,719),(652,749),(26,64,0),-1)#body
e1=cv2.circle(img6,(638,705),14,(155,226,254),-1)# head
e1=cv2.circle(img6,(670,690),6,(255,255,255),-1)# right ball
e1 = cv2.line(img6,(653,724),(669,709),(155,226,254),5)#right hand 
e1 = cv2.line(img6,(625,725),(620,732),(155,226,254),5)#left hand
e1 = cv2.line(img6,(632,702),(643,702),(0,0,0),20)#top hair
e1=cv2.rectangle(img6,(631,749),(637,762),(26,64,0),-1)#left leg
e1=cv2.rectangle(img6,(642,749),(648,762),(26,64,0),-1)#right leg



# pakistan player
e1=cv2.rectangle(img6,(292,293),(300,322),(26,64,0),-1)#right leg
e1=cv2.rectangle(img6,(288,253),(320,298),(26,64,0),-1)#body
e1=cv2.rectangle(img6,(309,293),(317,322),(26,64,0),-1)#left leg
e1=cv2.circle(img6,(303,239),16,(155,226,254),-1)# head
e1=cv2.circle(img6,(295,242),2,(0,0,0),-1)# right eye
e1=cv2.circle(img6,(310,242),2,(0,0,0),-1)# left eye
e1 = cv2.line(img6,(298,249),(307,249),(0,0,0),2)#mouth
e1 = cv2.line(img6,(289,265),(294,276),(155,226,254),4)#right hand 
e1 = cv2.line(img6,(318,265),(310,276),(155,226,254),4)#left hand
e1 = cv2.line(img6,(293,229),(312,229),(0,0,0),13)#top hair

#Indian  player
e1=cv2.rectangle(img6,(548,767),(555,784),(255,0,0),-1)#left leg
e1=cv2.rectangle(img6,(569,767),(545,742),(255,0,0),-1)#body
e1=cv2.rectangle(img6,(560,767),(567,784),(255,0,0),-1)#right leg
e1=cv2.circle(img6,(557,729),14,(155,226,254),-1)# head
e1 = cv2.line(img6,(570,748),(574,761),(155,226,254),3)#right hand 
e1 = cv2.line(img6,(544,747),(537,754),(155,226,254),3)#left hand
e1 = cv2.line(img6,(575,761),(580,778),(29,101,181),10)#bat
e1 = cv2.line(img6,(550,724),(562,724),(0,0,0),21)#top hair




cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # 5th point

# %%
img7=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img7,(0,0),(1200,800),(0,178,0),-1) #layout

e1 = cv2.line(img7,(600,800),(530,400),(128,178,194),10)# left line
e1 = cv2.line(img7,(610,800),(540,400),(128,178,194),10)# left line
e1 = cv2.line(img7,(620,800),(550,400),(128,178,194),10)# left line
e1 = cv2.line(img7,(630,800),(560,400),(128,178,194),10)# left line
e1 = cv2.line(img7,(640,800),(570,400),(128,178,194),10)# left line
e1 = cv2.line(img7,(650,800),(580,400),(128,178,194),10)# left line
e1 = cv2.line(img7,(660,800),(590,400),(128,178,194),10)# left line
e1 = cv2.line(img7,(670,800),(600,400),(128,178,194),10)# left line
e1 = cv2.line(img7,(680,800),(610,400),(128,178,194),10)# left line
e1 = cv2.line(img7,(690,800),(620,400),(128,178,194),10)# left line
e1 = cv2.line(img7,(700,800),(630,400),(128,178,194),10)# left line
e1 = cv2.line(img7,(710,800),(640,400),(128,178,194),10)# left line
e1 = cv2.line(img7,(720,800),(650,400),(128,178,194),10)# left line
e1 = cv2.line(img7,(730,800),(660,400),(128,178,194),10)# left line
e1 = cv2.line(img7,(740,800),(670,400),(128,178,194),10)# left line
e1 = cv2.line(img7,(750,800),(680,400),(128,178,194),10)# left line
e1 = cv2.line(img7,(760,800),(690,400),(128,178,194),10)# left line

e1 = cv2.line(img7,(450,800),(530,400),(128,178,194),10)#right line
e1 = cv2.line(img7,(460,800),(540,400),(128,178,194),10)#right line
e1 = cv2.line(img7,(470,800),(550,400),(128,178,194),10)#right line
e1 = cv2.line(img7,(480,800),(560,400),(128,178,194),10)#right line
e1 = cv2.line(img7,(490,800),(570,400),(128,178,194),10)#right line
e1 = cv2.line(img7,(500,800),(580,400),(128,178,194),10)#right line
e1 = cv2.line(img7,(510,800),(590,400),(128,178,194),10)#right line
e1 = cv2.line(img7,(520,800),(600,400),(128,178,194),10)#right line
e1 = cv2.line(img7,(530,800),(610,400),(128,178,194),10)#right line
e1 = cv2.line(img7,(540,800),(620,400),(128,178,194),10)#right line
e1 = cv2.line(img7,(550,800),(630,400),(128,178,194),10)#right line
e1 = cv2.line(img7,(560,800),(640,400),(128,178,194),10)#right line
e1 = cv2.line(img7,(570,800),(650,400),(128,178,194),10)#right line
e1 = cv2.line(img7,(580,800),(660,400),(128,178,194),10)#right line
e1 = cv2.line(img7,(590,800),(670,400),(128,178,194),10)#right line

e1 = cv2.line(img7,(760,800),(690,400),(255,255,255),2)# left line
e1 = cv2.line(img7,(450,800),(530,400),(255,255,255),2)#right line
e1 = cv2.line(img7,(690,400),(530,400),(255,255,255),2)# middle line
e1 = cv2.line(img7,(600,1200),(600,760),(0,0,0),5)   #middle wicket   #buttom side
e1 = cv2.line(img7,(590,1200),(590,760),(0,0,0),5)   #left wicket
e1 = cv2.line(img7,(610,1200),(610,760),(0,0,0),5)   #right wicket
e1 = cv2.line(img7,(590,760),(610,760),(0,0,0),5)    #top wicket
e1 = cv2.line(img7,(430,750),(780,750),(255,255,255),2)#buttom boundary line 
e1 = cv2.line(img7,(500,750),(490,850),(255,255,255),2)#boundary left line
e1 = cv2.line(img7,(710,750),(720,850),(255,255,255),2)#boundary right line

e1 = cv2.line(img7,(760,800),(690,400),(255,255,255),2)# left line
e1 = cv2.line(img7,(450,800),(530,400),(255,255,255),2)#right line
e1 = cv2.line(img7,(690,400),(530,400),(255,255,255),2)# middle line
e1 = cv2.line(img7,(620,400),(620,360),(0,0,0),5)   #right wicket     #top side
e1 = cv2.line(img7,(600,400),(600,360),(0,0,0),5)   #lift wicket
e1 = cv2.line(img7,(610,400),(610,360),(0,0,0),5)   #middle wicket
e1 = cv2.line(img7,(600,360),(620,360),(0,0,0),5)    #top wicket
e1 = cv2.line(img7,(490,440),(720,440),(255,255,255),2) # top boundary line
e1 = cv2.line(img7,(555,440),(560,400),(255,255,255),2)#boundary left line
e1 = cv2.line(img7,(655,440),(655,400),(255,255,255),2)#boundary right line




#indian player

e1=cv2.rectangle(img7,(642,402),(648,440),(255,0,0),-1)#right leg
e1=cv2.rectangle(img7,(629,352),(650,402),(255,0,0),-1)#body
e1=cv2.rectangle(img7,(631,402),(637,440),(255,0,0),-1)#left leg
e1=cv2.circle(img7,(640,339),13,(155,226,254),-1)# head
e1=cv2.circle(img7,(632,340),2,(0,0,0),-1)# right eye
e1=cv2.circle(img7,(637,340),2,(0,0,0),-1)# left eye
e1=cv2.circle(img7,(635,346),2,(0,0,0),-1)#mouth
e1 = cv2.line(img7,(632,364),(620,400),(155,226,254),3)#right hand 
e1 = cv2.line(img7,(641,373),(623,400),(155,226,254),3)#left hand
e1 = cv2.line(img7,(621,400),(603,435),(29,101,181),10)#bat
e1 = cv2.line(img7,(632,329),(647,329),(0,0,0),10)#top hair
e1 = cv2.line(img7,(647,336),(646,348),(0,0,0),10)#left hair


# pakistan wicket player

e1=cv2.rectangle(img7,(592,362),(586,395),(26,64,0),-1)#right leg
e1=cv2.rectangle(img7,(570,351),(593,379),(26,64,0),-1)#body
e1=cv2.rectangle(img7,(572,362),(579,395),(26,64,0),-1)#left leg
e1=cv2.circle(img7,(581,336),14,(155,226,254),-1)# head
e1=cv2.circle(img7,(576,338),2,(0,0,0),-1)# right eye
e1=cv2.circle(img7,(587,338),2,(0,0,0),-1)# left eye
e1 = cv2.line(img7,(578,345),(585,345),(0,0,0),2)#mouth
e1 = cv2.line(img7,(572,360),(582,369),(155,226,254),4)#right hand 
e1 = cv2.line(img7,(591,360),(582,369),(155,226,254),4)#left hand
e1 = cv2.line(img7,(581,368),(582,369),(255,255,255),10)#glove
e1 = cv2.line(img7,(571,326),(588,326),(0,0,0),10)#top hair



#bowler


e1=cv2.rectangle(img7,(626,719),(652,749),(26,64,0),-1)#body
e1=cv2.circle(img7,(638,705),14,(155,226,254),-1)# head
e1=cv2.circle(img7,(675,657),6,(255,255,255),-1)# right ball
e1 = cv2.line(img7,(653,724),(663,736),(155,226,254),5)#right hand 
e1 = cv2.line(img7,(625,725),(620,732),(155,226,254),5)#left hand
e1 = cv2.line(img7,(632,702),(643,702),(0,0,0),20)#top hair
e1=cv2.rectangle(img7,(631,749),(637,762),(26,64,0),-1)#left leg
e1=cv2.rectangle(img7,(642,749),(648,762),(26,64,0),-1)#right leg



# pakistan player
e1=cv2.rectangle(img7,(292,293),(300,322),(26,64,0),-1)#right leg
e1=cv2.rectangle(img7,(288,253),(320,298),(26,64,0),-1)#body
e1=cv2.rectangle(img7,(309,293),(317,322),(26,64,0),-1)#left leg
e1=cv2.circle(img7,(303,239),16,(155,226,254),-1)# head
e1=cv2.circle(img7,(295,242),2,(0,0,0),-1)# right eye
e1=cv2.circle(img7,(310,242),2,(0,0,0),-1)# left eye
e1 = cv2.line(img7,(298,249),(307,249),(0,0,0),2)#mouth
e1 = cv2.line(img7,(289,265),(294,276),(155,226,254),4)#right hand 
e1 = cv2.line(img7,(318,265),(310,276),(155,226,254),4)#left hand
e1 = cv2.line(img7,(293,229),(312,229),(0,0,0),13)#top hair


#Indian  player
e1=cv2.rectangle(img7,(548,767),(555,784),(255,0,0),-1)#left leg
e1=cv2.rectangle(img7,(569,767),(545,742),(255,0,0),-1)#body
e1=cv2.rectangle(img7,(560,767),(567,784),(255,0,0),-1)#right leg
e1=cv2.circle(img7,(557,729),14,(155,226,254),-1)# head
e1 = cv2.line(img7,(570,748),(574,761),(155,226,254),3)#right hand 
e1 = cv2.line(img7,(544,747),(537,754),(155,226,254),3)#left hand
e1 = cv2.line(img7,(575,761),(580,778),(29,101,181),10)#bat
e1 = cv2.line(img7,(550,724),(562,724),(0,0,0),21)#top hair



cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # 6th point

# %%
img8=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img8,(0,0),(1200,800),(0,178,0),-1) #layout

e1 = cv2.line(img8,(600,800),(530,400),(128,178,194),10)# left line
e1 = cv2.line(img8,(610,800),(540,400),(128,178,194),10)# left line
e1 = cv2.line(img8,(620,800),(550,400),(128,178,194),10)# left line
e1 = cv2.line(img8,(630,800),(560,400),(128,178,194),10)# left line
e1 = cv2.line(img8,(640,800),(570,400),(128,178,194),10)# left line
e1 = cv2.line(img8,(650,800),(580,400),(128,178,194),10)# left line
e1 = cv2.line(img8,(660,800),(590,400),(128,178,194),10)# left line
e1 = cv2.line(img8,(670,800),(600,400),(128,178,194),10)# left line
e1 = cv2.line(img8,(680,800),(610,400),(128,178,194),10)# left line
e1 = cv2.line(img8,(690,800),(620,400),(128,178,194),10)# left line
e1 = cv2.line(img8,(700,800),(630,400),(128,178,194),10)# left line
e1 = cv2.line(img8,(710,800),(640,400),(128,178,194),10)# left line
e1 = cv2.line(img8,(720,800),(650,400),(128,178,194),10)# left line
e1 = cv2.line(img8,(730,800),(660,400),(128,178,194),10)# left line
e1 = cv2.line(img8,(740,800),(670,400),(128,178,194),10)# left line
e1 = cv2.line(img8,(750,800),(680,400),(128,178,194),10)# left line
e1 = cv2.line(img8,(760,800),(690,400),(128,178,194),10)# left line

e1 = cv2.line(img8,(450,800),(530,400),(128,178,194),10)#right line
e1 = cv2.line(img8,(460,800),(540,400),(128,178,194),10)#right line
e1 = cv2.line(img8,(470,800),(550,400),(128,178,194),10)#right line
e1 = cv2.line(img8,(480,800),(560,400),(128,178,194),10)#right line
e1 = cv2.line(img8,(490,800),(570,400),(128,178,194),10)#right line
e1 = cv2.line(img8,(500,800),(580,400),(128,178,194),10)#right line
e1 = cv2.line(img8,(510,800),(590,400),(128,178,194),10)#right line
e1 = cv2.line(img8,(520,800),(600,400),(128,178,194),10)#right line
e1 = cv2.line(img8,(530,800),(610,400),(128,178,194),10)#right line
e1 = cv2.line(img8,(540,800),(620,400),(128,178,194),10)#right line
e1 = cv2.line(img8,(550,800),(630,400),(128,178,194),10)#right line
e1 = cv2.line(img8,(560,800),(640,400),(128,178,194),10)#right line
e1 = cv2.line(img8,(570,800),(650,400),(128,178,194),10)#right line
e1 = cv2.line(img8,(580,800),(660,400),(128,178,194),10)#right line
e1 = cv2.line(img8,(590,800),(670,400),(128,178,194),10)#right line

e1 = cv2.line(img8,(760,800),(690,400),(255,255,255),2)# left line
e1 = cv2.line(img8,(450,800),(530,400),(255,255,255),2)#right line
e1 = cv2.line(img8,(690,400),(530,400),(255,255,255),2)# middle line
e1 = cv2.line(img8,(600,1200),(600,760),(0,0,0),5)   #middle wicket   #buttom side
e1 = cv2.line(img8,(590,1200),(590,760),(0,0,0),5)   #left wicket
e1 = cv2.line(img8,(610,1200),(610,760),(0,0,0),5)   #right wicket
e1 = cv2.line(img8,(590,760),(610,760),(0,0,0),5)    #top wicket
e1 = cv2.line(img8,(430,750),(780,750),(255,255,255),2)#buttom boundary line 
e1 = cv2.line(img8,(500,750),(490,850),(255,255,255),2)#boundary left line
e1 = cv2.line(img8,(710,750),(720,850),(255,255,255),2)#boundary right line

e1 = cv2.line(img8,(760,800),(690,400),(255,255,255),2)# left line
e1 = cv2.line(img8,(450,800),(530,400),(255,255,255),2)#right line
e1 = cv2.line(img8,(690,400),(530,400),(255,255,255),2)# middle line
e1 = cv2.line(img8,(620,400),(620,360),(0,0,0),5)   #right wicket     #top side
e1 = cv2.line(img8,(600,400),(600,360),(0,0,0),5)   #lift wicket
e1 = cv2.line(img8,(610,400),(610,360),(0,0,0),5)   #middle wicket
e1 = cv2.line(img8,(600,360),(620,360),(0,0,0),5)    #top wicket
e1 = cv2.line(img8,(490,440),(720,440),(255,255,255),2) # top boundary line
e1 = cv2.line(img8,(555,440),(560,400),(255,255,255),2)#boundary left line
e1 = cv2.line(img8,(655,440),(655,400),(255,255,255),2)#boundary right line




#indian player

e1=cv2.rectangle(img8,(642,402),(648,440),(255,0,0),-1)#right leg
e1=cv2.rectangle(img8,(629,352),(650,402),(255,0,0),-1)#body
e1=cv2.rectangle(img8,(631,402),(637,440),(255,0,0),-1)#left leg
e1=cv2.circle(img8,(640,339),13,(155,226,254),-1)# head
e1=cv2.circle(img8,(632,340),2,(0,0,0),-1)# right eye
e1=cv2.circle(img8,(637,340),2,(0,0,0),-1)# left eye
e1=cv2.circle(img8,(635,346),2,(0,0,0),-1)#mouth
e1 = cv2.line(img8,(632,364),(620,400),(155,226,254),3)#right hand 
e1 = cv2.line(img8,(641,373),(623,400),(155,226,254),3)#left hand
e1 = cv2.line(img8,(621,400),(603,435),(29,101,181),10)#bat
e1 = cv2.line(img8,(632,329),(647,329),(0,0,0),10)#top hair
e1 = cv2.line(img8,(647,336),(646,348),(0,0,0),10)#left hair


# pakistan wicket player

e1=cv2.rectangle(img8,(592,362),(586,395),(26,64,0),-1)#right leg
e1=cv2.rectangle(img8,(570,351),(593,379),(26,64,0),-1)#body
e1=cv2.rectangle(img8,(572,362),(579,395),(26,64,0),-1)#left leg
e1=cv2.circle(img8,(581,336),14,(155,226,254),-1)# head
e1=cv2.circle(img8,(576,338),2,(0,0,0),-1)# right eye
e1=cv2.circle(img8,(587,338),2,(0,0,0),-1)# left eye
e1 = cv2.line(img8,(578,345),(585,345),(0,0,0),2)#mouth
e1 = cv2.line(img8,(572,360),(582,369),(155,226,254),4)#right hand 
e1 = cv2.line(img8,(591,360),(582,369),(155,226,254),4)#left hand
e1 = cv2.line(img8,(581,368),(582,369),(255,255,255),10)#glove
e1 = cv2.line(img8,(571,326),(588,326),(0,0,0),10)#top hair



#bowler


e1=cv2.rectangle(img8,(626,719),(652,749),(26,64,0),-1)#body
e1=cv2.circle(img8,(638,705),14,(155,226,254),-1)# head
e1=cv2.circle(img8,(673,626),6,(255,255,255),-1)# right ball
e1 = cv2.line(img8,(653,724),(663,736),(155,226,254),5)#right hand 
e1 = cv2.line(img8,(625,725),(620,732),(155,226,254),5)#left hand
e1 = cv2.line(img8,(632,702),(643,702),(0,0,0),20)#top hair
e1=cv2.rectangle(img8,(631,749),(637,762),(26,64,0),-1)#left leg
e1=cv2.rectangle(img8,(642,749),(648,762),(26,64,0),-1)#right leg



# pakistan player
e1=cv2.rectangle(img8,(292,293),(300,322),(26,64,0),-1)#right leg
e1=cv2.rectangle(img8,(288,253),(320,298),(26,64,0),-1)#body
e1=cv2.rectangle(img8,(309,293),(317,322),(26,64,0),-1)#left leg
e1=cv2.circle(img8,(303,239),16,(155,226,254),-1)# head
e1=cv2.circle(img8,(295,242),2,(0,0,0),-1)# right eye
e1=cv2.circle(img8,(310,242),2,(0,0,0),-1)# left eye
e1 = cv2.line(img8,(298,249),(307,249),(0,0,0),2)#mouth
e1 = cv2.line(img8,(289,265),(294,276),(155,226,254),4)#right hand 
e1 = cv2.line(img8,(318,265),(310,276),(155,226,254),4)#left hand
e1 = cv2.line(img8,(293,229),(312,229),(0,0,0),13)#top hair


#Indian  player
e1=cv2.rectangle(img8,(548,767),(555,784),(255,0,0),-1)#left leg
e1=cv2.rectangle(img8,(569,767),(545,742),(255,0,0),-1)#body
e1=cv2.rectangle(img8,(560,767),(567,784),(255,0,0),-1)#right leg
e1=cv2.circle(img8,(557,729),14,(155,226,254),-1)# head
e1 = cv2.line(img8,(570,748),(574,761),(155,226,254),3)#right hand 
e1 = cv2.line(img8,(544,747),(537,754),(155,226,254),3)#left hand
e1 = cv2.line(img8,(575,761),(580,778),(29,101,181),10)#bat
e1 = cv2.line(img8,(550,724),(562,724),(0,0,0),21)#top hair




cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # 7th point

# %%
img9=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img9,(0,0),(1200,800),(0,178,0),-1) #layout

e1 = cv2.line(img9,(600,800),(530,400),(128,178,194),10)# left line
e1 = cv2.line(img9,(610,800),(540,400),(128,178,194),10)# left line
e1 = cv2.line(img9,(620,800),(550,400),(128,178,194),10)# left line
e1 = cv2.line(img9,(630,800),(560,400),(128,178,194),10)# left line
e1 = cv2.line(img9,(640,800),(570,400),(128,178,194),10)# left line
e1 = cv2.line(img9,(650,800),(580,400),(128,178,194),10)# left line
e1 = cv2.line(img9,(660,800),(590,400),(128,178,194),10)# left line
e1 = cv2.line(img9,(670,800),(600,400),(128,178,194),10)# left line
e1 = cv2.line(img9,(680,800),(610,400),(128,178,194),10)# left line
e1 = cv2.line(img9,(690,800),(620,400),(128,178,194),10)# left line
e1 = cv2.line(img9,(700,800),(630,400),(128,178,194),10)# left line
e1 = cv2.line(img9,(710,800),(640,400),(128,178,194),10)# left line
e1 = cv2.line(img9,(720,800),(650,400),(128,178,194),10)# left line
e1 = cv2.line(img9,(730,800),(660,400),(128,178,194),10)# left line
e1 = cv2.line(img9,(740,800),(670,400),(128,178,194),10)# left line
e1 = cv2.line(img9,(750,800),(680,400),(128,178,194),10)# left line
e1 = cv2.line(img9,(760,800),(690,400),(128,178,194),10)# left line

e1 = cv2.line(img9,(450,800),(530,400),(128,178,194),10)#right line
e1 = cv2.line(img9,(460,800),(540,400),(128,178,194),10)#right line
e1 = cv2.line(img9,(470,800),(550,400),(128,178,194),10)#right line
e1 = cv2.line(img9,(480,800),(560,400),(128,178,194),10)#right line
e1 = cv2.line(img9,(490,800),(570,400),(128,178,194),10)#right line
e1 = cv2.line(img9,(500,800),(580,400),(128,178,194),10)#right line
e1 = cv2.line(img9,(510,800),(590,400),(128,178,194),10)#right line
e1 = cv2.line(img9,(520,800),(600,400),(128,178,194),10)#right line
e1 = cv2.line(img9,(530,800),(610,400),(128,178,194),10)#right line
e1 = cv2.line(img9,(540,800),(620,400),(128,178,194),10)#right line
e1 = cv2.line(img9,(550,800),(630,400),(128,178,194),10)#right line
e1 = cv2.line(img9,(560,800),(640,400),(128,178,194),10)#right line
e1 = cv2.line(img9,(570,800),(650,400),(128,178,194),10)#right line
e1 = cv2.line(img9,(580,800),(660,400),(128,178,194),10)#right line
e1 = cv2.line(img9,(590,800),(670,400),(128,178,194),10)#right line

e1 = cv2.line(img9,(760,800),(690,400),(255,255,255),2)# left line
e1 = cv2.line(img9,(450,800),(530,400),(255,255,255),2)#right line
e1 = cv2.line(img9,(690,400),(530,400),(255,255,255),2)# middle line
e1 = cv2.line(img9,(600,1200),(600,760),(0,0,0),5)   #middle wicket   #buttom side
e1 = cv2.line(img9,(590,1200),(590,760),(0,0,0),5)   #left wicket
e1 = cv2.line(img9,(610,1200),(610,760),(0,0,0),5)   #right wicket
e1 = cv2.line(img9,(590,760),(610,760),(0,0,0),5)    #top wicket
e1 = cv2.line(img9,(430,750),(780,750),(255,255,255),2)#buttom boundary line 
e1 = cv2.line(img9,(500,750),(490,850),(255,255,255),2)#boundary left line
e1 = cv2.line(img9,(710,750),(720,850),(255,255,255),2)#boundary right line

e1 = cv2.line(img9,(760,800),(690,400),(255,255,255),2)# left line
e1 = cv2.line(img9,(450,800),(530,400),(255,255,255),2)#right line
e1 = cv2.line(img9,(690,400),(530,400),(255,255,255),2)# middle line
e1 = cv2.line(img9,(620,400),(620,360),(0,0,0),5)   #right wicket     #top side
e1 = cv2.line(img9,(600,400),(600,360),(0,0,0),5)   #lift wicket
e1 = cv2.line(img9,(610,400),(610,360),(0,0,0),5)   #middle wicket
e1 = cv2.line(img9,(600,360),(620,360),(0,0,0),5)    #top wicket
e1 = cv2.line(img9,(490,440),(720,440),(255,255,255),2) # top boundary line
e1 = cv2.line(img9,(555,440),(560,400),(255,255,255),2)#boundary left line
e1 = cv2.line(img9,(655,440),(655,400),(255,255,255),2)#boundary right line




#indian player

e1=cv2.rectangle(img9,(642,402),(648,440),(255,0,0),-1)#right leg
e1=cv2.rectangle(img9,(629,352),(650,402),(255,0,0),-1)#body
e1=cv2.rectangle(img9,(631,402),(637,440),(255,0,0),-1)#left leg
e1=cv2.circle(img9,(640,339),13,(155,226,254),-1)# head
e1=cv2.circle(img9,(632,340),2,(0,0,0),-1)# right eye
e1=cv2.circle(img9,(637,340),2,(0,0,0),-1)# left eye
e1=cv2.circle(img9,(635,346),2,(0,0,0),-1)#mouth
e1 = cv2.line(img9,(632,364),(620,400),(155,226,254),3)#right hand 
e1 = cv2.line(img9,(641,373),(623,400),(155,226,254),3)#left hand
e1 = cv2.line(img9,(621,400),(603,435),(29,101,181),10)#bat
e1 = cv2.line(img9,(632,329),(647,329),(0,0,0),10)#top hair
e1 = cv2.line(img9,(647,336),(646,348),(0,0,0),10)#left hair


# pakistan wicket player

e1=cv2.rectangle(img9,(592,362),(586,395),(26,64,0),-1)#right leg
e1=cv2.rectangle(img9,(570,351),(593,379),(26,64,0),-1)#body
e1=cv2.rectangle(img9,(572,362),(579,395),(26,64,0),-1)#left leg
e1=cv2.circle(img9,(581,336),14,(155,226,254),-1)# head
e1=cv2.circle(img9,(576,338),2,(0,0,0),-1)# right eye
e1=cv2.circle(img9,(587,338),2,(0,0,0),-1)# left eye
e1 = cv2.line(img9,(578,345),(585,345),(0,0,0),2)#mouth
e1 = cv2.line(img9,(572,360),(582,369),(155,226,254),4)#right hand 
e1 = cv2.line(img9,(591,360),(582,369),(155,226,254),4)#left hand
e1 = cv2.line(img9,(581,368),(582,369),(255,255,255),10)#glove
e1 = cv2.line(img9,(571,326),(588,326),(0,0,0),10)#top hair



#bowler


e1=cv2.rectangle(img9,(626,719),(652,749),(26,64,0),-1)#body
e1=cv2.circle(img9,(638,705),14,(155,226,254),-1)# head
e1=cv2.circle(img9,(661,596),6,(255,255,255),-1)# right ball
e1 = cv2.line(img9,(653,724),(663,736),(155,226,254),5)#right hand 
e1 = cv2.line(img9,(625,725),(620,732),(155,226,254),5)#left hand
e1 = cv2.line(img9,(632,702),(643,702),(0,0,0),20)#top hair
e1=cv2.rectangle(img9,(631,749),(637,762),(26,64,0),-1)#left leg
e1=cv2.rectangle(img9,(642,749),(648,762),(26,64,0),-1)#right leg



# pakistan player
e1=cv2.rectangle(img9,(292,293),(300,322),(26,64,0),-1)#right leg
e1=cv2.rectangle(img9,(288,253),(320,298),(26,64,0),-1)#body
e1=cv2.rectangle(img9,(309,293),(317,322),(26,64,0),-1)#left leg
e1=cv2.circle(img9,(303,239),16,(155,226,254),-1)# head
e1=cv2.circle(img9,(295,242),2,(0,0,0),-1)# right eye
e1=cv2.circle(img9,(310,242),2,(0,0,0),-1)# left eye
e1 = cv2.line(img9,(298,249),(307,249),(0,0,0),2)#mouth
e1 = cv2.line(img9,(289,265),(294,276),(155,226,254),4)#right hand 
e1 = cv2.line(img9,(318,265),(310,276),(155,226,254),4)#left hand
e1 = cv2.line(img9,(293,229),(312,229),(0,0,0),13)#top hair


#Indian  player
e1=cv2.rectangle(img9,(548,767),(555,784),(255,0,0),-1)#left leg
e1=cv2.rectangle(img9,(569,767),(545,742),(255,0,0),-1)#body
e1=cv2.rectangle(img9,(560,767),(567,784),(255,0,0),-1)#right leg
e1=cv2.circle(img9,(557,729),14,(155,226,254),-1)# head
e1 = cv2.line(img9,(570,748),(574,761),(155,226,254),3)#right hand 
e1 = cv2.line(img9,(544,747),(537,754),(155,226,254),3)#left hand
e1 = cv2.line(img9,(575,761),(580,778),(29,101,181),10)#bat
e1 = cv2.line(img9,(550,724),(562,724),(0,0,0),21)#top hair




cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # 8th point

# %%
img10=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img10,(0,0),(1200,800),(0,178,0),-1) #layout

e1 = cv2.line(img10,(600,800),(530,400),(128,178,194),10)# left line
e1 = cv2.line(img10,(610,800),(540,400),(128,178,194),10)# left line
e1 = cv2.line(img10,(620,800),(550,400),(128,178,194),10)# left line
e1 = cv2.line(img10,(630,800),(560,400),(128,178,194),10)# left line
e1 = cv2.line(img10,(640,800),(570,400),(128,178,194),10)# left line
e1 = cv2.line(img10,(650,800),(580,400),(128,178,194),10)# left line
e1 = cv2.line(img10,(660,800),(590,400),(128,178,194),10)# left line
e1 = cv2.line(img10,(670,800),(600,400),(128,178,194),10)# left line
e1 = cv2.line(img10,(680,800),(610,400),(128,178,194),10)# left line
e1 = cv2.line(img10,(690,800),(620,400),(128,178,194),10)# left line
e1 = cv2.line(img10,(700,800),(630,400),(128,178,194),10)# left line
e1 = cv2.line(img10,(710,800),(640,400),(128,178,194),10)# left line
e1 = cv2.line(img10,(720,800),(650,400),(128,178,194),10)# left line
e1 = cv2.line(img10,(730,800),(660,400),(128,178,194),10)# left line
e1 = cv2.line(img10,(740,800),(670,400),(128,178,194),10)# left line
e1 = cv2.line(img10,(750,800),(680,400),(128,178,194),10)# left line
e1 = cv2.line(img10,(760,800),(690,400),(128,178,194),10)# left line

e1 = cv2.line(img10,(450,800),(530,400),(128,178,194),10)#right line
e1 = cv2.line(img10,(460,800),(540,400),(128,178,194),10)#right line
e1 = cv2.line(img10,(470,800),(550,400),(128,178,194),10)#right line
e1 = cv2.line(img10,(480,800),(560,400),(128,178,194),10)#right line
e1 = cv2.line(img10,(490,800),(570,400),(128,178,194),10)#right line
e1 = cv2.line(img10,(500,800),(580,400),(128,178,194),10)#right line
e1 = cv2.line(img10,(510,800),(590,400),(128,178,194),10)#right line
e1 = cv2.line(img10,(520,800),(600,400),(128,178,194),10)#right line
e1 = cv2.line(img10,(530,800),(610,400),(128,178,194),10)#right line
e1 = cv2.line(img10,(540,800),(620,400),(128,178,194),10)#right line
e1 = cv2.line(img10,(550,800),(630,400),(128,178,194),10)#right line
e1 = cv2.line(img10,(560,800),(640,400),(128,178,194),10)#right line
e1 = cv2.line(img10,(570,800),(650,400),(128,178,194),10)#right line
e1 = cv2.line(img10,(580,800),(660,400),(128,178,194),10)#right line
e1 = cv2.line(img10,(590,800),(670,400),(128,178,194),10)#right line

e1 = cv2.line(img10,(760,800),(690,400),(255,255,255),2)# left line
e1 = cv2.line(img10,(450,800),(530,400),(255,255,255),2)#right line
e1 = cv2.line(img10,(690,400),(530,400),(255,255,255),2)# middle line
e1 = cv2.line(img10,(600,1200),(600,760),(0,0,0),5)   #middle wicket   #buttom side
e1 = cv2.line(img10,(590,1200),(590,760),(0,0,0),5)   #left wicket
e1 = cv2.line(img10,(610,1200),(610,760),(0,0,0),5)   #right wicket
e1 = cv2.line(img10,(590,760),(610,760),(0,0,0),5)    #top wicket
e1 = cv2.line(img10,(430,750),(780,750),(255,255,255),2)#buttom boundary line 
e1 = cv2.line(img10,(500,750),(490,850),(255,255,255),2)#boundary left line
e1 = cv2.line(img10,(710,750),(720,850),(255,255,255),2)#boundary right line

e1 = cv2.line(img10,(760,800),(690,400),(255,255,255),2)# left line
e1 = cv2.line(img10,(450,800),(530,400),(255,255,255),2)#right line
e1 = cv2.line(img10,(690,400),(530,400),(255,255,255),2)# middle line
e1 = cv2.line(img10,(620,400),(620,360),(0,0,0),5)   #right wicket     #top side
e1 = cv2.line(img10,(600,400),(600,360),(0,0,0),5)   #lift wicket
e1 = cv2.line(img10,(610,400),(610,360),(0,0,0),5)   #middle wicket
e1 = cv2.line(img10,(600,360),(620,360),(0,0,0),5)    #top wicket
e1 = cv2.line(img10,(490,440),(720,440),(255,255,255),2) # top boundary line
e1 = cv2.line(img10,(555,440),(560,400),(255,255,255),2)#boundary left line
e1 = cv2.line(img10,(655,440),(655,400),(255,255,255),2)#boundary right line




#indian player

e1=cv2.rectangle(img10,(642,402),(648,440),(255,0,0),-1)#right leg
e1=cv2.rectangle(img10,(629,352),(650,402),(255,0,0),-1)#body
e1=cv2.rectangle(img10,(631,402),(637,440),(255,0,0),-1)#left leg
e1=cv2.circle(img10,(640,339),13,(155,226,254),-1)# head
e1=cv2.circle(img10,(632,340),2,(0,0,0),-1)# right eye
e1=cv2.circle(img10,(637,340),2,(0,0,0),-1)# left eye
e1=cv2.circle(img10,(635,346),2,(0,0,0),-1)#mouth
e1 = cv2.line(img10,(632,364),(620,400),(155,226,254),3)#right hand 
e1 = cv2.line(img10,(641,373),(623,400),(155,226,254),3)#left hand
e1 = cv2.line(img10,(621,400),(603,435),(29,101,181),10)#bat
e1 = cv2.line(img10,(632,329),(647,329),(0,0,0),10)#top hair
e1 = cv2.line(img10,(647,336),(646,348),(0,0,0),10)#left hair


# pakistan wicket player

e1=cv2.rectangle(img10,(592,362),(586,395),(26,64,0),-1)#right leg
e1=cv2.rectangle(img10,(570,351),(593,379),(26,64,0),-1)#body
e1=cv2.rectangle(img10,(572,362),(579,395),(26,64,0),-1)#left leg
e1=cv2.circle(img10,(581,336),14,(155,226,254),-1)# head
e1=cv2.circle(img10,(576,338),2,(0,0,0),-1)# right eye
e1=cv2.circle(img10,(587,338),2,(0,0,0),-1)# left eye
e1 = cv2.line(img10,(578,345),(585,345),(0,0,0),2)#mouth
e1 = cv2.line(img10,(572,360),(582,369),(155,226,254),4)#right hand 
e1 = cv2.line(img10,(591,360),(582,369),(155,226,254),4)#left hand
e1 = cv2.line(img10,(581,368),(582,369),(255,255,255),10)#glove
e1 = cv2.line(img10,(571,326),(588,326),(0,0,0),10)#top hair



#bowler


e1=cv2.rectangle(img10,(626,719),(652,749),(26,64,0),-1)#body
e1=cv2.circle(img10,(638,705),14,(155,226,254),-1)# head
e1=cv2.circle(img10,(653,555),6,(255,255,255),-1)# right ball
e1 = cv2.line(img10,(653,724),(663,736),(155,226,254),5)#right hand 
e1 = cv2.line(img10,(625,725),(620,732),(155,226,254),5)#left hand
e1 = cv2.line(img10,(632,702),(643,702),(0,0,0),20)#top hair
e1=cv2.rectangle(img10,(631,749),(637,762),(26,64,0),-1)#left leg
e1=cv2.rectangle(img10,(642,749),(648,762),(26,64,0),-1)#right leg



# pakistan player
e1=cv2.rectangle(img10,(292,293),(300,322),(26,64,0),-1)#right leg
e1=cv2.rectangle(img10,(288,253),(320,298),(26,64,0),-1)#body
e1=cv2.rectangle(img10,(309,293),(317,322),(26,64,0),-1)#left leg
e1=cv2.circle(img10,(303,239),16,(155,226,254),-1)# head
e1=cv2.circle(img10,(295,242),2,(0,0,0),-1)# right eye
e1=cv2.circle(img10,(310,242),2,(0,0,0),-1)# left eye
e1 = cv2.line(img10,(298,249),(307,249),(0,0,0),2)#mouth
e1 = cv2.line(img10,(289,265),(294,276),(155,226,254),4)#right hand 
e1 = cv2.line(img10,(318,265),(310,276),(155,226,254),4)#left hand
e1 = cv2.line(img10,(293,229),(312,229),(0,0,0),13)#top hair


#Indian  player
e1=cv2.rectangle(img10,(548,767),(555,784),(255,0,0),-1)#left leg
e1=cv2.rectangle(img10,(569,767),(545,742),(255,0,0),-1)#body
e1=cv2.rectangle(img10,(560,767),(567,784),(255,0,0),-1)#right leg
e1=cv2.circle(img10,(557,729),14,(155,226,254),-1)# head
e1 = cv2.line(img10,(570,748),(574,761),(155,226,254),3)#right hand 
e1 = cv2.line(img10,(544,747),(537,754),(155,226,254),3)#left hand
e1 = cv2.line(img10,(575,761),(580,778),(29,101,181),10)#bat
e1 = cv2.line(img10,(550,724),(562,724),(0,0,0),21)#top hair




cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # 9th point

# %%
img11=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img11,(0,0),(1200,800),(0,178,0),-1) #layout

e1 = cv2.line(img11,(600,800),(530,400),(128,178,194),10)# left line
e1 = cv2.line(img11,(610,800),(540,400),(128,178,194),10)# left line
e1 = cv2.line(img11,(620,800),(550,400),(128,178,194),10)# left line
e1 = cv2.line(img11,(630,800),(560,400),(128,178,194),10)# left line
e1 = cv2.line(img11,(640,800),(570,400),(128,178,194),10)# left line
e1 = cv2.line(img11,(650,800),(580,400),(128,178,194),10)# left line
e1 = cv2.line(img11,(660,800),(590,400),(128,178,194),10)# left line
e1 = cv2.line(img11,(670,800),(600,400),(128,178,194),10)# left line
e1 = cv2.line(img11,(680,800),(610,400),(128,178,194),10)# left line
e1 = cv2.line(img11,(690,800),(620,400),(128,178,194),10)# left line
e1 = cv2.line(img11,(700,800),(630,400),(128,178,194),10)# left line
e1 = cv2.line(img11,(710,800),(640,400),(128,178,194),10)# left line
e1 = cv2.line(img11,(720,800),(650,400),(128,178,194),10)# left line
e1 = cv2.line(img11,(730,800),(660,400),(128,178,194),10)# left line
e1 = cv2.line(img11,(740,800),(670,400),(128,178,194),10)# left line
e1 = cv2.line(img11,(750,800),(680,400),(128,178,194),10)# left line
e1 = cv2.line(img11,(760,800),(690,400),(128,178,194),10)# left line

e1 = cv2.line(img11,(450,800),(530,400),(128,178,194),10)#right line
e1 = cv2.line(img11,(460,800),(540,400),(128,178,194),10)#right line
e1 = cv2.line(img11,(470,800),(550,400),(128,178,194),10)#right line
e1 = cv2.line(img11,(480,800),(560,400),(128,178,194),10)#right line
e1 = cv2.line(img11,(490,800),(570,400),(128,178,194),10)#right line
e1 = cv2.line(img11,(500,800),(580,400),(128,178,194),10)#right line
e1 = cv2.line(img11,(510,800),(590,400),(128,178,194),10)#right line
e1 = cv2.line(img11,(520,800),(600,400),(128,178,194),10)#right line
e1 = cv2.line(img11,(530,800),(610,400),(128,178,194),10)#right line
e1 = cv2.line(img11,(540,800),(620,400),(128,178,194),10)#right line
e1 = cv2.line(img11,(550,800),(630,400),(128,178,194),10)#right line
e1 = cv2.line(img11,(560,800),(640,400),(128,178,194),10)#right line
e1 = cv2.line(img11,(570,800),(650,400),(128,178,194),10)#right line
e1 = cv2.line(img11,(580,800),(660,400),(128,178,194),10)#right line
e1 = cv2.line(img11,(590,800),(670,400),(128,178,194),10)#right line

e1 = cv2.line(img11,(760,800),(690,400),(255,255,255),2)# left line
e1 = cv2.line(img11,(450,800),(530,400),(255,255,255),2)#right line
e1 = cv2.line(img11,(690,400),(530,400),(255,255,255),2)# middle line
e1 = cv2.line(img11,(600,1200),(600,760),(0,0,0),5)   #middle wicket   #buttom side
e1 = cv2.line(img11,(590,1200),(590,760),(0,0,0),5)   #left wicket
e1 = cv2.line(img11,(610,1200),(610,760),(0,0,0),5)   #right wicket
e1 = cv2.line(img11,(590,760),(610,760),(0,0,0),5)    #top wicket
e1 = cv2.line(img11,(430,750),(780,750),(255,255,255),2)#buttom boundary line 
e1 = cv2.line(img11,(500,750),(490,850),(255,255,255),2)#boundary left line
e1 = cv2.line(img11,(710,750),(720,850),(255,255,255),2)#boundary right line

e1 = cv2.line(img11,(760,800),(690,400),(255,255,255),2)# left line
e1 = cv2.line(img11,(450,800),(530,400),(255,255,255),2)#right line
e1 = cv2.line(img11,(690,400),(530,400),(255,255,255),2)# middle line
e1 = cv2.line(img11,(620,400),(620,360),(0,0,0),5)   #right wicket     #top side
e1 = cv2.line(img11,(600,400),(600,360),(0,0,0),5)   #lift wicket
e1 = cv2.line(img11,(610,400),(610,360),(0,0,0),5)   #middle wicket
e1 = cv2.line(img11,(600,360),(620,360),(0,0,0),5)    #top wicket
e1 = cv2.line(img11,(490,440),(720,440),(255,255,255),2) # top boundary line
e1 = cv2.line(img11,(555,440),(560,400),(255,255,255),2)#boundary left line
e1 = cv2.line(img11,(655,440),(655,400),(255,255,255),2)#boundary right line




#indian player

e1=cv2.rectangle(img11,(642,402),(648,440),(255,0,0),-1)#right leg
e1=cv2.rectangle(img11,(629,352),(650,402),(255,0,0),-1)#body
e1=cv2.rectangle(img11,(631,402),(637,440),(255,0,0),-1)#left leg
e1=cv2.circle(img11,(640,339),13,(155,226,254),-1)# head
e1=cv2.circle(img11,(632,340),2,(0,0,0),-1)# right eye
e1=cv2.circle(img11,(637,340),2,(0,0,0),-1)# left eye
e1=cv2.circle(img11,(635,346),2,(0,0,0),-1)#mouth
e1 = cv2.line(img11,(632,364),(620,400),(155,226,254),3)#right hand 
e1 = cv2.line(img11,(641,373),(623,400),(155,226,254),3)#left hand
e1 = cv2.line(img11,(621,400),(603,435),(29,101,181),10)#bat
e1 = cv2.line(img11,(632,329),(647,329),(0,0,0),10)#top hair
e1 = cv2.line(img11,(647,336),(646,348),(0,0,0),10)#left hair


# pakistan wicket player

e1=cv2.rectangle(img11,(592,362),(586,395),(26,64,0),-1)#right leg
e1=cv2.rectangle(img11,(570,351),(593,379),(26,64,0),-1)#body
e1=cv2.rectangle(img11,(572,362),(579,395),(26,64,0),-1)#left leg
e1=cv2.circle(img11,(581,336),14,(155,226,254),-1)# head
e1=cv2.circle(img11,(576,338),2,(0,0,0),-1)# right eye
e1=cv2.circle(img11,(587,338),2,(0,0,0),-1)# left eye
e1 = cv2.line(img11,(578,345),(585,345),(0,0,0),2)#mouth
e1 = cv2.line(img11,(572,360),(582,369),(155,226,254),4)#right hand 
e1 = cv2.line(img11,(591,360),(582,369),(155,226,254),4)#left hand
e1 = cv2.line(img11,(581,368),(582,369),(255,255,255),10)#glove
e1 = cv2.line(img11,(571,326),(588,326),(0,0,0),10)#top hair



#bowler


e1=cv2.rectangle(img11,(626,719),(652,749),(26,64,0),-1)#body
e1=cv2.circle(img11,(638,705),14,(155,226,254),-1)# head
e1=cv2.circle(img11,(643,520),6,(255,255,255),-1)# right ball
e1 = cv2.line(img11,(653,724),(663,736),(155,226,254),5)#right hand 
e1 = cv2.line(img11,(625,725),(620,732),(155,226,254),5)#left hand
e1 = cv2.line(img11,(632,702),(643,702),(0,0,0),20)#top hair
e1=cv2.rectangle(img11,(631,749),(637,762),(26,64,0),-1)#left leg
e1=cv2.rectangle(img11,(642,749),(648,762),(26,64,0),-1)#right leg



# pakistan player
e1=cv2.rectangle(img11,(292,293),(300,322),(26,64,0),-1)#right leg
e1=cv2.rectangle(img11,(288,253),(320,298),(26,64,0),-1)#body
e1=cv2.rectangle(img11,(309,293),(317,322),(26,64,0),-1)#left leg
e1=cv2.circle(img11,(303,239),16,(155,226,254),-1)# head
e1=cv2.circle(img11,(295,242),2,(0,0,0),-1)# right eye
e1=cv2.circle(img11,(310,242),2,(0,0,0),-1)# left eye
e1 = cv2.line(img11,(298,249),(307,249),(0,0,0),2)#mouth
e1 = cv2.line(img11,(289,265),(294,276),(155,226,254),4)#right hand 
e1 = cv2.line(img11,(318,265),(310,276),(155,226,254),4)#left hand
e1 = cv2.line(img11,(293,229),(312,229),(0,0,0),13)#top hair


#Indian  player
e1=cv2.rectangle(img11,(548,767),(555,784),(255,0,0),-1)#left leg
e1=cv2.rectangle(img11,(569,767),(545,742),(255,0,0),-1)#body
e1=cv2.rectangle(img11,(560,767),(567,784),(255,0,0),-1)#right leg
e1=cv2.circle(img11,(557,729),14,(155,226,254),-1)# head
e1 = cv2.line(img11,(570,748),(574,761),(155,226,254),3)#right hand 
e1 = cv2.line(img11,(544,747),(537,754),(155,226,254),3)#left hand
e1 = cv2.line(img11,(575,761),(580,778),(29,101,181),10)#bat
e1 = cv2.line(img11,(550,724),(562,724),(0,0,0),21)#top hair




cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # 10th point

# %%
img12=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img12,(0,0),(1200,800),(0,178,0),-1) #layout

e1 = cv2.line(img12,(600,800),(530,400),(128,178,194),10)# left line
e1 = cv2.line(img12,(610,800),(540,400),(128,178,194),10)# left line
e1 = cv2.line(img12,(620,800),(550,400),(128,178,194),10)# left line
e1 = cv2.line(img12,(630,800),(560,400),(128,178,194),10)# left line
e1 = cv2.line(img12,(640,800),(570,400),(128,178,194),10)# left line
e1 = cv2.line(img12,(650,800),(580,400),(128,178,194),10)# left line
e1 = cv2.line(img12,(660,800),(590,400),(128,178,194),10)# left line
e1 = cv2.line(img12,(670,800),(600,400),(128,178,194),10)# left line
e1 = cv2.line(img12,(680,800),(610,400),(128,178,194),10)# left line
e1 = cv2.line(img12,(690,800),(620,400),(128,178,194),10)# left line
e1 = cv2.line(img12,(700,800),(630,400),(128,178,194),10)# left line
e1 = cv2.line(img12,(710,800),(640,400),(128,178,194),10)# left line
e1 = cv2.line(img12,(720,800),(650,400),(128,178,194),10)# left line
e1 = cv2.line(img12,(730,800),(660,400),(128,178,194),10)# left line
e1 = cv2.line(img12,(740,800),(670,400),(128,178,194),10)# left line
e1 = cv2.line(img12,(750,800),(680,400),(128,178,194),10)# left line
e1 = cv2.line(img12,(760,800),(690,400),(128,178,194),10)# left line

e1 = cv2.line(img12,(450,800),(530,400),(128,178,194),10)#right line
e1 = cv2.line(img12,(460,800),(540,400),(128,178,194),10)#right line
e1 = cv2.line(img12,(470,800),(550,400),(128,178,194),10)#right line
e1 = cv2.line(img12,(480,800),(560,400),(128,178,194),10)#right line
e1 = cv2.line(img12,(490,800),(570,400),(128,178,194),10)#right line
e1 = cv2.line(img12,(500,800),(580,400),(128,178,194),10)#right line
e1 = cv2.line(img12,(510,800),(590,400),(128,178,194),10)#right line
e1 = cv2.line(img12,(520,800),(600,400),(128,178,194),10)#right line
e1 = cv2.line(img12,(530,800),(610,400),(128,178,194),10)#right line
e1 = cv2.line(img12,(540,800),(620,400),(128,178,194),10)#right line
e1 = cv2.line(img12,(550,800),(630,400),(128,178,194),10)#right line
e1 = cv2.line(img12,(560,800),(640,400),(128,178,194),10)#right line
e1 = cv2.line(img12,(570,800),(650,400),(128,178,194),10)#right line
e1 = cv2.line(img12,(580,800),(660,400),(128,178,194),10)#right line
e1 = cv2.line(img12,(590,800),(670,400),(128,178,194),10)#right line

e1 = cv2.line(img12,(760,800),(690,400),(255,255,255),2)# left line
e1 = cv2.line(img12,(450,800),(530,400),(255,255,255),2)#right line
e1 = cv2.line(img12,(690,400),(530,400),(255,255,255),2)# middle line
e1 = cv2.line(img12,(600,1200),(600,760),(0,0,0),5)   #middle wicket   #buttom side
e1 = cv2.line(img12,(590,1200),(590,760),(0,0,0),5)   #left wicket
e1 = cv2.line(img12,(610,1200),(610,760),(0,0,0),5)   #right wicket
e1 = cv2.line(img12,(590,760),(610,760),(0,0,0),5)    #top wicket
e1 = cv2.line(img12,(430,750),(780,750),(255,255,255),2)#buttom boundary line 
e1 = cv2.line(img12,(500,750),(490,850),(255,255,255),2)#boundary left line
e1 = cv2.line(img12,(710,750),(720,850),(255,255,255),2)#boundary right line

e1 = cv2.line(img12,(760,800),(690,400),(255,255,255),2)# left line
e1 = cv2.line(img12,(450,800),(530,400),(255,255,255),2)#right line
e1 = cv2.line(img12,(690,400),(530,400),(255,255,255),2)# middle line
e1 = cv2.line(img12,(620,400),(620,360),(0,0,0),5)   #right wicket     #top side
e1 = cv2.line(img12,(600,400),(600,360),(0,0,0),5)   #lift wicket
e1 = cv2.line(img12,(610,400),(610,360),(0,0,0),5)   #middle wicket
e1 = cv2.line(img12,(600,360),(620,360),(0,0,0),5)    #top wicket
e1 = cv2.line(img12,(490,440),(720,440),(255,255,255),2) # top boundary line
e1 = cv2.line(img12,(555,440),(560,400),(255,255,255),2)#boundary left line
e1 = cv2.line(img12,(655,440),(655,400),(255,255,255),2)#boundary right line




#indian player

e1=cv2.rectangle(img12,(642,402),(648,440),(255,0,0),-1)#right leg
e1=cv2.rectangle(img12,(629,352),(650,402),(255,0,0),-1)#body
e1=cv2.rectangle(img12,(631,402),(637,440),(255,0,0),-1)#left leg
e1=cv2.circle(img12,(640,339),13,(155,226,254),-1)# head
e1=cv2.circle(img12,(632,340),2,(0,0,0),-1)# right eye
e1=cv2.circle(img12,(637,340),2,(0,0,0),-1)# left eye
e1=cv2.circle(img12,(635,346),2,(0,0,0),-1)#mouth
e1 = cv2.line(img12,(632,364),(620,400),(155,226,254),3)#right hand 
e1 = cv2.line(img12,(641,373),(623,400),(155,226,254),3)#left hand
e1 = cv2.line(img12,(621,400),(603,422),(29,101,181),10)#bat
e1 = cv2.line(img12,(632,329),(647,329),(0,0,0),10)#top hair
e1 = cv2.line(img12,(647,336),(646,348),(0,0,0),10)#left hair


# pakistan wicket player

e1=cv2.rectangle(img12,(592,362),(586,395),(26,64,0),-1)#right leg
e1=cv2.rectangle(img12,(570,351),(593,379),(26,64,0),-1)#body
e1=cv2.rectangle(img12,(572,362),(579,395),(26,64,0),-1)#left leg
e1=cv2.circle(img12,(581,336),14,(155,226,254),-1)# head
e1=cv2.circle(img12,(576,338),2,(0,0,0),-1)# right eye
e1=cv2.circle(img12,(587,338),2,(0,0,0),-1)# left eye
e1 = cv2.line(img12,(578,345),(585,345),(0,0,0),2)#mouth
e1 = cv2.line(img12,(572,360),(582,369),(155,226,254),4)#right hand 
e1 = cv2.line(img12,(591,360),(582,369),(155,226,254),4)#left hand
e1 = cv2.line(img12,(581,368),(582,369),(255,255,255),10)#glove
e1 = cv2.line(img12,(571,326),(588,326),(0,0,0),10)#top hair



#bowler


e1=cv2.rectangle(img12,(626,719),(652,749),(26,64,0),-1)#body
e1=cv2.circle(img12,(638,705),14,(155,226,254),-1)# head
e1=cv2.circle(img12,(634,490),6,(255,255,255),-1)# right ball
e1 = cv2.line(img12,(653,724),(663,736),(155,226,254),5)#right hand 
e1 = cv2.line(img12,(625,725),(620,732),(155,226,254),5)#left hand
e1 = cv2.line(img12,(632,702),(643,702),(0,0,0),20)#top hair
e1=cv2.rectangle(img12,(631,749),(637,762),(26,64,0),-1)#left leg
e1=cv2.rectangle(img12,(642,749),(648,762),(26,64,0),-1)#right leg



# pakistan player
e1=cv2.rectangle(img12,(292,293),(300,322),(26,64,0),-1)#right leg
e1=cv2.rectangle(img12,(288,253),(320,298),(26,64,0),-1)#body
e1=cv2.rectangle(img12,(309,293),(317,322),(26,64,0),-1)#left leg
e1=cv2.circle(img12,(303,239),16,(155,226,254),-1)# head
e1=cv2.circle(img12,(295,242),2,(0,0,0),-1)# right eye
e1=cv2.circle(img12,(310,242),2,(0,0,0),-1)# left eye
e1 = cv2.line(img12,(298,249),(307,249),(0,0,0),2)#mouth
e1 = cv2.line(img12,(289,265),(294,276),(155,226,254),4)#right hand 
e1 = cv2.line(img12,(318,265),(310,276),(155,226,254),4)#left hand
e1 = cv2.line(img12,(293,229),(312,229),(0,0,0),13)#top hair


#Indian  player
e1=cv2.rectangle(img12,(548,767),(555,784),(255,0,0),-1)#left leg
e1=cv2.rectangle(img12,(569,767),(545,742),(255,0,0),-1)#body
e1=cv2.rectangle(img12,(560,767),(567,784),(255,0,0),-1)#right leg
e1=cv2.circle(img12,(557,729),14,(155,226,254),-1)# head
e1 = cv2.line(img12,(570,748),(574,761),(155,226,254),3)#right hand 
e1 = cv2.line(img12,(544,747),(537,754),(155,226,254),3)#left hand
e1 = cv2.line(img12,(575,761),(580,778),(29,101,181),10)#bat
e1 = cv2.line(img12,(550,724),(562,724),(0,0,0),21)#top hair




cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # 11th point

# %%
img13=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img13,(0,0),(1200,800),(0,178,0),-1) #layout

e1 = cv2.line(img13,(600,800),(530,400),(128,178,194),10)# left line
e1 = cv2.line(img13,(610,800),(540,400),(128,178,194),10)# left line
e1 = cv2.line(img13,(620,800),(550,400),(128,178,194),10)# left line
e1 = cv2.line(img13,(630,800),(560,400),(128,178,194),10)# left line
e1 = cv2.line(img13,(640,800),(570,400),(128,178,194),10)# left line
e1 = cv2.line(img13,(650,800),(580,400),(128,178,194),10)# left line
e1 = cv2.line(img13,(660,800),(590,400),(128,178,194),10)# left line
e1 = cv2.line(img13,(670,800),(600,400),(128,178,194),10)# left line
e1 = cv2.line(img13,(680,800),(610,400),(128,178,194),10)# left line
e1 = cv2.line(img13,(690,800),(620,400),(128,178,194),10)# left line
e1 = cv2.line(img13,(700,800),(630,400),(128,178,194),10)# left line
e1 = cv2.line(img13,(710,800),(640,400),(128,178,194),10)# left line
e1 = cv2.line(img13,(720,800),(650,400),(128,178,194),10)# left line
e1 = cv2.line(img13,(730,800),(660,400),(128,178,194),10)# left line
e1 = cv2.line(img13,(740,800),(670,400),(128,178,194),10)# left line
e1 = cv2.line(img13,(750,800),(680,400),(128,178,194),10)# left line
e1 = cv2.line(img13,(760,800),(690,400),(128,178,194),10)# left line

e1 = cv2.line(img13,(450,800),(530,400),(128,178,194),10)#right line
e1 = cv2.line(img13,(460,800),(540,400),(128,178,194),10)#right line
e1 = cv2.line(img13,(470,800),(550,400),(128,178,194),10)#right line
e1 = cv2.line(img13,(480,800),(560,400),(128,178,194),10)#right line
e1 = cv2.line(img13,(490,800),(570,400),(128,178,194),10)#right line
e1 = cv2.line(img13,(500,800),(580,400),(128,178,194),10)#right line
e1 = cv2.line(img13,(510,800),(590,400),(128,178,194),10)#right line
e1 = cv2.line(img13,(520,800),(600,400),(128,178,194),10)#right line
e1 = cv2.line(img13,(530,800),(610,400),(128,178,194),10)#right line
e1 = cv2.line(img13,(540,800),(620,400),(128,178,194),10)#right line
e1 = cv2.line(img13,(550,800),(630,400),(128,178,194),10)#right line
e1 = cv2.line(img13,(560,800),(640,400),(128,178,194),10)#right line
e1 = cv2.line(img13,(570,800),(650,400),(128,178,194),10)#right line
e1 = cv2.line(img13,(580,800),(660,400),(128,178,194),10)#right line
e1 = cv2.line(img13,(590,800),(670,400),(128,178,194),10)#right line

e1 = cv2.line(img13,(760,800),(690,400),(255,255,255),2)# left line
e1 = cv2.line(img13,(450,800),(530,400),(255,255,255),2)#right line
e1 = cv2.line(img13,(690,400),(530,400),(255,255,255),2)# middle line
e1 = cv2.line(img13,(600,1200),(600,760),(0,0,0),5)   #middle wicket   #buttom side
e1 = cv2.line(img13,(590,1200),(590,760),(0,0,0),5)   #left wicket
e1 = cv2.line(img13,(610,1200),(610,760),(0,0,0),5)   #right wicket
e1 = cv2.line(img13,(590,760),(610,760),(0,0,0),5)    #top wicket
e1 = cv2.line(img13,(430,750),(780,750),(255,255,255),2)#buttom boundary line 
e1 = cv2.line(img13,(500,750),(490,850),(255,255,255),2)#boundary left line
e1 = cv2.line(img13,(710,750),(720,850),(255,255,255),2)#boundary right line

e1 = cv2.line(img13,(760,800),(690,400),(255,255,255),2)# left line
e1 = cv2.line(img13,(450,800),(530,400),(255,255,255),2)#right line
e1 = cv2.line(img13,(690,400),(530,400),(255,255,255),2)# middle line
e1 = cv2.line(img13,(620,400),(620,360),(0,0,0),5)   #right wicket     #top side
e1 = cv2.line(img13,(600,400),(600,360),(0,0,0),5)   #lift wicket
e1 = cv2.line(img13,(610,400),(610,360),(0,0,0),5)   #middle wicket
e1 = cv2.line(img13,(600,360),(620,360),(0,0,0),5)    #top wicket
e1 = cv2.line(img13,(490,440),(720,440),(255,255,255),2) # top boundary line
e1 = cv2.line(img13,(555,440),(560,400),(255,255,255),2)#boundary left line
e1 = cv2.line(img13,(655,440),(655,400),(255,255,255),2)#boundary right line




#indian player

e1=cv2.rectangle(img13,(642,402),(648,440),(255,0,0),-1)#right leg
e1=cv2.rectangle(img13,(629,352),(650,402),(255,0,0),-1)#body
e1=cv2.rectangle(img13,(631,402),(637,440),(255,0,0),-1)#left leg
e1=cv2.circle(img13,(640,339),13,(155,226,254),-1)# head
e1=cv2.circle(img13,(632,340),2,(0,0,0),-1)# right eye
e1=cv2.circle(img13,(637,340),2,(0,0,0),-1)# left eye
e1=cv2.circle(img13,(635,346),2,(0,0,0),-1)#mouth
e1 = cv2.line(img13,(632,364),(620,400),(155,226,254),3)#right hand 
e1 = cv2.line(img13,(641,373),(623,400),(155,226,254),3)#left hand
e1 = cv2.line(img13,(621,400),(603,422),(29,101,181),10)#bat
e1 = cv2.line(img13,(632,329),(647,329),(0,0,0),10)#top hair
e1 = cv2.line(img13,(647,336),(646,348),(0,0,0),10)#left hair


# pakistan wicket player

e1=cv2.rectangle(img13,(592,362),(586,395),(26,64,0),-1)#right leg
e1=cv2.rectangle(img13,(570,351),(593,379),(26,64,0),-1)#body
e1=cv2.rectangle(img13,(572,362),(579,395),(26,64,0),-1)#left leg
e1=cv2.circle(img13,(581,336),14,(155,226,254),-1)# head
e1=cv2.circle(img13,(576,338),2,(0,0,0),-1)# right eye
e1=cv2.circle(img13,(587,338),2,(0,0,0),-1)# left eye
e1 = cv2.line(img13,(578,345),(585,345),(0,0,0),2)#mouth
e1 = cv2.line(img13,(572,360),(582,369),(155,226,254),4)#right hand 
e1 = cv2.line(img13,(591,360),(582,369),(155,226,254),4)#left hand
e1 = cv2.line(img13,(581,368),(582,369),(255,255,255),10)#glove
e1 = cv2.line(img13,(571,326),(588,326),(0,0,0),10)#top hair



#bowler


e1=cv2.rectangle(img13,(626,719),(652,749),(26,64,0),-1)#body
e1=cv2.circle(img13,(638,705),14,(155,226,254),-1)# head
e1=cv2.circle(img13,(623,461),6,(255,255,255),-1)# right ball
e1 = cv2.line(img13,(653,724),(663,736),(155,226,254),5)#right hand 
e1 = cv2.line(img13,(625,725),(620,732),(155,226,254),5)#left hand
e1 = cv2.line(img13,(632,702),(643,702),(0,0,0),20)#top hair
e1=cv2.rectangle(img13,(631,749),(637,762),(26,64,0),-1)#left leg
e1=cv2.rectangle(img13,(642,749),(648,762),(26,64,0),-1)#right leg



# pakistan player
e1=cv2.rectangle(img13,(292,293),(300,322),(26,64,0),-1)#right leg
e1=cv2.rectangle(img13,(288,253),(320,298),(26,64,0),-1)#body
e1=cv2.rectangle(img13,(309,293),(317,322),(26,64,0),-1)#left leg
e1=cv2.circle(img13,(303,239),16,(155,226,254),-1)# head
e1=cv2.circle(img13,(295,242),2,(0,0,0),-1)# right eye
e1=cv2.circle(img13,(310,242),2,(0,0,0),-1)# left eye
e1 = cv2.line(img13,(298,249),(307,249),(0,0,0),2)#mouth
e1 = cv2.line(img13,(289,265),(294,276),(155,226,254),4)#right hand 
e1 = cv2.line(img13,(318,265),(310,276),(155,226,254),4)#left hand
e1 = cv2.line(img13,(293,229),(312,229),(0,0,0),13)#top hair


#Indian  player
e1=cv2.rectangle(img13,(548,767),(555,784),(255,0,0),-1)#left leg
e1=cv2.rectangle(img13,(569,767),(545,742),(255,0,0),-1)#body
e1=cv2.rectangle(img13,(560,767),(567,784),(255,0,0),-1)#right leg
e1=cv2.circle(img13,(557,729),14,(155,226,254),-1)# head
e1 = cv2.line(img13,(570,748),(574,761),(155,226,254),3)#right hand 
e1 = cv2.line(img13,(544,747),(537,754),(155,226,254),3)#left hand
e1 = cv2.line(img13,(575,761),(580,778),(29,101,181),10)#bat
e1 = cv2.line(img13,(550,724),(562,724),(0,0,0),21)#top hair




cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # 12th point

# %%
img14=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img14,(0,0),(1200,800),(0,178,0),-1) #layout

e1 = cv2.line(img14,(600,800),(530,400),(128,178,194),10)# left line
e1 = cv2.line(img14,(610,800),(540,400),(128,178,194),10)# left line
e1 = cv2.line(img14,(620,800),(550,400),(128,178,194),10)# left line
e1 = cv2.line(img14,(630,800),(560,400),(128,178,194),10)# left line
e1 = cv2.line(img14,(640,800),(570,400),(128,178,194),10)# left line
e1 = cv2.line(img14,(650,800),(580,400),(128,178,194),10)# left line
e1 = cv2.line(img14,(660,800),(590,400),(128,178,194),10)# left line
e1 = cv2.line(img14,(670,800),(600,400),(128,178,194),10)# left line
e1 = cv2.line(img14,(680,800),(610,400),(128,178,194),10)# left line
e1 = cv2.line(img14,(690,800),(620,400),(128,178,194),10)# left line
e1 = cv2.line(img14,(700,800),(630,400),(128,178,194),10)# left line
e1 = cv2.line(img14,(710,800),(640,400),(128,178,194),10)# left line
e1 = cv2.line(img14,(720,800),(650,400),(128,178,194),10)# left line
e1 = cv2.line(img14,(730,800),(660,400),(128,178,194),10)# left line
e1 = cv2.line(img14,(740,800),(670,400),(128,178,194),10)# left line
e1 = cv2.line(img14,(750,800),(680,400),(128,178,194),10)# left line
e1 = cv2.line(img14,(760,800),(690,400),(128,178,194),10)# left line

e1 = cv2.line(img14,(450,800),(530,400),(128,178,194),10)#right line
e1 = cv2.line(img14,(460,800),(540,400),(128,178,194),10)#right line
e1 = cv2.line(img14,(470,800),(550,400),(128,178,194),10)#right line
e1 = cv2.line(img14,(480,800),(560,400),(128,178,194),10)#right line
e1 = cv2.line(img14,(490,800),(570,400),(128,178,194),10)#right line
e1 = cv2.line(img14,(500,800),(580,400),(128,178,194),10)#right line
e1 = cv2.line(img14,(510,800),(590,400),(128,178,194),10)#right line
e1 = cv2.line(img14,(520,800),(600,400),(128,178,194),10)#right line
e1 = cv2.line(img14,(530,800),(610,400),(128,178,194),10)#right line
e1 = cv2.line(img14,(540,800),(620,400),(128,178,194),10)#right line
e1 = cv2.line(img14,(550,800),(630,400),(128,178,194),10)#right line
e1 = cv2.line(img14,(560,800),(640,400),(128,178,194),10)#right line
e1 = cv2.line(img14,(570,800),(650,400),(128,178,194),10)#right line
e1 = cv2.line(img14,(580,800),(660,400),(128,178,194),10)#right line
e1 = cv2.line(img14,(590,800),(670,400),(128,178,194),10)#right line

e1 = cv2.line(img14,(760,800),(690,400),(255,255,255),2)# left line
e1 = cv2.line(img14,(450,800),(530,400),(255,255,255),2)#right line
e1 = cv2.line(img14,(690,400),(530,400),(255,255,255),2)# middle line
e1 = cv2.line(img14,(600,1200),(600,760),(0,0,0),5)   #middle wicket   #buttom side
e1 = cv2.line(img14,(590,1200),(590,760),(0,0,0),5)   #left wicket
e1 = cv2.line(img14,(610,1200),(610,760),(0,0,0),5)   #right wicket
e1 = cv2.line(img14,(590,760),(610,760),(0,0,0),5)    #top wicket
e1 = cv2.line(img14,(430,750),(780,750),(255,255,255),2)#buttom boundary line 
e1 = cv2.line(img14,(500,750),(490,850),(255,255,255),2)#boundary left line
e1 = cv2.line(img14,(710,750),(720,850),(255,255,255),2)#boundary right line

e1 = cv2.line(img14,(760,800),(690,400),(255,255,255),2)# left line
e1 = cv2.line(img14,(450,800),(530,400),(255,255,255),2)#right line
e1 = cv2.line(img14,(690,400),(530,400),(255,255,255),2)# middle line
e1 = cv2.line(img14,(620,400),(620,360),(0,0,0),5)   #right wicket     #top side
e1 = cv2.line(img14,(600,400),(600,360),(0,0,0),5)   #lift wicket
e1 = cv2.line(img14,(610,400),(610,360),(0,0,0),5)   #middle wicket
e1 = cv2.line(img14,(600,360),(620,360),(0,0,0),5)    #top wicket
e1 = cv2.line(img14,(490,440),(720,440),(255,255,255),2) # top boundary line
e1 = cv2.line(img14,(555,440),(560,400),(255,255,255),2)#boundary left line
e1 = cv2.line(img14,(655,440),(655,400),(255,255,255),2)#boundary right line




#indian player

e1=cv2.rectangle(img14,(642,402),(648,440),(255,0,0),-1)#right leg
e1=cv2.rectangle(img14,(629,352),(650,402),(255,0,0),-1)#body
e1=cv2.rectangle(img14,(631,402),(637,440),(255,0,0),-1)#left leg
e1=cv2.circle(img14,(640,339),13,(155,226,254),-1)# head
e1=cv2.circle(img14,(632,340),2,(0,0,0),-1)# right eye
e1=cv2.circle(img14,(637,340),2,(0,0,0),-1)# left eye
e1=cv2.circle(img14,(635,346),2,(0,0,0),-1)#mouth
e1 = cv2.line(img14,(632,364),(620,400),(155,226,254),3)#right hand 
e1 = cv2.line(img14,(641,373),(623,400),(155,226,254),3)#left hand
e1 = cv2.line(img14,(621,400),(603,422),(29,101,181),10)#bat
e1 = cv2.line(img14,(632,329),(647,329),(0,0,0),10)#top hair
e1 = cv2.line(img14,(647,336),(646,348),(0,0,0),10)#left hair


# pakistan wicket player

e1=cv2.rectangle(img14,(592,362),(586,395),(26,64,0),-1)#right leg
e1=cv2.rectangle(img14,(570,351),(593,379),(26,64,0),-1)#body
e1=cv2.rectangle(img14,(572,362),(579,395),(26,64,0),-1)#left leg
e1=cv2.circle(img14,(581,336),14,(155,226,254),-1)# head
e1=cv2.circle(img14,(576,338),2,(0,0,0),-1)# right eye
e1=cv2.circle(img14,(587,338),2,(0,0,0),-1)# left eye
e1 = cv2.line(img14,(578,345),(585,345),(0,0,0),2)#mouth
e1 = cv2.line(img14,(572,360),(582,369),(155,226,254),4)#right hand 
e1 = cv2.line(img14,(591,360),(582,369),(155,226,254),4)#left hand
e1 = cv2.line(img14,(581,368),(582,369),(255,255,255),10)#glove
e1 = cv2.line(img14,(571,326),(588,326),(0,0,0),10)#top hair



#bowler


e1=cv2.rectangle(img14,(626,719),(652,749),(26,64,0),-1)#body
e1=cv2.circle(img14,(638,705),14,(155,226,254),-1)# head
e1=cv2.circle(img14,(603,422),6,(255,255,255),-1)# right ball
e1 = cv2.line(img14,(653,724),(663,736),(155,226,254),5)#right hand 
e1 = cv2.line(img14,(625,725),(620,732),(155,226,254),5)#left hand
e1 = cv2.line(img14,(632,702),(643,702),(0,0,0),20)#top hair
e1=cv2.rectangle(img14,(631,749),(637,762),(26,64,0),-1)#left leg
e1=cv2.rectangle(img14,(642,749),(648,762),(26,64,0),-1)#right leg



# pakistan player
e1=cv2.rectangle(img14,(292,293),(300,322),(26,64,0),-1)#right leg
e1=cv2.rectangle(img14,(288,253),(320,298),(26,64,0),-1)#body
e1=cv2.rectangle(img14,(309,293),(317,322),(26,64,0),-1)#left leg
e1=cv2.circle(img14,(303,239),16,(155,226,254),-1)# head
e1=cv2.circle(img14,(295,242),2,(0,0,0),-1)# right eye
e1=cv2.circle(img14,(310,242),2,(0,0,0),-1)# left eye
e1 = cv2.line(img14,(298,249),(307,249),(0,0,0),2)#mouth
e1 = cv2.line(img14,(289,265),(294,276),(155,226,254),4)#right hand 
e1 = cv2.line(img14,(318,265),(310,276),(155,226,254),4)#left hand
e1 = cv2.line(img14,(293,229),(312,229),(0,0,0),13)#top hair


#Indian  player
e1=cv2.rectangle(img14,(548,767),(555,784),(255,0,0),-1)#left leg
e1=cv2.rectangle(img14,(569,767),(545,742),(255,0,0),-1)#body
e1=cv2.rectangle(img14,(560,767),(567,784),(255,0,0),-1)#right leg
e1=cv2.circle(img14,(557,729),14,(155,226,254),-1)# head
e1 = cv2.line(img14,(570,748),(574,761),(155,226,254),3)#right hand 
e1 = cv2.line(img14,(544,747),(537,754),(155,226,254),3)#left hand
e1 = cv2.line(img14,(575,761),(580,778),(29,101,181),10)#bat
e1 = cv2.line(img14,(550,724),(562,724),(0,0,0),21)#top hair




cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # 13th point

# %%
img15=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img1,(0,0),(1200,800),(128,178,194),-1) #layout
e1 = cv2.line(img15,(500,400),(700,400),(140,160,180),1050) #dugout
e1 = cv2.line(img15,(500,400),(700,400),(106,206,234),800) #ground
e1 = cv2.line(img15,(500,400),(700,400),(35,215,0),780) #extraSpace
e1 = cv2.line(img15,(500,400),(700,400),(255,255,255),750) #boundary
e1 = cv2.line(img15,(500,400),(700,400),(0,206,0),748) #playarea
e1 = cv2.rectangle(img15,(630,300),(570,500),(128,178,194),-1) #pitch
e1 = cv2.rectangle(img15,(630,300),(570,500),(255,255,255),1) #pitchhighlighter
e1 = cv2.line(img15,(580,300),(580,315),(255,255,255),1) #leftwideline
e1 = cv2.line(img15,(620,300),(620,315),(255,255,255),1) #rightwideline
e1 = cv2.line(img15,(580,500),(580,485),(255,255,255),1) #leftwideline_non_stricker
e1 = cv2.line(img15,(620,500),(620,485),(255,255,255),1) #rightwideline_non_stricker
e1 = cv2.line(img15,(565,315),(635,315),(255,255,255),1) #crease
e1 = cv2.line(img15,(565,485),(635,485),(255,255,255),1) #crease_non_stricker
e1 = cv2.line(img15,(597,300),(603,300),(0,0,0),1) #wickets
e1 = cv2.line(img15,(597,500),(603,500),(0,0,0),1) #wickets_non_stricker
e1 = cv2.circle(img15,(600,400),270,(255,255,255),1) #insidecircle

e1 = cv2.circle(img15,(600,280),5,(32,100,1),-1) #wicketkeeper
e1 = cv2.circle(img15,(925,120),5,(32,100,1),-1) #fineleg
e1 = cv2.circle(img15,(580,270),5,(32,100,1),-1) #slip
e1 = cv2.circle(img15,(490,720),5,(32,100,1),-1) #longoff
e1 = cv2.circle(img15,(720,530),5,(32,100,1),-1) #midwicket
e1 = cv2.circle(img15,(420,500),5,(32,100,1),-1) #cover
e1 = cv2.circle(img15,(150,380),5,(32,100,1),-1) #deepcoverpoint
e1 = cv2.circle(img15,(700,340),5,(32,100,1),-1) #short
e1 = cv2.circle(img15,(950,480),5,(32,100,1),-1) #deepsweep
e1 = cv2.circle(img15,(500,300),5,(32,100,1),-1) #gully
e1 = cv2.circle(img15,(610,490),5,(32,100,1),-1) #bowler

e1 = cv2.circle(img15,(590,490),5,(255,30,0),-1) #batsmen
e1 = cv2.circle(img15,(610,310),5,(255,30,0),-1) #bowler

e1 = cv2.circle(img15,(600,520),5,(0,0,255),-1) #umpire
e1 = cv2.circle(img15,(750,315),5,(0,0,255),-1) #umpire2


e1=cv2.circle(img15,(600,315),4,(255,255,255),-1) #ball




cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # 14th point

# %%
img16=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img16,(0,0),(1200,800),(128,178,194),-1) #layout
e1 = cv2.line(img16,(500,400),(700,400),(140,160,180),1050) #dugout
e1 = cv2.line(img16,(500,400),(700,400),(106,206,234),800) #ground
e1 = cv2.line(img16,(500,400),(700,400),(35,215,0),780) #extraSpace
e1 = cv2.line(img16,(500,400),(700,400),(255,255,255),750) #boundary
e1 = cv2.line(img16,(500,400),(700,400),(0,206,0),748) #playarea
e1 = cv2.rectangle(img16,(630,300),(570,500),(128,178,194),-1) #pitch
e1 = cv2.rectangle(img16,(630,300),(570,500),(255,255,255),1) #pitchhighlighter
e1 = cv2.line(img16,(580,300),(580,315),(255,255,255),1) #leftwideline
e1 = cv2.line(img16,(620,300),(620,315),(255,255,255),1) #rightwideline
e1 = cv2.line(img16,(580,500),(580,485),(255,255,255),1) #leftwideline_non_stricker
e1 = cv2.line(img16,(620,500),(620,485),(255,255,255),1) #rightwideline_non_stricker
e1 = cv2.line(img16,(565,315),(635,315),(255,255,255),1) #crease
e1 = cv2.line(img16,(565,485),(635,485),(255,255,255),1) #crease_non_stricker
e1 = cv2.line(img16,(597,300),(603,300),(0,0,0),1) #wickets
e1 = cv2.line(img16,(597,500),(603,500),(0,0,0),1) #wickets_non_stricker
e1 = cv2.circle(img16,(600,400),270,(255,255,255),1) #insidecircle

e1 = cv2.circle(img16,(600,280),5,(32,100,1),-1) #wicketkeeper
e1 = cv2.circle(img16,(925,120),5,(32,100,1),-1) #fineleg
e1 = cv2.circle(img16,(580,270),5,(32,100,1),-1) #slip
e1 = cv2.circle(img16,(490,720),5,(32,100,1),-1) #longoff
e1 = cv2.circle(img16,(720,530),5,(32,100,1),-1) #midwicket
e1 = cv2.circle(img16,(420,500),5,(32,100,1),-1) #cover
e1 = cv2.circle(img16,(150,380),5,(32,100,1),-1) #deepcoverpoint
e1 = cv2.circle(img16,(700,340),5,(32,100,1),-1) #short
e1 = cv2.circle(img16,(950,480),5,(32,100,1),-1) #deepsweep
e1 = cv2.circle(img16,(500,300),5,(32,100,1),-1) #gully
e1 = cv2.circle(img16,(610,490),5,(32,100,1),-1) #bowler

e1 = cv2.circle(img16,(590,490),5,(255,30,0),-1) #batsmen
e1 = cv2.circle(img16,(610,310),5,(255,30,0),-1) #bowler

e1 = cv2.circle(img16,(600,520),5,(0,0,255),-1) #umpire
e1 = cv2.circle(img16,(750,315),5,(0,0,255),-1) #umpire2


e1=cv2.circle(img16,(650,318),4,(255,255,255),-1) #ball




cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # 15th point

# %%
img17=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img17,(0,0),(1200,800),(128,178,194),-1) #layout
e1 = cv2.line(img17,(500,400),(700,400),(140,160,180),1050) #dugout
e1 = cv2.line(img17,(500,400),(700,400),(106,206,234),800) #ground
e1 = cv2.line(img17,(500,400),(700,400),(35,215,0),780) #extraSpace
e1 = cv2.line(img17,(500,400),(700,400),(255,255,255),750) #boundary
e1 = cv2.line(img17,(500,400),(700,400),(0,206,0),748) #playarea
e1 = cv2.rectangle(img17,(630,300),(570,500),(128,178,194),-1) #pitch
e1 = cv2.rectangle(img17,(630,300),(570,500),(255,255,255),1) #pitchhighlighter
e1 = cv2.line(img17,(580,300),(580,315),(255,255,255),1) #leftwideline
e1 = cv2.line(img17,(620,300),(620,315),(255,255,255),1) #rightwideline
e1 = cv2.line(img17,(580,500),(580,485),(255,255,255),1) #leftwideline_non_stricker
e1 = cv2.line(img17,(620,500),(620,485),(255,255,255),1) #rightwideline_non_stricker
e1 = cv2.line(img17,(565,315),(635,315),(255,255,255),1) #crease
e1 = cv2.line(img17,(565,485),(635,485),(255,255,255),1) #crease_non_stricker
e1 = cv2.line(img17,(597,300),(603,300),(0,0,0),1) #wickets
e1 = cv2.line(img17,(597,500),(603,500),(0,0,0),1) #wickets_non_stricker
e1 = cv2.circle(img17,(600,400),270,(255,255,255),1) #insidecircle

e1 = cv2.circle(img17,(600,280),5,(32,100,1),-1) #wicketkeeper
e1 = cv2.circle(img17,(925,120),5,(32,100,1),-1) #fineleg
e1 = cv2.circle(img17,(580,270),5,(32,100,1),-1) #slip
e1 = cv2.circle(img17,(490,720),5,(32,100,1),-1) #longoff
e1 = cv2.circle(img17,(720,530),5,(32,100,1),-1) #midwicket
e1 = cv2.circle(img17,(420,500),5,(32,100,1),-1) #cover
e1 = cv2.circle(img17,(150,380),5,(32,100,1),-1) #deepcoverpoint
e1 = cv2.circle(img17,(700,340),5,(32,100,1),-1) #short
e1 = cv2.circle(img17,(950,480),5,(32,100,1),-1) #deepsweep
e1 = cv2.circle(img17,(500,300),5,(32,100,1),-1) #gully
e1 = cv2.circle(img17,(610,490),5,(32,100,1),-1) #bowler

e1 = cv2.circle(img17,(590,490),5,(255,30,0),-1) #batsmen
e1 = cv2.circle(img17,(610,310),5,(255,30,0),-1) #bowler

e1 = cv2.circle(img17,(600,520),5,(0,0,255),-1) #umpire
e1 = cv2.circle(img17,(750,315),5,(0,0,255),-1) #umpire2


e1=cv2.circle(img17,(700,321),4,(255,255,255),-1) #ball




cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # 16th point

# %%
img18=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img18,(0,0),(1200,800),(128,178,194),-1) #layout
e1 = cv2.line(img18,(500,400),(700,400),(140,160,180),1050) #dugout
e1 = cv2.line(img18,(500,400),(700,400),(106,206,234),800) #ground
e1 = cv2.line(img18,(500,400),(700,400),(35,215,0),780) #extraSpace
e1 = cv2.line(img18,(500,400),(700,400),(255,255,255),750) #boundary
e1 = cv2.line(img18,(500,400),(700,400),(0,206,0),748) #playarea
e1 = cv2.rectangle(img18,(630,300),(570,500),(128,178,194),-1) #pitch
e1 = cv2.rectangle(img18,(630,300),(570,500),(255,255,255),1) #pitchhighlighter
e1 = cv2.line(img18,(580,300),(580,315),(255,255,255),1) #leftwideline
e1 = cv2.line(img18,(620,300),(620,315),(255,255,255),1) #rightwideline
e1 = cv2.line(img18,(580,500),(580,485),(255,255,255),1) #leftwideline_non_stricker
e1 = cv2.line(img18,(620,500),(620,485),(255,255,255),1) #rightwideline_non_stricker
e1 = cv2.line(img18,(565,315),(635,315),(255,255,255),1) #crease
e1 = cv2.line(img18,(565,485),(635,485),(255,255,255),1) #crease_non_stricker
e1 = cv2.line(img18,(597,300),(603,300),(0,0,0),1) #wickets
e1 = cv2.line(img18,(597,500),(603,500),(0,0,0),1) #wickets_non_stricker
e1 = cv2.circle(img18,(600,400),270,(255,255,255),1) #insidecircle

e1 = cv2.circle(img18,(600,280),5,(32,100,1),-1) #wicketkeeper
e1 = cv2.circle(img18,(925,120),5,(32,100,1),-1) #fineleg
e1 = cv2.circle(img18,(580,270),5,(32,100,1),-1) #slip
e1 = cv2.circle(img18,(490,720),5,(32,100,1),-1) #longoff
e1 = cv2.circle(img18,(720,530),5,(32,100,1),-1) #midwicket
e1 = cv2.circle(img18,(420,500),5,(32,100,1),-1) #cover
e1 = cv2.circle(img18,(150,380),5,(32,100,1),-1) #deepcoverpoint
e1 = cv2.circle(img18,(700,340),5,(32,100,1),-1) #short
e1 = cv2.circle(img18,(950,480),5,(32,100,1),-1) #deepsweep
e1 = cv2.circle(img18,(500,300),5,(32,100,1),-1) #gully
e1 = cv2.circle(img18,(610,490),5,(32,100,1),-1) #bowler

e1 = cv2.circle(img18,(590,490),5,(255,30,0),-1) #batsmen
e1 = cv2.circle(img18,(610,310),5,(255,30,0),-1) #bowler

e1 = cv2.circle(img18,(600,520),5,(0,0,255),-1) #umpire
e1 = cv2.circle(img18,(750,315),5,(0,0,255),-1) #umpire2


e1=cv2.circle(img18,(750,324),4,(255,255,255),-1) #ball




cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # 17th point

# %%
img19=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img19,(0,0),(1200,800),(128,178,194),-1) #layout
e1 = cv2.line(img19,(500,400),(700,400),(140,160,180),1050) #dugout
e1 = cv2.line(img19,(500,400),(700,400),(106,206,234),800) #ground
e1 = cv2.line(img19,(500,400),(700,400),(35,215,0),780) #extraSpace
e1 = cv2.line(img19,(500,400),(700,400),(255,255,255),750) #boundary
e1 = cv2.line(img19,(500,400),(700,400),(0,206,0),748) #playarea
e1 = cv2.rectangle(img19,(630,300),(570,500),(128,178,194),-1) #pitch
e1 = cv2.rectangle(img19,(630,300),(570,500),(255,255,255),1) #pitchhighlighter
e1 = cv2.line(img19,(580,300),(580,315),(255,255,255),1) #leftwideline
e1 = cv2.line(img19,(620,300),(620,315),(255,255,255),1) #rightwideline
e1 = cv2.line(img19,(580,500),(580,485),(255,255,255),1) #leftwideline_non_stricker
e1 = cv2.line(img19,(620,500),(620,485),(255,255,255),1) #rightwideline_non_stricker
e1 = cv2.line(img19,(565,315),(635,315),(255,255,255),1) #crease
e1 = cv2.line(img19,(565,485),(635,485),(255,255,255),1) #crease_non_stricker
e1 = cv2.line(img19,(597,300),(603,300),(0,0,0),1) #wickets
e1 = cv2.line(img19,(597,500),(603,500),(0,0,0),1) #wickets_non_stricker
e1 = cv2.circle(img19,(600,400),270,(255,255,255),1) #insidecircle

e1 = cv2.circle(img19,(600,280),5,(32,100,1),-1) #wicketkeeper
e1 = cv2.circle(img19,(925,120),5,(32,100,1),-1) #fineleg
e1 = cv2.circle(img19,(580,270),5,(32,100,1),-1) #slip
e1 = cv2.circle(img19,(490,720),5,(32,100,1),-1) #longoff
e1 = cv2.circle(img19,(720,530),5,(32,100,1),-1) #midwicket
e1 = cv2.circle(img19,(420,500),5,(32,100,1),-1) #cover
e1 = cv2.circle(img19,(150,380),5,(32,100,1),-1) #deepcoverpoint
e1 = cv2.circle(img19,(700,340),5,(32,100,1),-1) #short
e1 = cv2.circle(img19,(950,480),5,(32,100,1),-1) #deepsweep
e1 = cv2.circle(img19,(500,300),5,(32,100,1),-1) #gully
e1 = cv2.circle(img19,(610,490),5,(32,100,1),-1) #bowler

e1 = cv2.circle(img19,(590,490),5,(255,30,0),-1) #batsmen
e1 = cv2.circle(img19,(610,310),5,(255,30,0),-1) #bowler

e1 = cv2.circle(img19,(600,520),5,(0,0,255),-1) #umpire
e1 = cv2.circle(img19,(750,315),5,(0,0,255),-1) #umpire2


e1=cv2.circle(img19,(800,327),4,(255,255,255),-1) #ball




cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # 18th point

# %%
img20=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img20,(0,0),(1200,800),(128,178,194),-1) #layout
e1 = cv2.line(img20,(500,400),(700,400),(140,160,180),1050) #dugout
e1 = cv2.line(img20,(500,400),(700,400),(106,206,234),800) #ground
e1 = cv2.line(img20,(500,400),(700,400),(35,215,0),780) #extraSpace
e1 = cv2.line(img20,(500,400),(700,400),(255,255,255),750) #boundary
e1 = cv2.line(img20,(500,400),(700,400),(0,206,0),748) #playarea
e1 = cv2.rectangle(img20,(630,300),(570,500),(128,178,194),-1) #pitch
e1 = cv2.rectangle(img20,(630,300),(570,500),(255,255,255),1) #pitchhighlighter
e1 = cv2.line(img20,(580,300),(580,315),(255,255,255),1) #leftwideline
e1 = cv2.line(img20,(620,300),(620,315),(255,255,255),1) #rightwideline
e1 = cv2.line(img20,(580,500),(580,485),(255,255,255),1) #leftwideline_non_stricker
e1 = cv2.line(img20,(620,500),(620,485),(255,255,255),1) #rightwideline_non_stricker
e1 = cv2.line(img20,(565,315),(635,315),(255,255,255),1) #crease
e1 = cv2.line(img20,(565,485),(635,485),(255,255,255),1) #crease_non_stricker
e1 = cv2.line(img20,(597,300),(603,300),(0,0,0),1) #wickets
e1 = cv2.line(img20,(597,500),(603,500),(0,0,0),1) #wickets_non_stricker
e1 = cv2.circle(img20,(600,400),270,(255,255,255),1) #insidecircle

e1 = cv2.circle(img20,(600,280),5,(32,100,1),-1) #wicketkeeper
e1 = cv2.circle(img20,(925,120),5,(32,100,1),-1) #fineleg
e1 = cv2.circle(img20,(580,270),5,(32,100,1),-1) #slip
e1 = cv2.circle(img20,(490,720),5,(32,100,1),-1) #longoff
e1 = cv2.circle(img20,(720,530),5,(32,100,1),-1) #midwicket
e1 = cv2.circle(img20,(420,500),5,(32,100,1),-1) #cover
e1 = cv2.circle(img20,(150,380),5,(32,100,1),-1) #deepcoverpoint
e1 = cv2.circle(img20,(700,340),5,(32,100,1),-1) #short
e1 = cv2.circle(img20,(950,480),5,(32,100,1),-1) #deepsweep
e1 = cv2.circle(img20,(500,300),5,(32,100,1),-1) #gully
e1 = cv2.circle(img20,(610,490),5,(32,100,1),-1) #bowler

e1 = cv2.circle(img20,(590,490),5,(255,30,0),-1) #batsmen
e1 = cv2.circle(img20,(610,310),5,(255,30,0),-1) #bowler

e1 = cv2.circle(img20,(600,520),5,(0,0,255),-1) #umpire
e1 = cv2.circle(img20,(750,315),5,(0,0,255),-1) #umpire2


e1=cv2.circle(img20,(850,330),4,(255,255,255),-1) #ball




cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # 19th point

# %%
img21=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img21,(0,0),(1200,800),(128,178,194),-1) #layout
e1 = cv2.line(img21,(500,400),(700,400),(140,160,180),1050) #dugout
e1 = cv2.line(img21,(500,400),(700,400),(106,206,234),800) #ground
e1 = cv2.line(img21,(500,400),(700,400),(35,215,0),780) #extraSpace
e1 = cv2.line(img21,(500,400),(700,400),(255,255,255),750) #boundary
e1 = cv2.line(img21,(500,400),(700,400),(0,206,0),748) #playarea
e1 = cv2.rectangle(img21,(630,300),(570,500),(128,178,194),-1) #pitch
e1 = cv2.rectangle(img21,(630,300),(570,500),(255,255,255),1) #pitchhighlighter
e1 = cv2.line(img21,(580,300),(580,315),(255,255,255),1) #leftwideline
e1 = cv2.line(img21,(620,300),(620,315),(255,255,255),1) #rightwideline
e1 = cv2.line(img21,(580,500),(580,485),(255,255,255),1) #leftwideline_non_stricker
e1 = cv2.line(img21,(620,500),(620,485),(255,255,255),1) #rightwideline_non_stricker
e1 = cv2.line(img21,(565,315),(635,315),(255,255,255),1) #crease
e1 = cv2.line(img21,(565,485),(635,485),(255,255,255),1) #crease_non_stricker
e1 = cv2.line(img21,(597,300),(603,300),(0,0,0),1) #wickets
e1 = cv2.line(img21,(597,500),(603,500),(0,0,0),1) #wickets_non_stricker
e1 = cv2.circle(img21,(600,400),270,(255,255,255),1) #insidecircle

e1 = cv2.circle(img21,(600,280),5,(32,100,1),-1) #wicketkeeper
e1 = cv2.circle(img21,(925,120),5,(32,100,1),-1) #fineleg
e1 = cv2.circle(img21,(580,270),5,(32,100,1),-1) #slip
e1 = cv2.circle(img21,(490,720),5,(32,100,1),-1) #longoff
e1 = cv2.circle(img21,(720,530),5,(32,100,1),-1) #midwicket
e1 = cv2.circle(img21,(420,500),5,(32,100,1),-1) #cover
e1 = cv2.circle(img21,(150,380),5,(32,100,1),-1) #deepcoverpoint
e1 = cv2.circle(img21,(700,340),5,(32,100,1),-1) #short
e1 = cv2.circle(img21,(950,480),5,(32,100,1),-1) #deepsweep
e1 = cv2.circle(img21,(500,300),5,(32,100,1),-1) #gully
e1 = cv2.circle(img21,(610,490),5,(32,100,1),-1) #bowler

e1 = cv2.circle(img21,(590,490),5,(255,30,0),-1) #batsmen
e1 = cv2.circle(img21,(610,310),5,(255,30,0),-1) #bowler

e1 = cv2.circle(img21,(600,520),5,(0,0,255),-1) #umpire
e1 = cv2.circle(img21,(750,315),5,(0,0,255),-1) #umpire2


e1=cv2.circle(img21,(900,333),4,(255,255,255),-1) #ball


cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # 20th point

# %%
img22=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img22,(0,0),(1200,800),(128,178,194),-1) #layout
e1 = cv2.line(img22,(500,400),(700,400),(140,160,180),1050) #dugout
e1 = cv2.line(img22,(500,400),(700,400),(106,206,234),800) #ground
e1 = cv2.line(img22,(500,400),(700,400),(35,215,0),780) #extraSpace
e1 = cv2.line(img22,(500,400),(700,400),(255,255,255),750) #boundary
e1 = cv2.line(img22,(500,400),(700,400),(0,206,0),748) #playarea
e1 = cv2.rectangle(img22,(630,300),(570,500),(128,178,194),-1) #pitch
e1 = cv2.rectangle(img22,(630,300),(570,500),(255,255,255),1) #pitchhighlighter
e1 = cv2.line(img22,(580,300),(580,315),(255,255,255),1) #leftwideline
e1 = cv2.line(img22,(620,300),(620,315),(255,255,255),1) #rightwideline
e1 = cv2.line(img22,(580,500),(580,485),(255,255,255),1) #leftwideline_non_stricker
e1 = cv2.line(img22,(620,500),(620,485),(255,255,255),1) #rightwideline_non_stricker
e1 = cv2.line(img22,(565,315),(635,315),(255,255,255),1) #crease
e1 = cv2.line(img22,(565,485),(635,485),(255,255,255),1) #crease_non_stricker
e1 = cv2.line(img22,(597,300),(603,300),(0,0,0),1) #wickets
e1 = cv2.line(img22,(597,500),(603,500),(0,0,0),1) #wickets_non_stricker
e1 = cv2.circle(img22,(600,400),270,(255,255,255),1) #insidecircle

e1 = cv2.circle(img22,(600,280),5,(32,100,1),-1) #wicketkeeper
e1 = cv2.circle(img22,(925,120),5,(32,100,1),-1) #fineleg
e1 = cv2.circle(img22,(580,270),5,(32,100,1),-1) #slip
e1 = cv2.circle(img22,(490,720),5,(32,100,1),-1) #longoff
e1 = cv2.circle(img22,(720,530),5,(32,100,1),-1) #midwicket
e1 = cv2.circle(img22,(420,500),5,(32,100,1),-1) #cover
e1 = cv2.circle(img22,(150,380),5,(32,100,1),-1) #deepcoverpoint
e1 = cv2.circle(img22,(700,340),5,(32,100,1),-1) #short
e1 = cv2.circle(img22,(950,480),5,(32,100,1),-1) #deepsweep
e1 = cv2.circle(img22,(500,300),5,(32,100,1),-1) #gully
e1 = cv2.circle(img22,(610,490),5,(32,100,1),-1) #bowler

e1 = cv2.circle(img22,(590,490),5,(255,30,0),-1) #batsmen
e1 = cv2.circle(img22,(610,310),5,(255,30,0),-1) #bowler

e1 = cv2.circle(img22,(600,520),5,(0,0,255),-1) #umpire
e1 = cv2.circle(img22,(750,315),5,(0,0,255),-1) #umpire2


e1=cv2.circle(img22,(950,336),4,(255,255,255),-1) #ball




cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # 21 point

# %%
img23=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img23,(0,0),(1200,800),(128,178,194),-1) #layout
e1 = cv2.line(img23,(500,400),(700,400),(140,160,180),1050) #dugout
e1 = cv2.line(img23,(500,400),(700,400),(106,206,234),800) #ground
e1 = cv2.line(img23,(500,400),(700,400),(35,215,0),780) #extraSpace
e1 = cv2.line(img23,(500,400),(700,400),(255,255,255),750) #boundary
e1 = cv2.line(img23,(500,400),(700,400),(0,206,0),748) #playarea
e1 = cv2.rectangle(img23,(630,300),(570,500),(128,178,194),-1) #pitch
e1 = cv2.rectangle(img23,(630,300),(570,500),(255,255,255),1) #pitchhighlighter
e1 = cv2.line(img23,(580,300),(580,315),(255,255,255),1) #leftwideline
e1 = cv2.line(img23,(620,300),(620,315),(255,255,255),1) #rightwideline
e1 = cv2.line(img23,(580,500),(580,485),(255,255,255),1) #leftwideline_non_stricker
e1 = cv2.line(img23,(620,500),(620,485),(255,255,255),1) #rightwideline_non_stricker
e1 = cv2.line(img23,(565,315),(635,315),(255,255,255),1) #crease
e1 = cv2.line(img23,(565,485),(635,485),(255,255,255),1) #crease_non_stricker
e1 = cv2.line(img23,(597,300),(603,300),(0,0,0),1) #wickets
e1 = cv2.line(img23,(597,500),(603,500),(0,0,0),1) #wickets_non_stricker
e1 = cv2.circle(img23,(600,400),270,(255,255,255),1) #insidecircle

e1 = cv2.circle(img23,(600,280),5,(32,100,1),-1) #wicketkeeper
e1 = cv2.circle(img23,(925,120),5,(32,100,1),-1) #fineleg
e1 = cv2.circle(img23,(580,270),5,(32,100,1),-1) #slip
e1 = cv2.circle(img23,(490,720),5,(32,100,1),-1) #longoff
e1 = cv2.circle(img23,(720,530),5,(32,100,1),-1) #midwicket
e1 = cv2.circle(img23,(420,500),5,(32,100,1),-1) #cover
e1 = cv2.circle(img23,(150,380),5,(32,100,1),-1) #deepcoverpoint
e1 = cv2.circle(img23,(700,340),5,(32,100,1),-1) #short
e1 = cv2.circle(img23,(950,480),5,(32,100,1),-1) #deepsweep
e1 = cv2.circle(img23,(500,300),5,(32,100,1),-1) #gully
e1 = cv2.circle(img23,(610,490),5,(32,100,1),-1) #bowler

e1 = cv2.circle(img23,(590,490),5,(255,30,0),-1) #batsmen
e1 = cv2.circle(img23,(610,310),5,(255,30,0),-1) #bowler

e1 = cv2.circle(img23,(600,520),5,(0,0,255),-1) #umpire
e1 = cv2.circle(img23,(750,315),5,(0,0,255),-1) #umpire2


e1=cv2.circle(img23,(1000,339),4,(255,255,255),-1) #ball




cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # 22 point

# %%
img24=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img24,(0,0),(1200,800),(128,178,194),-1) #layout
e1 = cv2.line(img24,(500,400),(700,400),(140,160,180),1050) #dugout
e1 = cv2.line(img24,(500,400),(700,400),(106,206,234),800) #ground
e1 = cv2.line(img24,(500,400),(700,400),(35,215,0),780) #extraSpace
e1 = cv2.line(img24,(500,400),(700,400),(255,255,255),750) #boundary
e1 = cv2.line(img24,(500,400),(700,400),(0,206,0),748) #playarea
e1 = cv2.rectangle(img24,(630,300),(570,500),(128,178,194),-1) #pitch
e1 = cv2.rectangle(img24,(630,300),(570,500),(255,255,255),1) #pitchhighlighter
e1 = cv2.line(img24,(580,300),(580,315),(255,255,255),1) #leftwideline
e1 = cv2.line(img24,(620,300),(620,315),(255,255,255),1) #rightwideline
e1 = cv2.line(img24,(580,500),(580,485),(255,255,255),1) #leftwideline_non_stricker
e1 = cv2.line(img24,(620,500),(620,485),(255,255,255),1) #rightwideline_non_stricker
e1 = cv2.line(img24,(565,315),(635,315),(255,255,255),1) #crease
e1 = cv2.line(img24,(565,485),(635,485),(255,255,255),1) #crease_non_stricker
e1 = cv2.line(img24,(597,300),(603,300),(0,0,0),1) #wickets
e1 = cv2.line(img24,(597,500),(603,500),(0,0,0),1) #wickets_non_stricker
e1 = cv2.circle(img24,(600,400),270,(255,255,255),1) #insidecircle

e1 = cv2.circle(img24,(600,280),5,(32,100,1),-1) #wicketkeeper
e1 = cv2.circle(img24,(925,120),5,(32,100,1),-1) #fineleg
e1 = cv2.circle(img24,(580,270),5,(32,100,1),-1) #slip
e1 = cv2.circle(img24,(490,720),5,(32,100,1),-1) #longoff
e1 = cv2.circle(img24,(720,530),5,(32,100,1),-1) #midwicket
e1 = cv2.circle(img24,(420,500),5,(32,100,1),-1) #cover
e1 = cv2.circle(img24,(150,380),5,(32,100,1),-1) #deepcoverpoint
e1 = cv2.circle(img24,(700,340),5,(32,100,1),-1) #short
e1 = cv2.circle(img24,(950,480),5,(32,100,1),-1) #deepsweep
e1 = cv2.circle(img24,(500,300),5,(32,100,1),-1) #gully
e1 = cv2.circle(img24,(610,490),5,(32,100,1),-1) #bowler

e1 = cv2.circle(img24,(590,490),5,(255,30,0),-1) #batsmen
e1 = cv2.circle(img24,(610,310),5,(255,30,0),-1) #bowler

e1 = cv2.circle(img24,(600,520),5,(0,0,255),-1) #umpire
e1 = cv2.circle(img24,(750,315),5,(0,0,255),-1) #umpire2


e1=cv2.circle(img24,(1050,342),4,(255,255,255),-1) #ball




cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # 23 point

# %%
img25=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img25,(0,0),(1200,800),(128,178,194),-1) #layout
e1 = cv2.line(img25,(500,400),(700,400),(140,160,180),1050) #dugout
e1 = cv2.line(img25,(500,400),(700,400),(106,206,234),800) #ground
e1 = cv2.line(img25,(500,400),(700,400),(35,215,0),780) #extraSpace
e1 = cv2.line(img25,(500,400),(700,400),(255,255,255),750) #boundary
e1 = cv2.line(img25,(500,400),(700,400),(0,206,0),748) #playarea
e1 = cv2.rectangle(img25,(630,300),(570,500),(128,178,194),-1) #pitch
e1 = cv2.rectangle(img25,(630,300),(570,500),(255,255,255),1) #pitchhighlighter
e1 = cv2.line(img25,(580,300),(580,315),(255,255,255),1) #leftwideline
e1 = cv2.line(img25,(620,300),(620,315),(255,255,255),1) #rightwideline
e1 = cv2.line(img25,(580,500),(580,485),(255,255,255),1) #leftwideline_non_stricker
e1 = cv2.line(img25,(620,500),(620,485),(255,255,255),1) #rightwideline_non_stricker
e1 = cv2.line(img25,(565,315),(635,315),(255,255,255),1) #crease
e1 = cv2.line(img25,(565,485),(635,485),(255,255,255),1) #crease_non_stricker
e1 = cv2.line(img25,(597,300),(603,300),(0,0,0),1) #wickets
e1 = cv2.line(img25,(597,500),(603,500),(0,0,0),1) #wickets_non_stricker
e1 = cv2.circle(img25,(600,400),270,(255,255,255),1) #insidecircle

e1 = cv2.circle(img25,(600,280),5,(32,100,1),-1) #wicketkeeper
e1 = cv2.circle(img25,(925,120),5,(32,100,1),-1) #fineleg
e1 = cv2.circle(img25,(580,270),5,(32,100,1),-1) #slip
e1 = cv2.circle(img25,(490,720),5,(32,100,1),-1) #longoff
e1 = cv2.circle(img25,(720,530),5,(32,100,1),-1) #midwicket
e1 = cv2.circle(img25,(420,500),5,(32,100,1),-1) #cover
e1 = cv2.circle(img25,(150,380),5,(32,100,1),-1) #deepcoverpoint
e1 = cv2.circle(img25,(700,340),5,(32,100,1),-1) #short
e1 = cv2.circle(img25,(950,480),5,(32,100,1),-1) #deepsweep
e1 = cv2.circle(img25,(500,300),5,(32,100,1),-1) #gully
e1 = cv2.circle(img25,(610,490),5,(32,100,1),-1) #bowler

e1 = cv2.circle(img25,(590,490),5,(255,30,0),-1) #batsmen
e1 = cv2.circle(img25,(610,310),5,(255,30,0),-1) #bowler

e1 = cv2.circle(img25,(600,520),5,(0,0,255),-1) #umpire
e1 = cv2.circle(img25,(750,315),5,(0,0,255),-1) #umpire2


e1=cv2.circle(img25,(1100,345),4,(255,255,255),-1) #ball




cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # Six

# %%
img26=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img26,(0,0),(1200,800),(128,178,194),-1) #layout
e1 = cv2.line(img26,(500,400),(700,400),(140,160,180),1050) #dugout
e1 = cv2.line(img26,(500,400),(700,400),(106,206,234),800) #ground
e1 = cv2.line(img26,(500,400),(700,400),(35,215,0),780)
e1 = cv2.line(img26,(500,400),(700,400),(255,255,255),750) #boundary
e1 = cv2.line(img26,(500,400),(700,400),(0,206,0),748) #playarea
e1 = cv2.rectangle(img26,(630,300),(570,500),(128,178,194),-1) #pitch
e1 = cv2.rectangle(img26,(630,300),(570,500),(255,255,255),1) #
e1 = cv2.line(img26,(580,300),(580,315),(255,255,255),1)
e1 = cv2.line(img26,(620,300),(620,315),(255,255,255),1)
e1 = cv2.line(img26,(580,500),(580,485),(255,255,255),1)
e1 = cv2.line(img26,(620,500),(620,485),(255,255,255),1)
e1 = cv2.line(img26,(570,315),(630,315),(255,255,255),1)
e1 = cv2.line(img26,(570,485),(630,485),(255,255,255),1)
e1 = cv2.line(img26,(597,300),(603,300),(0,0,0),1)
e1 = cv2.line(img26,(597,500),(603,500),(0,0,0),1)
e1 = cv2.circle(img26,(600,400),270,(255,0,0),1)
e1 = cv2.circle(img26,(600,400),270,(0,0,0),1)
e1 = cv2.circle(img26,(600,400),270,(255,255,255),1)
e1 = cv2.circle(img26,(600,400),270,(255,255,255),1)
e1 = cv2.circle(img26,(600,400),270,(255,255,255),1)
e1 = cv2.circle(img26,(600,400),270,(255,255,255),1)
e1 = cv2.circle(img26,(600,400),270,(255,255,255),1)
e1 = cv2.circle(img26,(600,400),270,(255,255,255),1)
e1 = cv2.circle(img26,(600,400),270,(255,255,255),1)
e1 = cv2.circle(img26,(600,400),270,(255,255,255),1)
e1 = cv2.circle(img26,(600,400),270,(255,255,255),1)
e1 = cv2.circle(img26,(600,400),270,(255,255,255),1)



e1 = cv2.rectangle(img26,(10,340),(1190,440),(0,0,0),-1)
e1 = cv2.putText(img26,"SIX",(553,412),cv2.FONT_HERSHEY_SIMPLEX,2,(255,255,255),4)

cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # 24 point (4's start)

# %%
img27=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img27,(0,0),(1200,800),(128,178,194),-1) #layout
e1 = cv2.line(img27,(500,400),(700,400),(140,160,180),1050) #dugout
e1 = cv2.line(img27,(500,400),(700,400),(106,206,234),800) #ground
e1 = cv2.line(img27,(500,400),(700,400),(35,215,0),780)
e1 = cv2.line(img27,(500,400),(700,400),(255,255,255),750) #boundary
e1 = cv2.line(img27,(500,400),(700,400),(0,206,0),748) #playarea
e1 = cv2.rectangle(img27,(630,300),(570,500),(128,178,194),-1) #pitch
e1 = cv2.rectangle(img27,(630,300),(570,500),(255,255,255),1) #
e1 = cv2.line(img27,(580,300),(580,315),(255,255,255),1)
e1 = cv2.line(img27,(620,300),(620,315),(255,255,255),1)
e1 = cv2.line(img27,(580,500),(580,485),(255,255,255),1)
e1 = cv2.line(img27,(620,500),(620,485),(255,255,255),1)
e1 = cv2.line(img27,(570,315),(630,315),(255,255,255),1)
e1 = cv2.line(img27,(570,485),(630,485),(255,255,255),1)
e1 = cv2.line(img27,(597,300),(603,300),(0,0,0),1)
e1 = cv2.line(img27,(597,500),(603,500),(0,0,0),1)
e1 = cv2.circle(img27,(600,400),270,(255,0,0),1)
e1 = cv2.circle(img27,(600,400),270,(0,0,0),1)
e1 = cv2.circle(img27,(600,400),270,(255,255,255),1)
e1 = cv2.circle(img27,(600,400),270,(255,255,255),1)
e1 = cv2.circle(img27,(600,400),270,(255,255,255),1)
e1 = cv2.circle(img27,(600,400),270,(255,255,255),1)
e1 = cv2.circle(img27,(600,400),270,(255,255,255),1)
e1 = cv2.circle(img27,(600,400),270,(255,255,255),1)
e1 = cv2.circle(img27,(600,400),270,(255,255,255),1)
e1 = cv2.circle(img27,(600,400),270,(255,255,255),1)
e1 = cv2.circle(img27,(600,400),270,(255,255,255),1)
e1 = cv2.circle(img27,(600,400),270,(255,255,255),1)



e1 = cv2.rectangle(img27,(10,340),(1190,440),(0,0,0),-1)
e1 = cv2.putText(img27,"KOHLI'S - COVER DRIVE",(300,412),cv2.FONT_HERSHEY_SIMPLEX,2,(255,255,255),4)

cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # 25 POINT

# %%
img28=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img28,(0,0),(1200,800),(0,178,0),-1) #layout

e1 = cv2.line(img28,(600,800),(530,400),(128,178,194),10)# left line
e1 = cv2.line(img28,(610,800),(540,400),(128,178,194),10)# left line
e1 = cv2.line(img28,(620,800),(550,400),(128,178,194),10)# left line
e1 = cv2.line(img28,(630,800),(560,400),(128,178,194),10)# left line
e1 = cv2.line(img28,(640,800),(570,400),(128,178,194),10)# left line
e1 = cv2.line(img28,(650,800),(580,400),(128,178,194),10)# left line
e1 = cv2.line(img28,(660,800),(590,400),(128,178,194),10)# left line
e1 = cv2.line(img28,(670,800),(600,400),(128,178,194),10)# left line
e1 = cv2.line(img28,(680,800),(610,400),(128,178,194),10)# left line
e1 = cv2.line(img28,(690,800),(620,400),(128,178,194),10)# left line
e1 = cv2.line(img28,(700,800),(630,400),(128,178,194),10)# left line
e1 = cv2.line(img28,(710,800),(640,400),(128,178,194),10)# left line
e1 = cv2.line(img28,(720,800),(650,400),(128,178,194),10)# left line
e1 = cv2.line(img28,(730,800),(660,400),(128,178,194),10)# left line
e1 = cv2.line(img28,(740,800),(670,400),(128,178,194),10)# left line
e1 = cv2.line(img28,(750,800),(680,400),(128,178,194),10)# left line
e1 = cv2.line(img28,(760,800),(690,400),(128,178,194),10)# left line

e1 = cv2.line(img28,(450,800),(530,400),(128,178,194),10)#right line
e1 = cv2.line(img28,(460,800),(540,400),(128,178,194),10)#right line
e1 = cv2.line(img28,(470,800),(550,400),(128,178,194),10)#right line
e1 = cv2.line(img28,(480,800),(560,400),(128,178,194),10)#right line
e1 = cv2.line(img28,(490,800),(570,400),(128,178,194),10)#right line
e1 = cv2.line(img28,(500,800),(580,400),(128,178,194),10)#right line
e1 = cv2.line(img28,(510,800),(590,400),(128,178,194),10)#right line
e1 = cv2.line(img28,(520,800),(600,400),(128,178,194),10)#right line
e1 = cv2.line(img28,(530,800),(610,400),(128,178,194),10)#right line
e1 = cv2.line(img28,(540,800),(620,400),(128,178,194),10)#right line
e1 = cv2.line(img28,(550,800),(630,400),(128,178,194),10)#right line
e1 = cv2.line(img28,(560,800),(640,400),(128,178,194),10)#right line
e1 = cv2.line(img28,(570,800),(650,400),(128,178,194),10)#right line
e1 = cv2.line(img28,(580,800),(660,400),(128,178,194),10)#right line
e1 = cv2.line(img28,(590,800),(670,400),(128,178,194),10)#right line

e1 = cv2.line(img28,(760,800),(690,400),(255,255,255),2)# left line
e1 = cv2.line(img28,(450,800),(530,400),(255,255,255),2)#right line
e1 = cv2.line(img28,(690,400),(530,400),(255,255,255),2)# middle line
e1 = cv2.line(img28,(600,1200),(600,760),(0,0,0),5)   #middle wicket   #buttom side
e1 = cv2.line(img28,(590,1200),(590,760),(0,0,0),5)   #left wicket
e1 = cv2.line(img28,(610,1200),(610,760),(0,0,0),5)   #right wicket
e1 = cv2.line(img28,(590,760),(610,760),(0,0,0),5)    #top wicket
e1 = cv2.line(img28,(430,750),(780,750),(255,255,255),2)#buttom boundary line 
e1 = cv2.line(img28,(500,750),(490,850),(255,255,255),2)#boundary left line
e1 = cv2.line(img28,(710,750),(720,850),(255,255,255),2)#boundary right line2
e1 = cv2.line(img28,(760,800),(690,400),(255,255,255),2)# left line
e1 = cv2.line(img28,(450,800),(530,400),(255,255,255),2)#right line
e1 = cv2.line(img28,(690,400),(530,400),(255,255,255),2)# middle line
e1 = cv2.line(img28,(620,400),(620,360),(0,0,0),5)   #right wicket     #top side
e1 = cv2.line(img28,(600,400),(600,360),(0,0,0),5)   #lift wicket
e1 = cv2.line(img28,(610,400),(610,360),(0,0,0),5)   #middle wicket
e1 = cv2.line(img28,(600,360),(620,360),(0,0,0),5)    #top wicket
e1 = cv2.line(img28,(490,440),(720,440),(255,255,255),2) # top boundary line
e1 = cv2.line(img28,(555,440),(560,400),(255,255,255),2)#boundary left line
e1 = cv2.line(img28,(655,440),(655,400),(255,255,255),2)#boundary right line




#indian player

e1=cv2.rectangle(img28,(642,402),(648,440),(255,0,0),-1)#right leg
e1=cv2.rectangle(img28,(629,352),(650,402),(255,0,0),-1)#body
e1=cv2.rectangle(img28,(631,402),(637,440),(255,0,0),-1)#left leg
e1=cv2.circle(img28,(640,339),13,(155,226,254),-1)# head
e1=cv2.circle(img28,(632,340),2,(0,0,0),-1)# right eye
e1=cv2.circle(img28,(637,340),2,(0,0,0),-1)# left eye
e1=cv2.circle(img28,(635,346),2,(0,0,0),-1)#mouth
e1 = cv2.line(img28,(632,364),(620,400),(155,226,254),3)#right hand 
e1 = cv2.line(img28,(641,373),(623,400),(155,226,254),3)#left hand
e1 = cv2.line(img28,(621,400),(603,435),(29,101,181),10)#bat
e1 = cv2.line(img28,(632,329),(647,329),(0,0,0),10)#top hair
e1 = cv2.line(img28,(647,336),(646,348),(0,0,0),10)#left hair


# pakistan wicket player

e1=cv2.rectangle(img28,(592,362),(586,395),(26,64,0),-1)#right leg
e1=cv2.rectangle(img28,(570,351),(593,379),(26,64,0),-1)#body
e1=cv2.rectangle(img28,(572,362),(579,395),(26,64,0),-1)#left leg
e1=cv2.circle(img28,(581,336),14,(155,226,254),-1)# head
e1=cv2.circle(img28,(576,338),2,(0,0,0),-1)# right eye
e1=cv2.circle(img28,(587,338),2,(0,0,0),-1)# left eye
e1 = cv2.line(img28,(578,345),(585,345),(0,0,0),2)#mouth
e1 = cv2.line(img28,(572,360),(582,369),(155,226,254),4)#right hand 
e1 = cv2.line(img28,(591,360),(582,369),(155,226,254),4)#left hand
e1 = cv2.line(img28,(581,368),(582,369),(255,255,255),10)#glove
e1 = cv2.line(img28,(571,326),(588,326),(0,0,0),10)#top hair



#bowler


e1=cv2.rectangle(img28,(626,759),(652,789),(26,64,0),-1)#body
e1=cv2.circle(img28,(638,745),14,(155,226,254),-1)# head
e1=cv2.circle(img28,(670,747),6,(255,255,255),-1)# right ball
e1 = cv2.line(img28,(653,764),(669,749),(155,226,254),5)#right hand 
e1 = cv2.line(img28,(625,765),(620,772),(155,226,254),5)#left hand
e1 = cv2.line(img28,(632,742),(643,742),(0,0,0),20)#top hair



# pakistan player
e1=cv2.rectangle(img28,(292,293),(300,322),(26,64,0),-1)#right leg
e1=cv2.rectangle(img28,(288,253),(320,298),(26,64,0),-1)#body
e1=cv2.rectangle(img28,(309,293),(317,322),(26,64,0),-1)#left leg
e1=cv2.circle(img28,(303,239),16,(155,226,254),-1)# head
e1=cv2.circle(img28,(295,242),2,(0,0,0),-1)# right eye
e1=cv2.circle(img28,(310,242),2,(0,0,0),-1)# left eye
e1 = cv2.line(img28,(298,249),(307,249),(0,0,0),2)#mouth
e1 = cv2.line(img28,(289,265),(294,276),(155,226,254),4)#right hand 
e1 = cv2.line(img28,(318,265),(310,276),(155,226,254),4)#left hand
e1 = cv2.line(img28,(293,229),(312,229),(0,0,0),13)#top hair


#Indian  player
e1=cv2.rectangle(img28,(548,767),(555,784),(255,0,0),-1)#left leg
e1=cv2.rectangle(img28,(569,767),(545,742),(255,0,0),-1)#body
e1=cv2.rectangle(img28,(560,767),(567,784),(255,0,0),-1)#right leg
e1=cv2.circle(img28,(557,729),14,(155,226,254),-1)# head
e1 = cv2.line(img28,(570,748),(574,761),(155,226,254),3)#right hand 
e1 = cv2.line(img28,(544,747),(537,754),(155,226,254),3)#left hand
e1 = cv2.line(img28,(575,761),(580,778),(29,101,181),10)#bat
e1 = cv2.line(img28,(550,724),(562,724),(0,0,0),21)#top hair




cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # 26 POINT

# %%
img29=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img29,(0,0),(1200,800),(0,178,0),-1) #layout

e1 = cv2.line(img29,(600,800),(530,400),(128,178,194),10)# left line
e1 = cv2.line(img29,(610,800),(540,400),(128,178,194),10)# left line
e1 = cv2.line(img29,(620,800),(550,400),(128,178,194),10)# left line
e1 = cv2.line(img29,(630,800),(560,400),(128,178,194),10)# left line
e1 = cv2.line(img29,(640,800),(570,400),(128,178,194),10)# left line
e1 = cv2.line(img29,(650,800),(580,400),(128,178,194),10)# left line
e1 = cv2.line(img29,(660,800),(590,400),(128,178,194),10)# left line
e1 = cv2.line(img29,(670,800),(600,400),(128,178,194),10)# left line
e1 = cv2.line(img29,(680,800),(610,400),(128,178,194),10)# left line
e1 = cv2.line(img29,(690,800),(620,400),(128,178,194),10)# left line
e1 = cv2.line(img29,(700,800),(630,400),(128,178,194),10)# left line
e1 = cv2.line(img29,(710,800),(640,400),(128,178,194),10)# left line
e1 = cv2.line(img29,(720,800),(650,400),(128,178,194),10)# left line
e1 = cv2.line(img29,(730,800),(660,400),(128,178,194),10)# left line
e1 = cv2.line(img29,(740,800),(670,400),(128,178,194),10)# left line
e1 = cv2.line(img29,(750,800),(680,400),(128,178,194),10)# left line
e1 = cv2.line(img29,(760,800),(690,400),(128,178,194),10)# left line

e1 = cv2.line(img29,(450,800),(530,400),(128,178,194),10)#right line
e1 = cv2.line(img29,(460,800),(540,400),(128,178,194),10)#right line
e1 = cv2.line(img29,(470,800),(550,400),(128,178,194),10)#right line
e1 = cv2.line(img29,(480,800),(560,400),(128,178,194),10)#right line
e1 = cv2.line(img29,(490,800),(570,400),(128,178,194),10)#right line
e1 = cv2.line(img29,(500,800),(580,400),(128,178,194),10)#right line
e1 = cv2.line(img29,(510,800),(590,400),(128,178,194),10)#right line
e1 = cv2.line(img29,(520,800),(600,400),(128,178,194),10)#right line
e1 = cv2.line(img29,(530,800),(610,400),(128,178,194),10)#right line
e1 = cv2.line(img29,(540,800),(620,400),(128,178,194),10)#right line
e1 = cv2.line(img29,(550,800),(630,400),(128,178,194),10)#right line
e1 = cv2.line(img29,(560,800),(640,400),(128,178,194),10)#right line
e1 = cv2.line(img29,(570,800),(650,400),(128,178,194),10)#right line
e1 = cv2.line(img29,(580,800),(660,400),(128,178,194),10)#right line
e1 = cv2.line(img29,(590,800),(670,400),(128,178,194),10)#right line

e1 = cv2.line(img29,(760,800),(690,400),(255,255,255),2)# left line
e1 = cv2.line(img29,(450,800),(530,400),(255,255,255),2)#right line
e1 = cv2.line(img29,(690,400),(530,400),(255,255,255),2)# middle line
e1 = cv2.line(img29,(600,1200),(600,760),(0,0,0),5)   #middle wicket   #buttom side
e1 = cv2.line(img29,(590,1200),(590,760),(0,0,0),5)   #left wicket
e1 = cv2.line(img29,(610,1200),(610,760),(0,0,0),5)   #right wicket
e1 = cv2.line(img29,(590,760),(610,760),(0,0,0),5)    #top wicket
e1 = cv2.line(img29,(430,750),(780,750),(255,255,255),2)#buttom boundary line 
e1 = cv2.line(img29,(500,750),(490,850),(255,255,255),2)#boundary left line
e1 = cv2.line(img29,(710,750),(720,850),(255,255,255),2)#boundary right line

e1 = cv2.line(img29,(760,800),(690,400),(255,255,255),2)# left line
e1 = cv2.line(img29,(450,800),(530,400),(255,255,255),2)#right line
e1 = cv2.line(img29,(690,400),(530,400),(255,255,255),2)# middle line
e1 = cv2.line(img29,(620,400),(620,360),(0,0,0),5)   #right wicket     #top side
e1 = cv2.line(img29,(600,400),(600,360),(0,0,0),5)   #lift wicket
e1 = cv2.line(img29,(610,400),(610,360),(0,0,0),5)   #middle wicket
e1 = cv2.line(img29,(600,360),(620,360),(0,0,0),5)    #top wicket
e1 = cv2.line(img29,(490,440),(720,440),(255,255,255),2) # top boundary line
e1 = cv2.line(img29,(555,440),(560,400),(255,255,255),2)#boundary left line
e1 = cv2.line(img29,(655,440),(655,400),(255,255,255),2)#boundary right line




#indian player

e1=cv2.rectangle(img29,(642,402),(648,440),(255,0,0),-1)#right leg
e1=cv2.rectangle(img29,(629,352),(650,402),(255,0,0),-1)#body
e1=cv2.rectangle(img29,(631,402),(637,440),(255,0,0),-1)#left leg
e1=cv2.circle(img29,(640,339),13,(155,226,254),-1)# head
e1=cv2.circle(img29,(632,340),2,(0,0,0),-1)# right eye
e1=cv2.circle(img29,(637,340),2,(0,0,0),-1)# left eye
e1=cv2.circle(img29,(635,346),2,(0,0,0),-1)#mouth
e1 = cv2.line(img29,(632,364),(620,400),(155,226,254),3)#right hand 
e1 = cv2.line(img29,(641,373),(623,400),(155,226,254),3)#left hand
e1 = cv2.line(img29,(618,400),(596,369),(29,101,181),10)#bat
e1 = cv2.line(img29,(632,329),(647,329),(0,0,0),10)#top hair
e1 = cv2.line(img29,(647,336),(646,348),(0,0,0),10)#left hair


# pakistan wicket player

e1=cv2.rectangle(img29,(592,362),(586,395),(26,64,0),-1)#right leg
e1=cv2.rectangle(img29,(570,351),(593,379),(26,64,0),-1)#body
e1=cv2.rectangle(img29,(572,362),(579,395),(26,64,0),-1)#left leg
e1=cv2.circle(img29,(581,336),14,(155,226,254),-1)# head
e1=cv2.circle(img29,(576,338),2,(0,0,0),-1)# right eye
e1=cv2.circle(img29,(587,338),2,(0,0,0),-1)# left eye
e1 = cv2.line(img29,(578,345),(585,345),(0,0,0),2)#mouth
e1 = cv2.line(img29,(572,360),(582,369),(155,226,254),4)#right hand 
e1 = cv2.line(img29,(591,360),(582,369),(155,226,254),4)#left hand
e1 = cv2.line(img29,(581,368),(582,369),(255,255,255),10)#glove
e1 = cv2.line(img29,(571,326),(588,326),(0,0,0),10)#top hair



#bowler


e1=cv2.rectangle(img29,(626,739),(652,769),(26,64,0),-1)#body
e1=cv2.circle(img29,(638,725),14,(155,226,254),-1)# head
e1=cv2.circle(img29,(670,727),6,(255,255,255),-1)# right ball
e1 = cv2.line(img29,(653,744),(669,729),(155,226,254),5)#right hand 
e1 = cv2.line(img29,(625,745),(620,752),(155,226,254),5)#left hand
e1 = cv2.line(img29,(632,722),(643,722),(0,0,0),20)#top hair
e1=cv2.rectangle(img29,(631,769),(637,782),(26,64,0),-1)#left leg
e1=cv2.rectangle(img29,(642,769),(648,782),(26,64,0),-1)#right leg



# pakistan player
e1=cv2.rectangle(img29,(292,293),(300,322),(26,64,0),-1)#right leg
e1=cv2.rectangle(img29,(288,253),(320,298),(26,64,0),-1)#body
e1=cv2.rectangle(img29,(309,293),(317,322),(26,64,0),-1)#left leg
e1=cv2.circle(img29,(303,239),16,(155,226,254),-1)# head
e1=cv2.circle(img29,(295,242),2,(0,0,0),-1)# right eye
e1=cv2.circle(img29,(310,242),2,(0,0,0),-1)# left eye
e1 = cv2.line(img29,(298,249),(307,249),(0,0,0),2)#mouth
e1 = cv2.line(img29,(289,265),(294,276),(155,226,254),4)#right hand 
e1 = cv2.line(img29,(318,265),(310,276),(155,226,254),4)#left hand
e1 = cv2.line(img29,(293,229),(312,229),(0,0,0),13)#top hair


#Indian  player
e1=cv2.rectangle(img29,(548,767),(555,784),(255,0,0),-1)#left leg
e1=cv2.rectangle(img29,(569,767),(545,742),(255,0,0),-1)#body
e1=cv2.rectangle(img29,(560,767),(567,784),(255,0,0),-1)#right leg
e1=cv2.circle(img29,(557,729),14,(155,226,254),-1)# head
e1 = cv2.line(img29,(570,748),(574,761),(155,226,254),3)#right hand 
e1 = cv2.line(img29,(544,747),(537,754),(155,226,254),3)#left hand
e1 = cv2.line(img29,(575,761),(580,778),(29,101,181),10)#bat
e1 = cv2.line(img29,(550,724),(562,724),(0,0,0),21)#top hair




cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # 27 POINT

# %%
img30=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img30,(0,0),(1200,800),(0,178,0),-1) #layout

e1 = cv2.line(img30,(600,800),(530,400),(128,178,194),10)# left line
e1 = cv2.line(img30,(610,800),(540,400),(128,178,194),10)# left line
e1 = cv2.line(img30,(620,800),(550,400),(128,178,194),10)# left line
e1 = cv2.line(img30,(630,800),(560,400),(128,178,194),10)# left line
e1 = cv2.line(img30,(640,800),(570,400),(128,178,194),10)# left line
e1 = cv2.line(img30,(650,800),(580,400),(128,178,194),10)# left line
e1 = cv2.line(img30,(660,800),(590,400),(128,178,194),10)# left line
e1 = cv2.line(img30,(670,800),(600,400),(128,178,194),10)# left line
e1 = cv2.line(img30,(680,800),(610,400),(128,178,194),10)# left line
e1 = cv2.line(img30,(690,800),(620,400),(128,178,194),10)# left line
e1 = cv2.line(img30,(700,800),(630,400),(128,178,194),10)# left line
e1 = cv2.line(img30,(710,800),(640,400),(128,178,194),10)# left line
e1 = cv2.line(img30,(720,800),(650,400),(128,178,194),10)# left line
e1 = cv2.line(img30,(730,800),(660,400),(128,178,194),10)# left line
e1 = cv2.line(img30,(740,800),(670,400),(128,178,194),10)# left line
e1 = cv2.line(img30,(750,800),(680,400),(128,178,194),10)# left line
e1 = cv2.line(img30,(760,800),(690,400),(128,178,194),10)# left line

e1 = cv2.line(img30,(450,800),(530,400),(128,178,194),10)#right line
e1 = cv2.line(img30,(460,800),(540,400),(128,178,194),10)#right line
e1 = cv2.line(img30,(470,800),(550,400),(128,178,194),10)#right line
e1 = cv2.line(img30,(480,800),(560,400),(128,178,194),10)#right line
e1 = cv2.line(img30,(490,800),(570,400),(128,178,194),10)#right line
e1 = cv2.line(img30,(500,800),(580,400),(128,178,194),10)#right line
e1 = cv2.line(img30,(510,800),(590,400),(128,178,194),10)#right line
e1 = cv2.line(img30,(520,800),(600,400),(128,178,194),10)#right line
e1 = cv2.line(img30,(530,800),(610,400),(128,178,194),10)#right line
e1 = cv2.line(img30,(540,800),(620,400),(128,178,194),10)#right line
e1 = cv2.line(img30,(550,800),(630,400),(128,178,194),10)#right line
e1 = cv2.line(img30,(560,800),(640,400),(128,178,194),10)#right line
e1 = cv2.line(img30,(570,800),(650,400),(128,178,194),10)#right line
e1 = cv2.line(img30,(580,800),(660,400),(128,178,194),10)#right line
e1 = cv2.line(img30,(590,800),(670,400),(128,178,194),10)#right line

e1 = cv2.line(img30,(760,800),(690,400),(255,255,255),2)# left line
e1 = cv2.line(img30,(450,800),(530,400),(255,255,255),2)#right line
e1 = cv2.line(img30,(690,400),(530,400),(255,255,255),2)# middle line
e1 = cv2.line(img30,(600,1200),(600,760),(0,0,0),5)   #middle wicket   #buttom side
e1 = cv2.line(img30,(590,1200),(590,760),(0,0,0),5)   #left wicket
e1 = cv2.line(img30,(610,1200),(610,760),(0,0,0),5)   #right wicket
e1 = cv2.line(img30,(590,760),(610,760),(0,0,0),5)    #top wicket
e1 = cv2.line(img30,(430,750),(780,750),(255,255,255),2)#buttom boundary line 
e1 = cv2.line(img30,(500,750),(490,850),(255,255,255),2)#boundary left line
e1 = cv2.line(img30,(710,750),(720,850),(255,255,255),2)#boundary right line

e1 = cv2.line(img30,(760,800),(690,400),(255,255,255),2)# left line
e1 = cv2.line(img30,(450,800),(530,400),(255,255,255),2)#right line
e1 = cv2.line(img30,(690,400),(530,400),(255,255,255),2)# middle line
e1 = cv2.line(img30,(620,400),(620,360),(0,0,0),5)   #right wicket     #top side
e1 = cv2.line(img30,(600,400),(600,360),(0,0,0),5)   #lift wicket
e1 = cv2.line(img30,(610,400),(610,360),(0,0,0),5)   #middle wicket
e1 = cv2.line(img30,(600,360),(620,360),(0,0,0),5)    #top wicket
e1 = cv2.line(img30,(490,440),(720,440),(255,255,255),2) # top boundary line
e1 = cv2.line(img30,(555,440),(560,400),(255,255,255),2)#boundary left line
e1 = cv2.line(img30,(655,440),(655,400),(255,255,255),2)#boundary right line




#indian player

e1=cv2.rectangle(img30,(642,402),(648,440),(255,0,0),-1)#right leg
e1=cv2.rectangle(img30,(629,352),(650,402),(255,0,0),-1)#body
e1=cv2.rectangle(img30,(631,402),(637,440),(255,0,0),-1)#left leg
e1=cv2.circle(img30,(640,339),13,(155,226,254),-1)# head
e1=cv2.circle(img30,(632,340),2,(0,0,0),-1)# right eye
e1=cv2.circle(img30,(637,340),2,(0,0,0),-1)# left eye
e1=cv2.circle(img30,(635,346),2,(0,0,0),-1)#mouth
e1 = cv2.line(img30,(632,364),(620,400),(155,226,254),3)#right hand 
e1 = cv2.line(img30,(641,373),(623,400),(155,226,254),3)#left hand
e1 = cv2.line(img30,(621,400),(584,416),(29,101,181),10)#bat
e1 = cv2.line(img30,(632,329),(647,329),(0,0,0),10)#top hair
e1 = cv2.line(img30,(647,336),(646,348),(0,0,0),10)#left hair


# pakistan wicket player

e1=cv2.rectangle(img30,(592,362),(586,395),(26,64,0),-1)#right leg
e1=cv2.rectangle(img30,(570,351),(593,379),(26,64,0),-1)#body
e1=cv2.rectangle(img30,(572,362),(579,395),(26,64,0),-1)#left leg
e1=cv2.circle(img30,(581,336),14,(155,226,254),-1)# head
e1=cv2.circle(img30,(576,338),2,(0,0,0),-1)# right eye
e1=cv2.circle(img30,(587,338),2,(0,0,0),-1)# left eye
e1 = cv2.line(img30,(578,345),(585,345),(0,0,0),2)#mouth
e1 = cv2.line(img30,(572,360),(582,369),(155,226,254),4)#right hand 
e1 = cv2.line(img30,(591,360),(582,369),(155,226,254),4)#left hand
e1 = cv2.line(img30,(581,368),(582,369),(255,255,255),10)#glove
e1 = cv2.line(img30,(571,326),(588,326),(0,0,0),10)#top hair



#bowler


e1=cv2.rectangle(img30,(626,719),(652,749),(26,64,0),-1)#body
e1=cv2.circle(img30,(638,705),14,(155,226,254),-1)# head
e1=cv2.circle(img30,(670,707),6,(255,255,255),-1)# right ball
e1 = cv2.line(img30,(653,724),(669,709),(155,226,254),5)#right hand 
e1 = cv2.line(img30,(625,725),(620,732),(155,226,254),5)#left hand
e1 = cv2.line(img30,(632,702),(643,702),(0,0,0),20)#top hair
e1=cv2.rectangle(img30,(631,749),(637,762),(26,64,0),-1)#left leg
e1=cv2.rectangle(img30,(642,749),(648,762),(26,64,0),-1)#right leg



# pakistan player
e1=cv2.rectangle(img30,(292,293),(300,322),(26,64,0),-1)#right leg
e1=cv2.rectangle(img30,(288,253),(320,298),(26,64,0),-1)#body
e1=cv2.rectangle(img30,(309,293),(317,322),(26,64,0),-1)#left leg
e1=cv2.circle(img30,(303,239),16,(155,226,254),-1)# head
e1=cv2.circle(img30,(295,242),2,(0,0,0),-1)# right eye
e1=cv2.circle(img30,(310,242),2,(0,0,0),-1)# left eye
e1 = cv2.line(img30,(298,249),(307,249),(0,0,0),2)#mouth
e1 = cv2.line(img30,(289,265),(294,276),(155,226,254),4)#right hand 
e1 = cv2.line(img30,(318,265),(310,276),(155,226,254),4)#left hand
e1 = cv2.line(img30,(293,229),(312,229),(0,0,0),13)#top hair


#Indian  player
e1=cv2.rectangle(img30,(548,767),(555,784),(255,0,0),-1)#left leg
e1=cv2.rectangle(img30,(569,767),(545,742),(255,0,0),-1)#body
e1=cv2.rectangle(img30,(560,767),(567,784),(255,0,0),-1)#right leg
e1=cv2.circle(img30,(557,729),14,(155,226,254),-1)# head
e1 = cv2.line(img30,(570,748),(574,761),(155,226,254),3)#right hand 
e1 = cv2.line(img30,(544,747),(537,754),(155,226,254),3)#left hand
e1 = cv2.line(img30,(575,761),(580,778),(29,101,181),10)#bat
e1 = cv2.line(img30,(550,724),(562,724),(0,0,0),21)#top hair




cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # 28 point

# %%
img31=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img31,(0,0),(1200,800),(0,178,0),-1) #layout

e1 = cv2.line(img31,(600,800),(530,400),(128,178,194),10)# left line
e1 = cv2.line(img31,(610,800),(540,400),(128,178,194),10)# left line
e1 = cv2.line(img31,(620,800),(550,400),(128,178,194),10)# left line
e1 = cv2.line(img31,(630,800),(560,400),(128,178,194),10)# left line
e1 = cv2.line(img31,(640,800),(570,400),(128,178,194),10)# left line
e1 = cv2.line(img31,(650,800),(580,400),(128,178,194),10)# left line
e1 = cv2.line(img31,(660,800),(590,400),(128,178,194),10)# left line
e1 = cv2.line(img31,(670,800),(600,400),(128,178,194),10)# left line
e1 = cv2.line(img31,(680,800),(610,400),(128,178,194),10)# left line
e1 = cv2.line(img31,(690,800),(620,400),(128,178,194),10)# left line
e1 = cv2.line(img31,(700,800),(630,400),(128,178,194),10)# left line
e1 = cv2.line(img31,(710,800),(640,400),(128,178,194),10)# left line
e1 = cv2.line(img31,(720,800),(650,400),(128,178,194),10)# left line
e1 = cv2.line(img31,(730,800),(660,400),(128,178,194),10)# left line
e1 = cv2.line(img31,(740,800),(670,400),(128,178,194),10)# left line
e1 = cv2.line(img31,(750,800),(680,400),(128,178,194),10)# left line
e1 = cv2.line(img31,(760,800),(690,400),(128,178,194),10)# left line

e1 = cv2.line(img31,(450,800),(530,400),(128,178,194),10)#right line
e1 = cv2.line(img31,(460,800),(540,400),(128,178,194),10)#right line
e1 = cv2.line(img31,(470,800),(550,400),(128,178,194),10)#right line
e1 = cv2.line(img31,(480,800),(560,400),(128,178,194),10)#right line
e1 = cv2.line(img31,(490,800),(570,400),(128,178,194),10)#right line
e1 = cv2.line(img31,(500,800),(580,400),(128,178,194),10)#right line
e1 = cv2.line(img31,(510,800),(590,400),(128,178,194),10)#right line
e1 = cv2.line(img31,(520,800),(600,400),(128,178,194),10)#right line
e1 = cv2.line(img31,(530,800),(610,400),(128,178,194),10)#right line
e1 = cv2.line(img31,(540,800),(620,400),(128,178,194),10)#right line
e1 = cv2.line(img31,(550,800),(630,400),(128,178,194),10)#right line
e1 = cv2.line(img31,(560,800),(640,400),(128,178,194),10)#right line
e1 = cv2.line(img31,(570,800),(650,400),(128,178,194),10)#right line
e1 = cv2.line(img31,(580,800),(660,400),(128,178,194),10)#right line
e1 = cv2.line(img31,(590,800),(670,400),(128,178,194),10)#right line

e1 = cv2.line(img31,(760,800),(690,400),(255,255,255),2)# left line
e1 = cv2.line(img31,(450,800),(530,400),(255,255,255),2)#right line
e1 = cv2.line(img31,(690,400),(530,400),(255,255,255),2)# middle line
e1 = cv2.line(img31,(600,1200),(600,760),(0,0,0),5)   #middle wicket   #buttom side
e1 = cv2.line(img31,(590,1200),(590,760),(0,0,0),5)   #left wicket
e1 = cv2.line(img31,(610,1200),(610,760),(0,0,0),5)   #right wicket
e1 = cv2.line(img31,(590,760),(610,760),(0,0,0),5)    #top wicket
e1 = cv2.line(img31,(430,750),(780,750),(255,255,255),2)#buttom boundary line 
e1 = cv2.line(img31,(500,750),(490,850),(255,255,255),2)#boundary left line
e1 = cv2.line(img31,(710,750),(720,850),(255,255,255),2)#boundary right line

e1 = cv2.line(img31,(760,800),(690,400),(255,255,255),2)# left line
e1 = cv2.line(img31,(450,800),(530,400),(255,255,255),2)#right line
e1 = cv2.line(img31,(690,400),(530,400),(255,255,255),2)# middle line
e1 = cv2.line(img31,(620,400),(620,360),(0,0,0),5)   #right wicket     #top side
e1 = cv2.line(img31,(600,400),(600,360),(0,0,0),5)   #lift wicket
e1 = cv2.line(img31,(610,400),(610,360),(0,0,0),5)   #middle wicket
e1 = cv2.line(img31,(600,360),(620,360),(0,0,0),5)    #top wicket
e1 = cv2.line(img31,(490,440),(720,440),(255,255,255),2) # top boundary line
e1 = cv2.line(img31,(555,440),(560,400),(255,255,255),2)#boundary left line
e1 = cv2.line(img31,(655,440),(655,400),(255,255,255),2)#boundary right line




#indian player

e1=cv2.rectangle(img31,(642,402),(648,440),(255,0,0),-1)#right leg
e1=cv2.rectangle(img31,(629,352),(650,402),(255,0,0),-1)#body
e1=cv2.rectangle(img31,(631,402),(637,440),(255,0,0),-1)#left leg
e1=cv2.circle(img31,(640,339),13,(155,226,254),-1)# head
e1=cv2.circle(img31,(632,340),2,(0,0,0),-1)# right eye
e1=cv2.circle(img31,(637,340),2,(0,0,0),-1)# left eye
e1=cv2.circle(img31,(635,346),2,(0,0,0),-1)#mouth
e1 = cv2.line(img31,(632,364),(620,400),(155,226,254),3)#right hand 
e1 = cv2.line(img31,(641,373),(623,400),(155,226,254),3)#left hand
e1 = cv2.line(img31,(621,400),(603,435),(29,101,181),10)#bat
e1 = cv2.line(img31,(632,329),(647,329),(0,0,0),10)#top hair
e1 = cv2.line(img31,(647,336),(646,348),(0,0,0),10)#left hair


# pakistan wicket player

e1=cv2.rectangle(img31,(592,362),(586,395),(26,64,0),-1)#right leg
e1=cv2.rectangle(img31,(570,351),(593,379),(26,64,0),-1)#body
e1=cv2.rectangle(img31,(572,362),(579,395),(26,64,0),-1)#left leg
e1=cv2.circle(img31,(581,336),14,(155,226,254),-1)# head
e1=cv2.circle(img31,(576,338),2,(0,0,0),-1)# right eye
e1=cv2.circle(img31,(587,338),2,(0,0,0),-1)# left eye
e1 = cv2.line(img31,(578,345),(585,345),(0,0,0),2)#mouth
e1 = cv2.line(img31,(572,360),(582,369),(155,226,254),4)#right hand 
e1 = cv2.line(img31,(591,360),(582,369),(155,226,254),4)#left hand
e1 = cv2.line(img31,(581,368),(582,369),(255,255,255),10)#glove
e1 = cv2.line(img31,(571,326),(588,326),(0,0,0),10)#top hair



#bowler


e1=cv2.rectangle(img31,(626,719),(652,749),(26,64,0),-1)#body
e1=cv2.circle(img31,(638,705),14,(155,226,254),-1)# head
e1=cv2.circle(img31,(670,690),6,(255,255,255),-1)# right ball
e1 = cv2.line(img31,(653,724),(669,709),(155,226,254),5)#right hand 
e1 = cv2.line(img31,(625,725),(620,732),(155,226,254),5)#left hand
e1 = cv2.line(img31,(632,702),(643,702),(0,0,0),20)#top hair
e1=cv2.rectangle(img31,(631,749),(637,762),(26,64,0),-1)#left leg
e1=cv2.rectangle(img31,(642,749),(648,762),(26,64,0),-1)#right leg



# pakistan player
e1=cv2.rectangle(img31,(292,293),(300,322),(26,64,0),-1)#right leg
e1=cv2.rectangle(img31,(288,253),(320,298),(26,64,0),-1)#body
e1=cv2.rectangle(img31,(309,293),(317,322),(26,64,0),-1)#left leg
e1=cv2.circle(img31,(303,239),16,(155,226,254),-1)# head
e1=cv2.circle(img31,(295,242),2,(0,0,0),-1)# right eye
e1=cv2.circle(img31,(310,242),2,(0,0,0),-1)# left eye
e1 = cv2.line(img31,(298,249),(307,249),(0,0,0),2)#mouth
e1 = cv2.line(img31,(289,265),(294,276),(155,226,254),4)#right hand 
e1 = cv2.line(img31,(318,265),(310,276),(155,226,254),4)#left hand
e1 = cv2.line(img31,(293,229),(312,229),(0,0,0),13)#top hair


#Indian  player
e1=cv2.rectangle(img31,(548,767),(555,784),(255,0,0),-1)#left leg
e1=cv2.rectangle(img31,(569,767),(545,742),(255,0,0),-1)#body
e1=cv2.rectangle(img31,(560,767),(567,784),(255,0,0),-1)#right leg
e1=cv2.circle(img31,(557,729),14,(155,226,254),-1)# head
e1 = cv2.line(img31,(570,748),(574,761),(155,226,254),3)#right hand 
e1 = cv2.line(img31,(544,747),(537,754),(155,226,254),3)#left hand
e1 = cv2.line(img31,(575,761),(580,778),(29,101,181),10)#bat
e1 = cv2.line(img31,(550,724),(562,724),(0,0,0),21)#top hair




cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # 29 POINT

# %%
img32=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img32,(0,0),(1200,800),(0,178,0),-1) #layout

e1 = cv2.line(img32,(600,800),(530,400),(128,178,194),10)# left line
e1 = cv2.line(img32,(610,800),(540,400),(128,178,194),10)# left line
e1 = cv2.line(img32,(620,800),(550,400),(128,178,194),10)# left line
e1 = cv2.line(img32,(630,800),(560,400),(128,178,194),10)# left line
e1 = cv2.line(img32,(640,800),(570,400),(128,178,194),10)# left line
e1 = cv2.line(img32,(650,800),(580,400),(128,178,194),10)# left line
e1 = cv2.line(img32,(660,800),(590,400),(128,178,194),10)# left line
e1 = cv2.line(img32,(670,800),(600,400),(128,178,194),10)# left line
e1 = cv2.line(img32,(680,800),(610,400),(128,178,194),10)# left line
e1 = cv2.line(img32,(690,800),(620,400),(128,178,194),10)# left line
e1 = cv2.line(img32,(700,800),(630,400),(128,178,194),10)# left line
e1 = cv2.line(img32,(710,800),(640,400),(128,178,194),10)# left line
e1 = cv2.line(img32,(720,800),(650,400),(128,178,194),10)# left line
e1 = cv2.line(img32,(730,800),(660,400),(128,178,194),10)# left line
e1 = cv2.line(img32,(740,800),(670,400),(128,178,194),10)# left line
e1 = cv2.line(img32,(750,800),(680,400),(128,178,194),10)# left line
e1 = cv2.line(img32,(760,800),(690,400),(128,178,194),10)# left line

e1 = cv2.line(img32,(450,800),(530,400),(128,178,194),10)#right line
e1 = cv2.line(img32,(460,800),(540,400),(128,178,194),10)#right line
e1 = cv2.line(img32,(470,800),(550,400),(128,178,194),10)#right line
e1 = cv2.line(img32,(480,800),(560,400),(128,178,194),10)#right line
e1 = cv2.line(img32,(490,800),(570,400),(128,178,194),10)#right line
e1 = cv2.line(img32,(500,800),(580,400),(128,178,194),10)#right line
e1 = cv2.line(img32,(510,800),(590,400),(128,178,194),10)#right line
e1 = cv2.line(img32,(520,800),(600,400),(128,178,194),10)#right line
e1 = cv2.line(img32,(530,800),(610,400),(128,178,194),10)#right line
e1 = cv2.line(img32,(540,800),(620,400),(128,178,194),10)#right line
e1 = cv2.line(img32,(550,800),(630,400),(128,178,194),10)#right line
e1 = cv2.line(img32,(560,800),(640,400),(128,178,194),10)#right line
e1 = cv2.line(img32,(570,800),(650,400),(128,178,194),10)#right line
e1 = cv2.line(img32,(580,800),(660,400),(128,178,194),10)#right line
e1 = cv2.line(img32,(590,800),(670,400),(128,178,194),10)#right line

e1 = cv2.line(img32,(760,800),(690,400),(255,255,255),2)# left line
e1 = cv2.line(img32,(450,800),(530,400),(255,255,255),2)#right line
e1 = cv2.line(img32,(690,400),(530,400),(255,255,255),2)# middle line
e1 = cv2.line(img32,(600,1200),(600,760),(0,0,0),5)   #middle wicket   #buttom side
e1 = cv2.line(img32,(590,1200),(590,760),(0,0,0),5)   #left wicket
e1 = cv2.line(img32,(610,1200),(610,760),(0,0,0),5)   #right wicket
e1 = cv2.line(img32,(590,760),(610,760),(0,0,0),5)    #top wicket
e1 = cv2.line(img32,(430,750),(780,750),(255,255,255),2)#buttom boundary line 
e1 = cv2.line(img32,(500,750),(490,850),(255,255,255),2)#boundary left line
e1 = cv2.line(img32,(710,750),(720,850),(255,255,255),2)#boundary right line

e1 = cv2.line(img32,(760,800),(690,400),(255,255,255),2)# left line
e1 = cv2.line(img32,(450,800),(530,400),(255,255,255),2)#right line
e1 = cv2.line(img32,(690,400),(530,400),(255,255,255),2)# middle line
e1 = cv2.line(img32,(620,400),(620,360),(0,0,0),5)   #right wicket     #top side
e1 = cv2.line(img32,(600,400),(600,360),(0,0,0),5)   #lift wicket
e1 = cv2.line(img32,(610,400),(610,360),(0,0,0),5)   #middle wicket
e1 = cv2.line(img32,(600,360),(620,360),(0,0,0),5)    #top wicket
e1 = cv2.line(img32,(490,440),(720,440),(255,255,255),2) # top boundary line
e1 = cv2.line(img32,(555,440),(560,400),(255,255,255),2)#boundary left line
e1 = cv2.line(img32,(655,440),(655,400),(255,255,255),2)#boundary right line




#indian player

e1=cv2.rectangle(img32,(642,402),(648,440),(255,0,0),-1)#right leg
e1=cv2.rectangle(img32,(629,352),(650,402),(255,0,0),-1)#body
e1=cv2.rectangle(img32,(631,402),(637,440),(255,0,0),-1)#left leg
e1=cv2.circle(img32,(640,339),13,(155,226,254),-1)# head
e1=cv2.circle(img32,(632,340),2,(0,0,0),-1)# right eye
e1=cv2.circle(img32,(637,340),2,(0,0,0),-1)# left eye
e1=cv2.circle(img32,(635,346),2,(0,0,0),-1)#mouth
e1 = cv2.line(img32,(632,364),(620,400),(155,226,254),3)#right hand 
e1 = cv2.line(img32,(641,373),(623,400),(155,226,254),3)#left hand
e1 = cv2.line(img32,(621,400),(603,435),(29,101,181),10)#bat
e1 = cv2.line(img32,(632,329),(647,329),(0,0,0),10)#top hair
e1 = cv2.line(img32,(647,336),(646,348),(0,0,0),10)#left hair


# pakistan wicket player

e1=cv2.rectangle(img32,(592,362),(586,395),(26,64,0),-1)#right leg
e1=cv2.rectangle(img32,(570,351),(593,379),(26,64,0),-1)#body
e1=cv2.rectangle(img32,(572,362),(579,395),(26,64,0),-1)#left leg
e1=cv2.circle(img32,(581,336),14,(155,226,254),-1)# head
e1=cv2.circle(img32,(576,338),2,(0,0,0),-1)# right eye
e1=cv2.circle(img32,(587,338),2,(0,0,0),-1)# left eye
e1 = cv2.line(img32,(578,345),(585,345),(0,0,0),2)#mouth
e1 = cv2.line(img32,(572,360),(582,369),(155,226,254),4)#right hand 
e1 = cv2.line(img32,(591,360),(582,369),(155,226,254),4)#left hand
e1 = cv2.line(img32,(581,368),(582,369),(255,255,255),10)#glove
e1 = cv2.line(img32,(571,326),(588,326),(0,0,0),10)#top hair



#bowler


e1=cv2.rectangle(img32,(626,719),(652,749),(26,64,0),-1)#body
e1=cv2.circle(img32,(638,705),14,(155,226,254),-1)# head
e1=cv2.circle(img32,(675,657),6,(255,255,255),-1)# right ball
e1 = cv2.line(img32,(653,724),(663,736),(155,226,254),5)#right hand 
e1 = cv2.line(img32,(625,725),(620,732),(155,226,254),5)#left hand
e1 = cv2.line(img32,(632,702),(643,702),(0,0,0),20)#top hair
e1=cv2.rectangle(img32,(631,749),(637,762),(26,64,0),-1)#left leg
e1=cv2.rectangle(img32,(642,749),(648,762),(26,64,0),-1)#right leg



# pakistan player
e1=cv2.rectangle(img32,(292,293),(300,322),(26,64,0),-1)#right leg
e1=cv2.rectangle(img32,(288,253),(320,298),(26,64,0),-1)#body
e1=cv2.rectangle(img32,(309,293),(317,322),(26,64,0),-1)#left leg
e1=cv2.circle(img32,(303,239),16,(155,226,254),-1)# head
e1=cv2.circle(img32,(295,242),2,(0,0,0),-1)# right eye
e1=cv2.circle(img32,(310,242),2,(0,0,0),-1)# left eye
e1 = cv2.line(img32,(298,249),(307,249),(0,0,0),2)#mouth
e1 = cv2.line(img32,(289,265),(294,276),(155,226,254),4)#right hand 
e1 = cv2.line(img32,(318,265),(310,276),(155,226,254),4)#left hand
e1 = cv2.line(img32,(293,229),(312,229),(0,0,0),13)#top hair


#Indian  player
e1=cv2.rectangle(img32,(548,767),(555,784),(255,0,0),-1)#left leg
e1=cv2.rectangle(img32,(569,767),(545,742),(255,0,0),-1)#body
e1=cv2.rectangle(img32,(560,767),(567,784),(255,0,0),-1)#right leg
e1=cv2.circle(img32,(557,729),14,(155,226,254),-1)# head
e1 = cv2.line(img32,(570,748),(574,761),(155,226,254),3)#right hand 
e1 = cv2.line(img32,(544,747),(537,754),(155,226,254),3)#left hand
e1 = cv2.line(img32,(575,761),(580,778),(29,101,181),10)#bat
e1 = cv2.line(img32,(550,724),(562,724),(0,0,0),21)#top hair




cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # 30 POINT

# %%
img33=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img33,(0,0),(1200,800),(0,178,0),-1) #layout

e1 = cv2.line(img33,(600,800),(530,400),(128,178,194),10)# left line
e1 = cv2.line(img33,(610,800),(540,400),(128,178,194),10)# left line
e1 = cv2.line(img33,(620,800),(550,400),(128,178,194),10)# left line
e1 = cv2.line(img33,(630,800),(560,400),(128,178,194),10)# left line
e1 = cv2.line(img33,(640,800),(570,400),(128,178,194),10)# left line
e1 = cv2.line(img33,(650,800),(580,400),(128,178,194),10)# left line
e1 = cv2.line(img33,(660,800),(590,400),(128,178,194),10)# left line
e1 = cv2.line(img33,(670,800),(600,400),(128,178,194),10)# left line
e1 = cv2.line(img33,(680,800),(610,400),(128,178,194),10)# left line
e1 = cv2.line(img33,(690,800),(620,400),(128,178,194),10)# left line
e1 = cv2.line(img33,(700,800),(630,400),(128,178,194),10)# left line
e1 = cv2.line(img33,(710,800),(640,400),(128,178,194),10)# left line
e1 = cv2.line(img33,(720,800),(650,400),(128,178,194),10)# left line
e1 = cv2.line(img33,(730,800),(660,400),(128,178,194),10)# left line
e1 = cv2.line(img33,(740,800),(670,400),(128,178,194),10)# left line
e1 = cv2.line(img33,(750,800),(680,400),(128,178,194),10)# left line
e1 = cv2.line(img33,(760,800),(690,400),(128,178,194),10)# left line

e1 = cv2.line(img33,(450,800),(530,400),(128,178,194),10)#right line
e1 = cv2.line(img33,(460,800),(540,400),(128,178,194),10)#right line
e1 = cv2.line(img33,(470,800),(550,400),(128,178,194),10)#right line
e1 = cv2.line(img33,(480,800),(560,400),(128,178,194),10)#right line
e1 = cv2.line(img33,(490,800),(570,400),(128,178,194),10)#right line
e1 = cv2.line(img33,(500,800),(580,400),(128,178,194),10)#right line
e1 = cv2.line(img33,(510,800),(590,400),(128,178,194),10)#right line
e1 = cv2.line(img33,(520,800),(600,400),(128,178,194),10)#right line
e1 = cv2.line(img33,(530,800),(610,400),(128,178,194),10)#right line
e1 = cv2.line(img33,(540,800),(620,400),(128,178,194),10)#right line
e1 = cv2.line(img33,(550,800),(630,400),(128,178,194),10)#right line
e1 = cv2.line(img33,(560,800),(640,400),(128,178,194),10)#right line
e1 = cv2.line(img33,(570,800),(650,400),(128,178,194),10)#right line
e1 = cv2.line(img33,(580,800),(660,400),(128,178,194),10)#right line
e1 = cv2.line(img33,(590,800),(670,400),(128,178,194),10)#right line

e1 = cv2.line(img33,(760,800),(690,400),(255,255,255),2)# left line
e1 = cv2.line(img33,(450,800),(530,400),(255,255,255),2)#right line
e1 = cv2.line(img33,(690,400),(530,400),(255,255,255),2)# middle line
e1 = cv2.line(img33,(600,1200),(600,760),(0,0,0),5)   #middle wicket   #buttom side
e1 = cv2.line(img33,(590,1200),(590,760),(0,0,0),5)   #left wicket
e1 = cv2.line(img33,(610,1200),(610,760),(0,0,0),5)   #right wicket
e1 = cv2.line(img33,(590,760),(610,760),(0,0,0),5)    #top wicket
e1 = cv2.line(img33,(430,750),(780,750),(255,255,255),2)#buttom boundary line 
e1 = cv2.line(img33,(500,750),(490,850),(255,255,255),2)#boundary left line
e1 = cv2.line(img33,(710,750),(720,850),(255,255,255),2)#boundary right line

e1 = cv2.line(img33,(760,800),(690,400),(255,255,255),2)# left line
e1 = cv2.line(img33,(450,800),(530,400),(255,255,255),2)#right line
e1 = cv2.line(img33,(690,400),(530,400),(255,255,255),2)# middle line
e1 = cv2.line(img33,(620,400),(620,360),(0,0,0),5)   #right wicket     #top side
e1 = cv2.line(img33,(600,400),(600,360),(0,0,0),5)   #lift wicket
e1 = cv2.line(img33,(610,400),(610,360),(0,0,0),5)   #middle wicket
e1 = cv2.line(img33,(600,360),(620,360),(0,0,0),5)    #top wicket
e1 = cv2.line(img33,(490,440),(720,440),(255,255,255),2) # top boundary line
e1 = cv2.line(img33,(555,440),(560,400),(255,255,255),2)#boundary left line
e1 = cv2.line(img33,(655,440),(655,400),(255,255,255),2)#boundary right line




#indian player

e1=cv2.rectangle(img33,(642,402),(648,440),(255,0,0),-1)#right leg
e1=cv2.rectangle(img33,(629,352),(650,402),(255,0,0),-1)#body
e1=cv2.rectangle(img33,(631,402),(637,440),(255,0,0),-1)#left leg
e1=cv2.circle(img33,(640,339),13,(155,226,254),-1)# head
e1=cv2.circle(img33,(632,340),2,(0,0,0),-1)# right eye
e1=cv2.circle(img33,(637,340),2,(0,0,0),-1)# left eye
e1=cv2.circle(img33,(635,346),2,(0,0,0),-1)#mouth
e1 = cv2.line(img33,(632,364),(620,400),(155,226,254),3)#right hand 
e1 = cv2.line(img33,(641,373),(623,400),(155,226,254),3)#left hand
e1 = cv2.line(img33,(621,400),(603,435),(29,101,181),10)#bat
e1 = cv2.line(img33,(632,329),(647,329),(0,0,0),10)#top hair
e1 = cv2.line(img33,(647,336),(646,348),(0,0,0),10)#left hair


# pakistan wicket player

e1=cv2.rectangle(img33,(592,362),(586,395),(26,64,0),-1)#right leg
e1=cv2.rectangle(img33,(570,351),(593,379),(26,64,0),-1)#body
e1=cv2.rectangle(img33,(572,362),(579,395),(26,64,0),-1)#left leg
e1=cv2.circle(img33,(581,336),14,(155,226,254),-1)# head
e1=cv2.circle(img33,(576,338),2,(0,0,0),-1)# right eye
e1=cv2.circle(img33,(587,338),2,(0,0,0),-1)# left eye
e1 = cv2.line(img33,(578,345),(585,345),(0,0,0),2)#mouth
e1 = cv2.line(img33,(572,360),(582,369),(155,226,254),4)#right hand 
e1 = cv2.line(img33,(591,360),(582,369),(155,226,254),4)#left hand
e1 = cv2.line(img33,(581,368),(582,369),(255,255,255),10)#glove
e1 = cv2.line(img33,(571,326),(588,326),(0,0,0),10)#top hair



#bowler


e1=cv2.rectangle(img33,(626,719),(652,749),(26,64,0),-1)#body
e1=cv2.circle(img33,(638,705),14,(155,226,254),-1)# head
e1=cv2.circle(img33,(673,626),6,(255,255,255),-1)# right ball
e1 = cv2.line(img33,(653,724),(663,736),(155,226,254),5)#right hand 
e1 = cv2.line(img33,(625,725),(620,732),(155,226,254),5)#left hand
e1 = cv2.line(img33,(632,702),(643,702),(0,0,0),20)#top hair
e1=cv2.rectangle(img33,(631,749),(637,762),(26,64,0),-1)#left leg
e1=cv2.rectangle(img33,(642,749),(648,762),(26,64,0),-1)#right leg



# pakistan player
e1=cv2.rectangle(img33,(292,293),(300,322),(26,64,0),-1)#right leg
e1=cv2.rectangle(img33,(288,253),(320,298),(26,64,0),-1)#body
e1=cv2.rectangle(img33,(309,293),(317,322),(26,64,0),-1)#left leg
e1=cv2.circle(img33,(303,239),16,(155,226,254),-1)# head
e1=cv2.circle(img33,(295,242),2,(0,0,0),-1)# right eye
e1=cv2.circle(img33,(310,242),2,(0,0,0),-1)# left eye
e1 = cv2.line(img33,(298,249),(307,249),(0,0,0),2)#mouth
e1 = cv2.line(img33,(289,265),(294,276),(155,226,254),4)#right hand 
e1 = cv2.line(img33,(318,265),(310,276),(155,226,254),4)#left hand
e1 = cv2.line(img33,(293,229),(312,229),(0,0,0),13)#top hair


#Indian  player
e1=cv2.rectangle(img33,(548,767),(555,784),(255,0,0),-1)#left leg
e1=cv2.rectangle(img33,(569,767),(545,742),(255,0,0),-1)#body
e1=cv2.rectangle(img33,(560,767),(567,784),(255,0,0),-1)#right leg
e1=cv2.circle(img33,(557,729),14,(155,226,254),-1)# head
e1 = cv2.line(img33,(570,748),(574,761),(155,226,254),3)#right hand 
e1 = cv2.line(img33,(544,747),(537,754),(155,226,254),3)#left hand
e1 = cv2.line(img33,(575,761),(580,778),(29,101,181),10)#bat
e1 = cv2.line(img33,(550,724),(562,724),(0,0,0),21)#top hair




cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # 31 POINT

# %%
img34=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img34,(0,0),(1200,800),(0,178,0),-1) #layout

e1 = cv2.line(img34,(600,800),(530,400),(128,178,194),10)# left line
e1 = cv2.line(img34,(610,800),(540,400),(128,178,194),10)# left line
e1 = cv2.line(img34,(620,800),(550,400),(128,178,194),10)# left line
e1 = cv2.line(img34,(630,800),(560,400),(128,178,194),10)# left line
e1 = cv2.line(img34,(640,800),(570,400),(128,178,194),10)# left line
e1 = cv2.line(img34,(650,800),(580,400),(128,178,194),10)# left line
e1 = cv2.line(img34,(660,800),(590,400),(128,178,194),10)# left line
e1 = cv2.line(img34,(670,800),(600,400),(128,178,194),10)# left line
e1 = cv2.line(img34,(680,800),(610,400),(128,178,194),10)# left line
e1 = cv2.line(img34,(690,800),(620,400),(128,178,194),10)# left line
e1 = cv2.line(img34,(700,800),(630,400),(128,178,194),10)# left line
e1 = cv2.line(img34,(710,800),(640,400),(128,178,194),10)# left line
e1 = cv2.line(img34,(720,800),(650,400),(128,178,194),10)# left line
e1 = cv2.line(img34,(730,800),(660,400),(128,178,194),10)# left line
e1 = cv2.line(img34,(740,800),(670,400),(128,178,194),10)# left line
e1 = cv2.line(img34,(750,800),(680,400),(128,178,194),10)# left line
e1 = cv2.line(img34,(760,800),(690,400),(128,178,194),10)# left line

e1 = cv2.line(img34,(450,800),(530,400),(128,178,194),10)#right line
e1 = cv2.line(img34,(460,800),(540,400),(128,178,194),10)#right line
e1 = cv2.line(img34,(470,800),(550,400),(128,178,194),10)#right line
e1 = cv2.line(img34,(480,800),(560,400),(128,178,194),10)#right line
e1 = cv2.line(img34,(490,800),(570,400),(128,178,194),10)#right line
e1 = cv2.line(img34,(500,800),(580,400),(128,178,194),10)#right line
e1 = cv2.line(img34,(510,800),(590,400),(128,178,194),10)#right line
e1 = cv2.line(img34,(520,800),(600,400),(128,178,194),10)#right line
e1 = cv2.line(img34,(530,800),(610,400),(128,178,194),10)#right line
e1 = cv2.line(img34,(540,800),(620,400),(128,178,194),10)#right line
e1 = cv2.line(img34,(550,800),(630,400),(128,178,194),10)#right line
e1 = cv2.line(img34,(560,800),(640,400),(128,178,194),10)#right line
e1 = cv2.line(img34,(570,800),(650,400),(128,178,194),10)#right line
e1 = cv2.line(img34,(580,800),(660,400),(128,178,194),10)#right line
e1 = cv2.line(img34,(590,800),(670,400),(128,178,194),10)#right line

e1 = cv2.line(img34,(760,800),(690,400),(255,255,255),2)# left line
e1 = cv2.line(img34,(450,800),(530,400),(255,255,255),2)#right line
e1 = cv2.line(img34,(690,400),(530,400),(255,255,255),2)# middle line
e1 = cv2.line(img34,(600,1200),(600,760),(0,0,0),5)   #middle wicket   #buttom side
e1 = cv2.line(img34,(590,1200),(590,760),(0,0,0),5)   #left wicket
e1 = cv2.line(img34,(610,1200),(610,760),(0,0,0),5)   #right wicket
e1 = cv2.line(img34,(590,760),(610,760),(0,0,0),5)    #top wicket
e1 = cv2.line(img34,(430,750),(780,750),(255,255,255),2)#buttom boundary line 
e1 = cv2.line(img34,(500,750),(490,850),(255,255,255),2)#boundary left line
e1 = cv2.line(img34,(710,750),(720,850),(255,255,255),2)#boundary right line

e1 = cv2.line(img34,(760,800),(690,400),(255,255,255),2)# left line
e1 = cv2.line(img34,(450,800),(530,400),(255,255,255),2)#right line
e1 = cv2.line(img34,(690,400),(530,400),(255,255,255),2)# middle line
e1 = cv2.line(img34,(620,400),(620,360),(0,0,0),5)   #right wicket     #top side
e1 = cv2.line(img34,(600,400),(600,360),(0,0,0),5)   #lift wicket
e1 = cv2.line(img34,(610,400),(610,360),(0,0,0),5)   #middle wicket
e1 = cv2.line(img34,(600,360),(620,360),(0,0,0),5)    #top wicket
e1 = cv2.line(img34,(490,440),(720,440),(255,255,255),2) # top boundary line
e1 = cv2.line(img34,(555,440),(560,400),(255,255,255),2)#boundary left line
e1 = cv2.line(img34,(655,440),(655,400),(255,255,255),2)#boundary right line




#indian player

e1=cv2.rectangle(img34,(642,402),(648,440),(255,0,0),-1)#right leg
e1=cv2.rectangle(img34,(629,352),(650,402),(255,0,0),-1)#body
e1=cv2.rectangle(img34,(631,402),(637,440),(255,0,0),-1)#left leg
e1=cv2.circle(img34,(640,339),13,(155,226,254),-1)# head
e1=cv2.circle(img34,(632,340),2,(0,0,0),-1)# right eye
e1=cv2.circle(img34,(637,340),2,(0,0,0),-1)# left eye
e1=cv2.circle(img34,(635,346),2,(0,0,0),-1)#mouth
e1 = cv2.line(img34,(632,364),(620,400),(155,226,254),3)#right hand 
e1 = cv2.line(img34,(641,373),(623,400),(155,226,254),3)#left hand
e1 = cv2.line(img34,(621,400),(603,435),(29,101,181),10)#bat
e1 = cv2.line(img34,(632,329),(647,329),(0,0,0),10)#top hair
e1 = cv2.line(img34,(647,336),(646,348),(0,0,0),10)#left hair


# pakistan wicket player

e1=cv2.rectangle(img34,(592,362),(586,395),(26,64,0),-1)#right leg
e1=cv2.rectangle(img34,(570,351),(593,379),(26,64,0),-1)#body
e1=cv2.rectangle(img34,(572,362),(579,395),(26,64,0),-1)#left leg
e1=cv2.circle(img34,(581,336),14,(155,226,254),-1)# head
e1=cv2.circle(img34,(576,338),2,(0,0,0),-1)# right eye
e1=cv2.circle(img34,(587,338),2,(0,0,0),-1)# left eye
e1 = cv2.line(img34,(578,345),(585,345),(0,0,0),2)#mouth
e1 = cv2.line(img34,(572,360),(582,369),(155,226,254),4)#right hand 
e1 = cv2.line(img34,(591,360),(582,369),(155,226,254),4)#left hand
e1 = cv2.line(img34,(581,368),(582,369),(255,255,255),10)#glove
e1 = cv2.line(img34,(571,326),(588,326),(0,0,0),10)#top hair



#bowler


e1=cv2.rectangle(img34,(626,719),(652,749),(26,64,0),-1)#body
e1=cv2.circle(img34,(638,705),14,(155,226,254),-1)# head
e1=cv2.circle(img34,(661,596),6,(255,255,255),-1)# right ball
e1 = cv2.line(img34,(653,724),(663,736),(155,226,254),5)#right hand 
e1 = cv2.line(img34,(625,725),(620,732),(155,226,254),5)#left hand
e1 = cv2.line(img34,(632,702),(643,702),(0,0,0),20)#top hair
e1=cv2.rectangle(img34,(631,749),(637,762),(26,64,0),-1)#left leg
e1=cv2.rectangle(img34,(642,749),(648,762),(26,64,0),-1)#right leg



# pakistan player
e1=cv2.rectangle(img34,(292,293),(300,322),(26,64,0),-1)#right leg
e1=cv2.rectangle(img34,(288,253),(320,298),(26,64,0),-1)#body
e1=cv2.rectangle(img34,(309,293),(317,322),(26,64,0),-1)#left leg
e1=cv2.circle(img34,(303,239),16,(155,226,254),-1)# head
e1=cv2.circle(img34,(295,242),2,(0,0,0),-1)# right eye
e1=cv2.circle(img34,(310,242),2,(0,0,0),-1)# left eye
e1 = cv2.line(img34,(298,249),(307,249),(0,0,0),2)#mouth
e1 = cv2.line(img34,(289,265),(294,276),(155,226,254),4)#right hand 
e1 = cv2.line(img34,(318,265),(310,276),(155,226,254),4)#left hand
e1 = cv2.line(img34,(293,229),(312,229),(0,0,0),13)#top hair


#Indian  player
e1=cv2.rectangle(img34,(548,767),(555,784),(255,0,0),-1)#left leg
e1=cv2.rectangle(img34,(569,767),(545,742),(255,0,0),-1)#body
e1=cv2.rectangle(img34,(560,767),(567,784),(255,0,0),-1)#right leg
e1=cv2.circle(img34,(557,729),14,(155,226,254),-1)# head
e1 = cv2.line(img34,(570,748),(574,761),(155,226,254),3)#right hand 
e1 = cv2.line(img34,(544,747),(537,754),(155,226,254),3)#left hand
e1 = cv2.line(img34,(575,761),(580,778),(29,101,181),10)#bat
e1 = cv2.line(img34,(550,724),(562,724),(0,0,0),21)#top hair




cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # 32 POINT

# %%
img35=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img35,(0,0),(1200,800),(0,178,0),-1) #layout

e1 = cv2.line(img35,(600,800),(530,400),(128,178,194),10)# left line
e1 = cv2.line(img35,(610,800),(540,400),(128,178,194),10)# left line
e1 = cv2.line(img35,(620,800),(550,400),(128,178,194),10)# left line
e1 = cv2.line(img35,(630,800),(560,400),(128,178,194),10)# left line
e1 = cv2.line(img35,(640,800),(570,400),(128,178,194),10)# left line
e1 = cv2.line(img35,(650,800),(580,400),(128,178,194),10)# left line
e1 = cv2.line(img35,(660,800),(590,400),(128,178,194),10)# left line
e1 = cv2.line(img35,(670,800),(600,400),(128,178,194),10)# left line
e1 = cv2.line(img35,(680,800),(610,400),(128,178,194),10)# left line
e1 = cv2.line(img35,(690,800),(620,400),(128,178,194),10)# left line
e1 = cv2.line(img35,(700,800),(630,400),(128,178,194),10)# left line
e1 = cv2.line(img35,(710,800),(640,400),(128,178,194),10)# left line
e1 = cv2.line(img35,(720,800),(650,400),(128,178,194),10)# left line
e1 = cv2.line(img35,(730,800),(660,400),(128,178,194),10)# left line
e1 = cv2.line(img35,(740,800),(670,400),(128,178,194),10)# left line
e1 = cv2.line(img35,(750,800),(680,400),(128,178,194),10)# left line
e1 = cv2.line(img35,(760,800),(690,400),(128,178,194),10)# left line

e1 = cv2.line(img35,(450,800),(530,400),(128,178,194),10)#right line
e1 = cv2.line(img35,(460,800),(540,400),(128,178,194),10)#right line
e1 = cv2.line(img35,(470,800),(550,400),(128,178,194),10)#right line
e1 = cv2.line(img35,(480,800),(560,400),(128,178,194),10)#right line
e1 = cv2.line(img35,(490,800),(570,400),(128,178,194),10)#right line
e1 = cv2.line(img35,(500,800),(580,400),(128,178,194),10)#right line
e1 = cv2.line(img35,(510,800),(590,400),(128,178,194),10)#right line
e1 = cv2.line(img35,(520,800),(600,400),(128,178,194),10)#right line
e1 = cv2.line(img35,(530,800),(610,400),(128,178,194),10)#right line
e1 = cv2.line(img35,(540,800),(620,400),(128,178,194),10)#right line
e1 = cv2.line(img35,(550,800),(630,400),(128,178,194),10)#right line
e1 = cv2.line(img35,(560,800),(640,400),(128,178,194),10)#right line
e1 = cv2.line(img35,(570,800),(650,400),(128,178,194),10)#right line
e1 = cv2.line(img35,(580,800),(660,400),(128,178,194),10)#right line
e1 = cv2.line(img35,(590,800),(670,400),(128,178,194),10)#right line

e1 = cv2.line(img35,(760,800),(690,400),(255,255,255),2)# left line
e1 = cv2.line(img35,(450,800),(530,400),(255,255,255),2)#right line
e1 = cv2.line(img35,(690,400),(530,400),(255,255,255),2)# middle line
e1 = cv2.line(img35,(600,1200),(600,760),(0,0,0),5)   #middle wicket   #buttom side
e1 = cv2.line(img35,(590,1200),(590,760),(0,0,0),5)   #left wicket
e1 = cv2.line(img35,(610,1200),(610,760),(0,0,0),5)   #right wicket
e1 = cv2.line(img35,(590,760),(610,760),(0,0,0),5)    #top wicket
e1 = cv2.line(img35,(430,750),(780,750),(255,255,255),2)#buttom boundary line 
e1 = cv2.line(img35,(500,750),(490,850),(255,255,255),2)#boundary left line
e1 = cv2.line(img35,(710,750),(720,850),(255,255,255),2)#boundary right line

e1 = cv2.line(img35,(760,800),(690,400),(255,255,255),2)# left line
e1 = cv2.line(img35,(450,800),(530,400),(255,255,255),2)#right line
e1 = cv2.line(img35,(690,400),(530,400),(255,255,255),2)# middle line
e1 = cv2.line(img35,(620,400),(620,360),(0,0,0),5)   #right wicket     #top side
e1 = cv2.line(img35,(600,400),(600,360),(0,0,0),5)   #lift wicket
e1 = cv2.line(img35,(610,400),(610,360),(0,0,0),5)   #middle wicket
e1 = cv2.line(img35,(600,360),(620,360),(0,0,0),5)    #top wicket
e1 = cv2.line(img35,(490,440),(720,440),(255,255,255),2) # top boundary line
e1 = cv2.line(img35,(555,440),(560,400),(255,255,255),2)#boundary left line
e1 = cv2.line(img35,(655,440),(655,400),(255,255,255),2)#boundary right line




#indian player

e1=cv2.rectangle(img35,(642,402),(648,440),(255,0,0),-1)#right leg
e1=cv2.rectangle(img35,(629,352),(650,402),(255,0,0),-1)#body
e1=cv2.rectangle(img35,(631,402),(637,440),(255,0,0),-1)#left leg
e1=cv2.circle(img35,(640,339),13,(155,226,254),-1)# head
e1=cv2.circle(img35,(632,340),2,(0,0,0),-1)# right eye
e1=cv2.circle(img35,(637,340),2,(0,0,0),-1)# left eye
e1=cv2.circle(img35,(635,346),2,(0,0,0),-1)#mouth
e1 = cv2.line(img35,(632,364),(620,400),(155,226,254),3)#right hand 
e1 = cv2.line(img35,(641,373),(623,400),(155,226,254),3)#left hand
e1 = cv2.line(img35,(621,400),(603,435),(29,101,181),10)#bat
e1 = cv2.line(img35,(632,329),(647,329),(0,0,0),10)#top hair
e1 = cv2.line(img35,(647,336),(646,348),(0,0,0),10)#left hair


# pakistan wicket player

e1=cv2.rectangle(img35,(592,362),(586,395),(26,64,0),-1)#right leg
e1=cv2.rectangle(img35,(570,351),(593,379),(26,64,0),-1)#body
e1=cv2.rectangle(img35,(572,362),(579,395),(26,64,0),-1)#left leg
e1=cv2.circle(img35,(581,336),14,(155,226,254),-1)# head
e1=cv2.circle(img35,(576,338),2,(0,0,0),-1)# right eye
e1=cv2.circle(img35,(587,338),2,(0,0,0),-1)# left eye
e1 = cv2.line(img35,(578,345),(585,345),(0,0,0),2)#mouth
e1 = cv2.line(img35,(572,360),(582,369),(155,226,254),4)#right hand 
e1 = cv2.line(img35,(591,360),(582,369),(155,226,254),4)#left hand
e1 = cv2.line(img35,(581,368),(582,369),(255,255,255),10)#glove
e1 = cv2.line(img35,(571,326),(588,326),(0,0,0),10)#top hair



#bowler


e1=cv2.rectangle(img35,(626,719),(652,749),(26,64,0),-1)#body
e1=cv2.circle(img35,(638,705),14,(155,226,254),-1)# head
e1=cv2.circle(img35,(653,555),6,(255,255,255),-1)# right ball
e1 = cv2.line(img35,(653,724),(663,736),(155,226,254),5)#right hand 
e1 = cv2.line(img35,(625,725),(620,732),(155,226,254),5)#left hand
e1 = cv2.line(img35,(632,702),(643,702),(0,0,0),20)#top hair
e1=cv2.rectangle(img35,(631,749),(637,762),(26,64,0),-1)#left leg
e1=cv2.rectangle(img35,(642,749),(648,762),(26,64,0),-1)#right leg



# pakistan player
e1=cv2.rectangle(img35,(292,293),(300,322),(26,64,0),-1)#right leg
e1=cv2.rectangle(img35,(288,253),(320,298),(26,64,0),-1)#body
e1=cv2.rectangle(img35,(309,293),(317,322),(26,64,0),-1)#left leg
e1=cv2.circle(img35,(303,239),16,(155,226,254),-1)# head
e1=cv2.circle(img35,(295,242),2,(0,0,0),-1)# right eye
e1=cv2.circle(img35,(310,242),2,(0,0,0),-1)# left eye
e1 = cv2.line(img35,(298,249),(307,249),(0,0,0),2)#mouth
e1 = cv2.line(img35,(289,265),(294,276),(155,226,254),4)#right hand 
e1 = cv2.line(img35,(318,265),(310,276),(155,226,254),4)#left hand
e1 = cv2.line(img35,(293,229),(312,229),(0,0,0),13)#top hair


#Indian  player
e1=cv2.rectangle(img35,(548,767),(555,784),(255,0,0),-1)#left leg
e1=cv2.rectangle(img35,(569,767),(545,742),(255,0,0),-1)#body
e1=cv2.rectangle(img35,(560,767),(567,784),(255,0,0),-1)#right leg
e1=cv2.circle(img35,(557,729),14,(155,226,254),-1)# head
e1 = cv2.line(img35,(570,748),(574,761),(155,226,254),3)#right hand 
e1 = cv2.line(img35,(544,747),(537,754),(155,226,254),3)#left hand
e1 = cv2.line(img35,(575,761),(580,778),(29,101,181),10)#bat
e1 = cv2.line(img35,(550,724),(562,724),(0,0,0),21)#top hair




cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # 33 POINT

# %%
img36=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img36,(0,0),(1200,800),(0,178,0),-1) #layout

e1 = cv2.line(img36,(600,800),(530,400),(128,178,194),10)# left line
e1 = cv2.line(img36,(610,800),(540,400),(128,178,194),10)# left line
e1 = cv2.line(img36,(620,800),(550,400),(128,178,194),10)# left line
e1 = cv2.line(img36,(630,800),(560,400),(128,178,194),10)# left line
e1 = cv2.line(img36,(640,800),(570,400),(128,178,194),10)# left line
e1 = cv2.line(img36,(650,800),(580,400),(128,178,194),10)# left line
e1 = cv2.line(img36,(660,800),(590,400),(128,178,194),10)# left line
e1 = cv2.line(img36,(670,800),(600,400),(128,178,194),10)# left line
e1 = cv2.line(img36,(680,800),(610,400),(128,178,194),10)# left line
e1 = cv2.line(img36,(690,800),(620,400),(128,178,194),10)# left line
e1 = cv2.line(img36,(700,800),(630,400),(128,178,194),10)# left line
e1 = cv2.line(img36,(710,800),(640,400),(128,178,194),10)# left line
e1 = cv2.line(img36,(720,800),(650,400),(128,178,194),10)# left line
e1 = cv2.line(img36,(730,800),(660,400),(128,178,194),10)# left line
e1 = cv2.line(img36,(740,800),(670,400),(128,178,194),10)# left line
e1 = cv2.line(img36,(750,800),(680,400),(128,178,194),10)# left line
e1 = cv2.line(img36,(760,800),(690,400),(128,178,194),10)# left line

e1 = cv2.line(img36,(450,800),(530,400),(128,178,194),10)#right line
e1 = cv2.line(img36,(460,800),(540,400),(128,178,194),10)#right line
e1 = cv2.line(img36,(470,800),(550,400),(128,178,194),10)#right line
e1 = cv2.line(img36,(480,800),(560,400),(128,178,194),10)#right line
e1 = cv2.line(img36,(490,800),(570,400),(128,178,194),10)#right line
e1 = cv2.line(img36,(500,800),(580,400),(128,178,194),10)#right line
e1 = cv2.line(img36,(510,800),(590,400),(128,178,194),10)#right line
e1 = cv2.line(img36,(520,800),(600,400),(128,178,194),10)#right line
e1 = cv2.line(img36,(530,800),(610,400),(128,178,194),10)#right line
e1 = cv2.line(img36,(540,800),(620,400),(128,178,194),10)#right line
e1 = cv2.line(img36,(550,800),(630,400),(128,178,194),10)#right line
e1 = cv2.line(img36,(560,800),(640,400),(128,178,194),10)#right line
e1 = cv2.line(img36,(570,800),(650,400),(128,178,194),10)#right line
e1 = cv2.line(img36,(580,800),(660,400),(128,178,194),10)#right line
e1 = cv2.line(img36,(590,800),(670,400),(128,178,194),10)#right line

e1 = cv2.line(img36,(760,800),(690,400),(255,255,255),2)# left line
e1 = cv2.line(img36,(450,800),(530,400),(255,255,255),2)#right line
e1 = cv2.line(img36,(690,400),(530,400),(255,255,255),2)# middle line
e1 = cv2.line(img36,(600,1200),(600,760),(0,0,0),5)   #middle wicket   #buttom side
e1 = cv2.line(img36,(590,1200),(590,760),(0,0,0),5)   #left wicket
e1 = cv2.line(img36,(610,1200),(610,760),(0,0,0),5)   #right wicket
e1 = cv2.line(img36,(590,760),(610,760),(0,0,0),5)    #top wicket
e1 = cv2.line(img36,(430,750),(780,750),(255,255,255),2)#buttom boundary line 
e1 = cv2.line(img36,(500,750),(490,850),(255,255,255),2)#boundary left line
e1 = cv2.line(img36,(710,750),(720,850),(255,255,255),2)#boundary right line

e1 = cv2.line(img36,(760,800),(690,400),(255,255,255),2)# left line
e1 = cv2.line(img36,(450,800),(530,400),(255,255,255),2)#right line
e1 = cv2.line(img36,(690,400),(530,400),(255,255,255),2)# middle line
e1 = cv2.line(img36,(620,400),(620,360),(0,0,0),5)   #right wicket     #top side
e1 = cv2.line(img36,(600,400),(600,360),(0,0,0),5)   #lift wicket
e1 = cv2.line(img36,(610,400),(610,360),(0,0,0),5)   #middle wicket
e1 = cv2.line(img36,(600,360),(620,360),(0,0,0),5)    #top wicket
e1 = cv2.line(img36,(490,440),(720,440),(255,255,255),2) # top boundary line
e1 = cv2.line(img36,(555,440),(560,400),(255,255,255),2)#boundary left line
e1 = cv2.line(img36,(655,440),(655,400),(255,255,255),2)#boundary right line




#indian player

e1=cv2.rectangle(img36,(642,402),(648,440),(255,0,0),-1)#right leg
e1=cv2.rectangle(img36,(629,352),(650,402),(255,0,0),-1)#body
e1=cv2.rectangle(img36,(631,402),(637,440),(255,0,0),-1)#left leg
e1=cv2.circle(img36,(640,339),13,(155,226,254),-1)# head
e1=cv2.circle(img36,(632,340),2,(0,0,0),-1)# right eye
e1=cv2.circle(img36,(637,340),2,(0,0,0),-1)# left eye
e1=cv2.circle(img36,(635,346),2,(0,0,0),-1)#mouth
e1 = cv2.line(img36,(632,364),(620,400),(155,226,254),3)#right hand 
e1 = cv2.line(img36,(641,373),(623,400),(155,226,254),3)#left hand
e1 = cv2.line(img36,(621,400),(603,435),(29,101,181),10)#bat
e1 = cv2.line(img36,(632,329),(647,329),(0,0,0),10)#top hair
e1 = cv2.line(img36,(647,336),(646,348),(0,0,0),10)#left hair


# pakistan wicket player

e1=cv2.rectangle(img36,(592,362),(586,395),(26,64,0),-1)#right leg
e1=cv2.rectangle(img36,(570,351),(593,379),(26,64,0),-1)#body
e1=cv2.rectangle(img36,(572,362),(579,395),(26,64,0),-1)#left leg
e1=cv2.circle(img36,(581,336),14,(155,226,254),-1)# head
e1=cv2.circle(img36,(576,338),2,(0,0,0),-1)# right eye
e1=cv2.circle(img36,(587,338),2,(0,0,0),-1)# left eye
e1 = cv2.line(img36,(578,345),(585,345),(0,0,0),2)#mouth
e1 = cv2.line(img36,(572,360),(582,369),(155,226,254),4)#right hand 
e1 = cv2.line(img36,(591,360),(582,369),(155,226,254),4)#left hand
e1 = cv2.line(img36,(581,368),(582,369),(255,255,255),10)#glove
e1 = cv2.line(img36,(571,326),(588,326),(0,0,0),10)#top hair



#bowler


e1=cv2.rectangle(img36,(626,719),(652,749),(26,64,0),-1)#body
e1=cv2.circle(img36,(638,705),14,(155,226,254),-1)# head
e1=cv2.circle(img36,(643,520),6,(255,255,255),-1)# right ball
e1 = cv2.line(img36,(653,724),(663,736),(155,226,254),5)#right hand 
e1 = cv2.line(img36,(625,725),(620,732),(155,226,254),5)#left hand
e1 = cv2.line(img36,(632,702),(643,702),(0,0,0),20)#top hair
e1=cv2.rectangle(img36,(631,749),(637,762),(26,64,0),-1)#left leg
e1=cv2.rectangle(img36,(642,749),(648,762),(26,64,0),-1)#right leg



# pakistan player
e1=cv2.rectangle(img36,(292,293),(300,322),(26,64,0),-1)#right leg
e1=cv2.rectangle(img36,(288,253),(320,298),(26,64,0),-1)#body
e1=cv2.rectangle(img36,(309,293),(317,322),(26,64,0),-1)#left leg
e1=cv2.circle(img36,(303,239),16,(155,226,254),-1)# head
e1=cv2.circle(img36,(295,242),2,(0,0,0),-1)# right eye
e1=cv2.circle(img36,(310,242),2,(0,0,0),-1)# left eye
e1 = cv2.line(img36,(298,249),(307,249),(0,0,0),2)#mouth
e1 = cv2.line(img36,(289,265),(294,276),(155,226,254),4)#right hand 
e1 = cv2.line(img36,(318,265),(310,276),(155,226,254),4)#left hand
e1 = cv2.line(img36,(293,229),(312,229),(0,0,0),13)#top hair


#Indian  player
e1=cv2.rectangle(img36,(548,767),(555,784),(255,0,0),-1)#left leg
e1=cv2.rectangle(img36,(569,767),(545,742),(255,0,0),-1)#body
e1=cv2.rectangle(img36,(560,767),(567,784),(255,0,0),-1)#right leg
e1=cv2.circle(img36,(557,729),14,(155,226,254),-1)# head
e1 = cv2.line(img36,(570,748),(574,761),(155,226,254),3)#right hand 
e1 = cv2.line(img36,(544,747),(537,754),(155,226,254),3)#left hand
e1 = cv2.line(img36,(575,761),(580,778),(29,101,181),10)#bat
e1 = cv2.line(img36,(550,724),(562,724),(0,0,0),21)#top hair




cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # 34 POINT

# %%
img37=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img37,(0,0),(1200,800),(0,178,0),-1) #layout

e1 = cv2.line(img37,(600,800),(530,400),(128,178,194),10)# left line
e1 = cv2.line(img37,(610,800),(540,400),(128,178,194),10)# left line
e1 = cv2.line(img37,(620,800),(550,400),(128,178,194),10)# left line
e1 = cv2.line(img37,(630,800),(560,400),(128,178,194),10)# left line
e1 = cv2.line(img37,(640,800),(570,400),(128,178,194),10)# left line
e1 = cv2.line(img37,(650,800),(580,400),(128,178,194),10)# left line
e1 = cv2.line(img37,(660,800),(590,400),(128,178,194),10)# left line
e1 = cv2.line(img37,(670,800),(600,400),(128,178,194),10)# left line
e1 = cv2.line(img37,(680,800),(610,400),(128,178,194),10)# left line
e1 = cv2.line(img37,(690,800),(620,400),(128,178,194),10)# left line
e1 = cv2.line(img37,(700,800),(630,400),(128,178,194),10)# left line
e1 = cv2.line(img37,(710,800),(640,400),(128,178,194),10)# left line
e1 = cv2.line(img37,(720,800),(650,400),(128,178,194),10)# left line
e1 = cv2.line(img37,(730,800),(660,400),(128,178,194),10)# left line
e1 = cv2.line(img37,(740,800),(670,400),(128,178,194),10)# left line
e1 = cv2.line(img37,(750,800),(680,400),(128,178,194),10)# left line
e1 = cv2.line(img37,(760,800),(690,400),(128,178,194),10)# left line

e1 = cv2.line(img37,(450,800),(530,400),(128,178,194),10)#right line
e1 = cv2.line(img37,(460,800),(540,400),(128,178,194),10)#right line
e1 = cv2.line(img37,(470,800),(550,400),(128,178,194),10)#right line
e1 = cv2.line(img37,(480,800),(560,400),(128,178,194),10)#right line
e1 = cv2.line(img37,(490,800),(570,400),(128,178,194),10)#right line
e1 = cv2.line(img37,(500,800),(580,400),(128,178,194),10)#right line
e1 = cv2.line(img37,(510,800),(590,400),(128,178,194),10)#right line
e1 = cv2.line(img37,(520,800),(600,400),(128,178,194),10)#right line
e1 = cv2.line(img37,(530,800),(610,400),(128,178,194),10)#right line
e1 = cv2.line(img37,(540,800),(620,400),(128,178,194),10)#right line
e1 = cv2.line(img37,(550,800),(630,400),(128,178,194),10)#right line
e1 = cv2.line(img37,(560,800),(640,400),(128,178,194),10)#right line
e1 = cv2.line(img37,(570,800),(650,400),(128,178,194),10)#right line
e1 = cv2.line(img37,(580,800),(660,400),(128,178,194),10)#right line
e1 = cv2.line(img37,(590,800),(670,400),(128,178,194),10)#right line

e1 = cv2.line(img37,(760,800),(690,400),(255,255,255),2)# left line
e1 = cv2.line(img37,(450,800),(530,400),(255,255,255),2)#right line
e1 = cv2.line(img37,(690,400),(530,400),(255,255,255),2)# middle line
e1 = cv2.line(img37,(600,1200),(600,760),(0,0,0),5)   #middle wicket   #buttom side
e1 = cv2.line(img37,(590,1200),(590,760),(0,0,0),5)   #left wicket
e1 = cv2.line(img37,(610,1200),(610,760),(0,0,0),5)   #right wicket
e1 = cv2.line(img37,(590,760),(610,760),(0,0,0),5)    #top wicket
e1 = cv2.line(img37,(430,750),(780,750),(255,255,255),2)#buttom boundary line 
e1 = cv2.line(img37,(500,750),(490,850),(255,255,255),2)#boundary left line
e1 = cv2.line(img37,(710,750),(720,850),(255,255,255),2)#boundary right line

e1 = cv2.line(img37,(760,800),(690,400),(255,255,255),2)# left line
e1 = cv2.line(img37,(450,800),(530,400),(255,255,255),2)#right line
e1 = cv2.line(img37,(690,400),(530,400),(255,255,255),2)# middle line
e1 = cv2.line(img37,(620,400),(620,360),(0,0,0),5)   #right wicket     #top side
e1 = cv2.line(img37,(600,400),(600,360),(0,0,0),5)   #lift wicket
e1 = cv2.line(img37,(610,400),(610,360),(0,0,0),5)   #middle wicket
e1 = cv2.line(img37,(600,360),(620,360),(0,0,0),5)    #top wicket
e1 = cv2.line(img37,(490,440),(720,440),(255,255,255),2) # top boundary line
e1 = cv2.line(img37,(555,440),(560,400),(255,255,255),2)#boundary left line
e1 = cv2.line(img37,(655,440),(655,400),(255,255,255),2)#boundary right line




#indian player

e1=cv2.rectangle(img37,(642,402),(648,440),(255,0,0),-1)#right leg
e1=cv2.rectangle(img37,(629,352),(650,402),(255,0,0),-1)#body
e1=cv2.rectangle(img37,(631,402),(637,440),(255,0,0),-1)#left leg
e1=cv2.circle(img37,(640,339),13,(155,226,254),-1)# head
e1=cv2.circle(img37,(632,340),2,(0,0,0),-1)# right eye
e1=cv2.circle(img37,(637,340),2,(0,0,0),-1)# left eye
e1=cv2.circle(img37,(635,346),2,(0,0,0),-1)#mouth
e1 = cv2.line(img37,(632,364),(620,400),(155,226,254),3)#right hand 
e1 = cv2.line(img37,(641,373),(623,400),(155,226,254),3)#left hand
e1 = cv2.line(img37,(621,400),(603,422),(29,101,181),10)#bat
e1 = cv2.line(img37,(632,329),(647,329),(0,0,0),10)#top hair
e1 = cv2.line(img37,(647,336),(646,348),(0,0,0),10)#left hair


# pakistan wicket player

e1=cv2.rectangle(img37,(592,362),(586,395),(26,64,0),-1)#right leg
e1=cv2.rectangle(img37,(570,351),(593,379),(26,64,0),-1)#body
e1=cv2.rectangle(img37,(572,362),(579,395),(26,64,0),-1)#left leg
e1=cv2.circle(img37,(581,336),14,(155,226,254),-1)# head
e1=cv2.circle(img37,(576,338),2,(0,0,0),-1)# right eye
e1=cv2.circle(img37,(587,338),2,(0,0,0),-1)# left eye
e1 = cv2.line(img37,(578,345),(585,345),(0,0,0),2)#mouth
e1 = cv2.line(img37,(572,360),(582,369),(155,226,254),4)#right hand 
e1 = cv2.line(img37,(591,360),(582,369),(155,226,254),4)#left hand
e1 = cv2.line(img37,(581,368),(582,369),(255,255,255),10)#glove
e1 = cv2.line(img37,(571,326),(588,326),(0,0,0),10)#top hair



#bowler


e1=cv2.rectangle(img37,(626,719),(652,749),(26,64,0),-1)#body
e1=cv2.circle(img37,(638,705),14,(155,226,254),-1)# head
e1=cv2.circle(img37,(634,490),6,(255,255,255),-1)# right ball
e1 = cv2.line(img37,(653,724),(663,736),(155,226,254),5)#right hand 
e1 = cv2.line(img37,(625,725),(620,732),(155,226,254),5)#left hand
e1 = cv2.line(img37,(632,702),(643,702),(0,0,0),20)#top hair
e1=cv2.rectangle(img37,(631,749),(637,762),(26,64,0),-1)#left leg
e1=cv2.rectangle(img37,(642,749),(648,762),(26,64,0),-1)#right leg



# pakistan player
e1=cv2.rectangle(img37,(292,293),(300,322),(26,64,0),-1)#right leg
e1=cv2.rectangle(img37,(288,253),(320,298),(26,64,0),-1)#body
e1=cv2.rectangle(img37,(309,293),(317,322),(26,64,0),-1)#left leg
e1=cv2.circle(img37,(303,239),16,(155,226,254),-1)# head
e1=cv2.circle(img37,(295,242),2,(0,0,0),-1)# right eye
e1=cv2.circle(img37,(310,242),2,(0,0,0),-1)# left eye
e1 = cv2.line(img37,(298,249),(307,249),(0,0,0),2)#mouth
e1 = cv2.line(img37,(289,265),(294,276),(155,226,254),4)#right hand 
e1 = cv2.line(img37,(318,265),(310,276),(155,226,254),4)#left hand
e1 = cv2.line(img37,(293,229),(312,229),(0,0,0),13)#top hair


#Indian  player
e1=cv2.rectangle(img37,(548,767),(555,784),(255,0,0),-1)#left leg
e1=cv2.rectangle(img37,(569,767),(545,742),(255,0,0),-1)#body
e1=cv2.rectangle(img37,(560,767),(567,784),(255,0,0),-1)#right leg
e1=cv2.circle(img37,(557,729),14,(155,226,254),-1)# head
e1 = cv2.line(img37,(570,748),(574,761),(155,226,254),3)#right hand 
e1 = cv2.line(img37,(544,747),(537,754),(155,226,254),3)#left hand
e1 = cv2.line(img37,(575,761),(580,778),(29,101,181),10)#bat
e1 = cv2.line(img37,(550,724),(562,724),(0,0,0),21)#top hair




cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # 35 POINT

# %%
img38=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img38,(0,0),(1200,800),(0,178,0),-1) #layout

e1 = cv2.line(img38,(600,800),(530,400),(128,178,194),10)# left line
e1 = cv2.line(img38,(610,800),(540,400),(128,178,194),10)# left line
e1 = cv2.line(img38,(620,800),(550,400),(128,178,194),10)# left line
e1 = cv2.line(img38,(630,800),(560,400),(128,178,194),10)# left line
e1 = cv2.line(img38,(640,800),(570,400),(128,178,194),10)# left line
e1 = cv2.line(img38,(650,800),(580,400),(128,178,194),10)# left line
e1 = cv2.line(img38,(660,800),(590,400),(128,178,194),10)# left line
e1 = cv2.line(img38,(670,800),(600,400),(128,178,194),10)# left line
e1 = cv2.line(img38,(680,800),(610,400),(128,178,194),10)# left line
e1 = cv2.line(img38,(690,800),(620,400),(128,178,194),10)# left line
e1 = cv2.line(img38,(700,800),(630,400),(128,178,194),10)# left line
e1 = cv2.line(img38,(710,800),(640,400),(128,178,194),10)# left line
e1 = cv2.line(img38,(720,800),(650,400),(128,178,194),10)# left line
e1 = cv2.line(img38,(730,800),(660,400),(128,178,194),10)# left line
e1 = cv2.line(img38,(740,800),(670,400),(128,178,194),10)# left line
e1 = cv2.line(img38,(750,800),(680,400),(128,178,194),10)# left line
e1 = cv2.line(img38,(760,800),(690,400),(128,178,194),10)# left line

e1 = cv2.line(img38,(450,800),(530,400),(128,178,194),10)#right line
e1 = cv2.line(img38,(460,800),(540,400),(128,178,194),10)#right line
e1 = cv2.line(img38,(470,800),(550,400),(128,178,194),10)#right line
e1 = cv2.line(img38,(480,800),(560,400),(128,178,194),10)#right line
e1 = cv2.line(img38,(490,800),(570,400),(128,178,194),10)#right line
e1 = cv2.line(img38,(500,800),(580,400),(128,178,194),10)#right line
e1 = cv2.line(img38,(510,800),(590,400),(128,178,194),10)#right line
e1 = cv2.line(img38,(520,800),(600,400),(128,178,194),10)#right line
e1 = cv2.line(img38,(530,800),(610,400),(128,178,194),10)#right line
e1 = cv2.line(img38,(540,800),(620,400),(128,178,194),10)#right line
e1 = cv2.line(img38,(550,800),(630,400),(128,178,194),10)#right line
e1 = cv2.line(img38,(560,800),(640,400),(128,178,194),10)#right line
e1 = cv2.line(img38,(570,800),(650,400),(128,178,194),10)#right line
e1 = cv2.line(img38,(580,800),(660,400),(128,178,194),10)#right line
e1 = cv2.line(img38,(590,800),(670,400),(128,178,194),10)#right line

e1 = cv2.line(img38,(760,800),(690,400),(255,255,255),2)# left line
e1 = cv2.line(img38,(450,800),(530,400),(255,255,255),2)#right line
e1 = cv2.line(img38,(690,400),(530,400),(255,255,255),2)# middle line
e1 = cv2.line(img38,(600,1200),(600,760),(0,0,0),5)   #middle wicket   #buttom side
e1 = cv2.line(img38,(590,1200),(590,760),(0,0,0),5)   #left wicket
e1 = cv2.line(img38,(610,1200),(610,760),(0,0,0),5)   #right wicket
e1 = cv2.line(img38,(590,760),(610,760),(0,0,0),5)    #top wicket
e1 = cv2.line(img38,(430,750),(780,750),(255,255,255),2)#buttom boundary line 
e1 = cv2.line(img38,(500,750),(490,850),(255,255,255),2)#boundary left line
e1 = cv2.line(img38,(710,750),(720,850),(255,255,255),2)#boundary right line

e1 = cv2.line(img38,(760,800),(690,400),(255,255,255),2)# left line
e1 = cv2.line(img38,(450,800),(530,400),(255,255,255),2)#right line
e1 = cv2.line(img38,(690,400),(530,400),(255,255,255),2)# middle line
e1 = cv2.line(img38,(620,400),(620,360),(0,0,0),5)   #right wicket     #top side
e1 = cv2.line(img38,(600,400),(600,360),(0,0,0),5)   #lift wicket
e1 = cv2.line(img38,(610,400),(610,360),(0,0,0),5)   #middle wicket
e1 = cv2.line(img38,(600,360),(620,360),(0,0,0),5)    #top wicket
e1 = cv2.line(img38,(490,440),(720,440),(255,255,255),2) # top boundary line
e1 = cv2.line(img38,(555,440),(560,400),(255,255,255),2)#boundary left line
e1 = cv2.line(img38,(655,440),(655,400),(255,255,255),2)#boundary right line




#indian player

e1=cv2.rectangle(img38,(642,402),(648,440),(255,0,0),-1)#right leg
e1=cv2.rectangle(img38,(629,352),(650,402),(255,0,0),-1)#body
e1=cv2.rectangle(img38,(631,402),(637,440),(255,0,0),-1)#left leg
e1=cv2.circle(img38,(640,339),13,(155,226,254),-1)# head
e1=cv2.circle(img38,(632,340),2,(0,0,0),-1)# right eye
e1=cv2.circle(img38,(637,340),2,(0,0,0),-1)# left eye
e1=cv2.circle(img38,(635,346),2,(0,0,0),-1)#mouth
e1 = cv2.line(img38,(632,364),(620,400),(155,226,254),3)#right hand 
e1 = cv2.line(img38,(641,373),(623,400),(155,226,254),3)#left hand
e1 = cv2.line(img38,(621,400),(603,422),(29,101,181),10)#bat
e1 = cv2.line(img38,(632,329),(647,329),(0,0,0),10)#top hair
e1 = cv2.line(img38,(647,336),(646,348),(0,0,0),10)#left hair


# pakistan wicket player

e1=cv2.rectangle(img38,(592,362),(586,395),(26,64,0),-1)#right leg
e1=cv2.rectangle(img38,(570,351),(593,379),(26,64,0),-1)#body
e1=cv2.rectangle(img38,(572,362),(579,395),(26,64,0),-1)#left leg
e1=cv2.circle(img38,(581,336),14,(155,226,254),-1)# head
e1=cv2.circle(img38,(576,338),2,(0,0,0),-1)# right eye
e1=cv2.circle(img38,(587,338),2,(0,0,0),-1)# left eye
e1 = cv2.line(img38,(578,345),(585,345),(0,0,0),2)#mouth
e1 = cv2.line(img38,(572,360),(582,369),(155,226,254),4)#right hand 
e1 = cv2.line(img38,(591,360),(582,369),(155,226,254),4)#left hand
e1 = cv2.line(img38,(581,368),(582,369),(255,255,255),10)#glove
e1 = cv2.line(img38,(571,326),(588,326),(0,0,0),10)#top hair



#bowler


e1=cv2.rectangle(img38,(626,719),(652,749),(26,64,0),-1)#body
e1=cv2.circle(img38,(638,705),14,(155,226,254),-1)# head
e1=cv2.circle(img38,(623,461),6,(255,255,255),-1)# right ball
e1 = cv2.line(img38,(653,724),(663,736),(155,226,254),5)#right hand 
e1 = cv2.line(img38,(625,725),(620,732),(155,226,254),5)#left hand
e1 = cv2.line(img38,(632,702),(643,702),(0,0,0),20)#top hair
e1=cv2.rectangle(img38,(631,749),(637,762),(26,64,0),-1)#left leg
e1=cv2.rectangle(img38,(642,749),(648,762),(26,64,0),-1)#right leg



# pakistan player
e1=cv2.rectangle(img38,(292,293),(300,322),(26,64,0),-1)#right leg
e1=cv2.rectangle(img38,(288,253),(320,298),(26,64,0),-1)#body
e1=cv2.rectangle(img38,(309,293),(317,322),(26,64,0),-1)#left leg
e1=cv2.circle(img38,(303,239),16,(155,226,254),-1)# head
e1=cv2.circle(img38,(295,242),2,(0,0,0),-1)# right eye
e1=cv2.circle(img38,(310,242),2,(0,0,0),-1)# left eye
e1 = cv2.line(img38,(298,249),(307,249),(0,0,0),2)#mouth
e1 = cv2.line(img38,(289,265),(294,276),(155,226,254),4)#right hand 
e1 = cv2.line(img38,(318,265),(310,276),(155,226,254),4)#left hand
e1 = cv2.line(img38,(293,229),(312,229),(0,0,0),13)#top hair


#Indian  player
e1=cv2.rectangle(img38,(548,767),(555,784),(255,0,0),-1)#left leg
e1=cv2.rectangle(img38,(569,767),(545,742),(255,0,0),-1)#body
e1=cv2.rectangle(img38,(560,767),(567,784),(255,0,0),-1)#right leg
e1=cv2.circle(img38,(557,729),14,(155,226,254),-1)# head
e1 = cv2.line(img38,(570,748),(574,761),(155,226,254),3)#right hand 
e1 = cv2.line(img38,(544,747),(537,754),(155,226,254),3)#left hand
e1 = cv2.line(img38,(575,761),(580,778),(29,101,181),10)#bat
e1 = cv2.line(img38,(550,724),(562,724),(0,0,0),21)#top hair




cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # 36 POINT

# %%
img39=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img39,(0,0),(1200,800),(0,178,0),-1) #layout

e1 = cv2.line(img39,(600,800),(530,400),(128,178,194),10)# left line
e1 = cv2.line(img39,(610,800),(540,400),(128,178,194),10)# left line
e1 = cv2.line(img39,(620,800),(550,400),(128,178,194),10)# left line
e1 = cv2.line(img39,(630,800),(560,400),(128,178,194),10)# left line
e1 = cv2.line(img39,(640,800),(570,400),(128,178,194),10)# left line
e1 = cv2.line(img39,(650,800),(580,400),(128,178,194),10)# left line
e1 = cv2.line(img39,(660,800),(590,400),(128,178,194),10)# left line
e1 = cv2.line(img39,(670,800),(600,400),(128,178,194),10)# left line
e1 = cv2.line(img39,(680,800),(610,400),(128,178,194),10)# left line
e1 = cv2.line(img39,(690,800),(620,400),(128,178,194),10)# left line
e1 = cv2.line(img39,(700,800),(630,400),(128,178,194),10)# left line
e1 = cv2.line(img39,(710,800),(640,400),(128,178,194),10)# left line
e1 = cv2.line(img39,(720,800),(650,400),(128,178,194),10)# left line
e1 = cv2.line(img39,(730,800),(660,400),(128,178,194),10)# left line
e1 = cv2.line(img39,(740,800),(670,400),(128,178,194),10)# left line
e1 = cv2.line(img39,(750,800),(680,400),(128,178,194),10)# left line
e1 = cv2.line(img39,(760,800),(690,400),(128,178,194),10)# left line

e1 = cv2.line(img39,(450,800),(530,400),(128,178,194),10)#right line
e1 = cv2.line(img39,(460,800),(540,400),(128,178,194),10)#right line
e1 = cv2.line(img39,(470,800),(550,400),(128,178,194),10)#right line
e1 = cv2.line(img39,(480,800),(560,400),(128,178,194),10)#right line
e1 = cv2.line(img39,(490,800),(570,400),(128,178,194),10)#right line
e1 = cv2.line(img39,(500,800),(580,400),(128,178,194),10)#right line
e1 = cv2.line(img39,(510,800),(590,400),(128,178,194),10)#right line
e1 = cv2.line(img39,(520,800),(600,400),(128,178,194),10)#right line
e1 = cv2.line(img39,(530,800),(610,400),(128,178,194),10)#right line
e1 = cv2.line(img39,(540,800),(620,400),(128,178,194),10)#right line
e1 = cv2.line(img39,(550,800),(630,400),(128,178,194),10)#right line
e1 = cv2.line(img39,(560,800),(640,400),(128,178,194),10)#right line
e1 = cv2.line(img39,(570,800),(650,400),(128,178,194),10)#right line
e1 = cv2.line(img39,(580,800),(660,400),(128,178,194),10)#right line
e1 = cv2.line(img39,(590,800),(670,400),(128,178,194),10)#right line

e1 = cv2.line(img39,(760,800),(690,400),(255,255,255),2)# left line
e1 = cv2.line(img39,(450,800),(530,400),(255,255,255),2)#right line
e1 = cv2.line(img39,(690,400),(530,400),(255,255,255),2)# middle line
e1 = cv2.line(img39,(600,1200),(600,760),(0,0,0),5)   #middle wicket   #buttom side
e1 = cv2.line(img39,(590,1200),(590,760),(0,0,0),5)   #left wicket
e1 = cv2.line(img39,(610,1200),(610,760),(0,0,0),5)   #right wicket
e1 = cv2.line(img39,(590,760),(610,760),(0,0,0),5)    #top wicket
e1 = cv2.line(img39,(430,750),(780,750),(255,255,255),2)#buttom boundary line 
e1 = cv2.line(img39,(500,750),(490,850),(255,255,255),2)#boundary left line
e1 = cv2.line(img39,(710,750),(720,850),(255,255,255),2)#boundary right line

e1 = cv2.line(img39,(760,800),(690,400),(255,255,255),2)# left line
e1 = cv2.line(img39,(450,800),(530,400),(255,255,255),2)#right line
e1 = cv2.line(img39,(690,400),(530,400),(255,255,255),2)# middle line
e1 = cv2.line(img39,(620,400),(620,360),(0,0,0),5)   #right wicket     #top side
e1 = cv2.line(img39,(600,400),(600,360),(0,0,0),5)   #lift wicket
e1 = cv2.line(img39,(610,400),(610,360),(0,0,0),5)   #middle wicket
e1 = cv2.line(img39,(600,360),(620,360),(0,0,0),5)    #top wicket
e1 = cv2.line(img39,(490,440),(720,440),(255,255,255),2) # top boundary line
e1 = cv2.line(img39,(555,440),(560,400),(255,255,255),2)#boundary left line
e1 = cv2.line(img39,(655,440),(655,400),(255,255,255),2)#boundary right line




#indian player

e1=cv2.rectangle(img39,(642,402),(648,440),(255,0,0),-1)#right leg
e1=cv2.rectangle(img39,(629,352),(650,402),(255,0,0),-1)#body
e1=cv2.rectangle(img39,(631,402),(637,440),(255,0,0),-1)#left leg
e1=cv2.circle(img39,(640,339),13,(155,226,254),-1)# head
e1=cv2.circle(img39,(632,340),2,(0,0,0),-1)# right eye
e1=cv2.circle(img39,(637,340),2,(0,0,0),-1)# left eye
e1=cv2.circle(img39,(635,346),2,(0,0,0),-1)#mouth
e1 = cv2.line(img39,(632,364),(620,400),(155,226,254),3)#right hand 
e1 = cv2.line(img39,(641,373),(623,400),(155,226,254),3)#left hand
e1 = cv2.line(img39,(621,400),(603,422),(29,101,181),10)#bat
e1 = cv2.line(img39,(632,329),(647,329),(0,0,0),10)#top hair
e1 = cv2.line(img39,(647,336),(646,348),(0,0,0),10)#left hair


# pakistan wicket player

e1=cv2.rectangle(img39,(592,362),(586,395),(26,64,0),-1)#right leg
e1=cv2.rectangle(img39,(570,351),(593,379),(26,64,0),-1)#body
e1=cv2.rectangle(img39,(572,362),(579,395),(26,64,0),-1)#left leg
e1=cv2.circle(img39,(581,336),14,(155,226,254),-1)# head
e1=cv2.circle(img39,(576,338),2,(0,0,0),-1)# right eye
e1=cv2.circle(img39,(587,338),2,(0,0,0),-1)# left eye
e1 = cv2.line(img39,(578,345),(585,345),(0,0,0),2)#mouth
e1 = cv2.line(img39,(572,360),(582,369),(155,226,254),4)#right hand 
e1 = cv2.line(img39,(591,360),(582,369),(155,226,254),4)#left hand
e1 = cv2.line(img39,(581,368),(582,369),(255,255,255),10)#glove
e1 = cv2.line(img39,(571,326),(588,326),(0,0,0),10)#top hair



#bowler


e1=cv2.rectangle(img39,(626,719),(652,749),(26,64,0),-1)#body
e1=cv2.circle(img39,(638,705),14,(155,226,254),-1)# head
e1=cv2.circle(img39,(603,422),6,(255,255,255),-1)# right ball
e1 = cv2.line(img39,(653,724),(663,736),(155,226,254),5)#right hand 
e1 = cv2.line(img39,(625,725),(620,732),(155,226,254),5)#left hand
e1 = cv2.line(img39,(632,702),(643,702),(0,0,0),20)#top hair
e1=cv2.rectangle(img39,(631,749),(637,762),(26,64,0),-1)#left leg
e1=cv2.rectangle(img39,(642,749),(648,762),(26,64,0),-1)#right leg



# pakistan player
e1=cv2.rectangle(img39,(292,293),(300,322),(26,64,0),-1)#right leg
e1=cv2.rectangle(img39,(288,253),(320,298),(26,64,0),-1)#body
e1=cv2.rectangle(img39,(309,293),(317,322),(26,64,0),-1)#left leg
e1=cv2.circle(img39,(303,239),16,(155,226,254),-1)# head
e1=cv2.circle(img39,(295,242),2,(0,0,0),-1)# right eye
e1=cv2.circle(img39,(310,242),2,(0,0,0),-1)# left eye
e1 = cv2.line(img39,(298,249),(307,249),(0,0,0),2)#mouth
e1 = cv2.line(img39,(289,265),(294,276),(155,226,254),4)#right hand 
e1 = cv2.line(img39,(318,265),(310,276),(155,226,254),4)#left hand
e1 = cv2.line(img39,(293,229),(312,229),(0,0,0),13)#top hair


#Indian  player
e1=cv2.rectangle(img39,(548,767),(555,784),(255,0,0),-1)#left leg
e1=cv2.rectangle(img39,(569,767),(545,742),(255,0,0),-1)#body
e1=cv2.rectangle(img39,(560,767),(567,784),(255,0,0),-1)#right leg
e1=cv2.circle(img39,(557,729),14,(155,226,254),-1)# head
e1 = cv2.line(img39,(570,748),(574,761),(155,226,254),3)#right hand 
e1 = cv2.line(img39,(544,747),(537,754),(155,226,254),3)#left hand
e1 = cv2.line(img39,(575,761),(580,778),(29,101,181),10)#bat
e1 = cv2.line(img39,(550,724),(562,724),(0,0,0),21)#top hair




cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # 37 POINT

# %%
img40=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img40,(0,0),(1200,800),(128,178,194),-1) #layout
e1 = cv2.line(img40,(500,400),(700,400),(140,160,180),1050) #dugout
e1 = cv2.line(img40,(500,400),(700,400),(106,206,234),800) #ground
e1 = cv2.line(img40,(500,400),(700,400),(35,215,0),780) #extraSpace
e1 = cv2.line(img40,(500,400),(700,400),(255,255,255),750) #boundary
e1 = cv2.line(img40,(500,400),(700,400),(0,206,0),748) #playarea
e1 = cv2.rectangle(img40,(630,300),(570,500),(128,178,194),-1) #pitch
e1 = cv2.rectangle(img40,(630,300),(570,500),(255,255,255),1) #pitchhighlighter
e1 = cv2.line(img40,(580,300),(580,315),(255,255,255),1) #leftwideline
e1 = cv2.line(img40,(620,300),(620,315),(255,255,255),1) #rightwideline
e1 = cv2.line(img40,(580,500),(580,485),(255,255,255),1) #leftwideline_non_stricker
e1 = cv2.line(img40,(620,500),(620,485),(255,255,255),1) #rightwideline_non_stricker
e1 = cv2.line(img40,(565,315),(635,315),(255,255,255),1) #crease
e1 = cv2.line(img40,(565,485),(635,485),(255,255,255),1) #crease_non_stricker
e1 = cv2.line(img40,(597,300),(603,300),(0,0,0),1) #wickets
e1 = cv2.line(img40,(597,500),(603,500),(0,0,0),1) #wickets_non_stricker
e1 = cv2.circle(img40,(600,400),270,(255,255,255),1) #insidecircle

e1 = cv2.circle(img40,(600,280),5,(32,100,1),-1) #wicketkeeper
e1 = cv2.circle(img40,(925,120),5,(32,100,1),-1) #fineleg
e1 = cv2.circle(img40,(580,270),5,(32,100,1),-1) #slip
e1 = cv2.circle(img40,(490,720),5,(32,100,1),-1) #longoff
e1 = cv2.circle(img40,(720,530),5,(32,100,1),-1) #midwicket
e1 = cv2.circle(img40,(420,500),5,(32,100,1),-1) #cover
e1 = cv2.circle(img40,(420,500),5,(32,100,1),-1) #cover
e1 = cv2.circle(img40,(150,380),5,(32,100,1),-1) #deepcoverpoint
e1 = cv2.circle(img40,(700,340),5,(32,100,1),-1) #short
e1 = cv2.circle(img40,(950,480),5,(32,100,1),-1) #deepsweep
e1 = cv2.circle(img40,(500,300),5,(32,100,1),-1) #gully
e1 = cv2.circle(img40,(610,490),5,(32,100,1),-1) #bowler

e1 = cv2.circle(img40,(590,490),5,(255,30,0),-1) #batsmen
e1 = cv2.circle(img40,(610,310),5,(255,30,0),-1) #bowler

e1 = cv2.circle(img40,(600,520),5,(0,0,255),-1) #umpire
e1 = cv2.circle(img40,(750,315),5,(0,0,255),-1) #umpire2


e1=cv2.circle(img40,(600,314),4,(255,255,255),-1) #ball




cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # 38 POINT

# %%
img41=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img41,(0,0),(1200,800),(128,178,194),-1) #layout
e1 = cv2.line(img41,(500,400),(700,400),(140,160,180),1050) #dugout
e1 = cv2.line(img41,(500,400),(700,400),(106,206,234),800) #ground
e1 = cv2.line(img41,(500,400),(700,400),(35,215,0),780) #extraSpace
e1 = cv2.line(img41,(500,400),(700,400),(255,255,255),750) #boundary
e1 = cv2.line(img41,(500,400),(700,400),(0,206,0),748) #playarea
e1 = cv2.rectangle(img41,(630,300),(570,500),(128,178,194),-1) #pitch
e1 = cv2.rectangle(img41,(630,300),(570,500),(255,255,255),1) #pitchhighlighter
e1 = cv2.line(img41,(580,300),(580,315),(255,255,255),1) #leftwideline
e1 = cv2.line(img41,(620,300),(620,315),(255,255,255),1) #rightwideline
e1 = cv2.line(img41,(580,500),(580,485),(255,255,255),1) #leftwideline_non_stricker
e1 = cv2.line(img41,(620,500),(620,485),(255,255,255),1) #rightwideline_non_stricker
e1 = cv2.line(img41,(565,315),(635,315),(255,255,255),1) #crease
e1 = cv2.line(img41,(565,485),(635,485),(255,255,255),1) #crease_non_stricker
e1 = cv2.line(img41,(597,300),(603,300),(0,0,0),1) #wickets
e1 = cv2.line(img41,(597,500),(603,500),(0,0,0),1) #wickets_non_stricker
e1 = cv2.circle(img41,(600,400),270,(255,255,255),1) #insidecircle

e1 = cv2.circle(img41,(600,280),5,(32,100,1),-1) #wicketkeeper
e1 = cv2.circle(img41,(925,120),5,(32,100,1),-1) #fineleg
e1 = cv2.circle(img41,(580,270),5,(32,100,1),-1) #slip
e1 = cv2.circle(img41,(490,720),5,(32,100,1),-1) #longoff
e1 = cv2.circle(img41,(720,530),5,(32,100,1),-1) #midwicket
e1 = cv2.circle(img41,(420,500),5,(32,100,1),-1) #cover
e1 = cv2.circle(img41,(150,380),5,(32,100,1),-1) #deepcoverpoint
e1 = cv2.circle(img41,(700,340),5,(32,100,1),-1) #short
e1 = cv2.circle(img41,(950,480),5,(32,100,1),-1) #deepsweep
e1 = cv2.circle(img41,(500,300),5,(32,100,1),-1) #gully
e1 = cv2.circle(img41,(610,490),5,(32,100,1),-1) #bowler

e1 = cv2.circle(img41,(590,490),5,(255,30,0),-1) #batsmen
e1 = cv2.circle(img41,(610,310),5,(255,30,0),-1) #bowler

e1 = cv2.circle(img41,(600,520),5,(0,0,255),-1) #umpire
e1 = cv2.circle(img41,(750,315),5,(0,0,255),-1) #umpire2


e1=cv2.circle(img41,(581,331),4,(255,255,255),-1) #ball




cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # 39 POINT

# %%
img42=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img42,(0,0),(1200,800),(128,178,194),-1) #layout
e1 = cv2.line(img42,(500,400),(700,400),(140,160,180),1050) #dugout
e1 = cv2.line(img42,(500,400),(700,400),(106,206,234),800) #ground
e1 = cv2.line(img42,(500,400),(700,400),(35,215,0),780) #extraSpace
e1 = cv2.line(img42,(500,400),(700,400),(255,255,255),750) #boundary
e1 = cv2.line(img42,(500,400),(700,400),(0,206,0),748) #playarea
e1 = cv2.rectangle(img42,(630,300),(570,500),(128,178,194),-1) #pitch
e1 = cv2.rectangle(img42,(630,300),(570,500),(255,255,255),1) #pitchhighlighter
e1 = cv2.line(img42,(580,300),(580,315),(255,255,255),1) #leftwideline
e1 = cv2.line(img42,(620,300),(620,315),(255,255,255),1) #rightwideline
e1 = cv2.line(img42,(580,500),(580,485),(255,255,255),1) #leftwideline_non_stricker
e1 = cv2.line(img42,(620,500),(620,485),(255,255,255),1) #rightwideline_non_stricker
e1 = cv2.line(img42,(565,315),(635,315),(255,255,255),1) #crease
e1 = cv2.line(img42,(565,485),(635,485),(255,255,255),1) #crease_non_stricker
e1 = cv2.line(img42,(597,300),(603,300),(0,0,0),1) #wickets
e1 = cv2.line(img42,(597,500),(603,500),(0,0,0),1) #wickets_non_stricker
e1 = cv2.circle(img42,(600,400),270,(255,255,255),1) #insidecircle

e1 = cv2.circle(img42,(600,280),5,(32,100,1),-1) #wicketkeeper
e1 = cv2.circle(img42,(925,120),5,(32,100,1),-1) #fineleg
e1 = cv2.circle(img42,(580,270),5,(32,100,1),-1) #slip
e1 = cv2.circle(img42,(490,720),5,(32,100,1),-1) #longoff
e1 = cv2.circle(img42,(720,530),5,(32,100,1),-1) #midwicket
e1 = cv2.circle(img42,(420,500),5,(32,100,1),-1) #cover
e1 = cv2.circle(img42,(150,380),5,(32,100,1),-1) #deepcoverpoint
e1 = cv2.circle(img42,(700,340),5,(32,100,1),-1) #short
e1 = cv2.circle(img42,(950,480),5,(32,100,1),-1) #deepsweep
e1 = cv2.circle(img42,(500,300),5,(32,100,1),-1) #gully
e1 = cv2.circle(img42,(610,490),5,(32,100,1),-1) #bowler

e1 = cv2.circle(img42,(590,490),5,(255,30,0),-1) #batsmen
e1 = cv2.circle(img42,(610,310),5,(255,30,0),-1) #bowler

e1 = cv2.circle(img42,(600,520),5,(0,0,255),-1) #umpire
e1 = cv2.circle(img42,(750,315),5,(0,0,255),-1) #umpire2


e1=cv2.circle(img42,(581,331),4,(255,255,255),-1) #ball




cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # 40 POINT

# %%
img43=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img43,(0,0),(1200,800),(128,178,194),-1) #layout
e1 = cv2.line(img43,(500,400),(700,400),(140,160,180),1050) #dugout
e1 = cv2.line(img43,(500,400),(700,400),(106,206,234),800) #ground
e1 = cv2.line(img43,(500,400),(700,400),(35,215,0),780) #extraSpace
e1 = cv2.line(img43,(500,400),(700,400),(255,255,255),750) #boundary
e1 = cv2.line(img43,(500,400),(700,400),(0,206,0),748) #playarea
e1 = cv2.rectangle(img43,(630,300),(570,500),(128,178,194),-1) #pitch
e1 = cv2.rectangle(img43,(630,300),(570,500),(255,255,255),1) #pitchhighlighter
e1 = cv2.line(img43,(580,300),(580,315),(255,255,255),1) #leftwideline
e1 = cv2.line(img43,(620,300),(620,315),(255,255,255),1) #rightwideline
e1 = cv2.line(img43,(580,500),(580,485),(255,255,255),1) #leftwideline_non_stricker
e1 = cv2.line(img43,(620,500),(620,485),(255,255,255),1) #rightwideline_non_stricker
e1 = cv2.line(img43,(565,315),(635,315),(255,255,255),1) #crease
e1 = cv2.line(img43,(565,485),(635,485),(255,255,255),1) #crease_non_stricker
e1 = cv2.line(img43,(597,300),(603,300),(0,0,0),1) #wickets
e1 = cv2.line(img43,(597,500),(603,500),(0,0,0),1) #wickets_non_stricker
e1 = cv2.circle(img43,(600,400),270,(255,255,255),1) #insidecircle

e1 = cv2.circle(img43,(600,280),5,(32,100,1),-1) #wicketkeeper
e1 = cv2.circle(img43,(925,120),5,(32,100,1),-1) #fineleg
e1 = cv2.circle(img43,(580,270),5,(32,100,1),-1) #slip
e1 = cv2.circle(img43,(490,720),5,(32,100,1),-1) #longoff
e1 = cv2.circle(img43,(720,530),5,(32,100,1),-1) #midwicket
e1 = cv2.circle(img43,(420,500),5,(32,100,1),-1) #cover
e1 = cv2.circle(img43,(150,380),5,(32,100,1),-1) #deepcoverpoint
e1 = cv2.circle(img43,(700,340),5,(32,100,1),-1) #short
e1 = cv2.circle(img43,(950,480),5,(32,100,1),-1) #deepsweep
e1 = cv2.circle(img43,(500,300),5,(32,100,1),-1) #gully
e1 = cv2.circle(img43,(610,490),5,(32,100,1),-1) #bowler

e1 = cv2.circle(img43,(590,490),5,(255,30,0),-1) #batsmen
e1 = cv2.circle(img43,(610,310),5,(255,30,0),-1) #bowler

e1 = cv2.circle(img43,(600,520),5,(0,0,255),-1) #umpire
e1 = cv2.circle(img43,(750,315),5,(0,0,255),-1) #umpire2


e1=cv2.circle(img43,(548,354),4,(255,255,255),-1) #ball




cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # 41 POINT

# %%
img44=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img44,(0,0),(1200,800),(128,178,194),-1) #layout
e1 = cv2.line(img44,(500,400),(700,400),(140,160,180),1050) #dugout
e1 = cv2.line(img44,(500,400),(700,400),(106,206,234),800) #ground
e1 = cv2.line(img44,(500,400),(700,400),(35,215,0),780) #extraSpace
e1 = cv2.line(img44,(500,400),(700,400),(255,255,255),750) #boundary
e1 = cv2.line(img44,(500,400),(700,400),(0,206,0),748) #playarea
e1 = cv2.rectangle(img44,(630,300),(570,500),(128,178,194),-1) #pitch
e1 = cv2.rectangle(img44,(630,300),(570,500),(255,255,255),1) #pitchhighlighter
e1 = cv2.line(img44,(580,300),(580,315),(255,255,255),1) #leftwideline
e1 = cv2.line(img44,(620,300),(620,315),(255,255,255),1) #rightwideline
e1 = cv2.line(img44,(580,500),(580,485),(255,255,255),1) #leftwideline_non_stricker
e1 = cv2.line(img44,(620,500),(620,485),(255,255,255),1) #rightwideline_non_stricker
e1 = cv2.line(img44,(565,315),(635,315),(255,255,255),1) #crease
e1 = cv2.line(img44,(565,485),(635,485),(255,255,255),1) #crease_non_stricker
e1 = cv2.line(img44,(597,300),(603,300),(0,0,0),1) #wickets
e1 = cv2.line(img44,(597,500),(603,500),(0,0,0),1) #wickets_non_stricker
e1 = cv2.circle(img44,(600,400),270,(255,255,255),1) #insidecircle

e1 = cv2.circle(img44,(600,280),5,(32,100,1),-1) #wicketkeeper
e1 = cv2.circle(img44,(925,120),5,(32,100,1),-1) #fineleg
e1 = cv2.circle(img44,(580,270),5,(32,100,1),-1) #slip
e1 = cv2.circle(img44,(490,720),5,(32,100,1),-1) #longoff
e1 = cv2.circle(img44,(720,530),5,(32,100,1),-1) #midwicket
e1 = cv2.circle(img44,(420,500),5,(32,100,1),-1) #cover
e1 = cv2.circle(img44,(150,380),5,(32,100,1),-1) #deepcoverpoint
e1 = cv2.circle(img44,(700,340),5,(32,100,1),-1) #short
e1 = cv2.circle(img44,(950,480),5,(32,100,1),-1) #deepsweep
e1 = cv2.circle(img44,(500,300),5,(32,100,1),-1) #gully
e1 = cv2.circle(img44,(610,490),5,(32,100,1),-1) #bowler

e1 = cv2.circle(img44,(590,490),5,(255,30,0),-1) #batsmen
e1 = cv2.circle(img44,(610,310),5,(255,30,0),-1) #bowler

e1 = cv2.circle(img44,(600,520),5,(0,0,255),-1) #umpire
e1 = cv2.circle(img44,(750,315),5,(0,0,255),-1) #umpire2


e1=cv2.circle(img44,(505,384),4,(255,255,255),-1) #ball




cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # 42 POINT

# %%
img45=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img45,(0,0),(1200,800),(128,178,194),-1) #layout
e1 = cv2.line(img45,(500,400),(700,400),(140,160,180),1050) #dugout
e1 = cv2.line(img45,(500,400),(700,400),(106,206,234),800) #ground
e1 = cv2.line(img45,(500,400),(700,400),(35,215,0),780) #extraSpace
e1 = cv2.line(img45,(500,400),(700,400),(255,255,255),750) #boundary
e1 = cv2.line(img45,(500,400),(700,400),(0,206,0),748) #playarea
e1 = cv2.rectangle(img45,(630,300),(570,500),(128,178,194),-1) #pitch
e1 = cv2.rectangle(img45,(630,300),(570,500),(255,255,255),1) #pitchhighlighter
e1 = cv2.line(img45,(580,300),(580,315),(255,255,255),1) #leftwideline
e1 = cv2.line(img45,(620,300),(620,315),(255,255,255),1) #rightwideline
e1 = cv2.line(img45,(580,500),(580,485),(255,255,255),1) #leftwideline_non_stricker
e1 = cv2.line(img45,(620,500),(620,485),(255,255,255),1) #rightwideline_non_stricker
e1 = cv2.line(img45,(565,315),(635,315),(255,255,255),1) #crease
e1 = cv2.line(img45,(565,485),(635,485),(255,255,255),1) #crease_non_stricker
e1 = cv2.line(img45,(597,300),(603,300),(0,0,0),1) #wickets
e1 = cv2.line(img45,(597,500),(603,500),(0,0,0),1) #wickets_non_stricker
e1 = cv2.circle(img45,(600,400),270,(255,255,255),1) #insidecircle

e1 = cv2.circle(img45,(600,280),5,(32,100,1),-1) #wicketkeeper
e1 = cv2.circle(img45,(925,120),5,(32,100,1),-1) #fineleg
e1 = cv2.circle(img45,(580,270),5,(32,100,1),-1) #slip
e1 = cv2.circle(img45,(490,720),5,(32,100,1),-1) #longoff
e1 = cv2.circle(img45,(720,530),5,(32,100,1),-1) #midwicket
e1 = cv2.circle(img45,(420,500),5,(32,100,1),-1) #cover
e1 = cv2.circle(img45,(150,380),5,(32,100,1),-1) #deepcoverpoint
e1 = cv2.circle(img45,(700,340),5,(32,100,1),-1) #short
e1 = cv2.circle(img45,(950,480),5,(32,100,1),-1) #deepsweep
e1 = cv2.circle(img45,(500,300),5,(32,100,1),-1) #gully
e1 = cv2.circle(img45,(610,490),5,(32,100,1),-1) #bowler

e1 = cv2.circle(img45,(590,490),5,(255,30,0),-1) #batsmen
e1 = cv2.circle(img45,(610,310),5,(255,30,0),-1) #bowler

e1 = cv2.circle(img45,(600,520),5,(0,0,255),-1) #umpire
e1 = cv2.circle(img45,(750,315),5,(0,0,255),-1) #umpire2


e1=cv2.circle(img45,(460,441),4,(255,255,255),-1) #ball




cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # 43 POINT

# %%
img46=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img46,(0,0),(1200,800),(128,178,194),-1) #layout
e1 = cv2.line(img46,(500,400),(700,400),(140,160,180),1050) #dugout
e1 = cv2.line(img46,(500,400),(700,400),(106,206,234),800) #ground
e1 = cv2.line(img46,(500,400),(700,400),(35,215,0),780) #extraSpace
e1 = cv2.line(img46,(500,400),(700,400),(255,255,255),750) #boundary
e1 = cv2.line(img46,(500,400),(700,400),(0,206,0),748) #playarea
e1 = cv2.rectangle(img46,(630,300),(570,500),(128,178,194),-1) #pitch
e1 = cv2.rectangle(img46,(630,300),(570,500),(255,255,255),1) #pitchhighlighter
e1 = cv2.line(img46,(580,300),(580,315),(255,255,255),1) #leftwideline
e1 = cv2.line(img46,(620,300),(620,315),(255,255,255),1) #rightwideline
e1 = cv2.line(img46,(580,500),(580,485),(255,255,255),1) #leftwideline_non_stricker
e1 = cv2.line(img46,(620,500),(620,485),(255,255,255),1) #rightwideline_non_stricker
e1 = cv2.line(img46,(565,315),(635,315),(255,255,255),1) #crease
e1 = cv2.line(img46,(565,485),(635,485),(255,255,255),1) #crease_non_stricker
e1 = cv2.line(img46,(597,300),(603,300),(0,0,0),1) #wickets
e1 = cv2.line(img46,(597,500),(603,500),(0,0,0),1) #wickets_non_stricker
e1 = cv2.circle(img46,(600,400),270,(255,255,255),1) #insidecircle

e1 = cv2.circle(img46,(600,280),5,(32,100,1),-1) #wicketkeeper
e1 = cv2.circle(img46,(925,120),5,(32,100,1),-1) #fineleg
e1 = cv2.circle(img46,(580,270),5,(32,100,1),-1) #slip
e1 = cv2.circle(img46,(490,720),5,(32,100,1),-1) #longoff
e1 = cv2.circle(img46,(720,530),5,(32,100,1),-1) #midwicket
e1 = cv2.circle(img46,(420,500),5,(32,100,1),-1) #cover
e1 = cv2.circle(img46,(150,380),5,(32,100,1),-1) #deepcoverpoint
e1 = cv2.circle(img46,(700,340),5,(32,100,1),-1) #short
e1 = cv2.circle(img46,(950,480),5,(32,100,1),-1) #deepsweep
e1 = cv2.circle(img46,(500,300),5,(32,100,1),-1) #gully
e1 = cv2.circle(img46,(610,490),5,(32,100,1),-1) #bowler

e1 = cv2.circle(img46,(590,490),5,(255,30,0),-1) #batsmen
e1 = cv2.circle(img46,(610,310),5,(255,30,0),-1) #bowler

e1 = cv2.circle(img46,(600,520),5,(0,0,255),-1) #umpire
e1 = cv2.circle(img46,(750,315),5,(0,0,255),-1) #umpire2


e1=cv2.circle(img46,(365,475),4,(255,255,255),-1) #ball




cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # 44 POINT

# %%
img47=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img47,(0,0),(1200,800),(128,178,194),-1) #layout
e1 = cv2.line(img47,(500,400),(700,400),(140,160,180),1050) #dugout
e1 = cv2.line(img47,(500,400),(700,400),(106,206,234),800) #ground
e1 = cv2.line(img47,(500,400),(700,400),(35,215,0),780) #extraSpace
e1 = cv2.line(img47,(500,400),(700,400),(255,255,255),750) #boundary
e1 = cv2.line(img47,(500,400),(700,400),(0,206,0),748) #playarea
e1 = cv2.rectangle(img47,(630,300),(570,500),(128,178,194),-1) #pitch
e1 = cv2.rectangle(img47,(630,300),(570,500),(255,255,255),1) #pitchhighlighter
e1 = cv2.line(img47,(580,300),(580,315),(255,255,255),1) #leftwideline
e1 = cv2.line(img47,(620,300),(620,315),(255,255,255),1) #rightwideline
e1 = cv2.line(img47,(580,500),(580,485),(255,255,255),1) #leftwideline_non_stricker
e1 = cv2.line(img47,(620,500),(620,485),(255,255,255),1) #rightwideline_non_stricker
e1 = cv2.line(img47,(565,315),(635,315),(255,255,255),1) #crease
e1 = cv2.line(img47,(565,485),(635,485),(255,255,255),1) #crease_non_stricker
e1 = cv2.line(img47,(597,300),(603,300),(0,0,0),1) #wickets
e1 = cv2.line(img47,(597,500),(603,500),(0,0,0),1) #wickets_non_stricker
e1 = cv2.circle(img47,(600,400),270,(255,255,255),1) #insidecircle

e1 = cv2.circle(img47,(600,280),5,(32,100,1),-1) #wicketkeeper
e1 = cv2.circle(img47,(925,120),5,(32,100,1),-1) #fineleg
e1 = cv2.circle(img47,(580,270),5,(32,100,1),-1) #slip
e1 = cv2.circle(img47,(490,720),5,(32,100,1),-1) #longoff
e1 = cv2.circle(img47,(720,530),5,(32,100,1),-1) #midwicket
e1 = cv2.circle(img47,(420,500),5,(32,100,1),-1) #cover
e1 = cv2.circle(img47,(150,380),5,(32,100,1),-1) #deepcoverpoint
e1 = cv2.circle(img47,(700,340),5,(32,100,1),-1) #short
e1 = cv2.circle(img47,(950,480),5,(32,100,1),-1) #deepsweep
e1 = cv2.circle(img47,(500,300),5,(32,100,1),-1) #gully
e1 = cv2.circle(img47,(610,490),5,(32,100,1),-1) #bowler

e1 = cv2.circle(img47,(590,490),5,(255,30,0),-1) #batsmen
e1 = cv2.circle(img47,(610,310),5,(255,30,0),-1) #bowler

e1 = cv2.circle(img47,(600,520),5,(0,0,255),-1) #umpire
e1 = cv2.circle(img47,(750,315),5,(0,0,255),-1) #umpire2


e1=cv2.circle(img47,(330,510),4,(255,255,255),-1) #ball




cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # 45 POINT

# %%
img48=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img48,(0,0),(1200,800),(128,178,194),-1) #layout
e1 = cv2.line(img48,(500,400),(700,400),(140,160,180),1050) #dugout
e1 = cv2.line(img48,(500,400),(700,400),(106,206,234),800) #ground
e1 = cv2.line(img48,(500,400),(700,400),(35,215,0),780) #extraSpace
e1 = cv2.line(img48,(500,400),(700,400),(255,255,255),750) #boundary
e1 = cv2.line(img48,(500,400),(700,400),(0,206,0),748) #playarea
e1 = cv2.rectangle(img48,(630,300),(570,500),(128,178,194),-1) #pitch
e1 = cv2.rectangle(img48,(630,300),(570,500),(255,255,255),1) #pitchhighlighter
e1 = cv2.line(img48,(580,300),(580,315),(255,255,255),1) #leftwideline
e1 = cv2.line(img48,(620,300),(620,315),(255,255,255),1) #rightwideline
e1 = cv2.line(img48,(580,500),(580,485),(255,255,255),1) #leftwideline_non_stricker
e1 = cv2.line(img48,(620,500),(620,485),(255,255,255),1) #rightwideline_non_stricker
e1 = cv2.line(img48,(565,315),(635,315),(255,255,255),1) #crease
e1 = cv2.line(img48,(565,485),(635,485),(255,255,255),1) #crease_non_stricker
e1 = cv2.line(img48,(597,300),(603,300),(0,0,0),1) #wickets
e1 = cv2.line(img48,(597,500),(603,500),(0,0,0),1) #wickets_non_stricker
e1 = cv2.circle(img48,(600,400),270,(255,255,255),1) #insidecircle

e1 = cv2.circle(img48,(600,280),5,(32,100,1),-1) #wicketkeeper
e1 = cv2.circle(img48,(925,120),5,(32,100,1),-1) #fineleg
e1 = cv2.circle(img48,(580,270),5,(32,100,1),-1) #slip
e1 = cv2.circle(img48,(490,720),5,(32,100,1),-1) #longoff
e1 = cv2.circle(img48,(720,530),5,(32,100,1),-1) #midwicket
e1 = cv2.circle(img48,(420,500),5,(32,100,1),-1) #cover
e1 = cv2.circle(img48,(150,380),5,(32,100,1),-1) #deepcoverpoint
e1 = cv2.circle(img48,(700,340),5,(32,100,1),-1) #short
e1 = cv2.circle(img48,(950,480),5,(32,100,1),-1) #deepsweep
e1 = cv2.circle(img48,(500,300),5,(32,100,1),-1) #gully
e1 = cv2.circle(img48,(610,490),5,(32,100,1),-1) #bowler

e1 = cv2.circle(img48,(590,490),5,(255,30,0),-1) #batsmen
e1 = cv2.circle(img48,(610,310),5,(255,30,0),-1) #bowler

e1 = cv2.circle(img48,(600,520),5,(0,0,255),-1) #umpire
e1 = cv2.circle(img48,(750,315),5,(0,0,255),-1) #umpire2


e1=cv2.circle(img48,(287,544),4,(255,255,255),-1) #ball




cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # 46 POINT

# %%
img49=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img49,(0,0),(1200,800),(128,178,194),-1) #layout
e1 = cv2.line(img49,(500,400),(700,400),(140,160,180),1050) #dugout
e1 = cv2.line(img49,(500,400),(700,400),(106,206,234),800) #ground
e1 = cv2.line(img49,(500,400),(700,400),(35,215,0),780) #extraSpace
e1 = cv2.line(img49,(500,400),(700,400),(255,255,255),750) #boundary
e1 = cv2.line(img49,(500,400),(700,400),(0,206,0),748) #playarea
e1 = cv2.rectangle(img49,(630,300),(570,500),(128,178,194),-1) #pitch
e1 = cv2.rectangle(img49,(630,300),(570,500),(255,255,255),1) #pitchhighlighter
e1 = cv2.line(img49,(580,300),(580,315),(255,255,255),1) #leftwideline
e1 = cv2.line(img49,(620,300),(620,315),(255,255,255),1) #rightwideline
e1 = cv2.line(img49,(580,500),(580,485),(255,255,255),1) #leftwideline_non_stricker
e1 = cv2.line(img49,(620,500),(620,485),(255,255,255),1) #rightwideline_non_stricker
e1 = cv2.line(img49,(565,315),(635,315),(255,255,255),1) #crease
e1 = cv2.line(img49,(565,485),(635,485),(255,255,255),1) #crease_non_stricker
e1 = cv2.line(img49,(597,300),(603,300),(0,0,0),1) #wickets
e1 = cv2.line(img49,(597,500),(603,500),(0,0,0),1) #wickets_non_stricker
e1 = cv2.circle(img49,(600,400),270,(255,255,255),1) #insidecircle

e1 = cv2.circle(img49,(600,280),5,(32,100,1),-1) #wicketkeeper
e1 = cv2.circle(img49,(925,120),5,(32,100,1),-1) #fineleg
e1 = cv2.circle(img49,(580,270),5,(32,100,1),-1) #slip
e1 = cv2.circle(img49,(490,720),5,(32,100,1),-1) #longoff
e1 = cv2.circle(img49,(720,530),5,(32,100,1),-1) #midwicket
e1 = cv2.circle(img49,(420,500),5,(32,100,1),-1) #cover
e1 = cv2.circle(img49,(150,380),5,(32,100,1),-1) #deepcoverpoint
e1 = cv2.circle(img49,(700,340),5,(32,100,1),-1) #short
e1 = cv2.circle(img49,(950,480),5,(32,100,1),-1) #deepsweep
e1 = cv2.circle(img49,(500,300),5,(32,100,1),-1) #gully
e1 = cv2.circle(img49,(610,490),5,(32,100,1),-1) #bowler

e1 = cv2.circle(img49,(590,490),5,(255,30,0),-1) #batsmen
e1 = cv2.circle(img49,(610,310),5,(255,30,0),-1) #bowler

e1 = cv2.circle(img49,(600,520),5,(0,0,255),-1) #umpire
e1 = cv2.circle(img49,(750,315),5,(0,0,255),-1) #umpire2


e1=cv2.circle(img49,(246,573),4,(255,255,255),-1) #ball




cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # 47 POINT

# %%
img50=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img50,(0,0),(1200,800),(128,178,194),-1) #layout
e1 = cv2.line(img50,(500,400),(700,400),(140,160,180),1050) #dugout
e1 = cv2.line(img50,(500,400),(700,400),(106,206,234),800) #ground
e1 = cv2.line(img50,(500,400),(700,400),(35,215,0),780) #extraSpace
e1 = cv2.line(img50,(500,400),(700,400),(255,255,255),750) #boundary
e1 = cv2.line(img50,(500,400),(700,400),(0,206,0),748) #playarea
e1 = cv2.rectangle(img50,(630,300),(570,500),(128,178,194),-1) #pitch
e1 = cv2.rectangle(img50,(630,300),(570,500),(255,255,255),1) #pitchhighlighter
e1 = cv2.line(img50,(580,300),(580,315),(255,255,255),1) #leftwideline
e1 = cv2.line(img50,(620,300),(620,315),(255,255,255),1) #rightwideline
e1 = cv2.line(img50,(580,500),(580,485),(255,255,255),1) #leftwideline_non_stricker
e1 = cv2.line(img50,(620,500),(620,485),(255,255,255),1) #rightwideline_non_stricker
e1 = cv2.line(img50,(565,315),(635,315),(255,255,255),1) #crease
e1 = cv2.line(img50,(565,485),(635,485),(255,255,255),1) #crease_non_stricker
e1 = cv2.line(img50,(597,300),(603,300),(0,0,0),1) #wickets
e1 = cv2.line(img50,(597,500),(603,500),(0,0,0),1) #wickets_non_stricker
e1 = cv2.circle(img50,(600,400),270,(255,255,255),1) #insidecircle

e1 = cv2.circle(img50,(600,280),5,(32,100,1),-1) #wicketkeeper
e1 = cv2.circle(img50,(925,120),5,(32,100,1),-1) #fineleg
e1 = cv2.circle(img50,(580,270),5,(32,100,1),-1) #slip
e1 = cv2.circle(img50,(490,720),5,(32,100,1),-1) #longoff
e1 = cv2.circle(img50,(720,530),5,(32,100,1),-1) #midwicket
e1 = cv2.circle(img50,(420,500),5,(32,100,1),-1) #cover
e1 = cv2.circle(img50,(150,380),5,(32,100,1),-1) #deepcoverpoint
e1 = cv2.circle(img50,(700,340),5,(32,100,1),-1) #short
e1 = cv2.circle(img50,(950,480),5,(32,100,1),-1) #deepsweep
e1 = cv2.circle(img50,(500,300),5,(32,100,1),-1) #gully
e1 = cv2.circle(img50,(610,490),5,(32,100,1),-1) #bowler

e1 = cv2.circle(img50,(590,490),5,(255,30,0),-1) #batsmen
e1 = cv2.circle(img50,(610,310),5,(255,30,0),-1) #bowler

e1 = cv2.circle(img50,(600,520),5,(0,0,255),-1) #umpire
e1 = cv2.circle(img50,(750,315),5,(0,0,255),-1) #umpire2


e1=cv2.circle(img50,(246,573),4,(255,255,255),-1) #ball




cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # 48 POINT

# %%
img51=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img51,(0,0),(1200,800),(128,178,194),-1) #layout
e1 = cv2.line(img51,(500,400),(700,400),(140,160,180),1050) #dugout
e1 = cv2.line(img51,(500,400),(700,400),(106,206,234),800) #ground
e1 = cv2.line(img51,(500,400),(700,400),(35,215,0),780) #extraSpace
e1 = cv2.line(img51,(500,400),(700,400),(255,255,255),750) #boundary
e1 = cv2.line(img51,(500,400),(700,400),(0,206,0),748) #playarea
e1 = cv2.rectangle(img51,(630,300),(570,500),(128,178,194),-1) #pitch
e1 = cv2.rectangle(img51,(630,300),(570,500),(255,255,255),1) #pitchhighlighter
e1 = cv2.line(img51,(580,300),(580,315),(255,255,255),1) #leftwideline
e1 = cv2.line(img51,(620,300),(620,315),(255,255,255),1) #rightwideline
e1 = cv2.line(img51,(580,500),(580,485),(255,255,255),1) #leftwideline_non_stricker
e1 = cv2.line(img51,(620,500),(620,485),(255,255,255),1) #rightwideline_non_stricker
e1 = cv2.line(img51,(565,315),(635,315),(255,255,255),1) #crease
e1 = cv2.line(img51,(565,485),(635,485),(255,255,255),1) #crease_non_stricker
e1 = cv2.line(img51,(597,300),(603,300),(0,0,0),1) #wickets
e1 = cv2.line(img51,(597,500),(603,500),(0,0,0),1) #wickets_non_stricker
e1 = cv2.circle(img51,(600,400),270,(255,255,255),1) #insidecircle

e1 = cv2.circle(img51,(600,280),5,(32,100,1),-1) #wicketkeeper
e1 = cv2.circle(img51,(925,120),5,(32,100,1),-1) #fineleg
e1 = cv2.circle(img51,(580,270),5,(32,100,1),-1) #slip
e1 = cv2.circle(img51,(490,720),5,(32,100,1),-1) #longoff
e1 = cv2.circle(img51,(720,530),5,(32,100,1),-1) #midwicket
e1 = cv2.circle(img51,(420,500),5,(32,100,1),-1) #cover
e1 = cv2.circle(img51,(150,380),5,(32,100,1),-1) #deepcoverpoint
e1 = cv2.circle(img51,(700,340),5,(32,100,1),-1) #short
e1 = cv2.circle(img51,(950,480),5,(32,100,1),-1) #deepsweep
e1 = cv2.circle(img51,(500,300),5,(32,100,1),-1) #gully
e1 = cv2.circle(img51,(610,490),5,(32,100,1),-1) #bowler

e1 = cv2.circle(img51,(590,490),5,(255,30,0),-1) #batsmen
e1 = cv2.circle(img51,(610,310),5,(255,30,0),-1) #bowler

e1 = cv2.circle(img51,(600,520),5,(0,0,255),-1) #umpire
e1 = cv2.circle(img51,(750,315),5,(0,0,255),-1) #umpire2


e1=cv2.circle(img51,(218,607),4,(255,255,255),-1) #ball




cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # 49 POINT

# %%
img52=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img52,(0,0),(1200,800),(128,178,194),-1) #layout
e1 = cv2.line(img52,(500,400),(700,400),(140,160,180),1050) #dugout
e1 = cv2.line(img52,(500,400),(700,400),(106,206,234),800) #ground
e1 = cv2.line(img52,(500,400),(700,400),(35,215,0),780) #extraSpace
e1 = cv2.line(img52,(500,400),(700,400),(255,255,255),750) #boundary
e1 = cv2.line(img52,(500,400),(700,400),(0,206,0),748) #playarea
e1 = cv2.rectangle(img52,(630,300),(570,500),(128,178,194),-1) #pitch
e1 = cv2.rectangle(img52,(630,300),(570,500),(255,255,255),1) #pitchhighlighter
e1 = cv2.line(img52,(580,300),(580,315),(255,255,255),1) #leftwideline
e1 = cv2.line(img52,(620,300),(620,315),(255,255,255),1) #rightwideline
e1 = cv2.line(img52,(580,500),(580,485),(255,255,255),1) #leftwideline_non_stricker
e1 = cv2.line(img52,(620,500),(620,485),(255,255,255),1) #rightwideline_non_stricker
e1 = cv2.line(img52,(565,315),(635,315),(255,255,255),1) #crease
e1 = cv2.line(img52,(565,485),(635,485),(255,255,255),1) #crease_non_stricker
e1 = cv2.line(img52,(597,300),(603,300),(0,0,0),1) #wickets
e1 = cv2.line(img52,(597,500),(603,500),(0,0,0),1) #wickets_non_stricker
e1 = cv2.circle(img52,(600,400),270,(255,255,255),1) #insidecircle

e1 = cv2.circle(img52,(600,280),5,(32,100,1),-1) #wicketkeeper
e1 = cv2.circle(img52,(925,120),5,(32,100,1),-1) #fineleg
e1 = cv2.circle(img52,(580,270),5,(32,100,1),-1) #slip
e1 = cv2.circle(img52,(490,720),5,(32,100,1),-1) #longoff
e1 = cv2.circle(img52,(720,530),5,(32,100,1),-1) #midwicket
e1 = cv2.circle(img52,(420,500),5,(32,100,1),-1) #cover
e1 = cv2.circle(img52,(150,380),5,(32,100,1),-1) #deepcoverpoint
e1 = cv2.circle(img52,(700,340),5,(32,100,1),-1) #short
e1 = cv2.circle(img52,(950,480),5,(32,100,1),-1) #deepsweep
e1 = cv2.circle(img52,(500,300),5,(32,100,1),-1) #gully
e1 = cv2.circle(img52,(610,490),5,(32,100,1),-1) #bowler

e1 = cv2.circle(img52,(590,490),5,(255,30,0),-1) #batsmen
e1 = cv2.circle(img52,(610,310),5,(255,30,0),-1) #bowler

e1 = cv2.circle(img52,(600,520),5,(0,0,255),-1) #umpire
e1 = cv2.circle(img52,(750,315),5,(0,0,255),-1) #umpire2


e1=cv2.circle(img52,(182,621),4,(255,255,255),-1) #ball




cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # 50 POINT

# %%
img53=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img53,(0,0),(1200,800),(128,178,194),-1) #layout
e1 = cv2.line(img53,(500,400),(700,400),(140,160,180),1050) #dugout
e1 = cv2.line(img53,(500,400),(700,400),(106,206,234),800) #ground
e1 = cv2.line(img53,(500,400),(700,400),(35,215,0),780)
e1 = cv2.line(img53,(500,400),(700,400),(255,255,255),750) #boundary
e1 = cv2.line(img53,(500,400),(700,400),(0,206,0),748) #playarea
e1 = cv2.rectangle(img53,(630,300),(570,500),(128,178,194),-1) #pitch
e1 = cv2.rectangle(img53,(630,300),(570,500),(255,255,255),1) #
e1 = cv2.line(img53,(580,300),(580,315),(255,255,255),1)
e1 = cv2.line(img53,(620,300),(620,315),(255,255,255),1)
e1 = cv2.line(img53,(580,500),(580,485),(255,255,255),1)
e1 = cv2.line(img53,(620,500),(620,485),(255,255,255),1)
e1 = cv2.line(img53,(570,315),(630,315),(255,255,255),1)
e1 = cv2.line(img53,(570,485),(630,485),(255,255,255),1)
e1 = cv2.line(img53,(597,300),(603,300),(0,0,0),1)
e1 = cv2.line(img53,(597,500),(603,500),(0,0,0),1)
e1 = cv2.circle(img53,(600,400),270,(255,0,0),1)
e1 = cv2.circle(img53,(600,400),270,(0,0,0),1)
e1 = cv2.circle(img53,(600,400),270,(255,255,255),1)
e1 = cv2.circle(img53,(600,400),270,(255,255,255),1)
e1 = cv2.circle(img53,(600,400),270,(255,255,255),1)
e1 = cv2.circle(img53,(600,400),270,(255,255,255),1)
e1 = cv2.circle(img53,(600,400),270,(255,255,255),1)
e1 = cv2.circle(img53,(600,400),270,(255,255,255),1)
e1 = cv2.circle(img53,(600,400),270,(255,255,255),1)
e1 = cv2.circle(img53,(600,400),270,(255,255,255),1)
e1 = cv2.circle(img53,(600,400),270,(255,255,255),1)
e1 = cv2.circle(img53,(600,400),270,(255,255,255),1)



e1 = cv2.rectangle(img53,(10,340),(1190,440),(0,0,0),-1)
e1 = cv2.putText(img53,"FOUR",(529,412),cv2.FONT_HERSHEY_SIMPLEX,2,(255,255,255),4)

cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # HARDIK

# %%
img54=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img54,(0,0),(1200,800),(128,178,194),-1) #layout
e1 = cv2.line(img54,(500,400),(700,400),(140,160,180),1050) #dugout
e1 = cv2.line(img54,(500,400),(700,400),(106,206,234),800) #ground
e1 = cv2.line(img54,(500,400),(700,400),(35,215,0),780) #extraSpace
e1 = cv2.line(img54,(500,400),(700,400),(255,255,255),750) #boundary
e1 = cv2.line(img54,(500,400),(700,400),(0,206,0),748) #playarea
e1 = cv2.rectangle(img54,(630,300),(570,500),(128,178,194),-1) #pitch
e1 = cv2.rectangle(img54,(630,300),(570,500),(255,255,255),1) #pitchhighlighter
e1 = cv2.line(img54,(580,300),(580,315),(255,255,255),1) #leftwideline
e1 = cv2.line(img54,(620,300),(620,315),(255,255,255),1) #rightwideline
e1 = cv2.line(img54,(580,500),(580,485),(255,255,255),1) #leftwideline_non_stricker
e1 = cv2.line(img54,(620,500),(620,485),(255,255,255),1) #rightwideline_non_stricker
e1 = cv2.line(img54,(565,315),(635,315),(255,255,255),1) #crease
e1 = cv2.line(img54,(565,485),(635,485),(255,255,255),1) #crease_non_stricker
e1 = cv2.line(img54,(597,300),(603,300),(0,0,0),1) #wickets
e1 = cv2.line(img54,(597,500),(603,500),(0,0,0),1) #wickets_non_stricker
e1 = cv2.circle(img54,(600,400),270,(255,255,255),1) #insidecircle

e1 = cv2.circle(img54,(600,280),5,(32,100,1),-1) #wicketkeeper
e1 = cv2.circle(img54,(925,120),5,(32,100,1),-1) #fineleg
e1 = cv2.circle(img54,(580,270),5,(32,100,1),-1) #slip
e1 = cv2.circle(img54,(490,720),5,(32,100,1),-1) #longoff
e1 = cv2.circle(img54,(720,530),5,(32,100,1),-1) #midwicket
e1 = cv2.circle(img54,(420,500),5,(32,100,1),-1) #cover
e1 = cv2.circle(img54,(150,380),5,(32,100,1),-1) #deepcoverpoint
e1 = cv2.circle(img54,(700,340),5,(32,100,1),-1) #short
e1 = cv2.circle(img54,(950,480),5,(32,100,1),-1) #deepsweep
e1 = cv2.circle(img54,(500,300),5,(32,100,1),-1) #gully
e1 = cv2.circle(img54,(610,490),5,(32,100,1),-1) #bowler

e1 = cv2.circle(img54,(590,490),5,(255,30,0),-1) #batsmen
e1 = cv2.circle(img54,(610,310),5,(255,30,0),-1) #bowler

e1 = cv2.circle(img54,(600,520),5,(0,0,255),-1) #umpire
e1 = cv2.circle(img54,(750,315),5,(0,0,255),-1) #umpire2

e1 = cv2.rectangle(img54,(10,340),(1190,440),(0,0,0),-1)
e1 = cv2.putText(img54,"HARDIK - SEMI HELICOPTER SHOT",(108,410),cv2.FONT_HERSHEY_SIMPLEX,2,(255,255,255),4)


cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
img55=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img55,(0,0),(1200,800),(0,178,0),-1) #layout

e1 = cv2.line(img55,(600,800),(530,400),(128,178,194),10)# left line
e1 = cv2.line(img55,(610,800),(540,400),(128,178,194),10)# left line
e1 = cv2.line(img55,(620,800),(550,400),(128,178,194),10)# left line
e1 = cv2.line(img55,(630,800),(560,400),(128,178,194),10)# left line
e1 = cv2.line(img55,(640,800),(570,400),(128,178,194),10)# left line
e1 = cv2.line(img55,(650,800),(580,400),(128,178,194),10)# left line
e1 = cv2.line(img55,(660,800),(590,400),(128,178,194),10)# left line
e1 = cv2.line(img55,(670,800),(600,400),(128,178,194),10)# left line
e1 = cv2.line(img55,(680,800),(610,400),(128,178,194),10)# left line
e1 = cv2.line(img55,(690,800),(620,400),(128,178,194),10)# left line
e1 = cv2.line(img55,(700,800),(630,400),(128,178,194),10)# left line
e1 = cv2.line(img55,(710,800),(640,400),(128,178,194),10)# left line
e1 = cv2.line(img55,(720,800),(650,400),(128,178,194),10)# left line
e1 = cv2.line(img55,(730,800),(660,400),(128,178,194),10)# left line
e1 = cv2.line(img55,(740,800),(670,400),(128,178,194),10)# left line
e1 = cv2.line(img55,(750,800),(680,400),(128,178,194),10)# left line
e1 = cv2.line(img55,(760,800),(690,400),(128,178,194),10)# left line

e1 = cv2.line(img55,(450,800),(530,400),(128,178,194),10)#right line
e1 = cv2.line(img55,(460,800),(540,400),(128,178,194),10)#right line
e1 = cv2.line(img55,(470,800),(550,400),(128,178,194),10)#right line
e1 = cv2.line(img55,(480,800),(560,400),(128,178,194),10)#right line
e1 = cv2.line(img55,(490,800),(570,400),(128,178,194),10)#right line
e1 = cv2.line(img55,(500,800),(580,400),(128,178,194),10)#right line
e1 = cv2.line(img55,(510,800),(590,400),(128,178,194),10)#right line
e1 = cv2.line(img55,(520,800),(600,400),(128,178,194),10)#right line
e1 = cv2.line(img55,(530,800),(610,400),(128,178,194),10)#right line
e1 = cv2.line(img55,(540,800),(620,400),(128,178,194),10)#right line
e1 = cv2.line(img55,(550,800),(630,400),(128,178,194),10)#right line
e1 = cv2.line(img55,(560,800),(640,400),(128,178,194),10)#right line
e1 = cv2.line(img55,(570,800),(650,400),(128,178,194),10)#right line
e1 = cv2.line(img55,(580,800),(660,400),(128,178,194),10)#right line
e1 = cv2.line(img55,(590,800),(670,400),(128,178,194),10)#right line

e1 = cv2.line(img55,(760,800),(690,400),(255,255,255),2)# left line
e1 = cv2.line(img55,(450,800),(530,400),(255,255,255),2)#right line
e1 = cv2.line(img55,(690,400),(530,400),(255,255,255),2)# middle line
e1 = cv2.line(img55,(600,1200),(600,760),(0,0,0),5)   #middle wicket   #buttom side
e1 = cv2.line(img55,(590,1200),(590,760),(0,0,0),5)   #left wicket
e1 = cv2.line(img55,(610,1200),(610,760),(0,0,0),5)   #right wicket
e1 = cv2.line(img55,(590,760),(610,760),(0,0,0),5)    #top wicket
e1 = cv2.line(img55,(430,750),(780,750),(255,255,255),2)#buttom boundary line 
e1 = cv2.line(img55,(500,750),(490,850),(255,255,255),2)#boundary left line
e1 = cv2.line(img55,(710,750),(720,850),(255,255,255),2)#boundary right line2
e1 = cv2.line(img55,(760,800),(690,400),(255,255,255),2)# left line
e1 = cv2.line(img55,(450,800),(530,400),(255,255,255),2)#right line
e1 = cv2.line(img55,(690,400),(530,400),(255,255,255),2)# middle line
e1 = cv2.line(img55,(620,400),(620,360),(0,0,0),5)   #right wicket     #top side
e1 = cv2.line(img55,(600,400),(600,360),(0,0,0),5)   #lift wicket
e1 = cv2.line(img55,(610,400),(610,360),(0,0,0),5)   #middle wicket
e1 = cv2.line(img55,(600,360),(620,360),(0,0,0),5)    #top wicket
e1 = cv2.line(img55,(490,440),(720,440),(255,255,255),2) # top boundary line
e1 = cv2.line(img55,(555,440),(560,400),(255,255,255),2)#boundary left line
e1 = cv2.line(img55,(655,440),(655,400),(255,255,255),2)#boundary right line




#indian player

e1=cv2.rectangle(img55,(642,402),(648,440),(255,0,0),-1)#right leg
e1=cv2.rectangle(img55,(629,352),(650,402),(255,0,0),-1)#body
e1=cv2.rectangle(img55,(631,402),(637,440),(255,0,0),-1)#left leg
e1=cv2.circle(img55,(640,339),13,(155,226,254),-1)# head
e1=cv2.circle(img55,(632,340),2,(0,0,0),-1)# right eye
e1=cv2.circle(img55,(637,340),2,(0,0,0),-1)# left eye
e1=cv2.circle(img55,(635,346),2,(0,0,0),-1)#mouth
e1 = cv2.line(img55,(632,364),(620,400),(155,226,254),3)#right hand 
e1 = cv2.line(img55,(641,373),(623,400),(155,226,254),3)#left hand
e1 = cv2.line(img55,(621,400),(603,435),(29,101,181),10)#bat
e1 = cv2.line(img55,(632,329),(647,329),(0,0,0),10)#top hair
e1 = cv2.line(img55,(647,336),(646,348),(0,0,0),10)#left hair


# pakistan wicket player

e1=cv2.rectangle(img55,(592,362),(586,395),(26,64,0),-1)#right leg
e1=cv2.rectangle(img55,(570,351),(593,379),(26,64,0),-1)#body
e1=cv2.rectangle(img55,(572,362),(579,395),(26,64,0),-1)#left leg
e1=cv2.circle(img55,(581,336),14,(155,226,254),-1)# head
e1=cv2.circle(img55,(576,338),2,(0,0,0),-1)# right eye
e1=cv2.circle(img55,(587,338),2,(0,0,0),-1)# left eye
e1 = cv2.line(img55,(578,345),(585,345),(0,0,0),2)#mouth
e1 = cv2.line(img55,(572,360),(582,369),(155,226,254),4)#right hand 
e1 = cv2.line(img55,(591,360),(582,369),(155,226,254),4)#left hand
e1 = cv2.line(img55,(581,368),(582,369),(255,255,255),10)#glove
e1 = cv2.line(img55,(571,326),(588,326),(0,0,0),10)#top hair



#bowler


e1=cv2.rectangle(img55,(626,759),(652,789),(26,64,0),-1)#body
e1=cv2.circle(img55,(638,745),14,(155,226,254),-1)# head
e1=cv2.circle(img55,(670,747),6,(255,255,255),-1)# right ball
e1 = cv2.line(img55,(653,764),(669,749),(155,226,254),5)#right hand 
e1 = cv2.line(img55,(625,765),(620,772),(155,226,254),5)#left hand
e1 = cv2.line(img55,(632,742),(643,742),(0,0,0),20)#top hair



# pakistan player
e1=cv2.rectangle(img55,(292,293),(300,322),(26,64,0),-1)#right leg
e1=cv2.rectangle(img55,(288,253),(320,298),(26,64,0),-1)#body
e1=cv2.rectangle(img55,(309,293),(317,322),(26,64,0),-1)#left leg
e1=cv2.circle(img55,(303,239),16,(155,226,254),-1)# head
e1=cv2.circle(img55,(295,242),2,(0,0,0),-1)# right eye
e1=cv2.circle(img55,(310,242),2,(0,0,0),-1)# left eye
e1 = cv2.line(img55,(298,249),(307,249),(0,0,0),2)#mouth
e1 = cv2.line(img55,(289,265),(294,276),(155,226,254),4)#right hand 
e1 = cv2.line(img55,(318,265),(310,276),(155,226,254),4)#left hand
e1 = cv2.line(img55,(293,229),(312,229),(0,0,0),13)#top hair


#Indian  player
e1=cv2.rectangle(img55,(548,767),(555,784),(255,0,0),-1)#left leg
e1=cv2.rectangle(img55,(569,767),(545,742),(255,0,0),-1)#body
e1=cv2.rectangle(img55,(560,767),(567,784),(255,0,0),-1)#right leg
e1=cv2.circle(img55,(557,729),14,(155,226,254),-1)# head
e1 = cv2.line(img55,(570,748),(574,761),(155,226,254),3)#right hand 
e1 = cv2.line(img55,(544,747),(537,754),(155,226,254),3)#left hand
e1 = cv2.line(img55,(575,761),(580,778),(29,101,181),10)#bat
e1 = cv2.line(img55,(550,724),(562,724),(0,0,0),21)#top hair




cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
img56=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img56,(0,0),(1200,800),(0,178,0),-1) #layout

e1 = cv2.line(img56,(600,800),(530,400),(128,178,194),10)# left line
e1 = cv2.line(img56,(610,800),(540,400),(128,178,194),10)# left line
e1 = cv2.line(img56,(620,800),(550,400),(128,178,194),10)# left line
e1 = cv2.line(img56,(630,800),(560,400),(128,178,194),10)# left line
e1 = cv2.line(img56,(640,800),(570,400),(128,178,194),10)# left line
e1 = cv2.line(img56,(650,800),(580,400),(128,178,194),10)# left line
e1 = cv2.line(img56,(660,800),(590,400),(128,178,194),10)# left line
e1 = cv2.line(img56,(670,800),(600,400),(128,178,194),10)# left line
e1 = cv2.line(img56,(680,800),(610,400),(128,178,194),10)# left line
e1 = cv2.line(img56,(690,800),(620,400),(128,178,194),10)# left line
e1 = cv2.line(img56,(700,800),(630,400),(128,178,194),10)# left line
e1 = cv2.line(img56,(710,800),(640,400),(128,178,194),10)# left line
e1 = cv2.line(img56,(720,800),(650,400),(128,178,194),10)# left line
e1 = cv2.line(img56,(730,800),(660,400),(128,178,194),10)# left line
e1 = cv2.line(img56,(740,800),(670,400),(128,178,194),10)# left line
e1 = cv2.line(img56,(750,800),(680,400),(128,178,194),10)# left line
e1 = cv2.line(img56,(760,800),(690,400),(128,178,194),10)# left line

e1 = cv2.line(img56,(450,800),(530,400),(128,178,194),10)#right line
e1 = cv2.line(img56,(460,800),(540,400),(128,178,194),10)#right line
e1 = cv2.line(img56,(470,800),(550,400),(128,178,194),10)#right line
e1 = cv2.line(img56,(480,800),(560,400),(128,178,194),10)#right line
e1 = cv2.line(img56,(490,800),(570,400),(128,178,194),10)#right line
e1 = cv2.line(img56,(500,800),(580,400),(128,178,194),10)#right line
e1 = cv2.line(img56,(510,800),(590,400),(128,178,194),10)#right line
e1 = cv2.line(img56,(520,800),(600,400),(128,178,194),10)#right line
e1 = cv2.line(img56,(530,800),(610,400),(128,178,194),10)#right line
e1 = cv2.line(img56,(540,800),(620,400),(128,178,194),10)#right line
e1 = cv2.line(img56,(550,800),(630,400),(128,178,194),10)#right line
e1 = cv2.line(img56,(560,800),(640,400),(128,178,194),10)#right line
e1 = cv2.line(img56,(570,800),(650,400),(128,178,194),10)#right line
e1 = cv2.line(img56,(580,800),(660,400),(128,178,194),10)#right line
e1 = cv2.line(img56,(590,800),(670,400),(128,178,194),10)#right line

e1 = cv2.line(img56,(760,800),(690,400),(255,255,255),2)# left line
e1 = cv2.line(img56,(450,800),(530,400),(255,255,255),2)#right line
e1 = cv2.line(img56,(690,400),(530,400),(255,255,255),2)# middle line
e1 = cv2.line(img56,(600,1200),(600,760),(0,0,0),5)   #middle wicket   #buttom side
e1 = cv2.line(img56,(590,1200),(590,760),(0,0,0),5)   #left wicket
e1 = cv2.line(img56,(610,1200),(610,760),(0,0,0),5)   #right wicket
e1 = cv2.line(img56,(590,760),(610,760),(0,0,0),5)    #top wicket
e1 = cv2.line(img56,(430,750),(780,750),(255,255,255),2)#buttom boundary line 
e1 = cv2.line(img56,(500,750),(490,850),(255,255,255),2)#boundary left line
e1 = cv2.line(img56,(710,750),(720,850),(255,255,255),2)#boundary right line

e1 = cv2.line(img56,(760,800),(690,400),(255,255,255),2)# left line
e1 = cv2.line(img56,(450,800),(530,400),(255,255,255),2)#right line
e1 = cv2.line(img56,(690,400),(530,400),(255,255,255),2)# middle line
e1 = cv2.line(img56,(620,400),(620,360),(0,0,0),5)   #right wicket     #top side
e1 = cv2.line(img56,(600,400),(600,360),(0,0,0),5)   #lift wicket
e1 = cv2.line(img56,(610,400),(610,360),(0,0,0),5)   #middle wicket
e1 = cv2.line(img56,(600,360),(620,360),(0,0,0),5)    #top wicket
e1 = cv2.line(img56,(490,440),(720,440),(255,255,255),2) # top boundary line
e1 = cv2.line(img56,(555,440),(560,400),(255,255,255),2)#boundary left line
e1 = cv2.line(img56,(655,440),(655,400),(255,255,255),2)#boundary right line



#indian player

e1=cv2.rectangle(img56,(642,402),(648,440),(255,0,0),-1)#right leg
e1=cv2.rectangle(img56,(629,352),(650,402),(255,0,0),-1)#body
e1=cv2.rectangle(img56,(631,402),(637,440),(255,0,0),-1)#left leg
e1=cv2.circle(img56,(640,339),13,(155,226,254),-1)# head
e1=cv2.circle(img56,(632,340),2,(0,0,0),-1)# right eye
e1=cv2.circle(img56,(637,340),2,(0,0,0),-1)# left eye
e1=cv2.circle(img56,(635,346),2,(0,0,0),-1)#mouth
e1 = cv2.line(img56,(632,364),(620,400),(155,226,254),3)#right hand 
e1 = cv2.line(img56,(641,373),(623,400),(155,226,254),3)#left hand
e1 = cv2.line(img56,(618,400),(596,369),(29,101,181),10)#bat
e1 = cv2.line(img56,(632,329),(647,329),(0,0,0),10)#top hair
e1 = cv2.line(img56,(647,336),(646,348),(0,0,0),10)#left hair


# pakistan wicket player

e1=cv2.rectangle(img56,(592,362),(586,395),(26,64,0),-1)#right leg
e1=cv2.rectangle(img56,(570,351),(593,379),(26,64,0),-1)#body
e1=cv2.rectangle(img56,(572,362),(579,395),(26,64,0),-1)#left leg
e1=cv2.circle(img56,(581,336),14,(155,226,254),-1)# head
e1=cv2.circle(img56,(576,338),2,(0,0,0),-1)# right eye
e1=cv2.circle(img56,(587,338),2,(0,0,0),-1)# left eye
e1 = cv2.line(img56,(578,345),(585,345),(0,0,0),2)#mouth
e1 = cv2.line(img56,(572,360),(582,369),(155,226,254),4)#right hand 
e1 = cv2.line(img56,(591,360),(582,369),(155,226,254),4)#left hand
e1 = cv2.line(img56,(581,368),(582,369),(255,255,255),10)#glove
e1 = cv2.line(img56,(571,326),(588,326),(0,0,0),10)#top hair



#bowler


e1=cv2.rectangle(img56,(626,739),(652,769),(26,64,0),-1)#body
e1=cv2.circle(img56,(638,725),14,(155,226,254),-1)# head
e1=cv2.circle(img56,(670,727),6,(255,255,255),-1)# right ball
e1 = cv2.line(img56,(653,744),(669,729),(155,226,254),5)#right hand 
e1 = cv2.line(img56,(625,745),(620,752),(155,226,254),5)#left hand
e1 = cv2.line(img56,(632,722),(643,722),(0,0,0),20)#top hair
e1=cv2.rectangle(img56,(631,769),(637,782),(26,64,0),-1)#left leg
e1=cv2.rectangle(img56,(642,769),(648,782),(26,64,0),-1)#right leg



# pakistan player
e1=cv2.rectangle(img56,(292,293),(300,322),(26,64,0),-1)#right leg
e1=cv2.rectangle(img56,(288,253),(320,298),(26,64,0),-1)#body
e1=cv2.rectangle(img56,(309,293),(317,322),(26,64,0),-1)#left leg
e1=cv2.circle(img56,(303,239),16,(155,226,254),-1)# head
e1=cv2.circle(img56,(295,242),2,(0,0,0),-1)# right eye
e1=cv2.circle(img56,(310,242),2,(0,0,0),-1)# left eye
e1 = cv2.line(img56,(298,249),(307,249),(0,0,0),2)#mouth
e1 = cv2.line(img56,(289,265),(294,276),(155,226,254),4)#right hand 
e1 = cv2.line(img56,(318,265),(310,276),(155,226,254),4)#left hand
e1 = cv2.line(img56,(293,229),(312,229),(0,0,0),13)#top hair


#Indian  player
e1=cv2.rectangle(img56,(548,767),(555,784),(255,0,0),-1)#left leg
e1=cv2.rectangle(img56,(569,767),(545,742),(255,0,0),-1)#body
e1=cv2.rectangle(img56,(560,767),(567,784),(255,0,0),-1)#right leg
e1=cv2.circle(img56,(557,729),14,(155,226,254),-1)# head
e1 = cv2.line(img56,(570,748),(574,761),(155,226,254),3)#right hand 
e1 = cv2.line(img56,(544,747),(537,754),(155,226,254),3)#left hand
e1 = cv2.line(img56,(575,761),(580,778),(29,101,181),10)#bat
e1 = cv2.line(img56,(550,724),(562,724),(0,0,0),21)#top hair




cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
img57=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img57,(0,0),(1200,800),(0,178,0),-1) #layout

e1 = cv2.line(img57,(600,800),(530,400),(128,178,194),10)# left line
e1 = cv2.line(img57,(610,800),(540,400),(128,178,194),10)# left line
e1 = cv2.line(img57,(620,800),(550,400),(128,178,194),10)# left line
e1 = cv2.line(img57,(630,800),(560,400),(128,178,194),10)# left line
e1 = cv2.line(img57,(640,800),(570,400),(128,178,194),10)# left line
e1 = cv2.line(img57,(650,800),(580,400),(128,178,194),10)# left line
e1 = cv2.line(img57,(660,800),(590,400),(128,178,194),10)# left line
e1 = cv2.line(img57,(670,800),(600,400),(128,178,194),10)# left line
e1 = cv2.line(img57,(680,800),(610,400),(128,178,194),10)# left line
e1 = cv2.line(img57,(690,800),(620,400),(128,178,194),10)# left line
e1 = cv2.line(img57,(700,800),(630,400),(128,178,194),10)# left line
e1 = cv2.line(img57,(710,800),(640,400),(128,178,194),10)# left line
e1 = cv2.line(img57,(720,800),(650,400),(128,178,194),10)# left line
e1 = cv2.line(img57,(730,800),(660,400),(128,178,194),10)# left line
e1 = cv2.line(img57,(740,800),(670,400),(128,178,194),10)# left line
e1 = cv2.line(img57,(750,800),(680,400),(128,178,194),10)# left line
e1 = cv2.line(img57,(760,800),(690,400),(128,178,194),10)# left line

e1 = cv2.line(img57,(450,800),(530,400),(128,178,194),10)#right line
e1 = cv2.line(img57,(460,800),(540,400),(128,178,194),10)#right line
e1 = cv2.line(img57,(470,800),(550,400),(128,178,194),10)#right line
e1 = cv2.line(img57,(480,800),(560,400),(128,178,194),10)#right line
e1 = cv2.line(img57,(490,800),(570,400),(128,178,194),10)#right line
e1 = cv2.line(img57,(500,800),(580,400),(128,178,194),10)#right line
e1 = cv2.line(img57,(510,800),(590,400),(128,178,194),10)#right line
e1 = cv2.line(img57,(520,800),(600,400),(128,178,194),10)#right line
e1 = cv2.line(img57,(530,800),(610,400),(128,178,194),10)#right line
e1 = cv2.line(img57,(540,800),(620,400),(128,178,194),10)#right line
e1 = cv2.line(img57,(550,800),(630,400),(128,178,194),10)#right line
e1 = cv2.line(img57,(560,800),(640,400),(128,178,194),10)#right line
e1 = cv2.line(img57,(570,800),(650,400),(128,178,194),10)#right line
e1 = cv2.line(img57,(580,800),(660,400),(128,178,194),10)#right line
e1 = cv2.line(img57,(590,800),(670,400),(128,178,194),10)#right line

e1 = cv2.line(img57,(760,800),(690,400),(255,255,255),2)# left line
e1 = cv2.line(img57,(450,800),(530,400),(255,255,255),2)#right line
e1 = cv2.line(img57,(690,400),(530,400),(255,255,255),2)# middle line
e1 = cv2.line(img57,(600,1200),(600,760),(0,0,0),5)   #middle wicket   #buttom side
e1 = cv2.line(img57,(590,1200),(590,760),(0,0,0),5)   #left wicket
e1 = cv2.line(img57,(610,1200),(610,760),(0,0,0),5)   #right wicket
e1 = cv2.line(img57,(590,760),(610,760),(0,0,0),5)    #top wicket
e1 = cv2.line(img57,(430,750),(780,750),(255,255,255),2)#buttom boundary line 
e1 = cv2.line(img57,(500,750),(490,850),(255,255,255),2)#boundary left line
e1 = cv2.line(img57,(710,750),(720,850),(255,255,255),2)#boundary right line

e1 = cv2.line(img57,(760,800),(690,400),(255,255,255),2)# left line
e1 = cv2.line(img57,(450,800),(530,400),(255,255,255),2)#right line
e1 = cv2.line(img57,(690,400),(530,400),(255,255,255),2)# middle line
e1 = cv2.line(img57,(620,400),(620,360),(0,0,0),5)   #right wicket     #top side
e1 = cv2.line(img57,(600,400),(600,360),(0,0,0),5)   #lift wicket
e1 = cv2.line(img57,(610,400),(610,360),(0,0,0),5)   #middle wicket
e1 = cv2.line(img57,(600,360),(620,360),(0,0,0),5)    #top wicket
e1 = cv2.line(img57,(490,440),(720,440),(255,255,255),2) # top boundary line
e1 = cv2.line(img57,(555,440),(560,400),(255,255,255),2)#boundary left line
e1 = cv2.line(img57,(655,440),(655,400),(255,255,255),2)#boundary right line




#indian player

e1=cv2.rectangle(img57,(642,402),(648,440),(255,0,0),-1)#right leg
e1=cv2.rectangle(img57,(629,352),(650,402),(255,0,0),-1)#body
e1=cv2.rectangle(img57,(631,402),(637,440),(255,0,0),-1)#left leg
e1=cv2.circle(img57,(640,339),13,(155,226,254),-1)# head
e1=cv2.circle(img57,(632,340),2,(0,0,0),-1)# right eye
e1=cv2.circle(img57,(637,340),2,(0,0,0),-1)# left eye
e1=cv2.circle(img57,(635,346),2,(0,0,0),-1)#mouth
e1 = cv2.line(img57,(632,364),(620,400),(155,226,254),3)#right hand 
e1 = cv2.line(img57,(641,373),(623,400),(155,226,254),3)#left hand
e1 = cv2.line(img57,(621,400),(584,416),(29,101,181),10)#bat
e1 = cv2.line(img57,(632,329),(647,329),(0,0,0),10)#top hair
e1 = cv2.line(img57,(647,336),(646,348),(0,0,0),10)#left hair


# pakistan wicket player

e1=cv2.rectangle(img57,(592,362),(586,395),(26,64,0),-1)#right leg
e1=cv2.rectangle(img57,(570,351),(593,379),(26,64,0),-1)#body
e1=cv2.rectangle(img57,(572,362),(579,395),(26,64,0),-1)#left leg
e1=cv2.circle(img57,(581,336),14,(155,226,254),-1)# head
e1=cv2.circle(img57,(576,338),2,(0,0,0),-1)# right eye
e1=cv2.circle(img57,(587,338),2,(0,0,0),-1)# left eye
e1 = cv2.line(img57,(578,345),(585,345),(0,0,0),2)#mouth
e1 = cv2.line(img57,(572,360),(582,369),(155,226,254),4)#right hand 
e1 = cv2.line(img57,(591,360),(582,369),(155,226,254),4)#left hand
e1 = cv2.line(img57,(581,368),(582,369),(255,255,255),10)#glove
e1 = cv2.line(img57,(571,326),(588,326),(0,0,0),10)#top hair



#bowler


e1=cv2.rectangle(img57,(626,719),(652,749),(26,64,0),-1)#body
e1=cv2.circle(img57,(638,705),14,(155,226,254),-1)# head
e1=cv2.circle(img57,(670,707),6,(255,255,255),-1)# right ball
e1 = cv2.line(img57,(653,724),(669,709),(155,226,254),5)#right hand 
e1 = cv2.line(img57,(625,725),(620,732),(155,226,254),5)#left hand
e1 = cv2.line(img57,(632,702),(643,702),(0,0,0),20)#top hair
e1=cv2.rectangle(img57,(631,749),(637,762),(26,64,0),-1)#left leg
e1=cv2.rectangle(img57,(642,749),(648,762),(26,64,0),-1)#right leg



# pakistan player
e1=cv2.rectangle(img57,(292,293),(300,322),(26,64,0),-1)#right leg
e1=cv2.rectangle(img57,(288,253),(320,298),(26,64,0),-1)#body
e1=cv2.rectangle(img57,(309,293),(317,322),(26,64,0),-1)#left leg
e1=cv2.circle(img57,(303,239),16,(155,226,254),-1)# head
e1=cv2.circle(img57,(295,242),2,(0,0,0),-1)# right eye
e1=cv2.circle(img57,(310,242),2,(0,0,0),-1)# left eye
e1 = cv2.line(img57,(298,249),(307,249),(0,0,0),2)#mouth
e1 = cv2.line(img57,(289,265),(294,276),(155,226,254),4)#right hand 
e1 = cv2.line(img57,(318,265),(310,276),(155,226,254),4)#left hand
e1 = cv2.line(img57,(293,229),(312,229),(0,0,0),13)#top hair


#Indian  player
e1=cv2.rectangle(img57,(548,767),(555,784),(255,0,0),-1)#left leg
e1=cv2.rectangle(img57,(569,767),(545,742),(255,0,0),-1)#body
e1=cv2.rectangle(img57,(560,767),(567,784),(255,0,0),-1)#right leg
e1=cv2.circle(img57,(557,729),14,(155,226,254),-1)# head
e1 = cv2.line(img57,(570,748),(574,761),(155,226,254),3)#right hand 
e1 = cv2.line(img57,(544,747),(537,754),(155,226,254),3)#left hand
e1 = cv2.line(img57,(575,761),(580,778),(29,101,181),10)#bat
e1 = cv2.line(img57,(550,724),(562,724),(0,0,0),21)#top hair




cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
img58=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img58,(0,0),(1200,800),(0,178,0),-1) #layout

e1 = cv2.line(img58,(600,800),(530,400),(128,178,194),10)# left line
e1 = cv2.line(img58,(610,800),(540,400),(128,178,194),10)# left line
e1 = cv2.line(img58,(620,800),(550,400),(128,178,194),10)# left line
e1 = cv2.line(img58,(630,800),(560,400),(128,178,194),10)# left line
e1 = cv2.line(img58,(640,800),(570,400),(128,178,194),10)# left line
e1 = cv2.line(img58,(650,800),(580,400),(128,178,194),10)# left line
e1 = cv2.line(img58,(660,800),(590,400),(128,178,194),10)# left line
e1 = cv2.line(img58,(670,800),(600,400),(128,178,194),10)# left line
e1 = cv2.line(img58,(680,800),(610,400),(128,178,194),10)# left line
e1 = cv2.line(img58,(690,800),(620,400),(128,178,194),10)# left line
e1 = cv2.line(img58,(700,800),(630,400),(128,178,194),10)# left line
e1 = cv2.line(img58,(710,800),(640,400),(128,178,194),10)# left line
e1 = cv2.line(img58,(720,800),(650,400),(128,178,194),10)# left line
e1 = cv2.line(img58,(730,800),(660,400),(128,178,194),10)# left line
e1 = cv2.line(img58,(740,800),(670,400),(128,178,194),10)# left line
e1 = cv2.line(img58,(750,800),(680,400),(128,178,194),10)# left line
e1 = cv2.line(img58,(760,800),(690,400),(128,178,194),10)# left line

e1 = cv2.line(img58,(450,800),(530,400),(128,178,194),10)#right line
e1 = cv2.line(img58,(460,800),(540,400),(128,178,194),10)#right line
e1 = cv2.line(img58,(470,800),(550,400),(128,178,194),10)#right line
e1 = cv2.line(img58,(480,800),(560,400),(128,178,194),10)#right line
e1 = cv2.line(img58,(490,800),(570,400),(128,178,194),10)#right line
e1 = cv2.line(img58,(500,800),(580,400),(128,178,194),10)#right line
e1 = cv2.line(img58,(510,800),(590,400),(128,178,194),10)#right line
e1 = cv2.line(img58,(520,800),(600,400),(128,178,194),10)#right line
e1 = cv2.line(img58,(530,800),(610,400),(128,178,194),10)#right line
e1 = cv2.line(img58,(540,800),(620,400),(128,178,194),10)#right line
e1 = cv2.line(img58,(550,800),(630,400),(128,178,194),10)#right line
e1 = cv2.line(img58,(560,800),(640,400),(128,178,194),10)#right line
e1 = cv2.line(img58,(570,800),(650,400),(128,178,194),10)#right line
e1 = cv2.line(img58,(580,800),(660,400),(128,178,194),10)#right line
e1 = cv2.line(img58,(590,800),(670,400),(128,178,194),10)#right line

e1 = cv2.line(img58,(760,800),(690,400),(255,255,255),2)# left line
e1 = cv2.line(img58,(450,800),(530,400),(255,255,255),2)#right line
e1 = cv2.line(img58,(690,400),(530,400),(255,255,255),2)# middle line
e1 = cv2.line(img58,(600,1200),(600,760),(0,0,0),5)   #middle wicket   #buttom side
e1 = cv2.line(img58,(590,1200),(590,760),(0,0,0),5)   #left wicket
e1 = cv2.line(img58,(610,1200),(610,760),(0,0,0),5)   #right wicket
e1 = cv2.line(img58,(590,760),(610,760),(0,0,0),5)    #top wicket
e1 = cv2.line(img58,(430,750),(780,750),(255,255,255),2)#buttom boundary line 
e1 = cv2.line(img58,(500,750),(490,850),(255,255,255),2)#boundary left line
e1 = cv2.line(img58,(710,750),(720,850),(255,255,255),2)#boundary right line

e1 = cv2.line(img58,(760,800),(690,400),(255,255,255),2)# left line
e1 = cv2.line(img58,(450,800),(530,400),(255,255,255),2)#right line
e1 = cv2.line(img58,(690,400),(530,400),(255,255,255),2)# middle line
e1 = cv2.line(img58,(620,400),(620,360),(0,0,0),5)   #right wicket     #top side
e1 = cv2.line(img58,(600,400),(600,360),(0,0,0),5)   #lift wicket
e1 = cv2.line(img58,(610,400),(610,360),(0,0,0),5)   #middle wicket
e1 = cv2.line(img58,(600,360),(620,360),(0,0,0),5)    #top wicket
e1 = cv2.line(img58,(490,440),(720,440),(255,255,255),2) # top boundary line
e1 = cv2.line(img58,(555,440),(560,400),(255,255,255),2)#boundary left line
e1 = cv2.line(img58,(655,440),(655,400),(255,255,255),2)#boundary right line




#indian player

e1=cv2.rectangle(img58,(642,402),(648,440),(255,0,0),-1)#right leg
e1=cv2.rectangle(img58,(629,352),(650,402),(255,0,0),-1)#body
e1=cv2.rectangle(img58,(631,402),(637,440),(255,0,0),-1)#left leg
e1=cv2.circle(img58,(640,339),13,(155,226,254),-1)# head
e1=cv2.circle(img58,(632,340),2,(0,0,0),-1)# right eye
e1=cv2.circle(img58,(637,340),2,(0,0,0),-1)# left eye
e1=cv2.circle(img58,(635,346),2,(0,0,0),-1)#mouth
e1 = cv2.line(img58,(632,364),(620,400),(155,226,254),3)#right hand 
e1 = cv2.line(img58,(641,373),(623,400),(155,226,254),3)#left hand
e1 = cv2.line(img58,(621,400),(603,435),(29,101,181),10)#bat
e1 = cv2.line(img58,(632,329),(647,329),(0,0,0),10)#top hair
e1 = cv2.line(img58,(647,336),(646,348),(0,0,0),10)#left hair


# pakistan wicket player

e1=cv2.rectangle(img58,(592,362),(586,395),(26,64,0),-1)#right leg
e1=cv2.rectangle(img58,(570,351),(593,379),(26,64,0),-1)#body
e1=cv2.rectangle(img58,(572,362),(579,395),(26,64,0),-1)#left leg
e1=cv2.circle(img58,(581,336),14,(155,226,254),-1)# head
e1=cv2.circle(img58,(576,338),2,(0,0,0),-1)# right eye
e1=cv2.circle(img58,(587,338),2,(0,0,0),-1)# left eye
e1 = cv2.line(img58,(578,345),(585,345),(0,0,0),2)#mouth
e1 = cv2.line(img58,(572,360),(582,369),(155,226,254),4)#right hand 
e1 = cv2.line(img58,(591,360),(582,369),(155,226,254),4)#left hand
e1 = cv2.line(img58,(581,368),(582,369),(255,255,255),10)#glove
e1 = cv2.line(img58,(571,326),(588,326),(0,0,0),10)#top hair



#bowler


e1=cv2.rectangle(img58,(626,719),(652,749),(26,64,0),-1)#body
e1=cv2.circle(img58,(638,705),14,(155,226,254),-1)# head
e1=cv2.circle(img58,(670,690),6,(255,255,255),-1)# right ball
e1 = cv2.line(img58,(653,724),(669,709),(155,226,254),5)#right hand 
e1 = cv2.line(img58,(625,725),(620,732),(155,226,254),5)#left hand
e1 = cv2.line(img58,(632,702),(643,702),(0,0,0),20)#top hair
e1=cv2.rectangle(img58,(631,749),(637,762),(26,64,0),-1)#left leg
e1=cv2.rectangle(img58,(642,749),(648,762),(26,64,0),-1)#right leg



# pakistan player
e1=cv2.rectangle(img58,(292,293),(300,322),(26,64,0),-1)#right leg
e1=cv2.rectangle(img58,(288,253),(320,298),(26,64,0),-1)#body
e1=cv2.rectangle(img58,(309,293),(317,322),(26,64,0),-1)#left leg
e1=cv2.circle(img58,(303,239),16,(155,226,254),-1)# head
e1=cv2.circle(img58,(295,242),2,(0,0,0),-1)# right eye
e1=cv2.circle(img58,(310,242),2,(0,0,0),-1)# left eye
e1 = cv2.line(img58,(298,249),(307,249),(0,0,0),2)#mouth
e1 = cv2.line(img58,(289,265),(294,276),(155,226,254),4)#right hand 
e1 = cv2.line(img58,(318,265),(310,276),(155,226,254),4)#left hand
e1 = cv2.line(img58,(293,229),(312,229),(0,0,0),13)#top hair

#Indian  player
e1=cv2.rectangle(img58,(548,767),(555,784),(255,0,0),-1)#left leg
e1=cv2.rectangle(img58,(569,767),(545,742),(255,0,0),-1)#body
e1=cv2.rectangle(img58,(560,767),(567,784),(255,0,0),-1)#right leg
e1=cv2.circle(img58,(557,729),14,(155,226,254),-1)# head
e1 = cv2.line(img58,(570,748),(574,761),(155,226,254),3)#right hand 
e1 = cv2.line(img58,(544,747),(537,754),(155,226,254),3)#left hand
e1 = cv2.line(img58,(575,761),(580,778),(29,101,181),10)#bat
e1 = cv2.line(img58,(550,724),(562,724),(0,0,0),21)#top hair




cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
img59=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img59,(0,0),(1200,800),(0,178,0),-1) #layout

e1 = cv2.line(img59,(600,800),(530,400),(128,178,194),10)# left line
e1 = cv2.line(img59,(610,800),(540,400),(128,178,194),10)# left line
e1 = cv2.line(img59,(620,800),(550,400),(128,178,194),10)# left line
e1 = cv2.line(img59,(630,800),(560,400),(128,178,194),10)# left line
e1 = cv2.line(img59,(640,800),(570,400),(128,178,194),10)# left line
e1 = cv2.line(img59,(650,800),(580,400),(128,178,194),10)# left line
e1 = cv2.line(img59,(660,800),(590,400),(128,178,194),10)# left line
e1 = cv2.line(img59,(670,800),(600,400),(128,178,194),10)# left line
e1 = cv2.line(img59,(680,800),(610,400),(128,178,194),10)# left line
e1 = cv2.line(img59,(690,800),(620,400),(128,178,194),10)# left line
e1 = cv2.line(img59,(700,800),(630,400),(128,178,194),10)# left line
e1 = cv2.line(img59,(710,800),(640,400),(128,178,194),10)# left line
e1 = cv2.line(img59,(720,800),(650,400),(128,178,194),10)# left line
e1 = cv2.line(img59,(730,800),(660,400),(128,178,194),10)# left line
e1 = cv2.line(img59,(740,800),(670,400),(128,178,194),10)# left line
e1 = cv2.line(img59,(750,800),(680,400),(128,178,194),10)# left line
e1 = cv2.line(img59,(760,800),(690,400),(128,178,194),10)# left line

e1 = cv2.line(img59,(450,800),(530,400),(128,178,194),10)#right line
e1 = cv2.line(img59,(460,800),(540,400),(128,178,194),10)#right line
e1 = cv2.line(img59,(470,800),(550,400),(128,178,194),10)#right line
e1 = cv2.line(img59,(480,800),(560,400),(128,178,194),10)#right line
e1 = cv2.line(img59,(490,800),(570,400),(128,178,194),10)#right line
e1 = cv2.line(img59,(500,800),(580,400),(128,178,194),10)#right line
e1 = cv2.line(img59,(510,800),(590,400),(128,178,194),10)#right line
e1 = cv2.line(img59,(520,800),(600,400),(128,178,194),10)#right line
e1 = cv2.line(img59,(530,800),(610,400),(128,178,194),10)#right line
e1 = cv2.line(img59,(540,800),(620,400),(128,178,194),10)#right line
e1 = cv2.line(img59,(550,800),(630,400),(128,178,194),10)#right line
e1 = cv2.line(img59,(560,800),(640,400),(128,178,194),10)#right line
e1 = cv2.line(img59,(570,800),(650,400),(128,178,194),10)#right line
e1 = cv2.line(img59,(580,800),(660,400),(128,178,194),10)#right line
e1 = cv2.line(img59,(590,800),(670,400),(128,178,194),10)#right line

e1 = cv2.line(img59,(760,800),(690,400),(255,255,255),2)# left line
e1 = cv2.line(img59,(450,800),(530,400),(255,255,255),2)#right line
e1 = cv2.line(img59,(690,400),(530,400),(255,255,255),2)# middle line
e1 = cv2.line(img59,(600,1200),(600,760),(0,0,0),5)   #middle wicket   #buttom side
e1 = cv2.line(img59,(590,1200),(590,760),(0,0,0),5)   #left wicket
e1 = cv2.line(img59,(610,1200),(610,760),(0,0,0),5)   #right wicket
e1 = cv2.line(img59,(590,760),(610,760),(0,0,0),5)    #top wicket
e1 = cv2.line(img59,(430,750),(780,750),(255,255,255),2)#buttom boundary line 
e1 = cv2.line(img59,(500,750),(490,850),(255,255,255),2)#boundary left line
e1 = cv2.line(img59,(710,750),(720,850),(255,255,255),2)#boundary right line

e1 = cv2.line(img59,(760,800),(690,400),(255,255,255),2)# left line
e1 = cv2.line(img59,(450,800),(530,400),(255,255,255),2)#right line
e1 = cv2.line(img59,(690,400),(530,400),(255,255,255),2)# middle line
e1 = cv2.line(img59,(620,400),(620,360),(0,0,0),5)   #right wicket     #top side
e1 = cv2.line(img59,(600,400),(600,360),(0,0,0),5)   #lift wicket
e1 = cv2.line(img59,(610,400),(610,360),(0,0,0),5)   #middle wicket
e1 = cv2.line(img59,(600,360),(620,360),(0,0,0),5)    #top wicket
e1 = cv2.line(img59,(490,440),(720,440),(255,255,255),2) # top boundary line
e1 = cv2.line(img59,(555,440),(560,400),(255,255,255),2)#boundary left line
e1 = cv2.line(img59,(655,440),(655,400),(255,255,255),2)#boundary right line




#indian player

e1=cv2.rectangle(img59,(642,402),(648,440),(255,0,0),-1)#right leg
e1=cv2.rectangle(img59,(629,352),(650,402),(255,0,0),-1)#body
e1=cv2.rectangle(img59,(631,402),(637,440),(255,0,0),-1)#left leg
e1=cv2.circle(img59,(640,339),13,(155,226,254),-1)# head
e1=cv2.circle(img59,(632,340),2,(0,0,0),-1)# right eye
e1=cv2.circle(img59,(637,340),2,(0,0,0),-1)# left eye
e1=cv2.circle(img59,(635,346),2,(0,0,0),-1)#mouth
e1 = cv2.line(img59,(632,364),(620,400),(155,226,254),3)#right hand 
e1 = cv2.line(img59,(641,373),(623,400),(155,226,254),3)#left hand
e1 = cv2.line(img59,(621,400),(603,435),(29,101,181),10)#bat
e1 = cv2.line(img59,(632,329),(647,329),(0,0,0),10)#top hair
e1 = cv2.line(img59,(647,336),(646,348),(0,0,0),10)#left hair


# pakistan wicket player

e1=cv2.rectangle(img59,(592,362),(586,395),(26,64,0),-1)#right leg
e1=cv2.rectangle(img59,(570,351),(593,379),(26,64,0),-1)#body
e1=cv2.rectangle(img59,(572,362),(579,395),(26,64,0),-1)#left leg
e1=cv2.circle(img59,(581,336),14,(155,226,254),-1)# head
e1=cv2.circle(img59,(576,338),2,(0,0,0),-1)# right eye
e1=cv2.circle(img59,(587,338),2,(0,0,0),-1)# left eye
e1 = cv2.line(img59,(578,345),(585,345),(0,0,0),2)#mouth
e1 = cv2.line(img59,(572,360),(582,369),(155,226,254),4)#right hand 
e1 = cv2.line(img59,(591,360),(582,369),(155,226,254),4)#left hand
e1 = cv2.line(img59,(581,368),(582,369),(255,255,255),10)#glove
e1 = cv2.line(img59,(571,326),(588,326),(0,0,0),10)#top hair



#bowler


e1=cv2.rectangle(img59,(626,719),(652,749),(26,64,0),-1)#body
e1=cv2.circle(img59,(638,705),14,(155,226,254),-1)# head
e1=cv2.circle(img59,(675,657),6,(255,255,255),-1)# right ball
e1 = cv2.line(img59,(653,724),(663,736),(155,226,254),5)#right hand 
e1 = cv2.line(img59,(625,725),(620,732),(155,226,254),5)#left hand
e1 = cv2.line(img59,(632,702),(643,702),(0,0,0),20)#top hair
e1=cv2.rectangle(img59,(631,749),(637,762),(26,64,0),-1)#left leg
e1=cv2.rectangle(img59,(642,749),(648,762),(26,64,0),-1)#right leg



# pakistan player
e1=cv2.rectangle(img59,(292,293),(300,322),(26,64,0),-1)#right leg
e1=cv2.rectangle(img59,(288,253),(320,298),(26,64,0),-1)#body
e1=cv2.rectangle(img59,(309,293),(317,322),(26,64,0),-1)#left leg
e1=cv2.circle(img59,(303,239),16,(155,226,254),-1)# head
e1=cv2.circle(img59,(295,242),2,(0,0,0),-1)# right eye
e1=cv2.circle(img59,(310,242),2,(0,0,0),-1)# left eye
e1 = cv2.line(img59,(298,249),(307,249),(0,0,0),2)#mouth
e1 = cv2.line(img59,(289,265),(294,276),(155,226,254),4)#right hand 
e1 = cv2.line(img59,(318,265),(310,276),(155,226,254),4)#left hand
e1 = cv2.line(img59,(293,229),(312,229),(0,0,0),13)#top hair


#Indian  player
e1=cv2.rectangle(img59,(548,767),(555,784),(255,0,0),-1)#left leg
e1=cv2.rectangle(img59,(569,767),(545,742),(255,0,0),-1)#body
e1=cv2.rectangle(img59,(560,767),(567,784),(255,0,0),-1)#right leg
e1=cv2.circle(img59,(557,729),14,(155,226,254),-1)# head
e1 = cv2.line(img59,(570,748),(574,761),(155,226,254),3)#right hand 
e1 = cv2.line(img59,(544,747),(537,754),(155,226,254),3)#left hand
e1 = cv2.line(img59,(575,761),(580,778),(29,101,181),10)#bat
e1 = cv2.line(img59,(550,724),(562,724),(0,0,0),21)#top hair



cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
img60=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img60,(0,0),(1200,800),(0,178,0),-1) #layout

e1 = cv2.line(img60,(600,800),(530,400),(128,178,194),10)# left line
e1 = cv2.line(img60,(610,800),(540,400),(128,178,194),10)# left line
e1 = cv2.line(img60,(620,800),(550,400),(128,178,194),10)# left line
e1 = cv2.line(img60,(630,800),(560,400),(128,178,194),10)# left line
e1 = cv2.line(img60,(640,800),(570,400),(128,178,194),10)# left line
e1 = cv2.line(img60,(650,800),(580,400),(128,178,194),10)# left line
e1 = cv2.line(img60,(660,800),(590,400),(128,178,194),10)# left line
e1 = cv2.line(img60,(670,800),(600,400),(128,178,194),10)# left line
e1 = cv2.line(img60,(680,800),(610,400),(128,178,194),10)# left line
e1 = cv2.line(img60,(690,800),(620,400),(128,178,194),10)# left line
e1 = cv2.line(img60,(700,800),(630,400),(128,178,194),10)# left line
e1 = cv2.line(img60,(710,800),(640,400),(128,178,194),10)# left line
e1 = cv2.line(img60,(720,800),(650,400),(128,178,194),10)# left line
e1 = cv2.line(img60,(730,800),(660,400),(128,178,194),10)# left line
e1 = cv2.line(img60,(740,800),(670,400),(128,178,194),10)# left line
e1 = cv2.line(img60,(750,800),(680,400),(128,178,194),10)# left line
e1 = cv2.line(img60,(760,800),(690,400),(128,178,194),10)# left line

e1 = cv2.line(img60,(450,800),(530,400),(128,178,194),10)#right line
e1 = cv2.line(img60,(460,800),(540,400),(128,178,194),10)#right line
e1 = cv2.line(img60,(470,800),(550,400),(128,178,194),10)#right line
e1 = cv2.line(img60,(480,800),(560,400),(128,178,194),10)#right line
e1 = cv2.line(img60,(490,800),(570,400),(128,178,194),10)#right line
e1 = cv2.line(img60,(500,800),(580,400),(128,178,194),10)#right line
e1 = cv2.line(img60,(510,800),(590,400),(128,178,194),10)#right line
e1 = cv2.line(img60,(520,800),(600,400),(128,178,194),10)#right line
e1 = cv2.line(img60,(530,800),(610,400),(128,178,194),10)#right line
e1 = cv2.line(img60,(540,800),(620,400),(128,178,194),10)#right line
e1 = cv2.line(img60,(550,800),(630,400),(128,178,194),10)#right line
e1 = cv2.line(img60,(560,800),(640,400),(128,178,194),10)#right line
e1 = cv2.line(img60,(570,800),(650,400),(128,178,194),10)#right line
e1 = cv2.line(img60,(580,800),(660,400),(128,178,194),10)#right line
e1 = cv2.line(img60,(590,800),(670,400),(128,178,194),10)#right line

e1 = cv2.line(img60,(760,800),(690,400),(255,255,255),2)# left line
e1 = cv2.line(img60,(450,800),(530,400),(255,255,255),2)#right line
e1 = cv2.line(img60,(690,400),(530,400),(255,255,255),2)# middle line
e1 = cv2.line(img60,(600,1200),(600,760),(0,0,0),5)   #middle wicket   #buttom side
e1 = cv2.line(img60,(590,1200),(590,760),(0,0,0),5)   #left wicket
e1 = cv2.line(img60,(610,1200),(610,760),(0,0,0),5)   #right wicket
e1 = cv2.line(img60,(590,760),(610,760),(0,0,0),5)    #top wicket
e1 = cv2.line(img60,(430,750),(780,750),(255,255,255),2)#buttom boundary line 
e1 = cv2.line(img60,(500,750),(490,850),(255,255,255),2)#boundary left line
e1 = cv2.line(img60,(710,750),(720,850),(255,255,255),2)#boundary right line

e1 = cv2.line(img60,(760,800),(690,400),(255,255,255),2)# left line
e1 = cv2.line(img60,(450,800),(530,400),(255,255,255),2)#right line
e1 = cv2.line(img60,(690,400),(530,400),(255,255,255),2)# middle line
e1 = cv2.line(img60,(620,400),(620,360),(0,0,0),5)   #right wicket     #top side
e1 = cv2.line(img60,(600,400),(600,360),(0,0,0),5)   #lift wicket
e1 = cv2.line(img60,(610,400),(610,360),(0,0,0),5)   #middle wicket
e1 = cv2.line(img60,(600,360),(620,360),(0,0,0),5)    #top wicket
e1 = cv2.line(img60,(490,440),(720,440),(255,255,255),2) # top boundary line
e1 = cv2.line(img60,(555,440),(560,400),(255,255,255),2)#boundary left line
e1 = cv2.line(img60,(655,440),(655,400),(255,255,255),2)#boundary right line




#indian player

e1=cv2.rectangle(img60,(642,402),(648,440),(255,0,0),-1)#right leg
e1=cv2.rectangle(img60,(629,352),(650,402),(255,0,0),-1)#body
e1=cv2.rectangle(img60,(631,402),(637,440),(255,0,0),-1)#left leg
e1=cv2.circle(img60,(640,339),13,(155,226,254),-1)# head
e1=cv2.circle(img60,(632,340),2,(0,0,0),-1)# right eye
e1=cv2.circle(img60,(637,340),2,(0,0,0),-1)# left eye
e1=cv2.circle(img60,(635,346),2,(0,0,0),-1)#mouth
e1 = cv2.line(img60,(632,364),(620,400),(155,226,254),3)#right hand 
e1 = cv2.line(img60,(641,373),(623,400),(155,226,254),3)#left hand
e1 = cv2.line(img60,(621,400),(603,435),(29,101,181),10)#bat
e1 = cv2.line(img60,(632,329),(647,329),(0,0,0),10)#top hair
e1 = cv2.line(img60,(647,336),(646,348),(0,0,0),10)#left hair


# pakistan wicket player

e1=cv2.rectangle(img60,(592,362),(586,395),(26,64,0),-1)#right leg
e1=cv2.rectangle(img60,(570,351),(593,379),(26,64,0),-1)#body
e1=cv2.rectangle(img60,(572,362),(579,395),(26,64,0),-1)#left leg
e1=cv2.circle(img60,(581,336),14,(155,226,254),-1)# head
e1=cv2.circle(img60,(576,338),2,(0,0,0),-1)# right eye
e1=cv2.circle(img60,(587,338),2,(0,0,0),-1)# left eye
e1 = cv2.line(img60,(578,345),(585,345),(0,0,0),2)#mouth
e1 = cv2.line(img60,(572,360),(582,369),(155,226,254),4)#right hand 
e1 = cv2.line(img60,(591,360),(582,369),(155,226,254),4)#left hand
e1 = cv2.line(img60,(581,368),(582,369),(255,255,255),10)#glove
e1 = cv2.line(img60,(571,326),(588,326),(0,0,0),10)#top hair



#bowler


e1=cv2.rectangle(img60,(626,719),(652,749),(26,64,0),-1)#body
e1=cv2.circle(img60,(638,705),14,(155,226,254),-1)# head
e1=cv2.circle(img60,(673,626),6,(255,255,255),-1)# right ball
e1 = cv2.line(img60,(653,724),(663,736),(155,226,254),5)#right hand 
e1 = cv2.line(img60,(625,725),(620,732),(155,226,254),5)#left hand
e1 = cv2.line(img60,(632,702),(643,702),(0,0,0),20)#top hair
e1=cv2.rectangle(img60,(631,749),(637,762),(26,64,0),-1)#left leg
e1=cv2.rectangle(img60,(642,749),(648,762),(26,64,0),-1)#right leg



# pakistan player
e1=cv2.rectangle(img60,(292,293),(300,322),(26,64,0),-1)#right leg
e1=cv2.rectangle(img60,(288,253),(320,298),(26,64,0),-1)#body
e1=cv2.rectangle(img60,(309,293),(317,322),(26,64,0),-1)#left leg
e1=cv2.circle(img60,(303,239),16,(155,226,254),-1)# head
e1=cv2.circle(img60,(295,242),2,(0,0,0),-1)# right eye
e1=cv2.circle(img60,(310,242),2,(0,0,0),-1)# left eye
e1 = cv2.line(img60,(298,249),(307,249),(0,0,0),2)#mouth
e1 = cv2.line(img60,(289,265),(294,276),(155,226,254),4)#right hand 
e1 = cv2.line(img60,(318,265),(310,276),(155,226,254),4)#left hand
e1 = cv2.line(img60,(293,229),(312,229),(0,0,0),13)#top hair


#Indian  player
e1=cv2.rectangle(img60,(548,767),(555,784),(255,0,0),-1)#left leg
e1=cv2.rectangle(img60,(569,767),(545,742),(255,0,0),-1)#body
e1=cv2.rectangle(img60,(560,767),(567,784),(255,0,0),-1)#right leg
e1=cv2.circle(img60,(557,729),14,(155,226,254),-1)# head
e1 = cv2.line(img60,(570,748),(574,761),(155,226,254),3)#right hand 
e1 = cv2.line(img60,(544,747),(537,754),(155,226,254),3)#left hand
e1 = cv2.line(img60,(575,761),(580,778),(29,101,181),10)#bat
e1 = cv2.line(img60,(550,724),(562,724),(0,0,0),21)#top hair




cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
img61=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img61,(0,0),(1200,800),(0,178,0),-1) #layout

e1 = cv2.line(img61,(600,800),(530,400),(128,178,194),10)# left line
e1 = cv2.line(img61,(610,800),(540,400),(128,178,194),10)# left line
e1 = cv2.line(img61,(620,800),(550,400),(128,178,194),10)# left line
e1 = cv2.line(img61,(630,800),(560,400),(128,178,194),10)# left line
e1 = cv2.line(img61,(640,800),(570,400),(128,178,194),10)# left line
e1 = cv2.line(img61,(650,800),(580,400),(128,178,194),10)# left line
e1 = cv2.line(img61,(660,800),(590,400),(128,178,194),10)# left line
e1 = cv2.line(img61,(670,800),(600,400),(128,178,194),10)# left line
e1 = cv2.line(img61,(680,800),(610,400),(128,178,194),10)# left line
e1 = cv2.line(img61,(690,800),(620,400),(128,178,194),10)# left line
e1 = cv2.line(img61,(700,800),(630,400),(128,178,194),10)# left line
e1 = cv2.line(img61,(710,800),(640,400),(128,178,194),10)# left line
e1 = cv2.line(img61,(720,800),(650,400),(128,178,194),10)# left line
e1 = cv2.line(img61,(730,800),(660,400),(128,178,194),10)# left line
e1 = cv2.line(img61,(740,800),(670,400),(128,178,194),10)# left line
e1 = cv2.line(img61,(750,800),(680,400),(128,178,194),10)# left line
e1 = cv2.line(img61,(760,800),(690,400),(128,178,194),10)# left line

e1 = cv2.line(img61,(450,800),(530,400),(128,178,194),10)#right line
e1 = cv2.line(img61,(460,800),(540,400),(128,178,194),10)#right line
e1 = cv2.line(img61,(470,800),(550,400),(128,178,194),10)#right line
e1 = cv2.line(img61,(480,800),(560,400),(128,178,194),10)#right line
e1 = cv2.line(img61,(490,800),(570,400),(128,178,194),10)#right line
e1 = cv2.line(img61,(500,800),(580,400),(128,178,194),10)#right line
e1 = cv2.line(img61,(510,800),(590,400),(128,178,194),10)#right line
e1 = cv2.line(img61,(520,800),(600,400),(128,178,194),10)#right line
e1 = cv2.line(img61,(530,800),(610,400),(128,178,194),10)#right line
e1 = cv2.line(img61,(540,800),(620,400),(128,178,194),10)#right line
e1 = cv2.line(img61,(550,800),(630,400),(128,178,194),10)#right line
e1 = cv2.line(img61,(560,800),(640,400),(128,178,194),10)#right line
e1 = cv2.line(img61,(570,800),(650,400),(128,178,194),10)#right line
e1 = cv2.line(img61,(580,800),(660,400),(128,178,194),10)#right line
e1 = cv2.line(img61,(590,800),(670,400),(128,178,194),10)#right line

e1 = cv2.line(img61,(760,800),(690,400),(255,255,255),2)# left line
e1 = cv2.line(img61,(450,800),(530,400),(255,255,255),2)#right line
e1 = cv2.line(img61,(690,400),(530,400),(255,255,255),2)# middle line
e1 = cv2.line(img61,(600,1200),(600,760),(0,0,0),5)   #middle wicket   #buttom side
e1 = cv2.line(img61,(590,1200),(590,760),(0,0,0),5)   #left wicket
e1 = cv2.line(img61,(610,1200),(610,760),(0,0,0),5)   #right wicket
e1 = cv2.line(img61,(590,760),(610,760),(0,0,0),5)    #top wicket
e1 = cv2.line(img61,(430,750),(780,750),(255,255,255),2)#buttom boundary line 
e1 = cv2.line(img61,(500,750),(490,850),(255,255,255),2)#boundary left line
e1 = cv2.line(img61,(710,750),(720,850),(255,255,255),2)#boundary right line

e1 = cv2.line(img61,(760,800),(690,400),(255,255,255),2)# left line
e1 = cv2.line(img61,(450,800),(530,400),(255,255,255),2)#right line
e1 = cv2.line(img61,(690,400),(530,400),(255,255,255),2)# middle line
e1 = cv2.line(img61,(620,400),(620,360),(0,0,0),5)   #right wicket     #top side
e1 = cv2.line(img61,(600,400),(600,360),(0,0,0),5)   #lift wicket
e1 = cv2.line(img61,(610,400),(610,360),(0,0,0),5)   #middle wicket
e1 = cv2.line(img61,(600,360),(620,360),(0,0,0),5)    #top wicket
e1 = cv2.line(img61,(490,440),(720,440),(255,255,255),2) # top boundary line
e1 = cv2.line(img61,(555,440),(560,400),(255,255,255),2)#boundary left line
e1 = cv2.line(img61,(655,440),(655,400),(255,255,255),2)#boundary right line




#indian player

e1=cv2.rectangle(img61,(642,402),(648,440),(255,0,0),-1)#right leg
e1=cv2.rectangle(img61,(629,352),(650,402),(255,0,0),-1)#body
e1=cv2.rectangle(img61,(631,402),(637,440),(255,0,0),-1)#left leg
e1=cv2.circle(img61,(640,339),13,(155,226,254),-1)# head
e1=cv2.circle(img61,(632,340),2,(0,0,0),-1)# right eye
e1=cv2.circle(img61,(637,340),2,(0,0,0),-1)# left eye
e1=cv2.circle(img61,(635,346),2,(0,0,0),-1)#mouth
e1 = cv2.line(img61,(632,364),(620,400),(155,226,254),3)#right hand 
e1 = cv2.line(img61,(641,373),(623,400),(155,226,254),3)#left hand
e1 = cv2.line(img61,(621,400),(603,435),(29,101,181),10)#bat
e1 = cv2.line(img61,(632,329),(647,329),(0,0,0),10)#top hair
e1 = cv2.line(img61,(647,336),(646,348),(0,0,0),10)#left hair


# pakistan wicket player

e1=cv2.rectangle(img61,(592,362),(586,395),(26,64,0),-1)#right leg
e1=cv2.rectangle(img61,(570,351),(593,379),(26,64,0),-1)#body
e1=cv2.rectangle(img61,(572,362),(579,395),(26,64,0),-1)#left leg
e1=cv2.circle(img61,(581,336),14,(155,226,254),-1)# head
e1=cv2.circle(img61,(576,338),2,(0,0,0),-1)# right eye
e1=cv2.circle(img61,(587,338),2,(0,0,0),-1)# left eye
e1 = cv2.line(img61,(578,345),(585,345),(0,0,0),2)#mouth
e1 = cv2.line(img61,(572,360),(582,369),(155,226,254),4)#right hand 
e1 = cv2.line(img61,(591,360),(582,369),(155,226,254),4)#left hand
e1 = cv2.line(img61,(581,368),(582,369),(255,255,255),10)#glove
e1 = cv2.line(img61,(571,326),(588,326),(0,0,0),10)#top hair



#bowler


e1=cv2.rectangle(img61,(626,719),(652,749),(26,64,0),-1)#body
e1=cv2.circle(img61,(638,705),14,(155,226,254),-1)# head
e1=cv2.circle(img61,(661,596),6,(255,255,255),-1)# right ball
e1 = cv2.line(img61,(653,724),(663,736),(155,226,254),5)#right hand 
e1 = cv2.line(img61,(625,725),(620,732),(155,226,254),5)#left hand
e1 = cv2.line(img61,(632,702),(643,702),(0,0,0),20)#top hair
e1=cv2.rectangle(img61,(631,749),(637,762),(26,64,0),-1)#left leg
e1=cv2.rectangle(img61,(642,749),(648,762),(26,64,0),-1)#right leg



# pakistan player
e1=cv2.rectangle(img61,(292,293),(300,322),(26,64,0),-1)#right leg
e1=cv2.rectangle(img61,(288,253),(320,298),(26,64,0),-1)#body
e1=cv2.rectangle(img61,(309,293),(317,322),(26,64,0),-1)#left leg
e1=cv2.circle(img61,(303,239),16,(155,226,254),-1)# head
e1=cv2.circle(img61,(295,242),2,(0,0,0),-1)# right eye
e1=cv2.circle(img61,(310,242),2,(0,0,0),-1)# left eye
e1 = cv2.line(img61,(298,249),(307,249),(0,0,0),2)#mouth
e1 = cv2.line(img61,(289,265),(294,276),(155,226,254),4)#right hand 
e1 = cv2.line(img61,(318,265),(310,276),(155,226,254),4)#left hand
e1 = cv2.line(img61,(293,229),(312,229),(0,0,0),13)#top hair


#Indian  player
e1=cv2.rectangle(img61,(548,767),(555,784),(255,0,0),-1)#left leg
e1=cv2.rectangle(img61,(569,767),(545,742),(255,0,0),-1)#body
e1=cv2.rectangle(img61,(560,767),(567,784),(255,0,0),-1)#right leg
e1=cv2.circle(img61,(557,729),14,(155,226,254),-1)# head
e1 = cv2.line(img61,(570,748),(574,761),(155,226,254),3)#right hand 
e1 = cv2.line(img61,(544,747),(537,754),(155,226,254),3)#left hand
e1 = cv2.line(img61,(575,761),(580,778),(29,101,181),10)#bat
e1 = cv2.line(img61,(550,724),(562,724),(0,0,0),21)#top hair




cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
img62=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img62,(0,0),(1200,800),(0,178,0),-1) #layout

e1 = cv2.line(img62,(600,800),(530,400),(128,178,194),10)# left line
e1 = cv2.line(img62,(610,800),(540,400),(128,178,194),10)# left line
e1 = cv2.line(img62,(620,800),(550,400),(128,178,194),10)# left line
e1 = cv2.line(img62,(630,800),(560,400),(128,178,194),10)# left line
e1 = cv2.line(img62,(640,800),(570,400),(128,178,194),10)# left line
e1 = cv2.line(img62,(650,800),(580,400),(128,178,194),10)# left line
e1 = cv2.line(img62,(660,800),(590,400),(128,178,194),10)# left line
e1 = cv2.line(img62,(670,800),(600,400),(128,178,194),10)# left line
e1 = cv2.line(img62,(680,800),(610,400),(128,178,194),10)# left line
e1 = cv2.line(img62,(690,800),(620,400),(128,178,194),10)# left line
e1 = cv2.line(img62,(700,800),(630,400),(128,178,194),10)# left line
e1 = cv2.line(img62,(710,800),(640,400),(128,178,194),10)# left line
e1 = cv2.line(img62,(720,800),(650,400),(128,178,194),10)# left line
e1 = cv2.line(img62,(730,800),(660,400),(128,178,194),10)# left line
e1 = cv2.line(img62,(740,800),(670,400),(128,178,194),10)# left line
e1 = cv2.line(img62,(750,800),(680,400),(128,178,194),10)# left line
e1 = cv2.line(img62,(760,800),(690,400),(128,178,194),10)# left line

e1 = cv2.line(img62,(450,800),(530,400),(128,178,194),10)#right line
e1 = cv2.line(img62,(460,800),(540,400),(128,178,194),10)#right line
e1 = cv2.line(img62,(470,800),(550,400),(128,178,194),10)#right line
e1 = cv2.line(img62,(480,800),(560,400),(128,178,194),10)#right line
e1 = cv2.line(img62,(490,800),(570,400),(128,178,194),10)#right line
e1 = cv2.line(img62,(500,800),(580,400),(128,178,194),10)#right line
e1 = cv2.line(img62,(510,800),(590,400),(128,178,194),10)#right line
e1 = cv2.line(img62,(520,800),(600,400),(128,178,194),10)#right line
e1 = cv2.line(img62,(530,800),(610,400),(128,178,194),10)#right line
e1 = cv2.line(img62,(540,800),(620,400),(128,178,194),10)#right line
e1 = cv2.line(img62,(550,800),(630,400),(128,178,194),10)#right line
e1 = cv2.line(img62,(560,800),(640,400),(128,178,194),10)#right line
e1 = cv2.line(img62,(570,800),(650,400),(128,178,194),10)#right line
e1 = cv2.line(img62,(580,800),(660,400),(128,178,194),10)#right line
e1 = cv2.line(img62,(590,800),(670,400),(128,178,194),10)#right line

e1 = cv2.line(img62,(760,800),(690,400),(255,255,255),2)# left line
e1 = cv2.line(img62,(450,800),(530,400),(255,255,255),2)#right line
e1 = cv2.line(img62,(690,400),(530,400),(255,255,255),2)# middle line
e1 = cv2.line(img62,(600,1200),(600,760),(0,0,0),5)   #middle wicket   #buttom side
e1 = cv2.line(img62,(590,1200),(590,760),(0,0,0),5)   #left wicket
e1 = cv2.line(img62,(610,1200),(610,760),(0,0,0),5)   #right wicket
e1 = cv2.line(img62,(590,760),(610,760),(0,0,0),5)    #top wicket
e1 = cv2.line(img62,(430,750),(780,750),(255,255,255),2)#buttom boundary line 
e1 = cv2.line(img62,(500,750),(490,850),(255,255,255),2)#boundary left line
e1 = cv2.line(img62,(710,750),(720,850),(255,255,255),2)#boundary right line

e1 = cv2.line(img62,(760,800),(690,400),(255,255,255),2)# left line
e1 = cv2.line(img62,(450,800),(530,400),(255,255,255),2)#right line
e1 = cv2.line(img62,(690,400),(530,400),(255,255,255),2)# middle line
e1 = cv2.line(img62,(620,400),(620,360),(0,0,0),5)   #right wicket     #top side
e1 = cv2.line(img62,(600,400),(600,360),(0,0,0),5)   #lift wicket
e1 = cv2.line(img62,(610,400),(610,360),(0,0,0),5)   #middle wicket
e1 = cv2.line(img62,(600,360),(620,360),(0,0,0),5)    #top wicket
e1 = cv2.line(img62,(490,440),(720,440),(255,255,255),2) # top boundary line
e1 = cv2.line(img62,(555,440),(560,400),(255,255,255),2)#boundary left line
e1 = cv2.line(img62,(655,440),(655,400),(255,255,255),2)#boundary right line




#indian player

e1=cv2.rectangle(img62,(642,402),(648,440),(255,0,0),-1)#right leg
e1=cv2.rectangle(img62,(629,352),(650,402),(255,0,0),-1)#body
e1=cv2.rectangle(img62,(631,402),(637,440),(255,0,0),-1)#left leg
e1=cv2.circle(img62,(640,339),13,(155,226,254),-1)# head
e1=cv2.circle(img62,(632,340),2,(0,0,0),-1)# right eye
e1=cv2.circle(img62,(637,340),2,(0,0,0),-1)# left eye
e1=cv2.circle(img62,(635,346),2,(0,0,0),-1)#mouth
e1 = cv2.line(img62,(632,364),(620,400),(155,226,254),3)#right hand 
e1 = cv2.line(img62,(641,373),(623,400),(155,226,254),3)#left hand
e1 = cv2.line(img62,(621,400),(603,435),(29,101,181),10)#bat
e1 = cv2.line(img62,(632,329),(647,329),(0,0,0),10)#top hair
e1 = cv2.line(img62,(647,336),(646,348),(0,0,0),10)#left hair


# pakistan wicket player

e1=cv2.rectangle(img62,(592,362),(586,395),(26,64,0),-1)#right leg
e1=cv2.rectangle(img62,(570,351),(593,379),(26,64,0),-1)#body
e1=cv2.rectangle(img62,(572,362),(579,395),(26,64,0),-1)#left leg
e1=cv2.circle(img62,(581,336),14,(155,226,254),-1)# head
e1=cv2.circle(img62,(576,338),2,(0,0,0),-1)# right eye
e1=cv2.circle(img62,(587,338),2,(0,0,0),-1)# left eye
e1 = cv2.line(img62,(578,345),(585,345),(0,0,0),2)#mouth
e1 = cv2.line(img62,(572,360),(582,369),(155,226,254),4)#right hand 
e1 = cv2.line(img62,(591,360),(582,369),(155,226,254),4)#left hand
e1 = cv2.line(img62,(581,368),(582,369),(255,255,255),10)#glove
e1 = cv2.line(img62,(571,326),(588,326),(0,0,0),10)#top hair



#bowler


e1=cv2.rectangle(img62,(626,719),(652,749),(26,64,0),-1)#body
e1=cv2.circle(img62,(638,705),14,(155,226,254),-1)# head
e1=cv2.circle(img62,(653,555),6,(255,255,255),-1)# right ball
e1 = cv2.line(img62,(653,724),(663,736),(155,226,254),5)#right hand 
e1 = cv2.line(img62,(625,725),(620,732),(155,226,254),5)#left hand
e1 = cv2.line(img62,(632,702),(643,702),(0,0,0),20)#top hair
e1=cv2.rectangle(img62,(631,749),(637,762),(26,64,0),-1)#left leg
e1=cv2.rectangle(img62,(642,749),(648,762),(26,64,0),-1)#right leg



# pakistan player
e1=cv2.rectangle(img62,(292,293),(300,322),(26,64,0),-1)#right leg
e1=cv2.rectangle(img62,(288,253),(320,298),(26,64,0),-1)#body
e1=cv2.rectangle(img62,(309,293),(317,322),(26,64,0),-1)#left leg
e1=cv2.circle(img62,(303,239),16,(155,226,254),-1)# head
e1=cv2.circle(img62,(295,242),2,(0,0,0),-1)# right eye
e1=cv2.circle(img62,(310,242),2,(0,0,0),-1)# left eye
e1 = cv2.line(img62,(298,249),(307,249),(0,0,0),2)#mouth
e1 = cv2.line(img62,(289,265),(294,276),(155,226,254),4)#right hand 
e1 = cv2.line(img62,(318,265),(310,276),(155,226,254),4)#left hand
e1 = cv2.line(img62,(293,229),(312,229),(0,0,0),13)#top hair


#Indian  player
e1=cv2.rectangle(img62,(548,767),(555,784),(255,0,0),-1)#left leg
e1=cv2.rectangle(img62,(569,767),(545,742),(255,0,0),-1)#body
e1=cv2.rectangle(img62,(560,767),(567,784),(255,0,0),-1)#right leg
e1=cv2.circle(img62,(557,729),14,(155,226,254),-1)# head
e1 = cv2.line(img62,(570,748),(574,761),(155,226,254),3)#right hand 
e1 = cv2.line(img62,(544,747),(537,754),(155,226,254),3)#left hand
e1 = cv2.line(img62,(575,761),(580,778),(29,101,181),10)#bat
e1 = cv2.line(img62,(550,724),(562,724),(0,0,0),21)#top hair




cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
img63=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img63,(0,0),(1200,800),(0,178,0),-1) #layout

e1 = cv2.line(img63,(600,800),(530,400),(128,178,194),10)# left line
e1 = cv2.line(img63,(610,800),(540,400),(128,178,194),10)# left line
e1 = cv2.line(img63,(620,800),(550,400),(128,178,194),10)# left line
e1 = cv2.line(img63,(630,800),(560,400),(128,178,194),10)# left line
e1 = cv2.line(img63,(640,800),(570,400),(128,178,194),10)# left line
e1 = cv2.line(img63,(650,800),(580,400),(128,178,194),10)# left line
e1 = cv2.line(img63,(660,800),(590,400),(128,178,194),10)# left line
e1 = cv2.line(img63,(670,800),(600,400),(128,178,194),10)# left line
e1 = cv2.line(img63,(680,800),(610,400),(128,178,194),10)# left line
e1 = cv2.line(img63,(690,800),(620,400),(128,178,194),10)# left line
e1 = cv2.line(img63,(700,800),(630,400),(128,178,194),10)# left line
e1 = cv2.line(img63,(710,800),(640,400),(128,178,194),10)# left line
e1 = cv2.line(img63,(720,800),(650,400),(128,178,194),10)# left line
e1 = cv2.line(img63,(730,800),(660,400),(128,178,194),10)# left line
e1 = cv2.line(img63,(740,800),(670,400),(128,178,194),10)# left line
e1 = cv2.line(img63,(750,800),(680,400),(128,178,194),10)# left line
e1 = cv2.line(img63,(760,800),(690,400),(128,178,194),10)# left line

e1 = cv2.line(img63,(450,800),(530,400),(128,178,194),10)#right line
e1 = cv2.line(img63,(460,800),(540,400),(128,178,194),10)#right line
e1 = cv2.line(img63,(470,800),(550,400),(128,178,194),10)#right line
e1 = cv2.line(img63,(480,800),(560,400),(128,178,194),10)#right line
e1 = cv2.line(img63,(490,800),(570,400),(128,178,194),10)#right line
e1 = cv2.line(img63,(500,800),(580,400),(128,178,194),10)#right line
e1 = cv2.line(img63,(510,800),(590,400),(128,178,194),10)#right line
e1 = cv2.line(img63,(520,800),(600,400),(128,178,194),10)#right line
e1 = cv2.line(img63,(530,800),(610,400),(128,178,194),10)#right line
e1 = cv2.line(img63,(540,800),(620,400),(128,178,194),10)#right line
e1 = cv2.line(img63,(550,800),(630,400),(128,178,194),10)#right line
e1 = cv2.line(img63,(560,800),(640,400),(128,178,194),10)#right line
e1 = cv2.line(img63,(570,800),(650,400),(128,178,194),10)#right line
e1 = cv2.line(img63,(580,800),(660,400),(128,178,194),10)#right line
e1 = cv2.line(img63,(590,800),(670,400),(128,178,194),10)#right line

e1 = cv2.line(img63,(760,800),(690,400),(255,255,255),2)# left line
e1 = cv2.line(img63,(450,800),(530,400),(255,255,255),2)#right line
e1 = cv2.line(img63,(690,400),(530,400),(255,255,255),2)# middle line
e1 = cv2.line(img63,(600,1200),(600,760),(0,0,0),5)   #middle wicket   #buttom side
e1 = cv2.line(img63,(590,1200),(590,760),(0,0,0),5)   #left wicket
e1 = cv2.line(img63,(610,1200),(610,760),(0,0,0),5)   #right wicket
e1 = cv2.line(img63,(590,760),(610,760),(0,0,0),5)    #top wicket
e1 = cv2.line(img63,(430,750),(780,750),(255,255,255),2)#buttom boundary line 
e1 = cv2.line(img63,(500,750),(490,850),(255,255,255),2)#boundary left line
e1 = cv2.line(img63,(710,750),(720,850),(255,255,255),2)#boundary right line

e1 = cv2.line(img63,(760,800),(690,400),(255,255,255),2)# left line
e1 = cv2.line(img63,(450,800),(530,400),(255,255,255),2)#right line
e1 = cv2.line(img63,(690,400),(530,400),(255,255,255),2)# middle line
e1 = cv2.line(img63,(620,400),(620,360),(0,0,0),5)   #right wicket     #top side
e1 = cv2.line(img63,(600,400),(600,360),(0,0,0),5)   #lift wicket
e1 = cv2.line(img63,(610,400),(610,360),(0,0,0),5)   #middle wicket
e1 = cv2.line(img63,(600,360),(620,360),(0,0,0),5)    #top wicket
e1 = cv2.line(img63,(490,440),(720,440),(255,255,255),2) # top boundary line
e1 = cv2.line(img63,(555,440),(560,400),(255,255,255),2)#boundary left line
e1 = cv2.line(img63,(655,440),(655,400),(255,255,255),2)#boundary right line




#indian player

e1=cv2.rectangle(img63,(642,402),(648,440),(255,0,0),-1)#right leg
e1=cv2.rectangle(img63,(629,352),(650,402),(255,0,0),-1)#body
e1=cv2.rectangle(img63,(631,402),(637,440),(255,0,0),-1)#left leg
e1=cv2.circle(img63,(640,339),13,(155,226,254),-1)# head
e1=cv2.circle(img63,(632,340),2,(0,0,0),-1)# right eye
e1=cv2.circle(img63,(637,340),2,(0,0,0),-1)# left eye
e1=cv2.circle(img63,(635,346),2,(0,0,0),-1)#mouth
e1 = cv2.line(img63,(632,364),(620,400),(155,226,254),3)#right hand 
e1 = cv2.line(img63,(641,373),(623,400),(155,226,254),3)#left hand
e1 = cv2.line(img63,(621,400),(603,435),(29,101,181),10)#bat
e1 = cv2.line(img63,(632,329),(647,329),(0,0,0),10)#top hair
e1 = cv2.line(img63,(647,336),(646,348),(0,0,0),10)#left hair


# pakistan wicket player

e1=cv2.rectangle(img63,(592,362),(586,395),(26,64,0),-1)#right leg
e1=cv2.rectangle(img63,(570,351),(593,379),(26,64,0),-1)#body
e1=cv2.rectangle(img63,(572,362),(579,395),(26,64,0),-1)#left leg
e1=cv2.circle(img63,(581,336),14,(155,226,254),-1)# head
e1=cv2.circle(img63,(576,338),2,(0,0,0),-1)# right eye
e1=cv2.circle(img63,(587,338),2,(0,0,0),-1)# left eye
e1 = cv2.line(img63,(578,345),(585,345),(0,0,0),2)#mouth
e1 = cv2.line(img63,(572,360),(582,369),(155,226,254),4)#right hand 
e1 = cv2.line(img63,(591,360),(582,369),(155,226,254),4)#left hand
e1 = cv2.line(img63,(581,368),(582,369),(255,255,255),10)#glove
e1 = cv2.line(img63,(571,326),(588,326),(0,0,0),10)#top hair



#bowler


e1=cv2.rectangle(img63,(626,719),(652,749),(26,64,0),-1)#body
e1=cv2.circle(img63,(638,705),14,(155,226,254),-1)# head
e1=cv2.circle(img63,(643,520),6,(255,255,255),-1)# right ball
e1 = cv2.line(img63,(653,724),(663,736),(155,226,254),5)#right hand 
e1 = cv2.line(img63,(625,725),(620,732),(155,226,254),5)#left hand
e1 = cv2.line(img63,(632,702),(643,702),(0,0,0),20)#top hair
e1=cv2.rectangle(img63,(631,749),(637,762),(26,64,0),-1)#left leg
e1=cv2.rectangle(img63,(642,749),(648,762),(26,64,0),-1)#right leg



# pakistan player
e1=cv2.rectangle(img63,(292,293),(300,322),(26,64,0),-1)#right leg
e1=cv2.rectangle(img63,(288,253),(320,298),(26,64,0),-1)#body
e1=cv2.rectangle(img63,(309,293),(317,322),(26,64,0),-1)#left leg
e1=cv2.circle(img63,(303,239),16,(155,226,254),-1)# head
e1=cv2.circle(img63,(295,242),2,(0,0,0),-1)# right eye
e1=cv2.circle(img63,(310,242),2,(0,0,0),-1)# left eye
e1 = cv2.line(img63,(298,249),(307,249),(0,0,0),2)#mouth
e1 = cv2.line(img63,(289,265),(294,276),(155,226,254),4)#right hand 
e1 = cv2.line(img63,(318,265),(310,276),(155,226,254),4)#left hand
e1 = cv2.line(img63,(293,229),(312,229),(0,0,0),13)#top hair


#Indian  player
e1=cv2.rectangle(img63,(548,767),(555,784),(255,0,0),-1)#left leg
e1=cv2.rectangle(img63,(569,767),(545,742),(255,0,0),-1)#body
e1=cv2.rectangle(img63,(560,767),(567,784),(255,0,0),-1)#right leg
e1=cv2.circle(img63,(557,729),14,(155,226,254),-1)# head
e1 = cv2.line(img63,(570,748),(574,761),(155,226,254),3)#right hand 
e1 = cv2.line(img63,(544,747),(537,754),(155,226,254),3)#left hand
e1 = cv2.line(img63,(575,761),(580,778),(29,101,181),10)#bat
e1 = cv2.line(img63,(550,724),(562,724),(0,0,0),21)#top hair




cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
img64=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img64,(0,0),(1200,800),(0,178,0),-1) #layout

e1 = cv2.line(img64,(600,800),(530,400),(128,178,194),10)# left line
e1 = cv2.line(img64,(610,800),(540,400),(128,178,194),10)# left line
e1 = cv2.line(img64,(620,800),(550,400),(128,178,194),10)# left line
e1 = cv2.line(img64,(630,800),(560,400),(128,178,194),10)# left line
e1 = cv2.line(img64,(640,800),(570,400),(128,178,194),10)# left line
e1 = cv2.line(img64,(650,800),(580,400),(128,178,194),10)# left line
e1 = cv2.line(img64,(660,800),(590,400),(128,178,194),10)# left line
e1 = cv2.line(img64,(670,800),(600,400),(128,178,194),10)# left line
e1 = cv2.line(img64,(680,800),(610,400),(128,178,194),10)# left line
e1 = cv2.line(img64,(690,800),(620,400),(128,178,194),10)# left line
e1 = cv2.line(img64,(700,800),(630,400),(128,178,194),10)# left line
e1 = cv2.line(img64,(710,800),(640,400),(128,178,194),10)# left line
e1 = cv2.line(img64,(720,800),(650,400),(128,178,194),10)# left line
e1 = cv2.line(img64,(730,800),(660,400),(128,178,194),10)# left line
e1 = cv2.line(img64,(740,800),(670,400),(128,178,194),10)# left line
e1 = cv2.line(img64,(750,800),(680,400),(128,178,194),10)# left line
e1 = cv2.line(img64,(760,800),(690,400),(128,178,194),10)# left line

e1 = cv2.line(img64,(450,800),(530,400),(128,178,194),10)#right line
e1 = cv2.line(img64,(460,800),(540,400),(128,178,194),10)#right line
e1 = cv2.line(img64,(470,800),(550,400),(128,178,194),10)#right line
e1 = cv2.line(img64,(480,800),(560,400),(128,178,194),10)#right line
e1 = cv2.line(img64,(490,800),(570,400),(128,178,194),10)#right line
e1 = cv2.line(img64,(500,800),(580,400),(128,178,194),10)#right line
e1 = cv2.line(img64,(510,800),(590,400),(128,178,194),10)#right line
e1 = cv2.line(img64,(520,800),(600,400),(128,178,194),10)#right line
e1 = cv2.line(img64,(530,800),(610,400),(128,178,194),10)#right line
e1 = cv2.line(img64,(540,800),(620,400),(128,178,194),10)#right line
e1 = cv2.line(img64,(550,800),(630,400),(128,178,194),10)#right line
e1 = cv2.line(img64,(560,800),(640,400),(128,178,194),10)#right line
e1 = cv2.line(img64,(570,800),(650,400),(128,178,194),10)#right line
e1 = cv2.line(img64,(580,800),(660,400),(128,178,194),10)#right line
e1 = cv2.line(img64,(590,800),(670,400),(128,178,194),10)#right line

e1 = cv2.line(img64,(760,800),(690,400),(255,255,255),2)# left line
e1 = cv2.line(img64,(450,800),(530,400),(255,255,255),2)#right line
e1 = cv2.line(img64,(690,400),(530,400),(255,255,255),2)# middle line
e1 = cv2.line(img64,(600,1200),(600,760),(0,0,0),5)   #middle wicket   #buttom side
e1 = cv2.line(img64,(590,1200),(590,760),(0,0,0),5)   #left wicket
e1 = cv2.line(img64,(610,1200),(610,760),(0,0,0),5)   #right wicket
e1 = cv2.line(img64,(590,760),(610,760),(0,0,0),5)    #top wicket
e1 = cv2.line(img64,(430,750),(780,750),(255,255,255),2)#buttom boundary line 
e1 = cv2.line(img64,(500,750),(490,850),(255,255,255),2)#boundary left line
e1 = cv2.line(img64,(710,750),(720,850),(255,255,255),2)#boundary right line

e1 = cv2.line(img64,(760,800),(690,400),(255,255,255),2)# left line
e1 = cv2.line(img64,(450,800),(530,400),(255,255,255),2)#right line
e1 = cv2.line(img64,(690,400),(530,400),(255,255,255),2)# middle line
e1 = cv2.line(img64,(620,400),(620,360),(0,0,0),5)   #right wicket     #top side
e1 = cv2.line(img64,(600,400),(600,360),(0,0,0),5)   #lift wicket
e1 = cv2.line(img64,(610,400),(610,360),(0,0,0),5)   #middle wicket
e1 = cv2.line(img64,(600,360),(620,360),(0,0,0),5)    #top wicket
e1 = cv2.line(img64,(490,440),(720,440),(255,255,255),2) # top boundary line
e1 = cv2.line(img64,(555,440),(560,400),(255,255,255),2)#boundary left line
e1 = cv2.line(img64,(655,440),(655,400),(255,255,255),2)#boundary right line




#indian player

e1=cv2.rectangle(img64,(642,402),(648,440),(255,0,0),-1)#right leg
e1=cv2.rectangle(img64,(629,352),(650,402),(255,0,0),-1)#body
e1=cv2.rectangle(img64,(631,402),(637,440),(255,0,0),-1)#left leg
e1=cv2.circle(img64,(640,339),13,(155,226,254),-1)# head
e1=cv2.circle(img64,(632,340),2,(0,0,0),-1)# right eye
e1=cv2.circle(img64,(637,340),2,(0,0,0),-1)# left eye
e1=cv2.circle(img64,(635,346),2,(0,0,0),-1)#mouth
e1 = cv2.line(img64,(632,364),(620,400),(155,226,254),3)#right hand 
e1 = cv2.line(img64,(641,373),(623,400),(155,226,254),3)#left hand
e1 = cv2.line(img64,(621,400),(603,422),(29,101,181),10)#bat
e1 = cv2.line(img64,(632,329),(647,329),(0,0,0),10)#top hair
e1 = cv2.line(img64,(647,336),(646,348),(0,0,0),10)#left hair


# pakistan wicket player

e1=cv2.rectangle(img64,(592,362),(586,395),(26,64,0),-1)#right leg
e1=cv2.rectangle(img64,(570,351),(593,379),(26,64,0),-1)#body
e1=cv2.rectangle(img64,(572,362),(579,395),(26,64,0),-1)#left leg
e1=cv2.circle(img64,(581,336),14,(155,226,254),-1)# head
e1=cv2.circle(img64,(576,338),2,(0,0,0),-1)# right eye
e1=cv2.circle(img64,(587,338),2,(0,0,0),-1)# left eye
e1 = cv2.line(img64,(578,345),(585,345),(0,0,0),2)#mouth
e1 = cv2.line(img64,(572,360),(582,369),(155,226,254),4)#right hand 
e1 = cv2.line(img64,(591,360),(582,369),(155,226,254),4)#left hand
e1 = cv2.line(img64,(581,368),(582,369),(255,255,255),10)#glove
e1 = cv2.line(img64,(571,326),(588,326),(0,0,0),10)#top hair



#bowler


e1=cv2.rectangle(img64,(626,719),(652,749),(26,64,0),-1)#body
e1=cv2.circle(img64,(638,705),14,(155,226,254),-1)# head
e1=cv2.circle(img64,(634,490),6,(255,255,255),-1)# right ball
e1 = cv2.line(img64,(653,724),(663,736),(155,226,254),5)#right hand 
e1 = cv2.line(img64,(625,725),(620,732),(155,226,254),5)#left hand
e1 = cv2.line(img64,(632,702),(643,702),(0,0,0),20)#top hair
e1=cv2.rectangle(img64,(631,749),(637,762),(26,64,0),-1)#left leg
e1=cv2.rectangle(img64,(642,749),(648,762),(26,64,0),-1)#right leg



# pakistan player
e1=cv2.rectangle(img64,(292,293),(300,322),(26,64,0),-1)#right leg
e1=cv2.rectangle(img64,(288,253),(320,298),(26,64,0),-1)#body
e1=cv2.rectangle(img64,(309,293),(317,322),(26,64,0),-1)#left leg
e1=cv2.circle(img64,(303,239),16,(155,226,254),-1)# head
e1=cv2.circle(img64,(295,242),2,(0,0,0),-1)# right eye
e1=cv2.circle(img64,(310,242),2,(0,0,0),-1)# left eye
e1 = cv2.line(img64,(298,249),(307,249),(0,0,0),2)#mouth
e1 = cv2.line(img64,(289,265),(294,276),(155,226,254),4)#right hand 
e1 = cv2.line(img64,(318,265),(310,276),(155,226,254),4)#left hand
e1 = cv2.line(img64,(293,229),(312,229),(0,0,0),13)#top hair


#Indian  player
e1=cv2.rectangle(img64,(548,767),(555,784),(255,0,0),-1)#left leg
e1=cv2.rectangle(img64,(569,767),(545,742),(255,0,0),-1)#body
e1=cv2.rectangle(img64,(560,767),(567,784),(255,0,0),-1)#right leg
e1=cv2.circle(img64,(557,729),14,(155,226,254),-1)# head
e1 = cv2.line(img64,(570,748),(574,761),(155,226,254),3)#right hand 
e1 = cv2.line(img64,(544,747),(537,754),(155,226,254),3)#left hand
e1 = cv2.line(img64,(575,761),(580,778),(29,101,181),10)#bat
e1 = cv2.line(img64,(550,724),(562,724),(0,0,0),21)#top hair




cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
img65=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img65,(0,0),(1200,800),(0,178,0),-1) #layout

e1 = cv2.line(img65,(600,800),(530,400),(128,178,194),10)# left line
e1 = cv2.line(img65,(610,800),(540,400),(128,178,194),10)# left line
e1 = cv2.line(img65,(620,800),(550,400),(128,178,194),10)# left line
e1 = cv2.line(img65,(630,800),(560,400),(128,178,194),10)# left line
e1 = cv2.line(img65,(640,800),(570,400),(128,178,194),10)# left line
e1 = cv2.line(img65,(650,800),(580,400),(128,178,194),10)# left line
e1 = cv2.line(img65,(660,800),(590,400),(128,178,194),10)# left line
e1 = cv2.line(img65,(670,800),(600,400),(128,178,194),10)# left line
e1 = cv2.line(img65,(680,800),(610,400),(128,178,194),10)# left line
e1 = cv2.line(img65,(690,800),(620,400),(128,178,194),10)# left line
e1 = cv2.line(img65,(700,800),(630,400),(128,178,194),10)# left line
e1 = cv2.line(img65,(710,800),(640,400),(128,178,194),10)# left line
e1 = cv2.line(img65,(720,800),(650,400),(128,178,194),10)# left line
e1 = cv2.line(img65,(730,800),(660,400),(128,178,194),10)# left line
e1 = cv2.line(img65,(740,800),(670,400),(128,178,194),10)# left line
e1 = cv2.line(img65,(750,800),(680,400),(128,178,194),10)# left line
e1 = cv2.line(img65,(760,800),(690,400),(128,178,194),10)# left line

e1 = cv2.line(img65,(450,800),(530,400),(128,178,194),10)#right line
e1 = cv2.line(img65,(460,800),(540,400),(128,178,194),10)#right line
e1 = cv2.line(img65,(470,800),(550,400),(128,178,194),10)#right line
e1 = cv2.line(img65,(480,800),(560,400),(128,178,194),10)#right line
e1 = cv2.line(img65,(490,800),(570,400),(128,178,194),10)#right line
e1 = cv2.line(img65,(500,800),(580,400),(128,178,194),10)#right line
e1 = cv2.line(img65,(510,800),(590,400),(128,178,194),10)#right line
e1 = cv2.line(img65,(520,800),(600,400),(128,178,194),10)#right line
e1 = cv2.line(img65,(530,800),(610,400),(128,178,194),10)#right line
e1 = cv2.line(img65,(540,800),(620,400),(128,178,194),10)#right line
e1 = cv2.line(img65,(550,800),(630,400),(128,178,194),10)#right line
e1 = cv2.line(img65,(560,800),(640,400),(128,178,194),10)#right line
e1 = cv2.line(img65,(570,800),(650,400),(128,178,194),10)#right line
e1 = cv2.line(img65,(580,800),(660,400),(128,178,194),10)#right line
e1 = cv2.line(img65,(590,800),(670,400),(128,178,194),10)#right line

e1 = cv2.line(img65,(760,800),(690,400),(255,255,255),2)# left line
e1 = cv2.line(img65,(450,800),(530,400),(255,255,255),2)#right line
e1 = cv2.line(img65,(690,400),(530,400),(255,255,255),2)# middle line
e1 = cv2.line(img65,(600,1200),(600,760),(0,0,0),5)   #middle wicket   #buttom side
e1 = cv2.line(img65,(590,1200),(590,760),(0,0,0),5)   #left wicket
e1 = cv2.line(img65,(610,1200),(610,760),(0,0,0),5)   #right wicket
e1 = cv2.line(img65,(590,760),(610,760),(0,0,0),5)    #top wicket
e1 = cv2.line(img65,(430,750),(780,750),(255,255,255),2)#buttom boundary line 
e1 = cv2.line(img65,(500,750),(490,850),(255,255,255),2)#boundary left line
e1 = cv2.line(img65,(710,750),(720,850),(255,255,255),2)#boundary right line

e1 = cv2.line(img65,(760,800),(690,400),(255,255,255),2)# left line
e1 = cv2.line(img65,(450,800),(530,400),(255,255,255),2)#right line
e1 = cv2.line(img65,(690,400),(530,400),(255,255,255),2)# middle line
e1 = cv2.line(img65,(620,400),(620,360),(0,0,0),5)   #right wicket     #top side
e1 = cv2.line(img65,(600,400),(600,360),(0,0,0),5)   #lift wicket
e1 = cv2.line(img65,(610,400),(610,360),(0,0,0),5)   #middle wicket
e1 = cv2.line(img65,(600,360),(620,360),(0,0,0),5)    #top wicket
e1 = cv2.line(img65,(490,440),(720,440),(255,255,255),2) # top boundary line
e1 = cv2.line(img65,(555,440),(560,400),(255,255,255),2)#boundary left line
e1 = cv2.line(img65,(655,440),(655,400),(255,255,255),2)#boundary right line




#indian player

e1=cv2.rectangle(img65,(642,402),(648,440),(255,0,0),-1)#right leg
e1=cv2.rectangle(img65,(629,352),(650,402),(255,0,0),-1)#body
e1=cv2.rectangle(img65,(631,402),(637,440),(255,0,0),-1)#left leg
e1=cv2.circle(img65,(640,339),13,(155,226,254),-1)# head
e1=cv2.circle(img65,(632,340),2,(0,0,0),-1)# right eye
e1=cv2.circle(img65,(637,340),2,(0,0,0),-1)# left eye
e1=cv2.circle(img65,(635,346),2,(0,0,0),-1)#mouth
e1 = cv2.line(img65,(632,364),(620,400),(155,226,254),3)#right hand 
e1 = cv2.line(img65,(641,373),(623,400),(155,226,254),3)#left hand
e1 = cv2.line(img65,(621,400),(603,422),(29,101,181),10)#bat
e1 = cv2.line(img65,(632,329),(647,329),(0,0,0),10)#top hair
e1 = cv2.line(img65,(647,336),(646,348),(0,0,0),10)#left hair


# pakistan wicket player

e1=cv2.rectangle(img65,(592,362),(586,395),(26,64,0),-1)#right leg
e1=cv2.rectangle(img65,(570,351),(593,379),(26,64,0),-1)#body
e1=cv2.rectangle(img65,(572,362),(579,395),(26,64,0),-1)#left leg
e1=cv2.circle(img65,(581,336),14,(155,226,254),-1)# head
e1=cv2.circle(img65,(576,338),2,(0,0,0),-1)# right eye
e1=cv2.circle(img65,(587,338),2,(0,0,0),-1)# left eye
e1 = cv2.line(img65,(578,345),(585,345),(0,0,0),2)#mouth
e1 = cv2.line(img65,(572,360),(582,369),(155,226,254),4)#right hand 
e1 = cv2.line(img65,(591,360),(582,369),(155,226,254),4)#left hand
e1 = cv2.line(img65,(581,368),(582,369),(255,255,255),10)#glove
e1 = cv2.line(img65,(571,326),(588,326),(0,0,0),10)#top hair



#bowler


e1=cv2.rectangle(img65,(626,719),(652,749),(26,64,0),-1)#body
e1=cv2.circle(img65,(638,705),14,(155,226,254),-1)# head
e1=cv2.circle(img65,(623,461),6,(255,255,255),-1)# right ball
e1 = cv2.line(img65,(653,724),(663,736),(155,226,254),5)#right hand 
e1 = cv2.line(img65,(625,725),(620,732),(155,226,254),5)#left hand
e1 = cv2.line(img65,(632,702),(643,702),(0,0,0),20)#top hair
e1=cv2.rectangle(img65,(631,749),(637,762),(26,64,0),-1)#left leg
e1=cv2.rectangle(img65,(642,749),(648,762),(26,64,0),-1)#right leg



# pakistan player
e1=cv2.rectangle(img65,(292,293),(300,322),(26,64,0),-1)#right leg
e1=cv2.rectangle(img65,(288,253),(320,298),(26,64,0),-1)#body
e1=cv2.rectangle(img65,(309,293),(317,322),(26,64,0),-1)#left leg
e1=cv2.circle(img65,(303,239),16,(155,226,254),-1)# head
e1=cv2.circle(img65,(295,242),2,(0,0,0),-1)# right eye
e1=cv2.circle(img65,(310,242),2,(0,0,0),-1)# left eye
e1 = cv2.line(img65,(298,249),(307,249),(0,0,0),2)#mouth
e1 = cv2.line(img65,(289,265),(294,276),(155,226,254),4)#right hand 
e1 = cv2.line(img65,(318,265),(310,276),(155,226,254),4)#left hand
e1 = cv2.line(img65,(293,229),(312,229),(0,0,0),13)#top hair


#Indian  player
e1=cv2.rectangle(img65,(548,767),(555,784),(255,0,0),-1)#left leg
e1=cv2.rectangle(img65,(569,767),(545,742),(255,0,0),-1)#body
e1=cv2.rectangle(img65,(560,767),(567,784),(255,0,0),-1)#right leg
e1=cv2.circle(img65,(557,729),14,(155,226,254),-1)# head
e1 = cv2.line(img65,(570,748),(574,761),(155,226,254),3)#right hand 
e1 = cv2.line(img65,(544,747),(537,754),(155,226,254),3)#left hand
e1 = cv2.line(img65,(575,761),(580,778),(29,101,181),10)#bat
e1 = cv2.line(img65,(550,724),(562,724),(0,0,0),21)#top hair




cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
img66 = np.zeros((800, 1200, 3), np.uint8)
e1 = cv2.rectangle(img66, (0, 0), (1200, 800), (0, 178, 0), -1)  # layout

e1 = cv2.line(img66, (600, 800), (530, 400), (128, 178, 194), 10)  # left line
e1 = cv2.line(img66, (610, 800), (540, 400), (128, 178, 194), 10)  # left line
e1 = cv2.line(img66, (620, 800), (550, 400), (128, 178, 194), 10)  # left line
e1 = cv2.line(img66, (630, 800), (560, 400), (128, 178, 194), 10)  # left line
e1 = cv2.line(img66, (640, 800), (570, 400), (128, 178, 194), 10)  # left line
e1 = cv2.line(img66, (650, 800), (580, 400), (128, 178, 194), 10)  # left line
e1 = cv2.line(img66, (660, 800), (590, 400), (128, 178, 194), 10)  # left line
e1 = cv2.line(img66, (670, 800), (600, 400), (128, 178, 194), 10)  # left line
e1 = cv2.line(img66, (680, 800), (610, 400), (128, 178, 194), 10)  # left line
e1 = cv2.line(img66, (690, 800), (620, 400), (128, 178, 194), 10)  # left line
e1 = cv2.line(img66, (700, 800), (630, 400), (128, 178, 194), 10)  # left line
e1 = cv2.line(img66, (710, 800), (640, 400), (128, 178, 194), 10)  # left line
e1 = cv2.line(img66, (720, 800), (650, 400), (128, 178, 194), 10)  # left line
e1 = cv2.line(img66, (730, 800), (660, 400), (128, 178, 194), 10)  # left line
e1 = cv2.line(img66, (740, 800), (670, 400), (128, 178, 194), 10)  # left line
e1 = cv2.line(img66, (750, 800), (680, 400), (128, 178, 194), 10)  # left line
e1 = cv2.line(img66, (760, 800), (690, 400), (128, 178, 194), 10)  # left line

e1 = cv2.line(img66, (450, 800), (530, 400), (128, 178, 194), 10)  # right line
e1 = cv2.line(img66, (460, 800), (540, 400), (128, 178, 194), 10)  # right line
e1 = cv2.line(img66, (470, 800), (550, 400), (128, 178, 194), 10)  # right line
e1 = cv2.line(img66, (480, 800), (560, 400), (128, 178, 194), 10)  # right line
e1 = cv2.line(img66, (490, 800), (570, 400), (128, 178, 194), 10)  # right line
e1 = cv2.line(img66, (500, 800), (580, 400), (128, 178, 194), 10)  # right line
e1 = cv2.line(img66, (510, 800), (590, 400), (128, 178, 194), 10)  # right line
e1 = cv2.line(img66, (520, 800), (600, 400), (128, 178, 194), 10)  # right line
e1 = cv2.line(img66, (530, 800), (610, 400), (128, 178, 194), 10)  # right line
e1 = cv2.line(img66, (540, 800), (620, 400), (128, 178, 194), 10)  # right line
e1 = cv2.line(img66, (550, 800), (630, 400), (128, 178, 194), 10)  # right line
e1 = cv2.line(img66, (560, 800), (640, 400), (128, 178, 194), 10)  # right line
e1 = cv2.line(img66, (570, 800), (650, 400), (128, 178, 194), 10)  # right line
e1 = cv2.line(img66, (580, 800), (660, 400), (128, 178, 194), 10)  # right line
e1 = cv2.line(img66, (590, 800), (670, 400), (128, 178, 194), 10)  # right line

e1 = cv2.line(img66, (760, 800), (690, 400), (255, 255, 255), 2)  # left line
e1 = cv2.line(img66, (450, 800), (530, 400), (255, 255, 255), 2)  # right line
e1 = cv2.line(img66, (690, 400), (530, 400), (255, 255, 255), 2)  # middle line
e1 = cv2.line(img66, (600, 1200), (600, 760), (0, 0, 0), 5)  # middle wicket  #buttom side
e1 = cv2.line(img66, (590, 1200), (590, 760), (0, 0, 0), 5)  # left wicket
e1 = cv2.line(img66, (610, 1200), (610, 760), (0, 0, 0), 5)  # right wicket
e1 = cv2.line(img66, (590, 760), (610, 760), (0, 0, 0), 5)  # top wicket
e1 = cv2.line(img66, (430, 750), (780, 750), (255, 255, 255), 2)  # buttom boundary line
e1 = cv2.line(img66, (500, 750), (490, 850), (255, 255, 255), 2)  # boundary left line
e1 = cv2.line(img66, (710, 750), (720, 850), (255, 255, 255), 2)  # boundary right line

e1 = cv2.line(img66, (760, 800), (690, 400), (255, 255, 255), 2)  # left line
e1 = cv2.line(img66, (450, 800), (530, 400), (255, 255, 255), 2)  # right line
e1 = cv2.line(img66, (690, 400), (530, 400), (255, 255, 255), 2)  # middle line
e1 = cv2.line(img66, (620, 400), (620, 360), (0, 0, 0), 5)  # right wicket  #top side
e1 = cv2.line(img66, (600, 400), (600, 360), (0, 0, 0), 5)  # lift wicket
e1 = cv2.line(img66, (610, 400), (610, 360), (0, 0, 0), 5)  # middle wicket
e1 = cv2.line(img66, (600, 360), (620, 360), (0, 0, 0), 5)  # top wicket
e1 = cv2.line(img66, (490, 440), (720, 440), (255, 255, 255), 2)  # top boundary line
e1 = cv2.line(img66, (555, 440), (560, 400), (255, 255, 255), 2)  # boundary left line
e1 = cv2.line(img66, (655, 440), (655, 400), (255, 255, 255), 2)  # boundary right line


#indian player
e1=cv2.rectangle(img66,(642,402),(648,440),(255,0,0),-1)#right leg
e1=cv2.rectangle(img66,(629,352),(650,402),(255,0,0),-1)#body
e1=cv2.rectangle(img66,(631,402),(637,440),(255,0,0),-1)#left leg
e1=cv2.circle(img66,(640,339),13,(155,226,254),-1)# head
e1=cv2.circle(img66,(632,340),2,(0,0,0),-1)# right eye
e1=cv2.circle(img66,(637,340),2,(0,0,0),-1)# left eye
e1=cv2.circle(img66,(635,346),2,(0,0,0),-1)#mouth
e1 = cv2.line(img66,(632,364),(620,400),(155,226,254),3)#right hand 
e1 = cv2.line(img66,(641,373),(623,400),(155,226,254),3)#left hand
e1 = cv2.line(img66,(621,400),(603,422),(29,101,181),10)#bat
e1 = cv2.line(img66,(632,329),(647,329),(0,0,0),10)#top hair
e1 = cv2.line(img66,(647,336),(646,348),(0,0,0),10)#left hair

# pakistan wicket player
e1=cv2.rectangle(img66,(592,362),(586,395),(26,64,0),-1)#right leg
e1=cv2.rectangle(img66,(570,351),(593,379),(26,64,0),-1)#body
e1=cv2.rectangle(img66,(572,362),(579,395),(26,64,0),-1)#left leg
e1=cv2.circle(img66,(581,336),14,(155,226,254),-1)# head
e1=cv2.circle(img66,(576,338),2,(0,0,0),-1)# right eye
e1=cv2.circle(img66,(587,338),2,(0,0,0),-1)# left eye
e1 = cv2.line(img66,(578,345),(585,345),(0,0,0),2)#mouth
e1 = cv2.line(img66,(572,360),(582,369),(155,226,254),4)#right hand 
e1 = cv2.line(img66,(591,360),(582,369),(155,226,254),4)#left hand
e1 = cv2.line(img66,(581,368),(582,369),(255,255,255),10)#glove
e1 = cv2.line(img66,(571,326),(588,326),(0,0,0),10)#top hair

#bowler
e1=cv2.rectangle(img66,(626,719),(652,749),(26,64,0),-1)#body
e1=cv2.circle(img66,(638,705),14,(155,226,254),-1)# head
e1=cv2.circle(img66,(603,422),6,(255,255,255),-1)# right ball
e1 = cv2.line(img66,(653,724),(663,736),(155,226,254),5)#right hand 
e1 = cv2.line(img66,(625,725),(620,732),(155,226,254),5)#left hand
e1 = cv2.line(img66,(632,702),(643,702),(0,0,0),20)#top hair
e1=cv2.rectangle(img66,(631,749),(637,762),(26,64,0),-1)#left leg
e1=cv2.rectangle(img66,(642,749),(648,762),(26,64,0),-1)#right leg

# pakistan player
e1=cv2.rectangle(img66,(292,293),(300,322),(26,64,0),-1)#right leg
e1=cv2.rectangle(img66,(288,253),(320,298),(26,64,0),-1)#body
e1=cv2.rectangle(img66,(309,293),(317,322),(26,64,0),-1)#left leg
e1=cv2.circle(img66,(303,239),16,(155,226,254),-1)# head
e1=cv2.circle(img66,(295,242),2,(0,0,0),-1)# right eye
e1=cv2.circle(img66,(310,242),2,(0,0,0),-1)# left eye
e1 = cv2.line(img66,(298,249),(307,249),(0,0,0),2)#mouth
e1 = cv2.line(img66,(289,265),(294,276),(155,226,254),4)#right hand 
e1 = cv2.line(img66,(318,265),(310,276),(155,226,254),4)#left hand
e1 = cv2.line(img66,(293,229),(312,229),(0,0,0),13)#top hair

#Indian  player
e1=cv2.rectangle(img66,(548,767),(555,784),(255,0,0),-1)#left leg
e1=cv2.rectangle(img66,(569,767),(545,742),(255,0,0),-1)#body
e1=cv2.rectangle(img66,(560,767),(567,784),(255,0,0),-1)#right leg
e1=cv2.circle(img66,(557,729),14,(155,226,254),-1)# head
e1 = cv2.line(img66,(570,748),(574,761),(155,226,254),3)#right hand 
e1 = cv2.line(img66,(544,747),(537,754),(155,226,254),3)#left hand
e1 = cv2.line(img66,(575,761),(580,778),(29,101,181),10)#bat
e1 = cv2.line(img66,(550,724),(562,724),(0,0,0),21)#top hair

cv2.imshow("Window name", e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # six

# %%
img67 = np.zeros((800, 1200, 3), np.uint8)
e1 = cv2.rectangle(img67, (0, 0), (1200, 800), (128, 178, 194), -1)  # layout
e1 = cv2.line(img67, (500, 400), (700, 400), (140, 160, 180), 1050)  # dugout
e1 = cv2.line(img67, (500, 400), (700, 400), (106, 206, 234), 800)  # ground
e1 = cv2.line(img67, (500, 400), (700, 400), (35, 215, 0), 780)  # extraSpace
e1 = cv2.line(img67, (500, 400), (700, 400), (255, 255, 255), 750)  # boundary
e1 = cv2.line(img67, (500, 400), (700, 400), (0, 206, 0), 748)  # playarea
e1 = cv2.rectangle(img67, (630, 300), (570, 500), (128, 178, 194), -1)  # pitch
e1 = cv2.rectangle(img67, (630, 300), (570, 500), (255, 255, 255), 1)  # pitchhighlighter
e1 = cv2.line(img67, (580, 300), (580, 315), (255, 255, 255), 1)  # leftwideline
e1 = cv2.line(img67, (620, 300), (620, 315), (255, 255, 255), 1)  # rightwideline
e1 = cv2.line(img67, (580, 500), (580, 485), (255, 255, 255), 1)  # leftwideline_non_stricker
e1 = cv2.line(img67, (620, 500), (620, 485), (255, 255, 255), 1)  # rightwideline_non_stricker
e1 = cv2.line(img67, (565, 315), (635, 315), (255, 255, 255), 1)  # crease
e1 = cv2.line(img67, (565, 485), (635, 485), (255, 255, 255), 1)  # crease_non_stricker
e1 = cv2.line(img67, (597, 300), (603, 300), (0, 0, 0), 1)  # wickets
e1 = cv2.line(img67, (597, 500), (603, 500), (0, 0, 0), 1)  # wickets_non_stricker
e1 = cv2.circle(img67, (600, 400), 270, (255, 255, 255), 1)  # insidecircle

e1 = cv2.circle(img67, (600, 280), 5, (32, 100, 1), -1)  # wicketkeeper
e1 = cv2.circle(img67, (925, 120), 5, (32, 100, 1), -1)  # fineleg
e1 = cv2.circle(img67, (580, 270), 5, (32, 100, 1), -1)  # slip
e1 = cv2.circle(img67, (490, 720), 5, (32, 100, 1), -1)  # longoff
e1 = cv2.circle(img67, (720, 530), 5, (32, 100, 1), -1)  # midwicket
e1 = cv2.circle(img67, (420, 500), 5, (32, 100, 1), -1)  # cover
e1 = cv2.circle(img67, (420, 500), 5, (32, 100, 1), -1)  # cover
e1 = cv2.circle(img67, (150, 380), 5, (32, 100, 1), -1)  # deepcoverpoint
e1 = cv2.circle(img67, (700, 340), 5, (32, 100, 1), -1)  # short
e1 = cv2.circle(img67, (950, 480), 5, (32, 100, 1), -1)  # deepsweep
e1 = cv2.circle(img67, (500, 300), 5, (32, 100, 1), -1)  # gully
e1 = cv2.circle(img67, (610, 490), 5, (32, 100, 1), -1)  # bowler

e1 = cv2.circle(img67, (590, 490), 5, (255, 30, 0), -1)  # batsmen
e1 = cv2.circle(img67, (610, 310), 5, (255, 30, 0), -1)  # bowler

e1 = cv2.circle(img67, (600, 520), 5, (0, 0, 255), -1)  # umpire
e1 = cv2.circle(img67, (750, 315), 5, (0, 0, 255), -1)  # umpire2

e1 = cv2.circle(img67, (600, 314), 4, (255, 255, 255), -1)  # ball

cv2.imshow("Window name", e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

img68 = np.zeros((800, 1200, 3), np.uint8)
e1 = cv2.rectangle(img68, (0, 0), (1200, 800), (128, 178, 194), -1)  # layout
e1 = cv2.line(img68, (500, 400), (700, 400), (140, 160, 180), 1050)  # dugout
e1 = cv2.line(img68, (500, 400), (700, 400), (106, 206, 234), 800)  # ground
e1 = cv2.line(img68, (500, 400), (700, 400), (35, 215, 0), 780)  # extraSpace
e1 = cv2.line(img68, (500, 400), (700, 400), (255, 255, 255), 750)  # boundary
e1 = cv2.line(img68, (500, 400), (700, 400), (0, 206, 0), 748)  # playarea
e1 = cv2.rectangle(img68, (630, 300), (570, 500), (128, 178, 194), -1)  # pitch
e1 = cv2.rectangle(img68, (630, 300), (570, 500), (255, 255, 255), 1)  # pitchhighlighter
e1 = cv2.line(img68, (580, 300), (580, 315), (255, 255, 255), 1)  # leftwideline
e1 = cv2.line(img68, (620, 300), (620, 315), (255, 255, 255), 1)  # rightwideline
e1 = cv2.line(img68, (580, 500), (580, 485), (255, 255, 255), 1)  # leftwideline_non_stricker
e1 = cv2.line(img68, (620, 500), (620, 485), (255, 255, 255), 1)  # rightwideline_non_stricker
e1 = cv2.line(img68, (565, 315), (635, 315), (255, 255, 255), 1)  # crease
e1 = cv2.line(img68, (565, 485), (635, 485), (255, 255, 255), 1)  # crease_non_stricker
e1 = cv2.line(img68, (597, 300), (603, 300), (0, 0, 0), 1)  # wickets
e1 = cv2.line(img68, (597, 500), (603, 500), (0, 0, 0), 1)  # wickets_non_stricker
e1 = cv2.circle(img68, (600, 400), 270, (255, 255, 255), 1)  # insidecircle

e1 = cv2.circle(img68, (600, 280), 5, (32, 100, 1), -1)  # wicketkeeper
e1 = cv2.circle(img68, (925, 120), 5, (32, 100, 1), -1)  # fineleg
e1 = cv2.circle(img68, (580, 270), 5, (32, 100, 1), -1)  # slip
e1 = cv2.circle(img68, (490, 720), 5, (32, 100, 1), -1)  # longoff
e1 = cv2.circle(img68, (720, 530), 5, (32, 100, 1), -1)  # midwicket
e1 = cv2.circle(img68, (420, 500), 5, (32, 100, 1), -1)  # cover
e1 = cv2.circle(img68, (150, 380), 5, (32, 100, 1), -1)  # deepcoverpoint
e1 = cv2.circle(img68, (700, 340), 5, (32, 100, 1), -1)  # short
e1 = cv2.circle(img68, (950, 480), 5, (32, 100, 1), -1)  # deepsweep
e1 = cv2.circle(img68, (500, 300), 5, (32, 100, 1), -1)  # gully
e1 = cv2.circle(img68, (610, 490), 5, (32, 100, 1), -1)  # bowler

e1 = cv2.circle(img68, (590, 490), 5, (255, 30, 0), -1)  # batsmen
e1 = cv2.circle(img68, (610, 310), 5, (255, 30, 0), -1)  # bowler

e1 = cv2.circle(img68, (600, 520), 5, (0, 0, 255), -1)  # umpire
e1 = cv2.circle(img68, (750, 315), 5, (0, 0, 255), -1)  # umpire2

e1 = cv2.circle(img68, (620, 375), 4, (255, 255, 255), -1)  # ball

cv2.imshow("Window name", e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
img69 = np.zeros((800, 1200, 3), np.uint8)
e1 = cv2.rectangle(img69, (0, 0), (1200, 800), (128, 178, 194), -1)  # layout
e1 = cv2.line(img69, (500, 400), (700, 400), (140, 160, 180), 1050)  # dugout
e1 = cv2.line(img69, (500, 400), (700, 400), (106, 206, 234), 800)  # ground
e1 = cv2.line(img69, (500, 400), (700, 400), (35, 215, 0), 780)  # extraSpace
e1 = cv2.line(img69, (500, 400), (700, 400), (255, 255, 255), 750)  # boundary
e1 = cv2.line(img69, (500, 400), (700, 400), (0, 206, 0), 748)  # playarea
e1 = cv2.rectangle(img69, (630, 300), (570, 500), (128, 178, 194), -1)  # pitch
e1 = cv2.rectangle(img69, (630, 300), (570, 500), (255, 255, 255), 1)  # pitchhighlighter
e1 = cv2.line(img69, (580, 300), (580, 315), (255, 255, 255), 1)  # leftwideline
e1 = cv2.line(img69, (620, 300), (620, 315), (255, 255, 255), 1)  # rightwideline
e1 = cv2.line(img69, (580, 500), (580, 485), (255, 255, 255), 1)  # leftwideline_non_stricker
e1 = cv2.line(img69, (620, 500), (620, 485), (255, 255, 255), 1)  # rightwideline_non_stricker
e1 = cv2.line(img69, (565, 315), (635, 315), (255, 255, 255), 1)  # crease
e1 = cv2.line(img69, (565, 485), (635, 485), (255, 255, 255), 1)  # crease_non_stricker
e1 = cv2.line(img69, (597, 300), (603, 300), (0, 0, 0), 1)  # wickets
e1 = cv2.line(img69, (597, 500), (603, 500), (0, 0, 0), 1)  # wickets_non_stricker
e1 = cv2.circle(img69, (600, 400), 270, (255, 255, 255), 1)  # insidecircle

e1 = cv2.circle(img69, (600, 280), 5, (32, 100, 1), -1)  # wicketkeeper
e1 = cv2.circle(img69, (925, 120), 5, (32, 100, 1), -1)  # fineleg
e1 = cv2.circle(img69, (580, 270), 5, (32, 100, 1), -1)  # slip
e1 = cv2.circle(img69, (490, 720), 5, (32, 100, 1), -1)  # longoff
e1 = cv2.circle(img69, (720, 530), 5, (32, 100, 1), -1)  # midwicket
e1 = cv2.circle(img69, (420, 500), 5, (32, 100, 1), -1)  # cover
e1 = cv2.circle(img69, (150, 380), 5, (32, 100, 1), -1)  # deepcoverpoint
e1 = cv2.circle(img69, (700, 340), 5, (32, 100, 1), -1)  # short
e1 = cv2.circle(img69, (950, 480), 5, (32, 100, 1), -1)  # deepsweep
e1 = cv2.circle(img69, (500, 300), 5, (32, 100, 1), -1)  # gully
e1 = cv2.circle(img69, (610, 490), 5, (32, 100, 1), -1)  # bowler

e1 = cv2.circle(img69, (590, 490), 5, (255, 30, 0), -1)  # batsmen
e1 = cv2.circle(img69, (610, 310), 5, (255, 30, 0), -1)  # bowler

e1 = cv2.circle(img69, (600, 520), 5, (0, 0, 255), -1)  # umpire
e1 = cv2.circle(img69, (750, 315), 5, (0, 0, 255), -1)  # umpire2

e1 = cv2.circle(img69, (640, 435), 4, (255, 255, 255), -1)  # ball

cv2.imshow("Window name", e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
img70 = np.zeros((800, 1200, 3), np.uint8)
e1 = cv2.rectangle(img70, (0, 0), (1200, 800), (128, 178, 194), -1)  # layout
e1 = cv2.line(img70, (500, 400), (700, 400), (140, 160, 180), 1050)  # dugout
e1 = cv2.line(img70, (500, 400), (700, 400), (106, 206, 234), 800)  # ground
e1 = cv2.line(img70, (500, 400), (700, 400), (35, 215, 0), 780)  # extraSpace
e1 = cv2.line(img70, (500, 400), (700, 400), (255, 255, 255), 750)  # boundary
e1 = cv2.line(img70, (500, 400), (700, 400), (0, 206, 0), 748)  # playarea
e1 = cv2.rectangle(img70, (630, 300), (570, 500), (128, 178, 194), -1)  # pitch
e1 = cv2.rectangle(img70, (630, 300), (570, 500), (255, 255, 255), 1)  # pitchhighlighter
e1 = cv2.line(img70, (580, 300), (580, 315), (255, 255, 255), 1)  # leftwideline
e1 = cv2.line(img70, (620, 300), (620, 315), (255, 255, 255), 1)  # rightwideline
e1 = cv2.line(img70, (580, 500), (580, 485), (255, 255, 255), 1)  # leftwideline_non_stricker
e1 = cv2.line(img70, (620, 500), (620, 485), (255, 255, 255), 1)  # rightwideline_non_stricker
e1 = cv2.line(img70, (565, 315), (635, 315), (255, 255, 255), 1)  # crease
e1 = cv2.line(img70, (565, 485), (635, 485), (255, 255, 255), 1)  # crease_non_stricker
e1 = cv2.line(img70, (597, 300), (603, 300), (0, 0, 0), 1)  # wickets
e1 = cv2.line(img70, (597, 500), (603, 500), (0, 0, 0), 1)  # wickets_non_stricker
e1 = cv2.circle(img70, (600, 400), 270, (255, 255, 255), 1)  # insidecircle

e1 = cv2.circle(img70, (600, 280), 5, (32, 100, 1), -1)  # wicketkeeper
e1 = cv2.circle(img70, (925, 120), 5, (32, 100, 1), -1)  # fineleg
e1 = cv2.circle(img70, (580, 270), 5, (32, 100, 1), -1)  # slip
e1 = cv2.circle(img70, (490, 720), 5, (32, 100, 1), -1)  # longoff
e1 = cv2.circle(img70, (720, 530), 5, (32, 100, 1), -1)  # midwicket
e1 = cv2.circle(img70, (420, 500), 5, (32, 100, 1), -1)  # cover
e1 = cv2.circle(img70, (150, 380), 5, (32, 100, 1), -1)  # deepcoverpoint
e1 = cv2.circle(img70, (700, 340), 5, (32, 100, 1), -1)  # short
e1 = cv2.circle(img70, (950, 480), 5, (32, 100, 1), -1)  # deepsweep
e1 = cv2.circle(img70, (500, 300), 5, (32, 100, 1), -1)  # gully
e1 = cv2.circle(img70, (610, 490), 5, (32, 100, 1), -1)  # bowler

e1 = cv2.circle(img70, (590, 490), 5, (255, 30, 0), -1)  # batsmen
e1 = cv2.circle(img70, (610, 310), 5, (255, 30, 0), -1)  # bowler

e1 = cv2.circle(img70, (600, 520), 5, (0, 0, 255), -1)  # umpire
e1 = cv2.circle(img70, (750, 315), 5, (0, 0, 255), -1)  # umpire2

e1 = cv2.circle(img70, (660, 495), 4, (255, 255, 255), -1)  # ball

cv2.imshow("Window name", e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
img71 = np.zeros((800, 1200, 3), np.uint8)
e1 = cv2.rectangle(img71, (0, 0), (1200, 800), (128, 178, 194), -1)  # layout
e1 = cv2.line(img71, (500, 400), (700, 400), (140, 160, 180), 1050)  # dugout
e1 = cv2.line(img71, (500, 400), (700, 400), (106, 206, 234), 800)  # ground
e1 = cv2.line(img71, (500, 400), (700, 400), (35, 215, 0), 780)  # extraSpace
e1 = cv2.line(img71, (500, 400), (700, 400), (255, 255, 255), 750)  # boundary
e1 = cv2.line(img71, (500, 400), (700, 400), (0, 206, 0), 748)  # playarea
e1 = cv2.rectangle(img71, (630, 300), (570, 500), (128, 178, 194), -1)  # pitch
e1 = cv2.rectangle(img71, (630, 300), (570, 500), (255, 255, 255), 1)  # pitchhighlighter
e1 = cv2.line(img71, (580, 300), (580, 315), (255, 255, 255), 1)  # leftwideline
e1 = cv2.line(img71, (620, 300), (620, 315), (255, 255, 255), 1)  # rightwideline
e1 = cv2.line(img71, (580, 500), (580, 485), (255, 255, 255), 1)  # leftwideline_non_stricker
e1 = cv2.line(img71, (620, 500), (620, 485), (255, 255, 255), 1)  # rightwideline_non_stricker
e1 = cv2.line(img71, (565, 315), (635, 315), (255, 255, 255), 1)  # crease
e1 = cv2.line(img71, (565, 485), (635, 485), (255, 255, 255), 1)  # crease_non_stricker
e1 = cv2.line(img71, (597, 300), (603, 300), (0, 0, 0), 1)  # wickets
e1 = cv2.line(img71, (597, 500), (603, 500), (0, 0, 0), 1)  # wickets_non_stricker
e1 = cv2.circle(img71, (600, 400), 270, (255, 255, 255), 1)  # insidecircle

e1 = cv2.circle(img71, (600, 280), 5, (32, 100, 1), -1)  # wicketkeeper
e1 = cv2.circle(img71, (925, 120), 5, (32, 100, 1), -1)  # fineleg
e1 = cv2.circle(img71, (580, 270), 5, (32, 100, 1), -1)  # slip
e1 = cv2.circle(img71, (490, 720), 5, (32, 100, 1), -1)  # longoff
e1 = cv2.circle(img71, (720, 530), 5, (32, 100, 1), -1)  # midwicket
e1 = cv2.circle(img71, (420, 500), 5, (32, 100, 1), -1)  # cover
e1 = cv2.circle(img71, (150, 380), 5, (32, 100, 1), -1)  # deepcoverpoint
e1 = cv2.circle(img71, (700, 340), 5, (32, 100, 1), -1)  # short
e1 = cv2.circle(img71, (950, 480), 5, (32, 100, 1), -1)  # deepsweep
e1 = cv2.circle(img71, (500, 300), 5, (32, 100, 1), -1)  # gully
e1 = cv2.circle(img71, (610, 490), 5, (32, 100, 1), -1)  # bowler

e1 = cv2.circle(img71, (590, 490), 5, (255, 30, 0), -1)  # batsmen
e1 = cv2.circle(img71, (610, 310), 5, (255, 30, 0), -1)  # bowler

e1 = cv2.circle(img71, (600, 520), 5, (0, 0, 255), -1)  # umpire
e1 = cv2.circle(img71, (750, 315), 5, (0, 0, 255), -1)  # umpire2

e1 = cv2.circle(img71, (680,555), 4, (255, 255, 255), -1)  # ball

cv2.imshow("Window name", e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
img72 = np.zeros((800, 1200, 3), np.uint8)
e1 = cv2.rectangle(img72, (0, 0), (1200, 800), (128, 178, 194), -1)  # layout
e1 = cv2.line(img72, (500, 400), (700, 400), (140, 160, 180), 1050)  # dugout
e1 = cv2.line(img72, (500, 400), (700, 400), (106, 206, 234), 800)  # ground
e1 = cv2.line(img72, (500, 400), (700, 400), (35, 215, 0), 780)  # extraSpace
e1 = cv2.line(img72, (500, 400), (700, 400), (255, 255, 255), 750)  # boundary
e1 = cv2.line(img72, (500, 400), (700, 400), (0, 206, 0), 748)  # playarea
e1 = cv2.rectangle(img72, (630, 300), (570, 500), (128, 178, 194), -1)  # pitch
e1 = cv2.rectangle(img72, (630, 300), (570, 500), (255, 255, 255), 1)  # pitchhighlighter
e1 = cv2.line(img72, (580, 300), (580, 315), (255, 255, 255), 1)  # leftwideline
e1 = cv2.line(img72, (620, 300), (620, 315), (255, 255, 255), 1)  # rightwideline
e1 = cv2.line(img72, (580, 500), (580, 485), (255, 255, 255), 1)  # leftwideline_non_stricker
e1 = cv2.line(img72, (620, 500), (620, 485), (255, 255, 255), 1)  # rightwideline_non_stricker
e1 = cv2.line(img72, (565, 315), (635, 315), (255, 255, 255), 1)  # crease
e1 = cv2.line(img72, (565, 485), (635, 485), (255, 255, 255), 1)  # crease_non_stricker
e1 = cv2.line(img72, (597, 300), (603, 300), (0, 0, 0), 1)  # wickets
e1 = cv2.line(img72, (597, 500), (603, 500), (0, 0, 0), 1)  # wickets_non_stricker
e1 = cv2.circle(img72, (600, 400), 270, (255, 255, 255), 1)  # insidecircle

e1 = cv2.circle(img72, (600, 280), 5, (32, 100, 1), -1)  # wicketkeeper
e1 = cv2.circle(img72, (925, 120), 5, (32, 100, 1), -1)  # fineleg
e1 = cv2.circle(img72, (580, 270), 5, (32, 100, 1), -1)  # slip
e1 = cv2.circle(img72, (490, 720), 5, (32, 100, 1), -1)  # longoff
e1 = cv2.circle(img72, (720, 530), 5, (32, 100, 1), -1)  # midwicket
e1 = cv2.circle(img72, (420, 500), 5, (32, 100, 1), -1)  # cover
e1 = cv2.circle(img72, (150, 380), 5, (32, 100, 1), -1)  # deepcoverpoint
e1 = cv2.circle(img72, (700, 340), 5, (32, 100, 1), -1)  # short
e1 = cv2.circle(img72, (950, 480), 5, (32, 100, 1), -1)  # deepsweep
e1 = cv2.circle(img72, (500, 300), 5, (32, 100, 1), -1)  # gully
e1 = cv2.circle(img72, (610, 490), 5, (32, 100, 1), -1)  # bowler

e1 = cv2.circle(img72, (590, 490), 5, (255, 30, 0), -1)  # batsmen
e1 = cv2.circle(img72, (610, 310), 5, (255, 30, 0), -1)  # bowler

e1 = cv2.circle(img72, (600, 520), 5, (0, 0, 255), -1)  # umpire
e1 = cv2.circle(img72, (750, 315), 5, (0, 0, 255), -1)  # umpire2

e1 = cv2.circle(img72, (700, 615), 4, (255, 255, 255), -1)  # ball

cv2.imshow("Window name", e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
img73 = np.zeros((800, 1200, 3), np.uint8)
e1 = cv2.rectangle(img73, (0, 0), (1200, 800), (128, 178, 194), -1)  # layout
e1 = cv2.line(img73, (500, 400), (700, 400), (140, 160, 180), 1050)  # dugout
e1 = cv2.line(img73, (500, 400), (700, 400), (106, 206, 234), 800)  # ground
e1 = cv2.line(img73, (500, 400), (700, 400), (35, 215, 0), 780)  # extraSpace
e1 = cv2.line(img73, (500, 400), (700, 400), (255, 255, 255), 750)  # boundary
e1 = cv2.line(img73, (500, 400), (700, 400), (0, 206, 0), 748)  # playarea
e1 = cv2.rectangle(img73, (630, 300), (570, 500), (128, 178, 194), -1)  # pitch
e1 = cv2.rectangle(img73, (630, 300), (570, 500), (255, 255, 255), 1)  # pitchhighlighter
e1 = cv2.line(img73, (580, 300), (580, 315), (255, 255, 255), 1)  # leftwideline
e1 = cv2.line(img73, (620, 300), (620, 315), (255, 255, 255), 1)  # rightwideline
e1 = cv2.line(img73, (580, 500), (580, 485), (255, 255, 255), 1)  # leftwideline_non_stricker
e1 = cv2.line(img73, (620, 500), (620, 485), (255, 255, 255), 1)  # rightwideline_non_stricker
e1 = cv2.line(img73, (565, 315), (635, 315), (255, 255, 255), 1)  # crease
e1 = cv2.line(img73, (565, 485), (635, 485), (255, 255, 255), 1)  # crease_non_stricker
e1 = cv2.line(img73, (597, 300), (603, 300), (0, 0, 0), 1)  # wickets
e1 = cv2.line(img73, (597, 500), (603, 500), (0, 0, 0), 1)  # wickets_non_stricker
e1 = cv2.circle(img73, (600, 400), 270, (255, 255, 255), 1)  # insidecircle

e1 = cv2.circle(img73, (600, 280), 5, (32, 100, 1), -1)  # wicketkeeper
e1 = cv2.circle(img73, (925, 120), 5, (32, 100, 1), -1)  # fineleg
e1 = cv2.circle(img73, (580, 270), 5, (32, 100, 1), -1)  # slip
e1 = cv2.circle(img73, (490, 720), 5, (32, 100, 1), -1)  # longoff
e1 = cv2.circle(img73, (720, 530), 5, (32, 100, 1), -1)  # midwicket
e1 = cv2.circle(img73, (420, 500), 5, (32, 100, 1), -1)  # cover
e1 = cv2.circle(img73, (150, 380), 5, (32, 100, 1), -1)  # deepcoverpoint
e1 = cv2.circle(img73, (700, 340), 5, (32, 100, 1), -1)  # short
e1 = cv2.circle(img73, (950, 480), 5, (32, 100, 1), -1)  # deepsweep
e1 = cv2.circle(img73, (500, 300), 5, (32, 100, 1), -1)  # gully
e1 = cv2.circle(img73, (610, 490), 5, (32, 100, 1), -1)  # bowler

e1 = cv2.circle(img73, (590, 490), 5, (255, 30, 0), -1)  # batsmen
e1 = cv2.circle(img73, (610, 310), 5, (255, 30, 0), -1)  # bowler

e1 = cv2.circle(img73, (600, 520), 5, (0, 0, 255), -1)  # umpire
e1 = cv2.circle(img73, (750, 315), 5, (0, 0, 255), -1)  # umpire2

e1 = cv2.circle(img73, (720, 675), 4, (255, 255, 255), -1)  # ball

cv2.imshow("Window name", e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
img74 = np.zeros((800, 1200, 3), np.uint8)
e1 = cv2.rectangle(img74, (0, 0), (1200, 800), (128, 178, 194), -1)  # layout
e1 = cv2.line(img74, (500, 400), (700, 400), (140, 160, 180), 1050)  # dugout
e1 = cv2.line(img74, (500, 400), (700, 400), (106, 206, 234), 800)  # ground
e1 = cv2.line(img74, (500, 400), (700, 400), (35, 215, 0), 780)  # extraSpace
e1 = cv2.line(img74, (500, 400), (700, 400), (255, 255, 255), 750)  # boundary
e1 = cv2.line(img74, (500, 400), (700, 400), (0, 206, 0), 748)  # playarea
e1 = cv2.rectangle(img74, (630, 300), (570, 500), (128, 178, 194), -1)  # pitch
e1 = cv2.rectangle(img74, (630, 300), (570, 500), (255, 255, 255), 1)  # pitchhighlighter
e1 = cv2.line(img74, (580, 300), (580, 315), (255, 255, 255), 1)  # leftwideline
e1 = cv2.line(img74, (620, 300), (620, 315), (255, 255, 255), 1)  # rightwideline
e1 = cv2.line(img74, (580, 500), (580, 485), (255, 255, 255), 1)  # leftwideline_non_stricker
e1 = cv2.line(img74, (620, 500), (620, 485), (255, 255, 255), 1)  # rightwideline_non_stricker
e1 = cv2.line(img74, (565, 315), (635, 315), (255, 255, 255), 1)  # crease
e1 = cv2.line(img74, (565, 485), (635, 485), (255, 255, 255), 1)  # crease_non_stricker
e1 = cv2.line(img74, (597, 300), (603, 300), (0, 0, 0), 1)  # wickets
e1 = cv2.line(img74, (597, 500), (603, 500), (0, 0, 0), 1)  # wickets_non_stricker
e1 = cv2.circle(img74, (600, 400), 270, (255, 255, 255), 1)  # insidecircle

e1 = cv2.circle(img74, (600, 280), 5, (32, 100, 1), -1)  # wicketkeeper
e1 = cv2.circle(img74, (925, 120), 5, (32, 100, 1), -1)  # fineleg
e1 = cv2.circle(img74, (580, 270), 5, (32, 100, 1), -1)  # slip
e1 = cv2.circle(img74, (490, 720), 5, (32, 100, 1), -1)  # longoff
e1 = cv2.circle(img74, (720, 530), 5, (32, 100, 1), -1)  # midwicket
e1 = cv2.circle(img74, (420, 500), 5, (32, 100, 1), -1)  # cover
e1 = cv2.circle(img74, (150, 380), 5, (32, 100, 1), -1)  # deepcoverpoint
e1 = cv2.circle(img74, (700, 340), 5, (32, 100, 1), -1)  # short
e1 = cv2.circle(img74, (950, 480), 5, (32, 100, 1), -1)  # deepsweep
e1 = cv2.circle(img74, (500, 300), 5, (32, 100, 1), -1)  # gully
e1 = cv2.circle(img74, (610, 490), 5, (32, 100, 1), -1)  # bowler

e1 = cv2.circle(img74, (590, 490), 5, (255, 30, 0), -1)  # batsmen
e1 = cv2.circle(img74, (610, 310), 5, (255, 30, 0), -1)  # bowler

e1 = cv2.circle(img74, (600, 520), 5, (0, 0, 255), -1)  # umpire
e1 = cv2.circle(img74, (750, 315), 5, (0, 0, 255), -1)  # umpire2

e1 = cv2.circle(img74, (740, 735), 4, (255, 255, 255), -1)  # ball

cv2.imshow("Window name", e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
img75 = np.zeros((800, 1200, 3), np.uint8)
e1 = cv2.rectangle(img75, (0, 0), (1200, 800), (128, 178, 194), -1)  # layout
e1 = cv2.line(img75, (500, 400), (700, 400), (140, 160, 180), 1050)  # dugout
e1 = cv2.line(img75, (500, 400), (700, 400), (106, 206, 234), 800)  # ground
e1 = cv2.line(img75, (500, 400), (700, 400), (35, 215, 0), 780)  # extraSpace
e1 = cv2.line(img75, (500, 400), (700, 400), (255, 255, 255), 750)  # boundary
e1 = cv2.line(img75, (500, 400), (700, 400), (0, 206, 0), 748)  # playarea
e1 = cv2.rectangle(img75, (630, 300), (570, 500), (128, 178, 194), -1)  # pitch
e1 = cv2.rectangle(img75, (630, 300), (570, 500), (255, 255, 255), 1)  # pitchhighlighter
e1 = cv2.line(img75, (580, 300), (580, 315), (255, 255, 255), 1)  # leftwideline
e1 = cv2.line(img75, (620, 300), (620, 315), (255, 255, 255), 1)  # rightwideline
e1 = cv2.line(img75, (580, 500), (580, 485), (255, 255, 255), 1)  # leftwideline_non_stricker
e1 = cv2.line(img75, (620, 500), (620, 485), (255, 255, 255), 1)  # rightwideline_non_stricker
e1 = cv2.line(img75, (565, 315), (635, 315), (255, 255, 255), 1)  # crease
e1 = cv2.line(img75, (565, 485), (635, 485), (255, 255, 255), 1)  # crease_non_stricker
e1 = cv2.line(img75, (597, 300), (603, 300), (0, 0, 0), 1)  # wickets
e1 = cv2.line(img75, (597, 500), (603, 500), (0, 0, 0), 1)  # wickets_non_stricker
e1 = cv2.circle(img75, (600, 400), 270, (255, 255, 255), 1)  # insidecircle

e1 = cv2.circle(img75, (600, 280), 5, (32, 100, 1), -1)  # wicketkeeper
e1 = cv2.circle(img75, (925, 120), 5, (32, 100, 1), -1)  # fineleg
e1 = cv2.circle(img75, (580, 270), 5, (32, 100, 1), -1)  # slip
e1 = cv2.circle(img75, (490, 720), 5, (32, 100, 1), -1)  # longoff
e1 = cv2.circle(img75, (720, 530), 5, (32, 100, 1), -1)  # midwicket
e1 = cv2.circle(img75, (420, 500), 5, (32, 100, 1), -1)  # cover
e1 = cv2.circle(img75, (150, 380), 5, (32, 100, 1), -1)  # deepcoverpoint
e1 = cv2.circle(img75, (700, 340), 5, (32, 100, 1), -1)  # short
e1 = cv2.circle(img75, (950, 480), 5, (32, 100, 1), -1)  # deepsweep
e1 = cv2.circle(img75, (500, 300), 5, (32, 100, 1), -1)  # gully
e1 = cv2.circle(img75, (610, 490), 5, (32, 100, 1), -1)  # bowler

e1 = cv2.circle(img75, (590, 490), 5, (255, 30, 0), -1)  # batsmen
e1 = cv2.circle(img75, (610, 310), 5, (255, 30, 0), -1)  # bowler

e1 = cv2.circle(img75, (600, 520), 5, (0, 0, 255), -1)  # umpire
e1 = cv2.circle(img75, (750, 315), 5, (0, 0, 255), -1)  # umpire2

e1 = cv2.circle(img75, (760, 795), 4, (255, 255, 255), -1)  # ball

cv2.imshow("Window name", e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
img76=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img76,(0,0),(1200,800),(128,178,194),-1) #layout
e1 = cv2.line(img76,(500,400),(700,400),(140,160,180),1050) #dugout
e1 = cv2.line(img76,(500,400),(700,400),(106,206,234),800) #ground
e1 = cv2.line(img76,(500,400),(700,400),(35,215,0),780)
e1 = cv2.line(img76,(500,400),(700,400),(255,255,255),750) #boundary
e1 = cv2.line(img76,(500,400),(700,400),(0,206,0),748) #playarea
e1 = cv2.rectangle(img76,(630,300),(570,500),(128,178,194),-1) #pitch
e1 = cv2.rectangle(img76,(630,300),(570,500),(255,255,255),1) #
e1 = cv2.line(img76,(580,300),(580,315),(255,255,255),1)
e1 = cv2.line(img76,(620,300),(620,315),(255,255,255),1)
e1 = cv2.line(img76,(580,500),(580,485),(255,255,255),1)
e1 = cv2.line(img76,(620,500),(620,485),(255,255,255),1)
e1 = cv2.line(img76,(570,315),(630,315),(255,255,255),1)
e1 = cv2.line(img76,(570,485),(630,485),(255,255,255),1)
e1 = cv2.line(img76,(597,300),(603,300),(0,0,0),1)
e1 = cv2.line(img76,(597,500),(603,500),(0,0,0),1)
e1 = cv2.circle(img76,(600,400),270,(255,0,0),1)
e1 = cv2.circle(img76,(600,400),270,(0,0,0),1)
e1 = cv2.circle(img76,(600,400),270,(255,255,255),1)
e1 = cv2.circle(img76,(600,400),270,(255,255,255),1)
e1 = cv2.circle(img76,(600,400),270,(255,255,255),1)
e1 = cv2.circle(img76,(600,400),270,(255,255,255),1)
e1 = cv2.circle(img76,(600,400),270,(255,255,255),1)
e1 = cv2.circle(img76,(600,400),270,(255,255,255),1)
e1 = cv2.circle(img76,(600,400),270,(255,255,255),1)
e1 = cv2.circle(img76,(600,400),270,(255,255,255),1)
e1 = cv2.circle(img76,(600,400),270,(255,255,255),1)
e1 = cv2.circle(img76,(600,400),270,(255,255,255),1)



e1 = cv2.rectangle(img76,(10,340),(1190,440),(0,0,0),-1)
e1 = cv2.putText(img76,"SIX",(553,412),cv2.FONT_HERSHEY_SIMPLEX,2,(255,255,255),4)

cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
img06=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img06,(0,0),(1200,800),(128,178,194),-1) #layout
e1 = cv2.line(img06,(500,400),(700,400),(140,160,180),1050) #dugout
e1 = cv2.line(img06,(500,400),(700,400),(106,206,234),800) #ground
e1 = cv2.line(img06,(500,400),(700,400),(35,215,0),780) #extraSpace
e1 = cv2.line(img06,(500,400),(700,400),(255,255,255),750) #boundary
e1 = cv2.line(img06,(500,400),(700,400),(0,206,0),748) #playarea
e1 = cv2.rectangle(img06,(630,300),(570,500),(128,178,194),-1) #pitch
e1 = cv2.rectangle(img06,(630,300),(570,500),(255,255,255),1) #pitchhighlighter
e1 = cv2.line(img06,(580,300),(580,315),(255,255,255),1) #leftwideline
e1 = cv2.line(img06,(620,300),(620,315),(255,255,255),1) #rightwideline
e1 = cv2.line(img06,(580,500),(580,485),(255,255,255),1) #leftwideline_non_stricker
e1 = cv2.line(img06,(620,500),(620,485),(255,255,255),1) #rightwideline_non_stricker
e1 = cv2.line(img06,(565,315),(635,315),(255,255,255),1) #crease
e1 = cv2.line(img06,(565,485),(635,485),(255,255,255),1) #crease_non_stricker
e1 = cv2.line(img06,(597,300),(603,300),(0,0,0),1) #wickets
e1 = cv2.line(img06,(597,500),(603,500),(0,0,0),1) #wickets_non_stricker
e1 = cv2.circle(img06,(600,400),270,(255,255,255),1) #insidecircle


e1 = cv2.rectangle(img06,(10,340),(1190,440),(0,0,0),-1)
e1 = cv2.putText(img06,"THANKS FOR WATCHING",(200,410),cv2.FONT_HERSHEY_SIMPLEX,2,(255,255,255),3)


cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
img061=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img061,(0,0),(1200,800),(128,178,194),-1) #layout
e1 = cv2.line(img061,(500,400),(700,400),(140,160,180),1050) #dugout
e1 = cv2.line(img061,(500,400),(700,400),(106,206,234),800) #ground
e1 = cv2.line(img061,(500,400),(700,400),(35,215,0),780) #extraSpace
e1 = cv2.line(img061,(500,400),(700,400),(255,255,255),750) #boundary
e1 = cv2.line(img061,(500,400),(700,400),(0,206,0),748) #playarea
e1 = cv2.rectangle(img061,(630,300),(570,500),(128,178,194),-1) #pitch
e1 = cv2.rectangle(img061,(630,300),(570,500),(255,255,255),1) #pitchhighlighter
e1 = cv2.line(img061,(580,300),(580,315),(255,255,255),1) #leftwideline
e1 = cv2.line(img061,(620,300),(620,315),(255,255,255),1) #rightwideline
e1 = cv2.line(img061,(580,500),(580,485),(255,255,255),1) #leftwideline_non_stricker
e1 = cv2.line(img061,(620,500),(620,485),(255,255,255),1) #rightwideline_non_stricker
e1 = cv2.line(img061,(565,315),(635,315),(255,255,255),1) #crease
e1 = cv2.line(img061,(565,485),(635,485),(255,255,255),1) #crease_non_stricker
e1 = cv2.line(img061,(597,300),(603,300),(0,0,0),1) #wickets
e1 = cv2.line(img061,(597,500),(603,500),(0,0,0),1) #wickets_non_stricker
e1 = cv2.circle(img061,(600,400),270,(255,255,255),1) #insidecircle


e1 = cv2.rectangle(img061,(10,340),(1190,440),(0,0,0),-1)
e1 = cv2.putText(img061,"DEDICATED TO ALL CIRCKET FANS",(100,410),cv2.FONT_HERSHEY_SIMPLEX,2,(255,255,255),3)


cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
img062=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img062,(0,0),(1200,800),(128,178,194),-1) #layout
e1 = cv2.line(img062,(500,400),(700,400),(140,160,180),1050) #dugout
e1 = cv2.line(img062,(500,400),(700,400),(106,206,234),800) #ground
e1 = cv2.line(img062,(500,400),(700,400),(35,215,0),780) #extraSpace
e1 = cv2.line(img062,(500,400),(700,400),(255,255,255),750) #boundary
e1 = cv2.line(img062,(500,400),(700,400),(0,206,0),748) #playarea
e1 = cv2.rectangle(img062,(630,300),(570,500),(128,178,194),-1) #pitch
e1 = cv2.rectangle(img062,(630,300),(570,500),(255,255,255),1) #pitchhighlighter
e1 = cv2.line(img062,(580,300),(580,315),(255,255,255),1) #leftwideline
e1 = cv2.line(img062,(620,300),(620,315),(255,255,255),1) #rightwideline
e1 = cv2.line(img062,(580,500),(580,485),(255,255,255),1) #leftwideline_non_stricker
e1 = cv2.line(img062,(620,500),(620,485),(255,255,255),1) #rightwideline_non_stricker
e1 = cv2.line(img062,(565,315),(635,315),(255,255,255),1) #crease
e1 = cv2.line(img062,(565,485),(635,485),(255,255,255),1) #crease_non_stricker
e1 = cv2.line(img062,(597,300),(603,300),(0,0,0),1) #wickets
e1 = cv2.line(img062,(597,500),(603,500),(0,0,0),1) #wickets_non_stricker
e1 = cv2.circle(img062,(600,400),270,(255,255,255),1) #insidecircle


e1 = cv2.rectangle(img062,(10,340),(1190,440),(0,0,0),-1)
e1 = cv2.putText(img062,"!! ENJOY WORLD CUP 2023 !!",(150,410),cv2.FONT_HERSHEY_SIMPLEX,2,(255,255,255),3)


cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
img07=np.zeros((800,1200,3),np.uint8)
e1 = cv2.rectangle(img07,(0,0),(1200,800),(128,178,194),-1) #layout
e1 = cv2.line(img07,(500,400),(700,400),(140,160,180),1050) #dugout
e1 = cv2.line(img07,(500,400),(700,400),(106,206,234),800) #ground
e1 = cv2.line(img07,(500,400),(700,400),(35,215,0),780) #extraSpace
e1 = cv2.line(img07,(500,400),(700,400),(255,255,255),750) #boundary
e1 = cv2.line(img07,(500,400),(700,400),(0,206,0),748) #playarea
e1 = cv2.rectangle(img07,(630,300),(570,500),(128,178,194),-1) #pitch
e1 = cv2.rectangle(img07,(630,300),(570,500),(255,255,255),1) #pitchhighlighter
e1 = cv2.line(img07,(580,300),(580,315),(255,255,255),1) #leftwideline
e1 = cv2.line(img07,(620,300),(620,315),(255,255,255),1) #rightwideline
e1 = cv2.line(img07,(580,500),(580,485),(255,255,255),1) #leftwideline_non_stricker
e1 = cv2.line(img07,(620,500),(620,485),(255,255,255),1) #rightwideline_non_stricker
e1 = cv2.line(img07,(565,315),(635,315),(255,255,255),1) #crease
e1 = cv2.line(img07,(565,485),(635,485),(255,255,255),1) #crease_non_stricker
e1 = cv2.line(img07,(597,300),(603,300),(0,0,0),1) #wickets
e1 = cv2.line(img07,(597,500),(603,500),(0,0,0),1) #wickets_non_stricker
e1 = cv2.circle(img07,(600,400),270,(255,255,255),1) #insidecircle


e1 = cv2.rectangle(img07,(10,300),(1190,530),(0,0,0),-1)
e1 = cv2.putText(img07,"DONE BY :",(50,360),cv2.FONT_HERSHEY_SIMPLEX,0.8,(255,255,255),3)
e1 = cv2.putText(img07,"SREE NITHYA (WK) | SIVA SAI (C) | SAI PRASANNA (VC)",(50,450),cv2.FONT_HERSHEY_SIMPLEX,1.3,(255,255,255),3)


cv2.imshow("Window name",e1)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # Loop

# %%
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i1.jpg",img01)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i2.jpg",img01)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i3.jpg",img01)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i4.jpg",img02)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i5.jpg",img02)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i6.jpg",img02)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i7.jpg",img03)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i8.jpg",img03)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i9.jpg",img03)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i10.jpg",img04)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i11.jpg",img04)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i12.jpg",img04)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i13.jpg",img041)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i14.jpg",img041)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i15.jpg",img041)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i16.jpg",img05)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i17.jpg",img05)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i18.jpg",img05)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i19.jpg",img05)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i20.jpg",img2)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i21.jpg",img2)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i22.jpg",img2)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i23.jpg",img3)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i24.jpg",img4)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i25.jpg",img5)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i26.jpg",img6)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i27.jpg",img7)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i28.jpg",img8)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i29.jpg",img9)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i30.jpg",img10)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i31.jpg",img11)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i32.jpg",img12)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i33.jpg",img13)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i34.jpg",img14)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i35.jpg",img15)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i36.jpg",img16)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i37.jpg",img17)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i38.jpg",img18)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i39.jpg",img19)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i40.jpg",img20)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i41.jpg",img21)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i42.jpg",img22)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i43.jpg",img23)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i44.jpg",img24)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i45.jpg",img25)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i46.jpg",img26)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i47.jpg",img26)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i48.jpg",img26)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i49.jpg",img27)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i50.jpg",img27)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i51.jpg",img27)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i52.jpg",img28)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i53.jpg",img29)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i54.jpg",img30)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i55.jpg",img31)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i56.jpg",img32)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i57.jpg",img33)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i58.jpg",img34)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i59.jpg",img35)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i60.jpg",img36)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i61.jpg",img37)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i62.jpg",img38)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i63.jpg",img39)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i64.jpg",img40)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i65.jpg",img41)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i66.jpg",img42)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i67.jpg",img43)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i68.jpg",img44)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i69.jpg",img45)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i70.jpg",img46)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i71.jpg",img47)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i72.jpg",img48)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i73.jpg",img49)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i74.jpg",img50)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i75.jpg",img51)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i76.jpg",img52)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i77.jpg",img53)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i78.jpg",img53)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i79.jpg",img53)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i80.jpg",img54)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i81.jpg",img54)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i82.jpg",img54)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i83.jpg",img55)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i84.jpg",img56)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i85.jpg",img57)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i86.jpg",img58)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i87.jpg",img59)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i88.jpg",img60)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i89.jpg",img61)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i90.jpg",img62)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i91.jpg",img63)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i92.jpg",img64)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i93.jpg",img65)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i94.jpg",img66)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i95.jpg",img67)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i96.jpg",img68)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i97.jpg",img69)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i98.jpg",img70)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i99.jpg",img71)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i100.jpg",img72)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i101.jpg",img73)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i102.jpg",img74)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i103.jpg",img75)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i104.jpg",img76)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i105.jpg",img76)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i106.jpg",img76)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i107.jpg",img06)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i108.jpg",img06)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i109.jpg",img06)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i110.jpg",img061)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i111.jpg",img061)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i112.jpg",img061)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i113.jpg",img062)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i114.jpg",img062)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i115.jpg",img062)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i116.jpg",img07)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i117.jpg",img07)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\SNS\i118.jpg",img07)

# %% [markdown]
# # FINAL VIDEO

# %%
count=1
while True:
    imgf=cv2.imread(r"C:\Users\ADMIN\Downloads\SNS\i{}.jpg".format(count))
    cv2.imshow("gif",imgf)
    if cv2.waitKey(350)& 255==ord("a"):
        break
    count=count+1
    if count==118:
        count=1
cv2.destroyAllWindows()
